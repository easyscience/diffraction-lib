# %%
# Check if the easydiffraction library is installed.
# If not, install it including the 'visualization' extras.
# This is needed, e.g., when running this as a notebook via Google Colab or
# Jupyter Notebook in an environment where the library is not pre-installed.
import builtins
import importlib.util

if hasattr(builtins, '__IPYTHON__'):
    if importlib.util.find_spec('easydiffraction') is None:
        # !pip install 'easydiffraction[visualization]'

# %% [markdown]
# # Structure Refinement: LBCO, HRPT
#
# This minimalistic example is designed to be as compact as possible for a
# Rietveld refinement of a crystal structure using constant-wavelength neutron
# powder diffraction data for La0.5Ba0.5CoO3 from HRPT at PSI.
#
# It does not contain any advanced features or options, and includes no
# comments or explanations—these can be found in the other tutorials.
# Default values are used for all parameters if not specified. Only essential
# and self-explanatory code is provided.
#
# The example is intended for users who are already familiar with the
# EasyDiffraction library and want to quickly get started with a simple
# refinement. It is also useful for those who want to see what a refinement
# might look like in code. For a more detailed explanation of the code, please
# refer to the other tutorials.

# %% [markdown]
# ## Import Library

# %%
import easydiffraction as ed

# %% [markdown]
# ## Step 1: Define Project

# %%
project = ed.Project()

# %% [markdown]
# ## Step 2: Define Sample Model

# %%
project.sample_models.add(name='lbco')

# %%
sample_model = project.sample_models['lbco']

# %%
sample_model.space_group.name_h_m = 'P m -3 m'
sample_model.space_group.it_coordinate_system_code = '1'

# %%
sample_model.cell.length_a = 3.88

# %%
sample_model.atom_sites.add('La', 'La', 0, 0, 0, b_iso=0.5, occupancy=0.5)
sample_model.atom_sites.add('Ba', 'Ba', 0, 0, 0, b_iso=0.5, occupancy=0.5)
sample_model.atom_sites.add('Co', 'Co', 0.5, 0.5, 0.5, b_iso=0.5)
sample_model.atom_sites.add('O', 'O', 0, 0.5, 0.5, b_iso=0.5)

# %% [markdown]
# ## Step 3: Define Experiment

# %%
ed.download_from_repository('hrpt_lbco.xye', destination='data')
# Out:
# ⚠️ Warning
# File 'data/hrpt_lbco.xye' already exists and will not be overwritten.

# %%
project.experiments.add(
    name='hrpt',
    sample_form='powder',
    beam_mode='constant wavelength',
    radiation_probe='neutron',
    data_path='data/hrpt_lbco.xye',
)
# Out:
# Loading measured data from ASCII file
# /Users/runner/work/diffraction-lib/diffraction-lib/tutorials/data/hrpt_lbco.xye
#
# Data loaded successfully
# Experiment 🔬 'hrpt'. Number of data points: 3098

# %%
experiment = project.experiments['hrpt']

# %%
experiment.instrument.setup_wavelength = 1.494
experiment.instrument.calib_twotheta_offset = 0.6

# %%
experiment.peak.broad_gauss_u = 0.1
experiment.peak.broad_gauss_v = -0.1
experiment.peak.broad_gauss_w = 0.1
experiment.peak.broad_lorentz_y = 0.1

# %%
experiment.background.add(x=10, y=170)
experiment.background.add(x=30, y=170)
experiment.background.add(x=50, y=170)
experiment.background.add(x=110, y=170)
experiment.background.add(x=165, y=170)

# %%
experiment.excluded_regions.add(start=0, end=5)
experiment.excluded_regions.add(start=165, end=180)

# %%
experiment.linked_phases.add(id='lbco', scale=10.0)

# %% [markdown]
# ## Step 4: Perform Analysis

# %%
sample_model.cell.length_a.free = True

sample_model.atom_sites['La'].b_iso.free = True
sample_model.atom_sites['Ba'].b_iso.free = True
sample_model.atom_sites['Co'].b_iso.free = True
sample_model.atom_sites['O'].b_iso.free = True

# %%
experiment.instrument.calib_twotheta_offset.free = True

experiment.peak.broad_gauss_u.free = True
experiment.peak.broad_gauss_v.free = True
experiment.peak.broad_gauss_w.free = True
experiment.peak.broad_lorentz_y.free = True

experiment.background['10'].y.free = True
experiment.background['30'].y.free = True
experiment.background['50'].y.free = True
experiment.background['110'].y.free = True
experiment.background['165'].y.free = True

experiment.linked_phases['lbco'].scale.free = True

# %%
project.analysis.fit()
# Out:
# Using experiment 🔬 'hrpt' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <table class="dataframe" style="border-collapse: collapse; border: 1px solid #515155; margin-left: 0.5em;margin-top: 0.5em;margin-bottom: 1em;">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="text-align: center;">iteration</th>
#       <th style="text-align: center;">χ²</th>
#       <th style="text-align: center;">improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><div style="text-align: center;">1</div></td>
#       <td><div style="text-align: center;">165.02</div></td>
#       <td><div style="text-align: center;"></div></td>
#     </tr>
#     <tr>
#       <td><div style="text-align: center;">28</div></td>
#       <td><div style="text-align: center;">33.58</div></td>
#       <td><div style="text-align: center;">79.7% ↓</div></td>
#     </tr>
#     <tr>
#       <td><div style="text-align: center;">45</div></td>
#       <td><div style="text-align: center;">10.82</div></td>
#       <td><div style="text-align: center;">67.8% ↓</div></td>
#     </tr>
#     <tr>
#       <td><div style="text-align: center;">63</div></td>
#       <td><div style="text-align: center;">6.49</div></td>
#       <td><div style="text-align: center;">40.0% ↓</div></td>
#     </tr>
#     <tr>
#       <td><div style="text-align: center;">81</div></td>
#       <td><div style="text-align: center;">3.35</div></td>
#       <td><div style="text-align: center;">48.4% ↓</div></td>
#     </tr>
#     <tr>
#       <td><div style="text-align: center;">98</div></td>
#       <td><div style="text-align: center;">2.24</div></td>
#       <td><div style="text-align: center;">33.1% ↓</div></td>
#     </tr>
#     <tr>
#       <td><div style="text-align: center;">116</div></td>
#       <td><div style="text-align: center;">1.91</div></td>
#       <td><div style="text-align: center;">14.7% ↓</div></td>
#     </tr>
#     <tr>
#       <td><div style="text-align: center;">133</div></td>
#       <td><div style="text-align: center;">1.50</div></td>
#       <td><div style="text-align: center;">21.3% ↓</div></td>
#     </tr>
#     <tr>
#       <td><div style="text-align: center;">150</div></td>
#       <td><div style="text-align: center;">1.45</div></td>
#       <td><div style="text-align: center;">3.6% ↓</div></td>
#     </tr>
#     <tr>
#       <td><div style="text-align: center;">167</div></td>
#       <td><div style="text-align: center;">1.34</div></td>
#       <td><div style="text-align: center;">7.8% ↓</div></td>
#     </tr>
#     <tr>
#       <td><div style="text-align: center;">185</div></td>
#       <td><div style="text-align: center;">1.29</div></td>
#       <td><div style="text-align: center;">3.4% ↓</div></td>
#     </tr>
#     <tr>
#       <td><div style="text-align: center;">276</div></td>
#       <td><div style="text-align: center;">1.29</div></td>
#       <td><div style="text-align: center;"></div></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 1.29 at iteration 275
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 2.11 seconds
# 📏 Goodness-of-fit (reduced χ²): 1.29
# 📏 R-factor (Rf): 5.63%
# 📏 R-factor squared (Rf²): 5.27%
# 📏 Weighted R-factor (wR): 4.41%
# 📈 Fitted parameters:
# <table class="dataframe" style="border-collapse: collapse; border: 1px solid #515155; margin-left: 0.5em;margin-top: 0.5em;margin-bottom: 1em;">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th style="text-align: left;">datablock</th>
#       <th style="text-align: left;">category</th>
#       <th style="text-align: left;">entry</th>
#       <th style="text-align: left;">parameter</th>
#       <th style="text-align: right;">start</th>
#       <th style="text-align: right;">fitted</th>
#       <th style="text-align: right;">uncertainty</th>
#       <th style="text-align: left;">units</th>
#       <th style="text-align: right;">change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><div style="text-align: left;">lbco</div></td>
#       <td><div style="text-align: left;">atom_sites</div></td>
#       <td><div style="text-align: left;">La</div></td>
#       <td><div style="text-align: left;">b_iso</div></td>
#       <td><div style="text-align: right;">0.5000</div></td>
#       <td><div style="text-align: right;">0.5052</div></td>
#       <td><div style="text-align: right;">3231.6242</div></td>
#       <td><div style="text-align: left;">Å²</div></td>
#       <td><div style="text-align: right;">1.04 % ↑</div></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><div style="text-align: left;">lbco</div></td>
#       <td><div style="text-align: left;">atom_sites</div></td>
#       <td><div style="text-align: left;">Ba</div></td>
#       <td><div style="text-align: left;">b_iso</div></td>
#       <td><div style="text-align: right;">0.5000</div></td>
#       <td><div style="text-align: right;">0.5049</div></td>
#       <td><div style="text-align: right;">5252.3879</div></td>
#       <td><div style="text-align: left;">Å²</div></td>
#       <td><div style="text-align: right;">0.97 % ↑</div></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><div style="text-align: left;">lbco</div></td>
#       <td><div style="text-align: left;">atom_sites</div></td>
#       <td><div style="text-align: left;">Co</div></td>
#       <td><div style="text-align: left;">b_iso</div></td>
#       <td><div style="text-align: right;">0.5000</div></td>
#       <td><div style="text-align: right;">0.2370</div></td>
#       <td><div style="text-align: right;">0.0611</div></td>
#       <td><div style="text-align: left;">Å²</div></td>
#       <td><div style="text-align: right;">52.60 % ↓</div></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><div style="text-align: left;">lbco</div></td>
#       <td><div style="text-align: left;">atom_sites</div></td>
#       <td><div style="text-align: left;">O</div></td>
#       <td><div style="text-align: left;">b_iso</div></td>
#       <td><div style="text-align: right;">0.5000</div></td>
#       <td><div style="text-align: right;">1.3935</div></td>
#       <td><div style="text-align: right;">0.0167</div></td>
#       <td><div style="text-align: left;">Å²</div></td>
#       <td><div style="text-align: right;">178.71 % ↑</div></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><div style="text-align: left;">lbco</div></td>
#       <td><div style="text-align: left;">cell</div></td>
#       <td><div style="text-align: left;"></div></td>
#       <td><div style="text-align: left;">length_a</div></td>
#       <td><div style="text-align: right;">3.8800</div></td>
#       <td><div style="text-align: right;">3.8909</div></td>
#       <td><div style="text-align: right;">0.0000</div></td>
#       <td><div style="text-align: left;">Å</div></td>
#       <td><div style="text-align: right;">0.28 % ↑</div></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><div style="text-align: left;">hrpt</div></td>
#       <td><div style="text-align: left;">background</div></td>
#       <td><div style="text-align: left;">10</div></td>
#       <td><div style="text-align: left;">y</div></td>
#       <td><div style="text-align: right;">170.0000</div></td>
#       <td><div style="text-align: right;">168.5585</div></td>
#       <td><div style="text-align: right;">1.3671</div></td>
#       <td><div style="text-align: left;"></div></td>
#       <td><div style="text-align: right;">0.85 % ↓</div></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><div style="text-align: left;">hrpt</div></td>
#       <td><div style="text-align: left;">background</div></td>
#       <td><div style="text-align: left;">30</div></td>
#       <td><div style="text-align: left;">y</div></td>
#       <td><div style="text-align: right;">170.0000</div></td>
#       <td><div style="text-align: right;">164.3357</div></td>
#       <td><div style="text-align: right;">0.9992</div></td>
#       <td><div style="text-align: left;"></div></td>
#       <td><div style="text-align: right;">3.33 % ↓</div></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><div style="text-align: left;">hrpt</div></td>
#       <td><div style="text-align: left;">background</div></td>
#       <td><div style="text-align: left;">50</div></td>
#       <td><div style="text-align: left;">y</div></td>
#       <td><div style="text-align: right;">170.0000</div></td>
#       <td><div style="text-align: right;">166.8881</div></td>
#       <td><div style="text-align: right;">0.7388</div></td>
#       <td><div style="text-align: left;"></div></td>
#       <td><div style="text-align: right;">1.83 % ↓</div></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><div style="text-align: left;">hrpt</div></td>
#       <td><div style="text-align: left;">background</div></td>
#       <td><div style="text-align: left;">110</div></td>
#       <td><div style="text-align: left;">y</div></td>
#       <td><div style="text-align: right;">170.0000</div></td>
#       <td><div style="text-align: right;">175.4006</div></td>
#       <td><div style="text-align: right;">0.6578</div></td>
#       <td><div style="text-align: left;"></div></td>
#       <td><div style="text-align: right;">3.18 % ↑</div></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><div style="text-align: left;">hrpt</div></td>
#       <td><div style="text-align: left;">background</div></td>
#       <td><div style="text-align: left;">165</div></td>
#       <td><div style="text-align: left;">y</div></td>
#       <td><div style="text-align: right;">170.0000</div></td>
#       <td><div style="text-align: right;">174.2813</div></td>
#       <td><div style="text-align: right;">0.9105</div></td>
#       <td><div style="text-align: left;"></div></td>
#       <td><div style="text-align: right;">2.52 % ↑</div></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><div style="text-align: left;">hrpt</div></td>
#       <td><div style="text-align: left;">instrument</div></td>
#       <td><div style="text-align: left;"></div></td>
#       <td><div style="text-align: left;">twotheta_offset</div></td>
#       <td><div style="text-align: right;">0.6000</div></td>
#       <td><div style="text-align: right;">0.6226</div></td>
#       <td><div style="text-align: right;">0.0010</div></td>
#       <td><div style="text-align: left;">deg</div></td>
#       <td><div style="text-align: right;">3.76 % ↑</div></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><div style="text-align: left;">hrpt</div></td>
#       <td><div style="text-align: left;">linked_phases</div></td>
#       <td><div style="text-align: left;">lbco</div></td>
#       <td><div style="text-align: left;">scale</div></td>
#       <td><div style="text-align: right;">10.0000</div></td>
#       <td><div style="text-align: right;">9.1351</div></td>
#       <td><div style="text-align: right;">0.0642</div></td>
#       <td><div style="text-align: left;"></div></td>
#       <td><div style="text-align: right;">8.65 % ↓</div></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><div style="text-align: left;">hrpt</div></td>
#       <td><div style="text-align: left;">peak</div></td>
#       <td><div style="text-align: left;"></div></td>
#       <td><div style="text-align: left;">broad_gauss_u</div></td>
#       <td><div style="text-align: right;">0.1000</div></td>
#       <td><div style="text-align: right;">0.0816</div></td>
#       <td><div style="text-align: right;">0.0031</div></td>
#       <td><div style="text-align: left;">deg²</div></td>
#       <td><div st

# %%
project.plot_meas_vs_calc(expt_name='hrpt', show_residual=True)
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="e2222f3d-ff8f-4cf1-9d00-7d7c9137019a" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e2222f3d-ff8f-4cf1-9d00-7d7c9137019a")) {                    Plotly.newPlot(                        "e2222f3d-ff8f-4cf1-9d00-7d7c9137019a",                        [{"line":{"color":"rgb(31, 119, 180)"},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"...\...\...\...\...\...\u002fQJqZmZmZGT9AZmZmZmYmP0AzMzMzMzM\u002fQAAAAAAAQD9AzczMzMxMP0CamZmZmVk\u002fQGZmZmZmZj9AMzMzMzNzP0AAAAAAAIA\u002fQM3MzMzMjD9AmpmZmZmZP0BmZmZmZqY\u002fQDMzMzMzsz9AAAAAAADAP0DNzMzMzMw\u002fQJqZmZmZ2T9AZmZmZmbmP0AzMzMzM\u002fM\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\u002fNgQM3MzMzM9GBAZmZmZmb2YEAAAAAAAPhgQJqZmZmZ+WBAMzMzMzP7YEDNzMzMzPxgQGZmZmZm\...\u002fthQM3MzMzM\...\u002fNjQM3MzMzM9GNAZmZmZmb2Y0AAAAAAAPhjQJqZmZmZ+WNAMzMzMzP7Y0DNzMzMzPxjQGZmZmZm\..."},"y":{"dtype":"f8","bdata":"..."},"type":"scatter"},{"line":{"color":"rgb(214, 39, 40)"},"mode":"lines","name":"Total calculated (Icalc)","x":{"dtype":"f8","bdata":"...\...\...\...\...\...\u002fQJqZmZmZGT9AZmZmZmYmP0AzMzMzMzM\u002fQAAAAAAAQD9AzczMzMxMP0CamZmZmVk\u002fQGZmZmZmZj9AMzMzMzNzP0AAAAAAAIA\u002fQM3MzMzMjD9AmpmZmZmZP0BmZmZmZqY\u002fQDMzMzMzsz9AAAAAAADAP0DNzMzMzMw\u002fQJqZmZmZ2T9AZmZmZmbmP0AzMzMzM\u002fM\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\u002fNgQM3MzMzM9GBAZmZmZmb2YEAAAAAAAPhgQJqZmZmZ+WBAMzMzMzP7YEDNzMzMzPxgQGZmZmZm\...\u002fthQM3MzMzM\...\u002fNjQM3MzMzM9GNAZmZmZmb2Y0AAAAAAAPhjQJqZmZmZ+WNAMzMzMzP7Y0DNzMzMzPxjQGZmZmZm\..."},"y":{"dtype":"f8","bdata":"MtQTYB1FZUBCXHmmW0RlQEzTuJebQ2VAaucwK91CZUAyKHlYIEJlQKBHYBdlQWVABWvqX6tAZUBZi08q8z9lQETk+W48P2VAYHGEJoc+ZUD8eLlJ0z1lQAAkkdEgPWVASCIwt288ZUASW+bzvztlQPCoLYERO2VA5KCoWGQ6ZUAaZCF0uDllQPR7iM0NOWVA4b\\u002fF\u002fE\u002fuJmVApAYo+GAmZUCfEjlX1CVlQBaOU2pIJWVAp5CqLr0kZUBZRYChMiRlQPiNJcCoI2VAR6n5hx8jZUCz22n2liJlQLMa8QgPImVAg7oXvYchZUBdHnMQASFlQPFqpQB7IGVAJjtdi\u002fUfZUAHV1WucB9lQMtsVGfsHmVA68sstGgeZUA2IryS5R1lQNA66wBjHWVAF7+t\u002fOAcZUBP+QGEXxxlQB6Z8JTeG2VAtHmMLV4bZUCsafJL3hplQHj0SO5eGmVAdy3AEuAZZUCEfJG3YRllQAps\u002f9rjGGVAhHhVe2YYZUB74eeW6RdlQMd7EyxtF2VARoU9OfEWZUDNedO8dRZlQGzpSrX6FWVA7U8hIYAVZUCO7dv+BRVlQOigB02MFGVABcI4ChMUZUCU\u002fgo1mhNlQEI3IcwhE2VAJF4lzqkSZUA7Vsg5MhJlQPvTwQ27EWVA5T7QSEQRZUAflLjpzRBlQAxKRu9XEGVA4TRLWOIPZUA1bJ8jbQ9lQHwxIVD4DmVAhNe03IMOZUDOqkTIDw5lQOPawBGcDWVAi2QfuCgNZUD2\u002fFu6tQxlQLr9dxdDDGVAz1F6ztALZUBhY2\u002feXgtlQIYKaUbtCmVA6Hx+BXwKZUA\u002fPswaCwplQMcRdIWaCWVAhuycRCoJZUCV6HJXughlQDY5J71KCGVA8x\u002fwdNsHZUCT4gh+bAdlQBvCsdf9BmVAqPIvgY8GZUBmlM15IQZlQGOt2cCzBWVAhySoVUYFZUCBvZE32QRlQM4V9GVsBGVA2qIx4P8DZUBGsbGlkwNlQEdl4LUnA2VAVrwuELwCZUD\u002fjxK0UAJlQBaaBqHlAWVAMXqK1noBZUCOvCJUEAFlQG3iWBmmAGVA7mu7JTwAZUCA49140v9kQAHrWBJp\u002f2RAkkrK8f\u002f+ZEBJAdUWl\u002f5kQMFXIYEu\u002fmRAwPRcMMb9ZEDs8zokXv1kQNj+c1z2\u002fGRAV2jG2I78ZEBtSvaYJ\u002fxkQNmmzZzA+2RAhIoc5Fn7ZEDjM7lu8\u002fpkQJo8gDyN+mRAgcZUTSf6ZEBNrCChwflkQBa21Ddc+WRADNJoEff4ZECNUdwtkvhkQP8qNo0t+GRAwECFL8n3ZECBreAUZfdkQIgWaD0B92RAJQREqZ32ZEAEQaZYOvZkQKhAykvX9WRA3o31gnT1ZECDQXj+EfVkQI2Crb6v9GRA1A\u002f8w030ZECm1NYO7PNkQM2IvZ+K82RANl09dynzZEActvGVyPJkQAT0hPxn8mRAvUyxqwfyZEDYtUGkp\...\u002forTouBkQFUtaOt74GRAQAOvuFngZEB9ocnJPOBkQGdJicMl4GRAfICAZRXgZEAiGWGPDOBkQABmpUcM4GRA9nviwxXgZEAgOEBzKuBkQN4fvgtM4GRAfgknm3zgZEBWCeicvuBkQEk8dBYV4WRAD3eH ...
