# %%
# Check whether easydiffraction is installed; install it if needed.
# Required for remote environments such as Google Colab.
import importlib.util

if importlib.util.find_spec('easydiffraction') is None:
    # %pip install easydiffraction==0.13.0

# %% [markdown]
# # Structure Refinement: PbSO4, NPD + XRD
#
# This example demonstrates a more advanced use of the EasyDiffraction
# library by explicitly creating and configuring structures and
# experiments before adding them to a project. It could be more suitable
# for users who are interested in creating custom workflows. This
# tutorial provides minimal explanation and is intended for users
# already familiar with EasyDiffraction.
#
# The tutorial covers a Rietveld refinement of PbSO4 crystal structure
# based on the joint fit of both X-ray and neutron diffraction data.

# %% [markdown]
# ## Import Library

# %%
from easydiffraction import ExperimentFactory
from easydiffraction import Project
from easydiffraction import StructureFactory
from easydiffraction import download_data

# %% [markdown]
# ## Define Structure
#
# This section shows how to add structures and modify their
# parameters.
#
# #### Create Structure

# %%
structure = StructureFactory.from_scratch(name='pbso4')

# %% [markdown]
# #### Set Space Group

# %%
structure.space_group.name_h_m = 'P n m a'

# %% [markdown]
# #### Set Unit Cell

# %%
structure.cell.length_a = 8.47
structure.cell.length_b = 5.39
structure.cell.length_c = 6.95

# %% [markdown]
# #### Set Atom Sites

# %%
structure.atom_sites.create(
    label='Pb',
    type_symbol='Pb',
    fract_x=0.1876,
    fract_y=0.25,
    fract_z=0.167,
    wyckoff_letter='c',
    adp_iso=1.37,
)
structure.atom_sites.create(
    label='S',
    type_symbol='S',
    fract_x=0.0654,
    fract_y=0.25,
    fract_z=0.684,
    wyckoff_letter='c',
    adp_iso=0.3777,
)
structure.atom_sites.create(
    label='O1',
    type_symbol='O',
    fract_x=0.9082,
    fract_y=0.25,
    fract_z=0.5954,
    wyckoff_letter='c',
    adp_iso=1.9764,
)
structure.atom_sites.create(
    label='O2',
    type_symbol='O',
    fract_x=0.1935,
    fract_y=0.25,
    fract_z=0.5432,
    wyckoff_letter='c',
    adp_iso=1.4456,
)
structure.atom_sites.create(
    label='O3',
    type_symbol='O',
    fract_x=0.0811,
    fract_y=0.0272,
    fract_z=0.8086,
    wyckoff_letter='d',
    adp_iso=1.2822,
)

# %% [markdown]
# ## Define Experiments
#
# This section shows how to add experiments, configure their parameters,
# and link the structures defined in the previous step.
#
# ### Experiment 1: npd
#
# #### Download Data

# %%
data_path1 = download_data(id=13, destination='data')
# Out:
# Getting data...
# Data #13: PbSO4, D1A (ILL)
# ✅ Data #13 downloaded to 'data/ed-13.dat'

# %% [markdown]
# #### Create Experiment

# %%
expt1 = ExperimentFactory.from_data_path(
    name='npd',
    data_path=data_path1,
    radiation_probe='neutron',
)

# %% [markdown]
# #### Set Instrument

# %%
expt1.instrument.setup_wavelength = 1.91
expt1.instrument.calib_twotheta_offset = -0.1406

# %% [markdown]
# #### Set Peak Profile

# %%
expt1.peak.broad_gauss_u = 0.139
expt1.peak.broad_gauss_v = -0.412
expt1.peak.broad_gauss_w = 0.386
expt1.peak.broad_lorentz_x = 0
expt1.peak.broad_lorentz_y = 0.088

# %% [markdown]
# #### Set Background

# %% [markdown]
# Select the background type.

# %%
expt1.background_type = 'line-segment'
# Out:
# Background type for experiment 'npd' already set to
# line-segment

# %% [markdown]
# Add background points.

# %%
for id, x, y in [
    ('1', 11.0, 206.1624),
    ('2', 15.0, 194.75),
    ('3', 20.0, 194.505),
    ('4', 30.0, 188.4375),
    ('5', 50.0, 207.7633),
    ('6', 70.0, 201.7002),
    ('7', 120.0, 244.4525),
    ('8', 153.0, 226.0595),
]:
    expt1.background.create(id=id, x=x, y=y)

# %% [markdown]
# #### Set Linked Phases

# %%
expt1.linked_phases.create(id='pbso4', scale=1.5)

# %% [markdown]
# ### Experiment 2: xrd
#
# #### Download Data

# %%
data_path2 = download_data(id=16, destination='data')
# Out:
# Getting data...
# Data #16: PbSO4, laboratory X-ray
# ✅ Data #16 downloaded to 'data/ed-16.dat'

# %% [markdown]
# #### Create Experiment

# %%
expt2 = ExperimentFactory.from_data_path(
    name='xrd',
    data_path=data_path2,
    radiation_probe='xray',
)

# %% [markdown]
# #### Set Instrument

# %%
expt2.instrument.setup_wavelength = 1.540567
expt2.instrument.calib_twotheta_offset = -0.05181

# %% [markdown]
# #### Set Peak Profile

# %%
expt2.peak.broad_gauss_u = 0.304138
expt2.peak.broad_gauss_v = -0.112622
expt2.peak.broad_gauss_w = 0.021272
expt2.peak.broad_lorentz_x = 0
expt2.peak.broad_lorentz_y = 0.057691

# %% [markdown]
# #### Set Background

# %% [markdown]
# Select background type.

# %%
expt2.background_type = 'chebyshev'
# Out:
# Background type for experiment 'xrd' changed to
# chebyshev

# %% [markdown]
# Add background points.

# %%
for id, x, y in [
    ('1', 0, 119.195),
    ('2', 1, 6.221),
    ('3', 2, -45.725),
    ('4', 3, 8.119),
    ('5', 4, 54.552),
    ('6', 5, -20.661),
]:
    expt2.background.create(id=id, order=x, coef=y)

# %% [markdown]
# #### Set Linked Phases

# %%
expt2.linked_phases.create(id='pbso4', scale=0.001)

# %% [markdown]
# ## Define Project
#
# The project object is used to manage structures, experiments, and
# analysis.
#
# #### Create Project

# %%
project = Project()

# %% [markdown]
# #### Add Structure

# %%
project.structures.add(structure)

# %% [markdown]
# #### Add Experiments

# %%
project.experiments.add(expt1)
project.experiments.add(expt2)

# %% [markdown]
# ## Perform Analysis
#
# This section outlines the analysis process, including how to configure
# calculation and fitting engines.
#
# #### Set Fit Mode

# %%
project.analysis.fit_mode.mode = 'joint'

# %% [markdown]
# #### Set Minimizer

# %%
project.analysis.current_minimizer = 'lmfit'
# Out:
# Current minimizer changed to
# lmfit

# %% [markdown]
# #### Set Fitting Parameters
#
# Set structure parameters to be optimized.

# %%
structure.cell.length_a.free = True
structure.cell.length_b.free = True
structure.cell.length_c.free = True

# %% [markdown]
# Set experiment parameters to be optimized.

# %%
expt1.linked_phases['pbso4'].scale.free = True

expt1.instrument.calib_twotheta_offset.free = True

expt1.peak.broad_gauss_u.free = True
expt1.peak.broad_gauss_v.free = True
expt1.peak.broad_gauss_w.free = True
expt1.peak.broad_lorentz_y.free = True

# %%
expt2.linked_phases['pbso4'].scale.free = True

expt2.instrument.calib_twotheta_offset.free = True

expt2.peak.broad_gauss_u.free = True
expt2.peak.broad_gauss_v.free = True
expt2.peak.broad_gauss_w.free = True
expt2.peak.broad_lorentz_y.free = True

for term in expt2.background:
    term.coef.free = True

# %% [markdown]
# #### Perform Fit

# %%
project.analysis.fit()
project.analysis.display.fit_results()
project.plotter.plot_param_correlations()
# Out:
# Using all experiments 🔬 ['npd', 'xrd'] for 'joint' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_4207c   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_4207c thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_4207c th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_4207c  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_4207c th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_4207c tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_4207c  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_4207c th.col0 {
#   text-align: center;
# }
# #T_4207c th.col1 {
#   text-align: center;
# }
# #T_4207c th.col2 {
#   text-align: center;
# }
# #T_4207c_row0_col0, #T_4207c_row0_col1, #T_4207c_row0_col2, #T_4207c_row1_col0, #T_4207c_row1_col1, #T_4207c_row1_col2, #T_4207c_row2_col0, #T_4207c_row2_col1, #T_4207c_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_4207c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4207c_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_4207c_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_4207c_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4207c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4207c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4207c_row0_col1" class="data row0 col1" >37.01</td>
#       <td id="T_4207c_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_4207c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4207c_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_4207c_row1_col1" class="data row1 col1" >16.30</td>
#       <td id="T_4207c_row1_col2" class="data row1 col2" >56.0% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_4207c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4207c_row2_col0" class="data row2 col0" >136</td>
#       <td id="T_4207c_row2_col1" class="data row2 col1" >16.21</td>
#       <td id="T_4207c_row2_col2" class="data row2 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 16.21 at iteration 135
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 27.07 seconds
# 📏 Goodness-of-fit (reduced χ²): 16.21
# 📏 R-factor (Rf): 13.18%
# 📏 R-factor squared (Rf²): 17.19%
# 📏 Weighted R-factor (wR): 17.09%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_bb739   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_bb739 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_bb739 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_bb739  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_bb739 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_bb739 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_bb739  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_bb739 th.col0 {
#   text-align: left;
# }
# #T_bb739 th.col1 {
#   text-align: left;
# }
# #T_bb739 th.col2 {
#   text-align: left;
# }
# #T_bb739 th.col3 {
#   text-align: left;
# }
# #T_bb739 th.col4 {
#   text-align: right;
# }
# #T_bb739 th.col5 {
#   text-align: right;
# }
# #T_bb739 th.col6 {
#   text-align: right;
# }
# #T_bb739 th.col7 {
#   text-align: left;
# }
# #T_bb739 th.col8 {
#   text-align: right;
# }
# #T_bb739_row0_col0, #T_bb739_row0_col1, #T_bb739_row0_col2, #T_bb739_row0_col3, #T_bb739_row0_col7, #T_bb739_row1_col0, #T_bb739_row1_col1, #T_bb739_row1_col2, #T_bb739_row1_col3, #T_bb739_row1_col7, #T_bb739_row2_col0, #T_bb739_row2_col1, #T_bb739_row2_col2, #T_bb739_row2_col3, #T_bb739_row2_col7, #T_bb739_row3_col0, #T_bb739_row3_col1, #T_bb739_row3_col2, #T_bb739_row3_col3, #T_bb739_row3_col7, #T_bb739_row4_col0, #T_bb739_row4_col1, #T_bb739_row4_col2, #T_bb739_row4_col3, #T_bb739_row4_col7, #T_bb739_row5_col0, #T_bb739_row5_col1, #T_bb739_row5_col2, #T_bb739_row5_col3, #T_bb739_row5_col7, #T_bb739_row6_col0, #T_bb739_row6_col1, #T_bb739_row6_col2, #T_bb739_row6_col3, #T_bb739_row6_col7, #T_bb739_row7_col0, #T_bb739_row7_col1, #T_bb739_row7_col2, #T_bb739_row7_col3, #T_bb739_row7_col7, #T_bb739_row8_col0, #T_bb739_row8_col1, #T_bb739_row8_col2, #T_bb739_row8_col3, #T_bb739_row8_col7, #T_bb739_row9_col0, #T_bb739_row9_col1, #T_bb739_row9_col2, #T_bb739_row9_col3, #T_bb739_row9_col7, #T_bb739_row10_col0, #T_bb739_row10_col1, #T_bb739_row10_col2, #T_bb739_row10_col3, #T_bb739_row10_col7, #T_bb739_row11_col0, #T_bb739_row11_col1, #T_bb739_row11_col2, #T_bb739_row11_col3, #T_bb739_row11_col7, #T_bb739_row12_col0, #T_bb739_row12_col1, #T_bb739_row12_col2, #T_bb739_row12_col3, #T_bb739_row12_col7, #T_bb739_row13_col0, #T_bb739_row13_col1, #T_bb739_row13_col2, #T_bb739_row13_col3, #T_bb739_row13_col7, #T_bb739_row14_col0, #T_bb739_row14_col1, #T_bb739_row14_col2, #T_bb739_row14_col3, #T_bb739_row14_col7, #T_bb739_row15_col0, #T_bb739_row15_col1, #T_bb739_row15_col2, #T_bb739_row15_col3, #T_bb739_row15_col7, #T_bb739_row16_col0, #T_bb739_row16_col1, #T_bb739_row16_col2, #T_bb739_row16_col3, #T_bb739_row16_col7, #T_bb739_row17_col0, #T_bb739_row17_col1, #T_bb739_row17_col2, #T_bb739_row17_col3, #T_bb739_row17_col7, #T_bb739_row18_col0, #T_bb739_row18_col1, #T_bb739_row18_col2, #T_bb739_row18_col3, #T_bb739_row18_col7, #T_bb739_row19_col0, #T_bb739_row19_col1, #T_bb739_row19_col2, #T_bb739_row19_col3, #T_bb739_row19_col7, #T_bb739_row20_col0, #T_bb739_row20_col1, #T_bb739_row20_col2, #T_bb739_row20_col3, #T_bb739_row20_col7 {
#   text-align: left;
# }
# #T_bb739_row0_col4, #T_bb739_row0_col5, #T_bb739_row0_col6, #T_bb739_row0_col8, #T_bb739_row1_col4, #T_bb739_row1_col5, #T_bb739_row1_col6, #T_bb739_row1_col8, #T_bb739_row2_col4, #T_bb739_row2_col5, #T_bb739_row2_col6, #T_bb739_row2_col8, #T_bb739_row3_col4, #T_bb739_row3_col5, #T_bb739_row3_col6, #T_bb739_row3_col8, #T_bb739_row4_col4, #T_bb739_row4_col5, #T_bb739_row4_col6, #T_bb739_row4_col8, #T_bb739_row5_col4, #T_bb739_row5_col5, #T_bb739_row5_col6, #T_bb739_row5_col8, #T_bb739_row6_col4, #T_bb739_row6_col5, #T_bb739_row6_col6, #T_bb739_row6_col8, #T_bb739_row7_col4, #T_bb739_row7_col5, #T_bb739_row7_col6, #T_bb739_row7_col8, #T_bb739_row8_col4, #T_bb739_row8_col5, #T_bb739_row8_col6, #T_bb739_row8_col8, #T_bb739_row9_col4, #T_bb739_row9_col5, #T_bb739_row9_col6, #T_bb739_row9_col8, #T_bb739_row10_col4, #T_bb739_row10_col5, #T_bb739_row10_col6, #T_bb739_row10_col8, #T_bb739_row11_col4, #T_bb739_row11_col5, #T_bb739_row11_col6, #T_bb739_row11_col8, #T_bb739_row12_col4, #T_bb739_row12_col5, #T_bb739_row12_col6, #T_bb739_row12_col8, #T_bb739_row13_col4, #T_bb739_row13_col5, #T_bb739_row13_col6, #T_bb739_row13_col8, #T_bb739_row14_col4, #T_bb739_row14_col5, #T_bb739_row14_col6, #T_bb739_row14_col8, #T_bb739_row15_col4, #T_bb739_row15_col5, #T_bb739_row15_col6, #T_bb739_row15_col8, #T_bb739_row16_col4, #T_bb739_row16_col5, #T_bb739_row16_col6, #T_bb739_row16_col8, #T_bb739_row17_col4, #T_bb739_row17_col5, #T_bb739_row17_col6, #T_bb739_row17_col8, #T_bb739_row18_col4, #T_bb739_row18_col5, #T_bb739_row18_col6, #T_bb739_row18_col8, #T_bb739_row19_col4, #T_bb739_row19_col5, #T_bb739_row19_col6, #T_bb739_row19_col8, #T_bb739_row20_col4, #T_bb739_row20_col5, #T_bb739_row20_col6, #T_bb739_row20_col8 {
#   text-align: right;
# }
# </style>
# <table id="T_bb739" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb739_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_bb739_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_bb739_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_bb739_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_bb739_level0_col4" class="col_heading level0 col4" >start</th>
#       <th id="T_bb739_level0_col5" class="col_heading level0 col5" >fitted</th>
#       <th id="T_bb739_level0_col6" class="col_heading level0 col6" >uncertainty</th>
#       <th id="T_bb739_level0_col7" class="col_heading level0 col7" >units</th>
#       <th id="T_bb739_level0_col8" class="col_heading level0 col8" >change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb739_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_bb739_row0_col0" class="data row0 col0" >pbso4</td>
#       <td id="T_bb739_row0_col1" class="data row0 col1" >cell</td>
#       <td id="T_bb739_row0_col2" class="data row0 col2" ></td>
#       <td id="T_bb739_row0_col3" class="data row0 col3" >length_a</td>
#       <td id="T_bb739_row0_col4" class="data row0 col4" >8.4700</td>
#       <td id="T_bb739_row0_col5" class="data row0 col5" >8.4693</td>
#       <td id="T_bb739_row0_col6" class="data row0 col6" >0.0002</td>
#       <td id="T_bb739_row0_col7" class="data row0 col7" >Å</td>
#       <td id="T_bb739_row0_col8" class="data row0 col8" >0.01 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_bb739_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_bb739_row1_col0" class="data row1 col0" >pbso4</td>
#       <td id="T_bb739_row1_col1" class="data row1 col1" >cell</td>
#       <td id="T_bb739_row1_col2" class="data row1 col2" ></td>
#       <td id="T_bb739_row1_col3" class="data row1 col3" >length_b</td>
#       <td id="T_bb739_row1_col4" class="data row1 col4" >5.3900</td>
#       <td id="T_bb739_row1_col5" class="data row1 col5" >5.3912</td>
#       <td id="T_bb739_row1_col6" class="data row1 col6" >0.0001</td>
#       <td id="T_bb739_row1_col7" class="data row1 col7" >Å</td>
#       <td id="T_bb739_row1_col8" class="data row1 col8" >0.02 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_bb739_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_bb739_row2_col0" class="data row2 col0" >pbso4</td>
#       <td id="T_bb739_row2_col1" class="data row2 col1" >cell</td>
#       <td id="T_bb739_row2_col2" class="data row2 col2" ></td>
#       <td id="T_bb739_row2_col3" class="data row2 col3" >length_c</td>
#       <td id="T_bb739_row2_col4" class="data row2 col4" >6.9500</td>
#       <td id="T_bb739_row2_col5" class="data row2 col5" >6.9504</td>
#       <td id="T_bb739_row2_col6" class="data row2 col6" >0.0002</td>
#       <td id="T_bb739_row2_col7" class="data row2 col7" >Å</td>
#       <td id="T_bb739_row2_col8" class="data row2 col8" >0.01 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T