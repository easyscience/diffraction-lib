# %%
from easydiffraction.sample_models.components.cell import Cell
from easydiffraction.sample_models.components.space_group import SpaceGroup
from easydiffraction.sample_models.collections.atom_sites import AtomSite, AtomSites
from easydiffraction.sample_models.sample_model import SampleModel
from easydiffraction.sample_models.sample_models import SampleModels

# %%
from easydiffraction.utils.logging import Logger

Logger.configure(
    level=Logger.Level.DEBUG,
    mode=Logger.Mode.COMPACT,
    reaction=Logger.Reaction.WARN,
)

# %%
s1 = AtomSite(label='La', type_symbol='La')
# Out:
# DEBUG    Setting <label> to validated 'La'.
# DEBUG    Setting <type_symbol> to validated 'La'.
# DEBUG    No value provided for <fract_x>. Using default 0.0.
# DEBUG    No value provided for <fract_y>. Using default 0.0.
# DEBUG    No value provided for <fract_z>. Using default 0.0.
# DEBUG    No value provided for <wyckoff_letter>. Using default 'a'.
# DEBUG    No value provided for <occupancy>. Using default 1.0.
# DEBUG    No value provided for <b_iso>. Using default 0.0.
# DEBUG    No value provided for <adp_type>. Using default 'Biso'.

# %%
s1.fract_x.value = 1.234
# Out:
# DEBUG    Setting <atom_site.La.fract_x> to validated 1.234.

# %%
s1.fract_x.value = 'xyz'
# Out:
# WARNING  Type mismatch for <atom_site.La.fract_x>. Provided 'xyz' (str) is not float. Keeping current 1.234.

# %%
s1.fract_x = 'qwe'
# Out:
# WARNING  Type mismatch for <atom_site.La.fract_x>. Provided 'qwe' (str) is not float. Keeping current 1.234.

# %%
s1 = AtomSite(label='Si', type_symbol='Si', fract_x='uuuu')
# Out:
# DEBUG    Setting <label> to validated 'Si'.
# DEBUG    Setting <type_symbol> to validated 'Si'.
# WARNING  Type mismatch for <fract_x>. Provided 'uuuu' (str) is not float. Using default 0.0.
# DEBUG    No value provided for <fract_y>. Using default 0.0.
# DEBUG    No value provided for <fract_z>. Using default 0.0.
# DEBUG    No value provided for <wyckoff_letter>. Using default 'a'.
# DEBUG    No value provided for <occupancy>. Using default 1.0.
# DEBUG    No value provided for <b_iso>. Using default 0.0.
# DEBUG    No value provided for <adp_type>. Using default 'Biso'.

# %%
s1.fract_x.free = True

# %%
s1.fract_x.free = 'abc'
# Out:
# WARNING  Type mismatch for <atom_site.Si.fract_x.free>. Provided 'abc' (str) is not bool.

# %%
c = Cell()
# Out:
# DEBUG    No value provided for <length_a>. Using default 10.0.
# DEBUG    No value provided for <length_b>. Using default 10.0.
# DEBUG    No value provided for <length_c>. Using default 10.0.
# DEBUG    No value provided for <angle_alpha>. Using default 90.0.
# DEBUG    No value provided for <angle_beta>. Using default 90.0.
# DEBUG    No value provided for <angle_gamma>. Using default 90.0.

# %%
c = Cell(length_b=-8.8)
# Out:
# DEBUG    No value provided for <length_a>. Using default 10.0.
# WARNING  Value mismatch for <length_b>. Provided -8.8 is outside of [0, 1000]. Using default 10.0.
# DEBUG    No value provided for <length_c>. Using default 10.0.
# DEBUG    No value provided for <angle_alpha>. Using default 90.0.
# DEBUG    No value provided for <angle_beta>. Using default 90.0.
# DEBUG    No value provided for <angle_gamma>. Using default 90.0.

# %%
c = Cell(length_b='7.7')
# Out:
# DEBUG    No value provided for <length_a>. Using default 10.0.
# WARNING  Type mismatch for <length_b>. Provided '7.7' (str) is not float. Using default 10.0.
# DEBUG    No value provided for <length_c>. Using default 10.0.
# DEBUG    No value provided for <angle_alpha>. Using default 90.0.
# DEBUG    No value provided for <angle_beta>. Using default 90.0.
# DEBUG    No value provided for <angle_gamma>. Using default 90.0.

# %%
c = Cell(length_b=6.6)
# Out:
# DEBUG    No value provided for <length_a>. Using default 10.0.
# DEBUG    Setting <length_b> to validated 6.6.
# DEBUG    No value provided for <length_c>. Using default 10.0.
# DEBUG    No value provided for <angle_alpha>. Using default 90.0.
# DEBUG    No value provided for <angle_beta>. Using default 90.0.
# DEBUG    No value provided for <angle_gamma>. Using default 90.0.

# %%
c.length_b.value = -5.5
# Out:
# WARNING  Value mismatch for <cell.length_b>. Provided -5.5 is outside of [0, 1000]. Keeping current 6.6.

# %%
c.length_b = -4.4
# Out:
# WARNING  Value mismatch for <cell.length_b>. Provided -4.4 is outside of [0, 1000]. Keeping current 6.6.

# %%
c.length_b = 3.3
# Out:
# DEBUG    Setting <cell.length_b> to validated 3.3.

# %%
c.length_b = 2222.2
# Out:
# WARNING  Value mismatch for <cell.length_b>. Provided 2222.2 is outside of [0, 1000]. Keeping current 3.3.

# %%
c.length_b.free = 'qwe'
# Out:
# WARNING  Type mismatch for <cell.length_b.free>. Provided 'qwe' (str) is not bool.

# %%
c.length_b.fre = 'fre'
# Out:
# WARNING  Unknown attribute 'fre' of <cell.length_b>. Did you mean 'free'?

# %%
c.length_b.qwe = 'qwe'
# Out:
# WARNING  Unknown attribute 'qwe' of <cell.length_b>. Allowed: 'fit_max', 'fit_min', 'free', 'uncertainty', 'value'.

# %%
c.length_b.description = 'desc'
# Out:
# WARNING  Cannot modify read-only attribute 'description' of <cell.length_b>.

# %%
c.qwe = 'qwe'
# Out:
# WARNING  Unknown attribute 'qwe' of <cell>. Allowed: 'angle_alpha', 'angle_beta', 'angle_gamma', 'length_a', 'length_b',
#          'length_c'.

# %%
sg = SpaceGroup()
# Out:
# DEBUG    No value provided for <name_h_m>. Using default 'P 1'.
# DEBUG    No value provided for <it_coordinate_system_code>. Using default ''.

# %%
sg = SpaceGroup(name_h_m='qwe')
# Out:
# WARNING  Value mismatch for <name_h_m>. Provided 'qwe' is unknown. Using default 'P 1'.
# DEBUG    No value provided for <it_coordinate_system_code>. Using default ''.

# %%
sg = SpaceGroup(name_h_m='P n m', it_coordinate_system_code='cab')
# Out:
# WARNING  Value mismatch for <name_h_m>. Provided 'P n m' is unknown. Using default 'P 1'.
# WARNING  Value mismatch for <it_coordinate_system_code>. Provided 'cab' is unknown. Using default ''.

# %%
sg = SpaceGroup(name_h_m='P n m a', it_coordinate_system_code='cab')
# Out:
# DEBUG    Setting <name_h_m> to validated 'P n m a'.
# DEBUG    Setting <it_coordinate_system_code> to validated 'cab'.

# %%
sg.name_h_m = 34.9
# Out:
# WARNING  Value mismatch for <space_group.name_h_m>. Provided 34.9 is unknown. Keeping current 'P n m a'.
# DEBUG    Setting <space_group.it_coordinate_system_code> to validated 'abc'.

# %%
sg.name_h_m = 'P 1'
# Out:
# DEBUG    Setting <space_group.name_h_m> to validated 'P 1'.
# DEBUG    Setting <space_group.it_coordinate_system_code> to validated ''.

# %%
sg.name_h_m = 'P n m a'
# Out:
# DEBUG    Setting <space_group.name_h_m> to validated 'P n m a'.
# DEBUG    Setting <space_group.it_coordinate_system_code> to validated 'abc'.
