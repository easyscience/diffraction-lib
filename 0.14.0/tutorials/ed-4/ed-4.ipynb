# %%
# Check whether easydiffraction is installed; install it if needed.
# Required for remote environments such as Google Colab.
import importlib.util

if importlib.util.find_spec('easydiffraction') is None:
    # %pip install easydiffraction==0.14.0

# %% [markdown]
# # Structure Refinement: PbSO4, NPD + XRD
#
# This example demonstrates a more advanced use of the EasyDiffraction
# library by explicitly creating and configuring structures and
# experiments before adding them to a project. It could be more suitable
# for users who are interested in creating custom workflows. This
# tutorial provides minimal explanation and is intended for users
# already familiar with EasyDiffraction.
#
# The tutorial covers a Rietveld refinement of PbSO4 crystal structure
# based on the joint fit of both X-ray and neutron diffraction data.

# %% [markdown]
# ## Import Library

# %%
from easydiffraction import ExperimentFactory
from easydiffraction import Project
from easydiffraction import StructureFactory
from easydiffraction import download_data

# %% [markdown]
# ## Define Structure
#
# This section shows how to add structures and modify their
# parameters.
#
# #### Create Structure

# %%
structure = StructureFactory.from_scratch(name='pbso4')

# %% [markdown]
# #### Set Space Group

# %%
structure.space_group.name_h_m = 'P n m a'

# %% [markdown]
# #### Set Unit Cell

# %%
structure.cell.length_a = 8.47
structure.cell.length_b = 5.39
structure.cell.length_c = 6.95

# %% [markdown]
# #### Set Atom Sites

# %%
structure.atom_sites.create(
    label='Pb',
    type_symbol='Pb',
    fract_x=0.1876,
    fract_y=0.25,
    fract_z=0.167,
    wyckoff_letter='c',
    adp_iso=1.37,
)
structure.atom_sites.create(
    label='S',
    type_symbol='S',
    fract_x=0.0654,
    fract_y=0.25,
    fract_z=0.684,
    wyckoff_letter='c',
    adp_iso=0.3777,
)
structure.atom_sites.create(
    label='O1',
    type_symbol='O',
    fract_x=0.9082,
    fract_y=0.25,
    fract_z=0.5954,
    wyckoff_letter='c',
    adp_iso=1.9764,
)
structure.atom_sites.create(
    label='O2',
    type_symbol='O',
    fract_x=0.1935,
    fract_y=0.25,
    fract_z=0.5432,
    wyckoff_letter='c',
    adp_iso=1.4456,
)
structure.atom_sites.create(
    label='O3',
    type_symbol='O',
    fract_x=0.0811,
    fract_y=0.0272,
    fract_z=0.8086,
    wyckoff_letter='d',
    adp_iso=1.2822,
)

# %% [markdown]
# ## Define Experiments
#
# This section shows how to add experiments, configure their parameters,
# and link the structures defined in the previous step.
#
# ### Experiment 1: npd
#
# #### Download Data

# %%
data_path1 = download_data(id=13, destination='data')
# Out:
# Getting data...
# Data #13: PbSO4, D1A (ILL)
# ✅ Data #13 downloaded to 'data/ed-13.dat'

# %% [markdown]
# #### Create Experiment

# %%
expt1 = ExperimentFactory.from_data_path(
    name='npd',
    data_path=data_path1,
    radiation_probe='neutron',
)

# %% [markdown]
# #### Set Instrument

# %%
expt1.instrument.setup_wavelength = 1.91
expt1.instrument.calib_twotheta_offset = -0.1406

# %% [markdown]
# #### Set Peak Profile

# %%
expt1.peak.broad_gauss_u = 0.139
expt1.peak.broad_gauss_v = -0.412
expt1.peak.broad_gauss_w = 0.386
expt1.peak.broad_lorentz_x = 0
expt1.peak.broad_lorentz_y = 0.088

# %% [markdown]
# #### Set Background

# %% [markdown]
# Select the background type.

# %%
expt1.background_type = 'line-segment'
# Out:
# Background type for experiment 'npd' already set to
# line-segment

# %% [markdown]
# Add background points.

# %%
for id, x, y in [
    ('1', 11.0, 206.1624),
    ('2', 15.0, 194.75),
    ('3', 20.0, 194.505),
    ('4', 30.0, 188.4375),
    ('5', 50.0, 207.7633),
    ('6', 70.0, 201.7002),
    ('7', 120.0, 244.4525),
    ('8', 153.0, 226.0595),
]:
    expt1.background.create(id=id, x=x, y=y)

# %% [markdown]
# #### Set Linked Phases

# %%
expt1.linked_phases.create(id='pbso4', scale=1.5)

# %% [markdown]
# ### Experiment 2: xrd
#
# #### Download Data

# %%
data_path2 = download_data(id=16, destination='data')
# Out:
# Getting data...
# Data #16: PbSO4, laboratory X-ray
# ✅ Data #16 downloaded to 'data/ed-16.dat'

# %% [markdown]
# #### Create Experiment

# %%
expt2 = ExperimentFactory.from_data_path(
    name='xrd',
    data_path=data_path2,
    radiation_probe='xray',
)

# %% [markdown]
# #### Set Instrument

# %%
expt2.instrument.setup_wavelength = 1.540567
expt2.instrument.calib_twotheta_offset = -0.05181

# %% [markdown]
# #### Set Peak Profile

# %%
expt2.peak.broad_gauss_u = 0.304138
expt2.peak.broad_gauss_v = -0.112622
expt2.peak.broad_gauss_w = 0.021272
expt2.peak.broad_lorentz_x = 0
expt2.peak.broad_lorentz_y = 0.057691

# %% [markdown]
# #### Set Background

# %% [markdown]
# Select background type.

# %%
expt2.background_type = 'chebyshev'
# Out:
# Background type for experiment 'xrd' changed to
# chebyshev

# %% [markdown]
# Add background points.

# %%
for id, x, y in [
    ('1', 0, 119.195),
    ('2', 1, 6.221),
    ('3', 2, -45.725),
    ('4', 3, 8.119),
    ('5', 4, 54.552),
    ('6', 5, -20.661),
]:
    expt2.background.create(id=id, order=x, coef=y)

# %% [markdown]
# #### Set Linked Phases

# %%
expt2.linked_phases.create(id='pbso4', scale=0.001)

# %% [markdown]
# ## Define Project
#
# The project object is used to manage structures, experiments, and
# analysis.
#
# #### Create Project

# %%
project = Project()

# %% [markdown]
# #### Add Structure

# %%
project.structures.add(structure)

# %% [markdown]
# #### Add Experiments

# %%
project.experiments.add(expt1)
project.experiments.add(expt2)

# %% [markdown]
# ## Perform Analysis
#
# This section outlines the analysis process, including how to configure
# calculation and fitting engines.
#
# #### Set Fit Mode

# %%
project.analysis.fit.mode = 'joint'

# %% [markdown]
# #### Set Minimizer

# %%
project.analysis.fit.minimizer_type = 'lmfit'
# Out:
# Current minimizer changed to
# lmfit

# %% [markdown]
# #### Set Fitting Parameters
#
# Set structure parameters to be optimized.

# %%
structure.cell.length_a.free = True
structure.cell.length_b.free = True
structure.cell.length_c.free = True

# %% [markdown]
# Set experiment parameters to be optimized.

# %%
expt1.linked_phases['pbso4'].scale.free = True

expt1.instrument.calib_twotheta_offset.free = True

expt1.peak.broad_gauss_u.free = True
expt1.peak.broad_gauss_v.free = True
expt1.peak.broad_gauss_w.free = True
expt1.peak.broad_lorentz_y.free = True

# %%
expt2.linked_phases['pbso4'].scale.free = True

expt2.instrument.calib_twotheta_offset.free = True

expt2.peak.broad_gauss_u.free = True
expt2.peak.broad_gauss_v.free = True
expt2.peak.broad_gauss_w.free = True
expt2.peak.broad_lorentz_y.free = True

for term in expt2.background:
    term.coef.free = True

# %% [markdown]
# #### Perform Fit

# %% [markdown]
# #### Plot Measured vs Calculated

# %%
project.display.plotter.plot_meas_vs_calc(
    expt_name='npd', x_min=35.5, x_max=38.3, show_residual=True
)
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="64198d12-1403-4bdd-a1be-2f826247497e" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("64198d12-1403-4bdd-a1be-2f826247497e")) {                    Plotly.newPlot(                        "64198d12-1403-4bdd-a1be-2f826247497e",                        [{"line":{"color":"rgb(31, 119, 180)"},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"..."},"type":"scatter"},{"line":{"color":"rgb(214, 39, 40)"},"mode":"lines","name":"Total calculated (Icalc)","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"Ib2c+ny2aUDbFdTAh8BpQGyvOKPJzGlA3MGYiV3baUB9RcN7dOxpQAbtqH9XAGpAEGKWDHEXakCxyozdYjJqQCxTeZEyUmpA889n6p94akBEvbjNwqhqQOSXm6Mb6GpAxl6K8EhAa0BFYBdyjsFrQCQTc0A1hmxATPj+c3m2bUCpzp7cMYxvQAEW8VRZKnFAzn2QcWk3c0BoqGNGaSF2QHTfKehGGXpAJPCx\u002fRdBf0AaeHFcEc+CQNa9p+exhYZARNKMGAyYikBYbdFjrL6OQKzPZmAkTZFA6051tCzekkAozdlG09uTQE60ZyGPHZRAiVkMKIGXk0Bqcxbmxl+SQNG9he99pZBAjEB9TM1CjUCmU6CgSBOJQOAucdRrFYVA\u002f+iW+ieIgUBsaJvueh19QEalk8W9ZnhAXPuZ5vLZdECK2ofG10xyQJiPJoXWinBAbTQ0Vmu\u002fbkDocg4DaDxtQC7YGDS4RWxAOichYSuoa0CE\u002fuSfT0FrQPjt9rpW+2pAWY\u002fNcSbJakChZOkiMaNqQAZnZWQ5hWpABVuTCeFsakCN\u002foZqzVhqQA3wfhYtSGpAGZoVd3c6akD\u002fe2dVTC9qQOMM0c1jJmpA"},"type":"scatter"},{"line":{"color":"rgb(44, 160, 44)"},"mode":"lines","name":"Residual (Imeas - Icalc)","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"IKSXU5\u002fPEsBgu4Ia+BAYwMD2ijOazCjAwB2Mmdi1JcCgr2h4j44RwGDQjvp3BSrAACFmyRB3KcCAp5o5kc72P4Ca1dCtuRVAYP75TP0TE8AAXqEjmZ77P4ADjYyL\u002fBZA0Amte7j9MkDY\u002fURvjPM5QHCzM\u002f4qZ0BA0B4EMBqmRECuYsJGnKdQQPhPd1g1LU9AkBF8c7RETEBgXnHmWjpRQDCCWF\u002fk2lFA4H5wEkB3TEDA\u002fNBx1B08QICKEBaGkyBAgEiaEYMBPcCA1RY9xmpEwID12QyMJEjAgHWnOloWJ8AApTnbaPpBwOBEexby2FDAIDGLASVwRsBAbc7C3PhHwBDdW\u002fjeF1DAYATqY2oWUsAwnQIFRVpSwAB3iaNea1LA+Ee31D9BUMBgQ9t01+tHwDAqnSzutUHAwLWfaS6fNMCgqH1ofM09wID5aFJorTLAaKOhsVr7M8BAl3MYQOMzwMAFG4MGtxDAAMbY3p7U5z+A0J\u002f88ykcwAC\u002f3V7XahPAkPXYHGeSKMAQSpYuEjMuwDA4KyPLKTTAKNiaTAhnMsDQ6G+o1owtwNAA72fRgiLAIEOz4u5OG8Dgf++siukZwDDOEN08ZiDA"},"type":"scatter"}],                        {"legend":{"x":1.0,"xanchor":"right","y":1.0,"yanchor":"top"},"margin":{"autoexpand":true,"b":45,"r":30,"t":40},"title":{"text":"Measured vs Calculated data for experiment \ud83d\udd2c 'npd'"},"xaxis":{"mirror":true,"showline":true,"title":{"text":"2\u03b8 (degree)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"yaxis":{"mirror":true,"showline":true,"title":{"text":"Intensity (arb. units)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555 ...

# %%
project.display.plotter.plot_meas_vs_calc(
    expt_name='xrd', x_min=29.0, x_max=30.4, show_residual=True
)
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="1e3d824d-1f5d-4c11-99d0-e74526299d07" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1e3d824d-1f5d-4c11-99d0-e74526299d07")) {                    Plotly.newPlot(                        "1e3d824d-1f5d-4c11-99d0-e74526299d07",                        [{"line":{"color":"rgb(31, 119, 180)"},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"..."},"type":"scatter"},{"line":{"color":"rgb(214, 39, 40)"},"mode":"lines","name":"Total calculated (Icalc)","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"1rgGp41bZkB9OYUL7e5mQOC1etV9lWdAeFUhx0NSaECQQfvN7ChpQCpVTV3+HWpAgA1WnBE3a0CmM4AkJHtsQE+nQaUF821APtIdue6pb0CNN1qtKddwQBkszpGGCXJAraTA0oR4c0CkXe\u002f94zR1QJ4A+MegVXdAQUP8n4D7eUA+IXHsWFl9QB4Jk1bu5YBAiOyPVpwPhEB8PIe8kR+JQNnXhNFxI5FA5hFSpEzkmUC7QKTEIgilQFkd\u002fHwXQLFAvER56Z\u002fsukASy8OJjDHDQN0b1SzaLshAG05OGL3uyUAV5PdHfkDHQCYIFXcK5MFA59jkOv+GuEBpHsY6ffeuQDNQrrHMzqJAHMNu5xpfl0AAlCu0pX+PQGoHNCkyfIdAtSOEZjn3gkAt3CBfqhSAQBumBkK9DHxAmFNazkfreEASKNYeoHN2QASMgR3Ed3RA4F0k6YrZckBaeDbspYNxQDPkIe5\u002fZnBAPTE7YO\u002fsbkDHmuE1eFVtQPl7s8EM+WtA+oML2yDNakDSyTcdZ8lpQGUEIgRF52hAAndF\u002fWwhaED89PAok3NnQNJQXyM12mZAjHkZjW9SZkDGH4Kg3dllQIi6HTaAbmVA"},"type":"scatter"},{"line":{"color":"rgb(44, 160, 44)"},"mode":"lines","name":"Residual (Imeas - Icalc)","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"YI1rcNq4K8DQl1O40O4uwACv1avuqzrAALyqkOMh+b9ABu03syNAwKBS1dTl3yPAAGyw4oy4P8AwnQEkIdkzwDydBpUWzEXAfKQ7ct3TUcDQeKPVmnI3wMhgcY40zEXA0EoKLE2IO8AAuEQhBDjmP8ATAP8YtCLACBri\u002fwTcQMAQ9nacOLVIQBC3Z0uNEF9A4E3ApY5haEAIh\u002fGG3EBxQJyg7Lk4Un1ANNxbt2a\u002fhEAU\u002fW7tdE+HQDgVHxhE54dAEO0aWoCBk0C40\u002fDYzbmlQIyQq0yX8KlAKI+NPRcKkkDA+gYCbsBkQKB9r45Yd4BAyDjZKAbQikBwGZ5TLOhjQJiBco1llnPA4Bh2O9c4ZMAAADbqJS0UQMASf9m6eTxAsMS9l2mMTkDQwg3ypcpHwGDD1EColyXAgDml5Xy0M8CABIq1B+gQwBAwBnYQH1DAALyLJF0xLcBgepg8ocUyQGCGPMT9zy7AYNiZ+BNiFkCAnDIP5UP1PwD5e7PBDOm\u002f0B9c2AZpNcAgnXzTcZYgwFBGIEJQdC7A4I+oKzDpJUAAPz08yuQEwCAN9TVSoyHAoDM0l4NsNkDA+EMQtDsbwIBXJJ78FytA"},"type":"scatter"}],                        {"legend":{"x":1.0,"xanchor":"right","y":1.0,"yanchor":"top"},"margin":{"autoexpand":true,"b":45,"r":30,"t":40},"title":{"text":"Measured vs Calculated data for experiment \ud83d\udd2c 'xrd'"},"xaxis":{"mirror":true,"showline":true,"title":{"text":"2\u03b8 (degree)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"yaxis":{"mirror":true,"showline":true,"title":{"text":"Intensity (arb. units)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b ...
