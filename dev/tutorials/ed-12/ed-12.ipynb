# %%
# Check if the easydiffraction library is installed.
# If not, install it with the 'visualization' extras.
# Needed when running remotely (e.g. Colab) where the lib is absent.
import builtins
import importlib.util

if (hasattr(builtins, '__IPYTHON__') and
    importlib.util.find_spec('easydiffraction') is None):
    # !pip install 'easydiffraction[visualization]'

# %% [markdown]
# # Pair Distribution Function: NaCl, XRD
#
# This example demonstrates a pair distribution function (PDF) analysis
# of NaCl, based on data collected from an X-ray powder diffraction
# experiment.
#
# The dataset is taken from:
# https://github.com/diffpy/add2019-diffpy-cmi/tree/master

# %% [markdown]
# ## Import Library

# %%
import easydiffraction as ed

# %% [markdown]
# ## Create Project

# %%
project = ed.Project()

# %% [markdown]
# ## Set Plotting Engine

# %%
# Keep the auto-selected engine. Alternatively, you can uncomment the
# line below to explicitly set the engine to the required one.
# project.plotter.engine = 'plotly'

# %%
# Set global plot range for plots
project.plotter.x_min = 2.0
project.plotter.x_max = 30.0

# %% [markdown]
# ## Add Sample Model

# %%
project.sample_models.add(name='nacl')

# %%
project.sample_models['nacl'].space_group.name_h_m = 'F m -3 m'
project.sample_models['nacl'].space_group.it_coordinate_system_code = '1'
project.sample_models['nacl'].cell.length_a = 5.62
project.sample_models['nacl'].atom_sites.add(
    label='Na',
    type_symbol='Na',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    b_iso=1.0,
)
project.sample_models['nacl'].atom_sites.add(
    label='Cl',
    type_symbol='Cl',
    fract_x=0.5,
    fract_y=0.5,
    fract_z=0.5,
    wyckoff_letter='b',
    b_iso=1.0,
)

# %% [markdown]
# ## Add Experiment

# %%
data_path = ed.download_data(id=4, destination='data')
# Out:
# Getting data...
# Data #4: NaCl.gr
# ✅ Data #4 downloaded to 'data/ed-4.gr'

# %%
project.experiments.add(
    name='xray_pdf',
    data_path=data_path,
    sample_form='powder',
    beam_mode='constant wavelength',
    radiation_probe='xray',
    scattering_type='total',
)
# Out:
# Warning: No uncertainty (sy) column provided. Defaulting to 0.03.
# Data loaded successfully
# Experiment 🔬 'xray_pdf'. Number of data points: 5000

# %%
project.experiments['xray_pdf'].show_supported_peak_profile_types()
# Out:
# Supported peak profile types
# <style type="text/css">
# #T_e4861   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_e4861 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_e4861 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_e4861  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_e4861 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_e4861 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_e4861  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_e4861 th.col0 {
#   text-align: left;
# }
# #T_e4861 th.col1 {
#   text-align: left;
# }
# #T_e4861_row0_col0, #T_e4861_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_e4861" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4861_level0_col0" class="col_heading level0 col0" >Peak profile type</th>
#       <th id="T_e4861_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4861_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e4861_row0_col0" class="data row0 col0" >gaussian-damped-sinc</td>
#       <td id="T_e4861_row0_col1" class="data row0 col1" >Gaussian-damped sinc profile for pair distribution function (PDF) analysis.</td>
#     </tr>
#   </tbody>
# </table>

# %%
project.experiments['xray_pdf'].show_current_peak_profile_type()
# Out:
# Current peak profile type
# PeakProfileTypeEnum.GAUSSIAN_DAMPED_SINC

# %%
project.experiments['xray_pdf'].peak_profile_type = 'gaussian-damped-sinc'
# Out:
# Peak profile type for experiment 'xray_pdf' changed to
# gaussian-damped-sinc

# %%
project.experiments['xray_pdf'].peak.damp_q = 0.03
project.experiments['xray_pdf'].peak.broad_q = 0
project.experiments['xray_pdf'].peak.cutoff_q = 21
project.experiments['xray_pdf'].peak.sharp_delta_1 = 0
project.experiments['xray_pdf'].peak.sharp_delta_2 = 5
project.experiments['xray_pdf'].peak.damp_particle_diameter = 0

# %%
project.experiments['xray_pdf'].linked_phases.add(id='nacl', scale=0.5)

# %% [markdown]
# ## Select Fitting Parameters

# %%
project.sample_models['nacl'].cell.length_a.free = True
project.sample_models['nacl'].atom_sites['Na'].b_iso.free = True
project.sample_models['nacl'].atom_sites['Cl'].b_iso.free = True

# %%
project.experiments['xray_pdf'].linked_phases['nacl'].scale.free = True
project.experiments['xray_pdf'].peak.damp_q.free = True
project.experiments['xray_pdf'].peak.sharp_delta_2.free = True

# %% [markdown]
# ## Run Fitting

# %%
project.analysis.current_calculator = 'pdffit'
project.analysis.fit()
project.analysis.show_fit_results()
# Out:
# Current calculator changed to
# pdffit
# Using experiment 🔬 'xray_pdf' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_df7a0   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_df7a0 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_df7a0 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_df7a0  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_df7a0 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_df7a0 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_df7a0  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_df7a0 th.col0 {
#   text-align: center;
# }
# #T_df7a0 th.col1 {
#   text-align: center;
# }
# #T_df7a0 th.col2 {
#   text-align: center;
# }
# #T_df7a0_row0_col0, #T_df7a0_row0_col1, #T_df7a0_row0_col2, #T_df7a0_row1_col0, #T_df7a0_row1_col1, #T_df7a0_row1_col2, #T_df7a0_row2_col0, #T_df7a0_row2_col1, #T_df7a0_row2_col2, #T_df7a0_row3_col0, #T_df7a0_row3_col1, #T_df7a0_row3_col2, #T_df7a0_row4_col0, #T_df7a0_row4_col1, #T_df7a0_row4_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_df7a0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df7a0_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_df7a0_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_df7a0_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df7a0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_df7a0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_df7a0_row0_col1" class="data row0 col1" >163.09</td>
#       <td id="T_df7a0_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_df7a0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_df7a0_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_df7a0_row1_col1" class="data row1 col1" >19.59</td>
#       <td id="T_df7a0_row1_col2" class="data row1 col2" >88.0% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_df7a0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_df7a0_row2_col0" class="data row2 col0" >17</td>
#       <td id="T_df7a0_row2_col1" class="data row2 col1" >10.95</td>
#       <td id="T_df7a0_row2_col2" class="data row2 col2" >44.1% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_df7a0_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_df7a0_row3_col0" class="data row3 col0" >24</td>
#       <td id="T_df7a0_row3_col1" class="data row3 col1" >10.69</td>
#       <td id="T_df7a0_row3_col2" class="data row3 col2" >2.3% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_df7a0_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_df7a0_row4_col0" class="data row4 col0" >46</td>
#       <td id="T_df7a0_row4_col1" class="data row4 col1" >10.69</td>
#       <td id="T_df7a0_row4_col2" class="data row4 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 10.69 at iteration 45
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 7.08 seconds
# 📏 Goodness-of-fit (reduced χ²): 10.69
# 📏 R-factor (Rf): 34.82%
# 📏 R-factor squared (Rf²): 30.63%
# 📏 Weighted R-factor (wR): 30.63%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_99029   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_99029 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_99029 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_99029  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_99029 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_99029 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_99029  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_99029 th.col0 {
#   text-align: left;
# }
# #T_99029 th.col1 {
#   text-align: left;
# }
# #T_99029 th.col2 {
#   text-align: left;
# }
# #T_99029 th.col3 {
#   text-align: left;
# }
# #T_99029 th.col4 {
#   text-align: right;
# }
# #T_99029 th.col5 {
#   text-align: right;
# }
# #T_99029 th.col6 {
#   text-align: right;
# }
# #T_99029 th.col7 {
#   text-align: left;
# }
# #T_99029 th.col8 {
#   text-align: right;
# }
# #T_99029_row0_col0, #T_99029_row0_col1, #T_99029_row0_col2, #T_99029_row0_col3, #T_99029_row0_col7, #T_99029_row1_col0, #T_99029_row1_col1, #T_99029_row1_col2, #T_99029_row1_col3, #T_99029_row1_col7, #T_99029_row2_col0, #T_99029_row2_col1, #T_99029_row2_col2, #T_99029_row2_col3, #T_99029_row2_col7, #T_99029_row3_col0, #T_99029_row3_col1, #T_99029_row3_col2, #T_99029_row3_col3, #T_99029_row3_col7, #T_99029_row4_col0, #T_99029_row4_col1, #T_99029_row4_col2, #T_99029_row4_col3, #T_99029_row4_col7, #T_99029_row5_col0, #T_99029_row5_col1, #T_99029_row5_col2, #T_99029_row5_col3, #T_99029_row5_col7 {
#   text-align: left;
# }
# #T_99029_row0_col4, #T_99029_row0_col5, #T_99029_row0_col6, #T_99029_row0_col8, #T_99029_row1_col4, #T_99029_row1_col5, #T_99029_row1_col6, #T_99029_row1_col8, #T_99029_row2_col4, #T_99029_row2_col5, #T_99029_row2_col6, #T_99029_row2_col8, #T_99029_row3_col4, #T_99029_row3_col5, #T_99029_row3_col6, #T_99029_row3_col8, #T_99029_row4_col4, #T_99029_row4_col5, #T_99029_row4_col6, #T_99029_row4_col8, #T_99029_row5_col4, #T_99029_row5_col5, #T_99029_row5_col6, #T_99029_row5_col8 {
#   text-align: right;
# }
# </style>
# <table id="T_99029" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99029_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_99029_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_99029_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_99029_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_99029_level0_col4" class="col_heading level0 col4" >start</th>
#       <th id="T_99029_level0_col5" class="col_heading level0 col5" >fitted</th>
#       <th id="T_99029_level0_col6" class="col_heading level0 col6" >uncertainty</th>
#       <th id="T_99029_level0_col7" class="col_heading level0 col7" >units</th>
#       <th id="T_99029_level0_col8" class="col_heading level0 col8" >change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99029_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_99029_row0_col0" class="data row0 col0" >nacl</td>
#       <td id="T_99029_row0_col1" class="data row0 col1" >cell</td>
#       <td id="T_99029_row0_col2" class="data row0 col2" ></td>
#       <td id="T_99029_row0_col3" class="data row0 col3" >length_a</td>
#       <td id="T_99029_row0_col4" class="data row0 col4" >5.6200</td>
#       <td id="T_99029_row0_col5" class="data row0 col5" >5.6175</td>
#       <td id="T_99029_row0_col6" class="data row0 col6" >N/A</td>
#       <td id="T_99029_row0_col7" class="data row0 col7" >Å</td>
#       <td id="T_99029_row0_col8" class="data row0 col8" >0.04 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_99029_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_99029_row1_col0" class="data row1 col0" >nacl</td>
#       <td id="T_99029_row1_col1" class="data row1 col1" >atom_site</td>
#       <td id="T_99029_row1_col2" class="data row1 col2" >Na</td>
#       <td id="T_99029_row1_col3" class="data row1 col3" >b_iso</td>
#       <td id="T_99029_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_99029_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_99029_row1_col6" class="data row1 col6" >N/A</td>
#       <td id="T_99029_row1_col7" class="data row1 col7" >Å²</td>
#       <td id="T_99029_row1_col8" class="data row1 col8" >0.00 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_99029_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_99029_row2_col0" class="data row2 col0" >nacl</td>
#       <td id="T_99029_row2_col1" class="data row2 col1" >atom_site</td>
#       <td id="T_99029_row2_col2" class="data row2 col2" >Cl</td>
#       <td id="T_99029_row2_col3" class="data row2 col3" >b_iso</td>
#       <td id="T_99029_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_99029_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_99029_row2_col6" class="data row2 col6" >N/A</td>
#       <td id="T_99029_row2_col7" class="data row2 col7" >Å²</td>
#       <td id="T_99029_row2_col8" class="data row2 col8" >0.00 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_99029_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_99029_row3_col0" class="data row3 col0" >xray_pdf</td>
#       <td id="T_99029_row3_col1" class="data row3 col1" >linked_phases</td>
#       <td id="T_99029_row3_col2" class="data row3 col2" >nacl</td>
#       <td id="T_99029_row3_col3" class="data row3 col3" >scale</td>
#       <td id="T_99029_row3_col4" class="data row3 col4" >0.5000</td>
#       <td id="T_99029_row3_col5" class="data row3 col5" >0.4469</td>
#       <td id="T_99029_row3_col6" class="data row3 col6" >N/A</td>
#       <td id="T_99029_row3_col7" class="data row3 col7" ></td>
#       <td id="T_99029_row3_col8" class="data row3 col8" >10.61 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_99029_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_99029_row4_col0" class="data row4 col0" >xray_pdf</td>
#       <td id="T_99029_row4_col1" class="data row4 col1" >peak</td>
#       <td id="T_99029_row4_col2" class="data row4 col2" ></td>
#       <td id="T_99029_row4_col3" class="data row4 col3" >damp_q</td>
#       <td id="T_99029_row4_col4" class="data row4 col4" >0.0300</td>
#       <td id="T_99029_row4_col5" class="data row4 col5" >0.0625</td>
#       <td id="T_99029_row4_col6" class="data row4 col6" >N/A</td>
#       <td id="T_99029_row4_col7" class="data row4 col7" >Å⁻¹</td>
#       <td id="T_99029_row4_col8" class="data row4 col8" >108.42 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_99029_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_99029_row5_col0" class="data row5 col0" >xray_pdf</td>
#       <td id="T_99029_row5_col1" class="data row5 col1" >peak</td>
#       <td id="T_99029_row5_col2" class="data row5 col2" ></td>
#       <td id="T_99029_row5_col3" class="data row5 col3" >sharp_delta_2</td>
#       <td id="T_99029_row5_col4" class="data row5 col4" >5.0000</td>
#       <td id="T_99029_row5_col5" class="data row5 col5" >4.3628</td>
#       <td id="T_99029_row5_col6" class="data row5 col6" >N/A</td>
#       <td id="T_99029_row5_col7" class="data row5 col7" >Å²</td>
#       <td id="T_99029_row5_col8" class="data row5 col8" >12.74 % ↓</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Plot Measured vs Calculated

# %%
project.plot_meas_vs_calc(expt_name='xray_pdf')
# Out:
# ❌ No two_theta data available for experiment xray_pdf
