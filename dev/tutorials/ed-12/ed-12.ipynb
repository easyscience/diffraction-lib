# %%
# Check whether easydiffraction is installed; install it if needed.
# Required for remote environments such as Google Colab.
import importlib.util

if importlib.util.find_spec('easydiffraction') is None:
    # %pip install easydiffraction

# %% [markdown]
# # Pair Distribution Function: NaCl, XRD
#
# This example demonstrates a pair distribution function (PDF) analysis
# of NaCl, based on data collected from an X-ray powder diffraction
# experiment.
#
# The dataset is taken from:
# https://github.com/diffpy/add2019-diffpy-cmi/tree/master

# %% [markdown]
# ## Import Library

# %%
import easydiffraction as ed

# %% [markdown]
# ## Create Project

# %%
project = ed.Project()

# %% [markdown]
# ## Set Plotting Engine

# %%
# Keep the auto-selected engine. Alternatively, you can uncomment the
# line below to explicitly set the engine to the required one.
# project.plotter.engine = 'plotly'

# %%
# Set global plot range for plots
project.plotter.x_min = 2.0
project.plotter.x_max = 30.0

# %% [markdown]
# ## Add Structure

# %%
project.structures.create(name='nacl')

# %%
project.structures['nacl'].space_group.name_h_m = 'F m -3 m'
project.structures['nacl'].space_group.it_coordinate_system_code = '1'
project.structures['nacl'].cell.length_a = 5.62
project.structures['nacl'].atom_sites.create(
    label='Na',
    type_symbol='Na',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    adp_iso=1.0,
)
project.structures['nacl'].atom_sites.create(
    label='Cl',
    type_symbol='Cl',
    fract_x=0.5,
    fract_y=0.5,
    fract_z=0.5,
    wyckoff_letter='b',
    adp_iso=1.0,
)

# %% [markdown]
# ## Add Experiment

# %%
data_path = ed.download_data(id=4, destination='data')
# Out:
# Getting data...
# Data #4: NaCl.gr
# ✅ Data #4 downloaded to 'data/ed-4.gr'

# %%
project.experiments.add_from_data_path(
    name='xray_pdf',
    data_path=data_path,
    sample_form='powder',
    beam_mode='constant wavelength',
    radiation_probe='xray',
    scattering_type='total',
)
# Out:
# ⚠️ No uncertainty (sy) column provided. Defaulting to 0.03.
# Data loaded successfully
# Experiment 🔬 'xray_pdf'. Number of data points: 5000.

# %%
project.experiments['xray_pdf'].show_supported_peak_profile_types()
# Out:
# Supported types
# <style type="text/css">
# #T_016d5   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_016d5 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_016d5 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_016d5  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_016d5 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_016d5 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_016d5  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_016d5 th.col0 {
#   text-align: left;
# }
# #T_016d5 th.col1 {
#   text-align: left;
# }
# #T_016d5_row0_col0, #T_016d5_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_016d5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_016d5_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_016d5_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_016d5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_016d5_row0_col0" class="data row0 col0" >gaussian-damped-sinc</td>
#       <td id="T_016d5_row0_col1" class="data row0 col1" >Gaussian-damped sinc for pair distribution function analysis</td>
#     </tr>
#   </tbody>
# </table>

# %%
project.experiments['xray_pdf'].show_current_peak_profile_type()
# Out:
# Current peak profile type
# gaussian-damped-sinc

# %%
project.experiments['xray_pdf'].peak_profile_type = 'gaussian-damped-sinc'
# Out:
# ⚠️ Switching peak profile type discards existing peak parameters.
# Peak profile type for experiment 'xray_pdf' changed to
# gaussian-damped-sinc

# %%
project.experiments['xray_pdf'].peak.damp_q = 0.03
project.experiments['xray_pdf'].peak.broad_q = 0
project.experiments['xray_pdf'].peak.cutoff_q = 21
project.experiments['xray_pdf'].peak.sharp_delta_1 = 0
project.experiments['xray_pdf'].peak.sharp_delta_2 = 5
project.experiments['xray_pdf'].peak.damp_particle_diameter = 0

# %%
project.experiments['xray_pdf'].linked_phases.create(id='nacl', scale=0.5)

# %% [markdown]
# ## Select Fitting Parameters

# %%
project.structures['nacl'].cell.length_a.free = True
project.structures['nacl'].atom_sites['Na'].adp_iso.free = True
project.structures['nacl'].atom_sites['Cl'].adp_iso.free = True

# %%
project.experiments['xray_pdf'].linked_phases['nacl'].scale.free = True
project.experiments['xray_pdf'].peak.damp_q.free = True
project.experiments['xray_pdf'].peak.sharp_delta_2.free = True

# %% [markdown]
# ## Run Fitting

# %%
project.analysis.fit()
project.analysis.display.fit_results()
project.plotter.plot_param_correlations()
# Out:
# Standard fitting
# 📋 Using experiment 🔬 'xray_pdf' for 'single' fitting
# 🚀 Starting fit process with 'bumps (lm)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_40ee2   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_40ee2 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_40ee2 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_40ee2  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_40ee2 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_40ee2 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_40ee2  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_40ee2 th.col0 {
#   text-align: center;
# }
# #T_40ee2 th.col1 {
#   text-align: center;
# }
# #T_40ee2 th.col2 {
#   text-align: center;
# }
# #T_40ee2_row0_col0, #T_40ee2_row0_col1, #T_40ee2_row0_col2, #T_40ee2_row1_col0, #T_40ee2_row1_col1, #T_40ee2_row1_col2, #T_40ee2_row2_col0, #T_40ee2_row2_col1, #T_40ee2_row2_col2, #T_40ee2_row3_col0, #T_40ee2_row3_col1, #T_40ee2_row3_col2, #T_40ee2_row4_col0, #T_40ee2_row4_col1, #T_40ee2_row4_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_40ee2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40ee2_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_40ee2_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_40ee2_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40ee2_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_40ee2_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_40ee2_row0_col1" class="data row0 col1" >163.09</td>
#       <td id="T_40ee2_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_40ee2_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_40ee2_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_40ee2_row1_col1" class="data row1 col1" >16.87</td>
#       <td id="T_40ee2_row1_col2" class="data row1 col2" >89.7% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_40ee2_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_40ee2_row2_col0" class="data row2 col0" >16</td>
#       <td id="T_40ee2_row2_col1" class="data row2 col1" >2.34</td>
#       <td id="T_40ee2_row2_col2" class="data row2 col2" >86.1% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_40ee2_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_40ee2_row3_col0" class="data row3 col0" >23</td>
#       <td id="T_40ee2_row3_col1" class="data row3 col1" >1.49</td>
#       <td id="T_40ee2_row3_col2" class="data row3 col2" >36.4% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_40ee2_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_40ee2_row4_col0" class="data row4 col0" >60</td>
#       <td id="T_40ee2_row4_col1" class="data row4 col1" >1.48</td>
#       <td id="T_40ee2_row4_col2" class="data row4 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 1.48 at iteration 59
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 13.73 seconds
# 📏 Goodness-of-fit (reduced χ²): 1.48
# 📏 R-factor (Rf): 11.02%
# 📏 R-factor squared (Rf²): 11.38%
# 📏 Weighted R-factor (wR): 11.38%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_a32a4   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_a32a4 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_a32a4 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a32a4  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a32a4 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_a32a4 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_a32a4  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_a32a4 th.col0 {
#   text-align: left;
# }
# #T_a32a4 th.col1 {
#   text-align: left;
# }
# #T_a32a4 th.col2 {
#   text-align: left;
# }
# #T_a32a4 th.col3 {
#   text-align: left;
# }
# #T_a32a4 th.col4 {
#   text-align: right;
# }
# #T_a32a4 th.col5 {
#   text-align: right;
# }
# #T_a32a4 th.col6 {
#   text-align: right;
# }
# #T_a32a4 th.col7 {
#   text-align: left;
# }
# #T_a32a4 th.col8 {
#   text-align: right;
# }
# #T_a32a4_row0_col0, #T_a32a4_row0_col1, #T_a32a4_row0_col2, #T_a32a4_row0_col3, #T_a32a4_row0_col7, #T_a32a4_row1_col0, #T_a32a4_row1_col1, #T_a32a4_row1_col2, #T_a32a4_row1_col3, #T_a32a4_row1_col7, #T_a32a4_row2_col0, #T_a32a4_row2_col1, #T_a32a4_row2_col2, #T_a32a4_row2_col3, #T_a32a4_row2_col7, #T_a32a4_row3_col0, #T_a32a4_row3_col1, #T_a32a4_row3_col2, #T_a32a4_row3_col3, #T_a32a4_row3_col7, #T_a32a4_row4_col0, #T_a32a4_row4_col1, #T_a32a4_row4_col2, #T_a32a4_row4_col3, #T_a32a4_row4_col7, #T_a32a4_row5_col0, #T_a32a4_row5_col1, #T_a32a4_row5_col2, #T_a32a4_row5_col3, #T_a32a4_row5_col7 {
#   text-align: left;
# }
# #T_a32a4_row0_col4, #T_a32a4_row0_col5, #T_a32a4_row0_col6, #T_a32a4_row0_col8, #T_a32a4_row1_col4, #T_a32a4_row1_col5, #T_a32a4_row1_col6, #T_a32a4_row1_col8, #T_a32a4_row2_col4, #T_a32a4_row2_col5, #T_a32a4_row2_col6, #T_a32a4_row2_col8, #T_a32a4_row3_col4, #T_a32a4_row3_col5, #T_a32a4_row3_col6, #T_a32a4_row3_col8, #T_a32a4_row4_col4, #T_a32a4_row4_col5, #T_a32a4_row4_col6, #T_a32a4_row4_col8, #T_a32a4_row5_col4, #T_a32a4_row5_col5, #T_a32a4_row5_col6, #T_a32a4_row5_col8 {
#   text-align: right;
# }
# </style>
# <table id="T_a32a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a32a4_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_a32a4_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_a32a4_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_a32a4_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_a32a4_level0_col4" class="col_heading level0 col4" >start</th>
#       <th id="T_a32a4_level0_col5" class="col_heading level0 col5" >fitted</th>
#       <th id="T_a32a4_level0_col6" class="col_heading level0 col6" >uncertainty</th>
#       <th id="T_a32a4_level0_col7" class="col_heading level0 col7" >units</th>
#       <th id="T_a32a4_level0_col8" class="col_heading level0 col8" >change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a32a4_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a32a4_row0_col0" class="data row0 col0" >nacl</td>
#       <td id="T_a32a4_row0_col1" class="data row0 col1" >cell</td>
#       <td id="T_a32a4_row0_col2" class="data row0 col2" ></td>
#       <td id="T_a32a4_row0_col3" class="data row0 col3" >length_a</td>
#       <td id="T_a32a4_row0_col4" class="data row0 col4" >5.6200</td>
#       <td id="T_a32a4_row0_col5" class="data row0 col5" >5.6018</td>
#       <td id="T_a32a4_row0_col6" class="data row0 col6" >N/A</td>
#       <td id="T_a32a4_row0_col7" class="data row0 col7" >Å</td>
#       <td id="T_a32a4_row0_col8" class="data row0 col8" >0.32 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_a32a4_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a32a4_row1_col0" class="data row1 col0" >nacl</td>
#       <td id="T_a32a4_row1_col1" class="data row1 col1" >atom_site</td>
#       <td id="T_a32a4_row1_col2" class="data row1 col2" >Na</td>
#       <td id="T_a32a4_row1_col3" class="data row1 col3" >adp_iso</td>
#       <td id="T_a32a4_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_a32a4_row1_col5" class="data row1 col5" >1.1056</td>
#       <td id="T_a32a4_row1_col6" class="data row1 col6" >N/A</td>
#       <td id="T_a32a4_row1_col7" class="data row1 col7" >Å²</td>
#       <td id="T_a32a4_row1_col8" class="data row1 col8" >10.56 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_a32a4_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a32a4_row2_col0" class="data row2 col0" >nacl</td>
#       <td id="T_a32a4_row2_col1" class="data row2 col1" >atom_site</td>
#       <td id="T_a32a4_row2_col2" class="data row2 col2" >Cl</td>
#       <td id="T_a32a4_row2_col3" class="data row2 col3" >adp_iso</td>
#       <td id="T_a32a4_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_a32a4_row2_col5" class="data row2 col5" >0.5706</td>
#       <td id="T_a32a4_row2_col6" class="data row2 col6" >N/A</td>
#       <td id="T_a32a4_row2_col7" class="data row2 col7" >Å²</td>
#       <td id="T_a32a4_row2_col8" class="data row2 col8" >42.94 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_a32a4_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a32a4_row3_col0" class="data row3 col0" >xray_pdf</td>
#       <td id="T_a32a4_row3_col1" class="data row3 col1" >linked_phases</td>
#       <td id="T_a32a4_row3_col2" class="data row3 col2" >nacl</td>
#       <td id="T_a32a4_row3_col3" class="data row3 col3" >scale</td>
#       <td id="T_a32a4_row3_col4" class="data row3 col4" >0.5000</td>
#       <td id="T_a32a4_row3_col5" class="data row3 col5" >0.4254</td>
#       <td id="T_a32a4_row3_col6" class="data row3 col6" >N/A</td>
#       <td id="T_a32a4_row3_col7" class="data row3 col7" ></td>
#       <td id="T_a32a4_row3_col8" class="data row3 col8" >14.93 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_a32a4_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_a32a4_row4_col0" class="data row4 col0" >xray_pdf</td>
#       <td id="T_a32a4_row4_col1" class="data row4 col1" >peak</td>
#       <td id="T_a32a4_row4_col2" class="data row4 col2" ></td>
#       <td id="T_a32a4_row4_col3" class="data row4 col3" >damp_q</td>
#       <td id="T_a32a4_row4_col4" class="data row4 col4" >0.0300</td>
#       <td id="T_a32a4_row4_col5" class="data row4 col5" >0.0606</td>
#       <td id="T_a32a4_row4_col6" class="data row4 col6" >N/A</td>
#       <td id="T_a32a4_row4_col7" class="data row4 col7" >Å⁻¹</td>
#       <td id="T_a32a4_row4_col8" class="data row4 col8" >102.13 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_a32a4_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_a32a4_row5_col0" class="data row5 col0" >xray_pdf</td>
#       <td id="T_a32a4_row5_col1" class="data row5 col1" >peak</td>
#       <td id="T_a32a4_row5_col2" class="data row5 col2" ></td>
#       <td id="T_a32a4_row5_col3" class="data row5 col3" >sharp_delta_2</td>
#       <td id="T_a32a4_row5_col4" class="data row5 col4" >5.0000</td>
#       <td id="T_a32a4_row5_col5" class="data row5 col5" >3.5046</td>
#       <td id="T_a32a4_row5_col6" class="data row5 col6" >N/A</td>
#       <td id="T_a32a4_row5_col7" class="data row5 col7" >Å²</td>
#       <td id="T_a32a4_row5_col8" class="data row5 col8" >29.91 % ↓</td>
#     </tr>
#   </tbody>
# </table>
# ⚠️ Correlation matrix is unavailable for this fit. Use the lmfit minimizer and ensure covariance estimation succeeds.

# %% [markdown]
# ## Plot Measured vs Calculated

# %%
project.plotter.plot_meas_vs_calc(expt_name='xray_pdf')
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="faf35bf0-2ebb-49fd-89a6-e119eb71c367" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("faf35bf0-2ebb-49fd-89a6-e119eb71c367")) {                    Plotly.newPlot(                        "faf35bf0-2ebb-49fd-89a6-e119eb71c367",                        [{"line":{"color":"rgb(31, 119, 180)"},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"\u002fC9ShcjwJApHA9CtejAkC4HoXrUbgCQM3MzMzMzAJA4XoUrkfhAkD2KFyPwvUCQArXo3A9CgNAH4XrUbgeA0AzMzMzMzMDQEjhehSuRwNAXI\u002fC9ShcA0BxPQrXo3ADQIXrUbgehQNAmpmZmZmZA0CuR+F6FK4DQMP1KFyPwgNA