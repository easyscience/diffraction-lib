# %%
# Check whether easydiffraction is installed; install it if needed.
# Required for remote environments such as Google Colab.
import importlib.util

if importlib.util.find_spec('easydiffraction') is None:
    # %pip install easydiffraction

# %% [markdown]
# # Fitting Powder Diffraction data
#
# This notebook guides you through the Rietveld refinement of crystal
# structures using simulated powder diffraction data. It consists of two
# parts:
# - Introduction: A simple reference fit using silicon (Si) crystal
#   structure.
# - Exercise: A more complex fit using La₀.₅Ba₀.₅CoO₃ (LBCO) crystal
#   structure.
#
# ## 🛠️ Import Library
#
# We start by importing the necessary library for the analysis. In this
# notebook, we use the EasyDiffraction library. As mentioned in the
# introduction to EasyScience, EasyDiffraction is built on that
# framework and offers a high-level interface focused specifically for
# diffraction analysis.
#
# This notebook is self-contained and designed for hands-on learning.
# However, if you're interested in exploring more advanced features or
# learning about additional capabilities of the EasyDiffraction library,
# please refer to the official documentation:
# https://docs.easydiffraction.org/lib
#
# Depending on your requirements, you may choose to import only specific
# classes. However, for the sake of simplicity in this notebook, we will
# import the entire library.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/first-steps/#importing-easydiffraction)
# for more details about importing the EasyDiffraction library and its
# components.

# %%
import easydiffraction as ed

# %% [markdown]
# ## 📘 Introduction: Simple Reference Fit – Si
#
# Before diving into the more complex fitting exercise with the
# La₀.₅Ba₀.₅CoO₃ (LBCO) crystal structure, let's start with a simpler
# example using the silicon (Si) crystal structure. This will help us
# understand the basic concepts and steps involved in fitting a crystal
# structure using powder diffraction data.
#
# For this part of the notebook, we will use the powder diffraction data
# previously simulated using the Si crystal structure.
#
# ### 📦 Create a Project – 'reference'
#
# In EasyDiffraction, a project serves as a container for all
# information related to the analysis of a specific experiment or set of
# experiments. It enables you to organize your data, experiments,
# crystal structures, and fitting parameters in an organized manner. You
# can think of it as a folder containing all the essential details about
# your analysis. The project also allows us to visualize both the
# measured and calculated diffraction patterns, among other things.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/project/)
# for more details about creating a project and its purpose in the
# analysis workflow.

# %%
project_1 = ed.Project(name='reference')

# %% [markdown]
# You can set the title and description of the project to provide
# context and information about the analysis being performed. This is
# useful for documentation purposes and helps others (or yourself in the
# future) understand the purpose of the project at a glance.

# %%
project_1.info.title = 'Reference Silicon Fit'
project_1.info.description = 'Fitting simulated powder diffraction pattern of Si.'

# %% [markdown]
# ### 🔬 Create an Experiment
#
# An experiment represents a specific diffraction measurement performed
# on a specific sample using a particular instrument. It contains
# details about the measured data, instrument parameters, and other
# relevant information.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/experiment/)
# for more details about experiments and their purpose in the analysis
# workflow.

# %%
data_dir = 'data'
file_name = 'reduced_Si.xye'
si_xye_path = f'{data_dir}/{file_name}'

# %% [markdown]
# Uncomment the following cell if your data reduction failed and the
# reduced data file is missing. In this case, you can download our
# pre-generated reduced data file from the EasyDiffraction repository.
# The `download_data` function will not overwrite an existing file
# unless you set `overwrite=True`, so it's safe to run even if the
# file is already present.

# %%
si_xye_path = ed.download_data(id=17, destination=data_dir)
# Out:
# Getting data...
# Data #17: Si, McStas simulation, DMSC Summer School 2025
# ✅ Data #17 downloaded to 'data/ed-17.xye'

# %% [markdown]
# Now we can create the experiment and load the measured data. In this
# case, the experiment is defined as a powder diffraction measurement
# using time-of-flight neutrons. The measured data is loaded from a file
# containing the reduced diffraction pattern of Si from the data
# reduction notebook.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/experiment/#defining-an-experiment-manually)
# for more details about different types of experiments.

# %%
project_1.experiments.add_from_data_path(
    name='sim_si',
    data_path=si_xye_path,
    sample_form='powder',
    beam_mode='time-of-flight',
    radiation_probe='neutron',
)
# Out:
# Data loaded successfully
# Experiment 🔬 'sim_si'. Number of data points: 900.

# %% [markdown]
# #### Inspect Measured Data
#
# After creating the experiment, we can examine the measured data. The
# measured data consists of a diffraction pattern having time-of-flight
# (TOF) values and corresponding intensities. The TOF values are given
# in microseconds (μs), and the intensities are in arbitrary units.
#
# The data is stored in XYE format, a simple text format containing
# three columns: TOF, intensity, and intensity error (if available).

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/experiment/#measured-data-category)
# for more details about the measured data and its format.
#
# To visualize the measured data, we can use the `plot_meas` method of
# the project.

# %%
project_1.display.plotter.plot_meas(expt_name='sim_si')
# Out:
# Warning: No linked phases defined. Returning empty pattern.
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="2ec75815-5866-43e3-a393-5215b2719340" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2ec75815-5866-43e3-a393-5215b2719340")) {                    Plotly.newPlot(                        "2ec75815-5866-43e3-a393-5215b2719340",                        [{"hovertemplate":"Measured (Imeas)\u003cbr\u003ex: %{x}\u003cbr\u003ey: %{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendrank":10,"line":{"color":"rgb(31, 119, 180)","width":2.0},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"7zhFRzII5UBCYOXQjhflQJSHhVrrJuVA5q4l5Ec25UA51sVtpEXlQHRGlPYAVeVAxm00gF1k5UAYldQJunPlQGq8dJMWg+VAveMUHXOS5UAPC7Wmz6HlQGEyVTAsseVAnKIjuYjA5UDvycNC5c\u002flQEHxY8xB3+VAkxgEVp7u5UDmP6Tf+v3lQDhnRGlXDeZAio7k8rMc5kDdtYR8ECzmQBgmUwVtO+ZAak3zjslK5kC8dJMYJlrmQA+cM6KCaeZAYcPTK9945kCz6nO1O4jmQAYSFD+Yl+ZAQYLix\u002fSm5kCTqYJRUbbmQOXQItutxeZAOPjCZArV5kCKH2PuZuTmQNxGA3jD8+ZAL26jASAD50CBlUOLfBLnQLwFEhTZIedADi2ynTUx50BhVFInkkDnQLN78rDuT+dABaOSOktf50BYyjLEp27nQKrx0k0EfudA5WGh1mCN50A3iUFgvZznQIqw4ekZrOdA3NeBc3a750Au\u002fyH90srnQIEmwoYv2udA001iEIzp50AldQKa6PjnQGDl0CJFCOhAswxxrKEX6EAFNBE2\u002fiboQFdbsb9aNuhAqoJRSbdF6ED8qfHSE1XoQE7RkVxwZOhAiUFg5cxz6EDcaABvKYPoQC6QoPiFkuhAgLdAguKh6EDT3uALP7HoQCUGgZWbwOhAdy0hH\u002fjP6EDKVMGoVN\u002foQAXFjzGx7uhAV+wvuw3+6ECpE9BEag3pQPs6cM7GHOlATmIQWCMs6UCgibDhfzvpQPKwUGvcSulALSEf9Dha6UCASL99lWnpQNJvXwfyeOlAJJf\u002fkE6I6UB3vp8aq5fpQMnlP6QHp+lAGw3gLWS26UBuNIC3wMXpQKmkTkAd1elA+8vuyXnk6UBN845T1vPpQKAaL90yA+pA8kHPZo8S6kBEaW\u002fw6yHqQJeQD3pIMepA0gDeAqVA6kAkKH6MAVDqQHZPHhZeX+pAyXa+n7pu6kAbnl4pF37qQG3F\u002frJzjepAwOyePNCc6kASFD\u002fGLKzqQE2EDU+Ju+pAn6ut2OXK6kDy0k1iQtrqQ
# %% [markdown]
# If you zoom in on the highest TOF peak (around 120,000 μs), you will
# notice that it has a broad and unusual shape. This distortion, along
# with additional effects on the low TOF peaks, is most likely an
# artifact related to the simplifications made during the simulation
# and/or reduction process and is currently under investigation.
# However, this is outside the scope of this school. Therefore, we will
# simply exclude both the low and high TOF regions from the analysis by
# adding an excluded regions to the experiment.
#
# In real experiments, it is often necessary to exclude certain regions
# from the measured data. For example, the direct beam can significantly
# increase the background at very low angles, making those parts of the
# diffractogram unreliable. Additionally, sample environment components
# may introduce unwanted peaks. In such cases, excluding specific
# regions is often simpler and more effective than modeling them with an
# additional sample phase.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/experiment/#excluded-regions-category)
# for more details about excluding regions from the measured data.

# %%
project_1.experiments['sim_si'].excluded_regions.create(id='1', start=0, end=55000)
project_1.experiments['sim_si'].excluded_regions.create(id='2', start=105500, end=200000)

# %% [markdown]
# To visualize the effect of excluding the high TOF region, we can plot
# the measured data again. The excluded region will be omitted from the
# plot and is not used in the fitting process.

# %%
project_1.display.plotter.plot_meas(expt_name='sim_si')
# Out:
# Warning: No linked phases defined. Returning empty pattern.
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="bbe465f7-8e4e-445e-a756-1b965d6e5f93" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bbe465f7-8e4e-445e-a756-1b965d6e5f93")) {                    Plotly.newPlot(                        "bbe465f7-8e4e-445e-a756-1b965d6e5f93",                        [{"hovertemplate":"Measured (Imeas)\u003cbr\u003ex: %{x}\u003cbr\u003ey: %{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendrank":10,"line":{"color":"rgb(31, 119, 180)","width":2.0},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"RPrt657p6kCWIY51+\u002fjqQOlILv9XCOtAO3DOiLQX60B24JwRESfrQMgHPZttNutAGy\u002fdJMpF60BtVn2uJlXrQL99HTiDZOtAEqW9wd9z60BkzF1LPIPrQLbz\u002fdSYkutA8WPMXfWh60BEi2znUbHrQJayDHGuwOtA6Nms+grQ60A7AU2EZ9\u002frQI0o7Q3E7utA30+NlyD+60AawFsgfQ3sQG3n+6nZHOxAvw6cMzYs7EARNjy9kjvsQGRd3EbvSuxAtoR80Eta7EAIrBxaqGnsQFvTvOMEeexAlkOLbGGI7EDoaiv2vZfsQDqSy38ap+xAjLlrCXe27EDf4AuT08XsQDEIrBww1exAgy9Mpozk7EC+nxov6fPsQBHHurhFA+1AY+5aQqIS7UC1FfvL\u002fiHtQAg9m1VbMe1AWmQ737dA7UCsi9toFFDtQOf7qfFwX+1AOiNKe81u7UCMSuoEKn7tQN5xio6Gje1AMZkqGOOc7UCDwMqhP6ztQNXnaiucu+1AKA8LtfjK7UBjf9k9VdrtQLWmecex6e1AB84ZUQ757UBa9bnaagjuQKwcWmTHF+5A\u002fkP67SMn7kBRa5p3gDbuQIzbaADdRe5A3gIJijlV7kAwKqkTlmTuQINRSZ3yc+5A1XjpJk+D7kAnoImwq5LuQHrHKToIou5AzO7Jw2Sx7kAHX5hMwcDuQFmGONYd0O5ArK3YX3rf7kD+1Hjp1u7uQFD8GHMz\u002fu5AoyO5\u002fI8N70D1SlmG7BzvQDC7Jw9JLO9AguLHmKU770DVCWgiAkvvQCcx
cRgM2\u002f\u002fNAB\u002fAWSOQG9ECwA+eMkg70QM07TtFAFvRAdk8eFu8d9EAgY+5anSX0QMl2vp9LLfRAcoqO5Pk09EAbnl4pqDz0QMSxLm5WRPRA4umVsgRM9ECL\u002fWX3slP0QDQRNjxhW\u002fRA3SQGgQ9j9ECGONbFvWr0QDBMpgpscvRA2V92Txp69ECCc0aUyIH0QJ+rrdh2ifRASL99HSWR9EDy0k1i05j0QJvmHaeBoPRARPrt6y+o9EDtDb4w3q\u002f0QJYhjnWMt\u002fRAtFn1uTq\u002f9EBdbcX+6Mb0QAaBlUOXzvRAr5RliEXW9EBYqDXN8930QAK8BRKi5fRAq8\u002fVVlDt9EBU46Wb\u002fvT0QHEbDeCs\u002fPRAGy\u002fdJFsE9UDEQq1pCQz1QG1Wfa63E\u002fVAFmpN82Ub9UC\u002ffR04FCP1QGiR7XzCKvVAhslUwXAy9UAv3SQGHzr1QNjw9ErNQfVAgQTFj3tJ9UArGJXUKVH1QNQrZRnYWPVAfT81XoZg9UAmUwWjNGj1QESLbOfib\u002fVA7Z48LJF39UCWsgx ...

# %% [markdown]
# #### Set Instrument Parameters
#
# After the experiment is created and measured data is loaded, we need
# to set the instrument parameters.
#
# In this type of experiment, the instrument parameters define how the
# measured data is converted between d-spacing and time-of-flight (TOF)
# during the data reduction process as well as the angular position of
# the detector. So, we put values based on those from the reduction.
# These values can be found in the header of the corresponding .XYE
# file. Their names are `two_theta` and `DIFC`, which stand for the
# two-theta angle and the linear conversion factor from d-spacing to
# TOF, respectively.
#
# You can set them manually, but it is more convenient to use the
# `extract_metadata` function from the EasyDiffraction library.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/experiment/#instrument-category)
# for more details about the instrument parameters.

# %%
project_1.experiments['sim_si'].instrument.setup_twotheta_bank = ed.extract_metadata(
    si_xye_path, r'two_theta\s*=\s*(\d*\.?\d+)'
)
project_1.experiments['sim_si'].instrument.calib_d_to_tof_linear = ed.extract_metadata(
    si_xye_path, r'DIFC\s*=\s*(\d*\.?\d+)'
)

# %% [markdown]
# Before proceeding, let's take a quick look at the concept of
# parameters in EasyDiffraction, which is similar to the parameter
# concept in EasyScience. The current version of EasyDiffraction is
# transitioning to reuse the parameter system from EasyScience.
#
# That is, every parameter is an object, which has different attributes,
# such as `value`, `units`, etc. To display the parameter of interest,
# you can simply print the parameter object.
#
# For example, to display the linear conversion factor from d-spacing to
# TOF, which is the `calib_d_to_tof_linear` parameter, you can do the
# following:

# %%
print(project_1.experiments['sim_si'].instrument.calib_d_to_tof_linear)
# Out:
# <sim_si.instrument.d_to_tof_linear = 61445.893309194034 μs/Å (free=False)>

# %% [markdown]
# The `value` attribute represents the current value of the parameter as
# a float. You can access it directly by using the `value` attribute of
# the parameter. This is useful when you want to use the parameter value
# in calculations or when you want to assign it to another parameter.
# For example, to get only the value of the same parameter as floating
# point number, but not the whole object, you can do the following:

# %%
print(project_1.experiments['sim_si'].instrument.calib_d_to_tof_linear.value)
# Out:
# 61445.893309194034

# %% [markdown]
# Note that to set the value of the parameter, you can simply assign a
# new value to the parameter object without using the `value` attribute,
# as we did above.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/parameters/)
# for more details about parameters in EasyDiffraction and their
# attributes.

# %% [markdown]
# #### Set Peak Profile Parameters
#
# The next set of parameters is needed to define the peak profile used
# in the fitting process. The peak profile describes the shape of the
# diffraction peaks.
#
# Several peak profile functions are commonly used:
# - **Gaussian**: A symmetric bell-shaped peak profile. It is often used
#   when instrumental broadening is dominant. [Click for more
#   details.](https://mantidproject.github.io/docs-versioned/v6.1.0/fitting/fitfunctions/Gaussian.html)
# - **Lorentzian**: A symmetric peak profile with a sharper centre and
#   longer tails than a Gaussian. It is often used to describe size
#   broadening effects. [Click for more
#   details.](https://mantidproject.github.io/docs-versioned/v6.1.0/fitting/fitfunctions/Lorentzian.html)
# - **Pseudo-Voigt**: A linear combination of Gaussian and Lorentzian
#   components. It provides a flexible approximation for many real
#   diffraction peak shapes. [Click for more
#   details.](https://mantidproject.github.io/docs-versioned/v6.1.0/fitting/fitfunctions/PseudoVoigt.html)
# - **Jorgensen**: A convolution of back-to-back exponentials with a
#   Gaussian. This profile can describe asymmetric TOF peak shapes.
#   [Click for more details.](
#   https://docs.mantidproject.org/nightly/fitting/fitfunctions/BackToBackExponential.html)
# - **Jorgensen–Von Dreele**: A convolution of back-to-back exponentials
#   with a pseudo-Voigt function. This extends the Jorgensen profile by
#   allowing a more flexible symmetric peak component.
#   [Click for more details.](https://docs.mantidproject.org/nightly/fitting/fitfunctions/BackToBackExponential.html)
# - **Ikeda–Carpenter pseudo-Voigt**: A convolution of the
#   Ikeda–Carpenter function with a pseudo-Voigt function. It includes
#   asymmetry caused by the neutron pulse shape and is commonly used for
#   TOF neutron powder diffraction data. [Click for more
#   details.](https://docs.mantidproject.org/v6.1.0/fitting/fitfunctions/IkedaCarpenterPV.html)
#
# In TOF neutron powder diffraction, peak profiles are usually built by
# combining a symmetric peak-shape function, such as a Gaussian,
# Lorentzian, or pseudo-Voigt, with an asymmetric component, such as a
# back-to-back exponential or Ikeda–Carpenter function. This combination
# gives a more realistic description of TOF peak shapes, which are often
# asymmetric because of the neutron pulse shape and instrumental effects.
#
# Here, we use a simple Jorgensen peak profile.
#
# The parameter values are typically determined experimentally on the
# same instrument and under the same configuration as the data being
# analyzed, using measurements of a standard sample. In our case, the Si
# sample serves as this standard reference. We will refine the peak
# profile parameters here, and these refined values will be used as
# starting points for the more complex fit in the next part of the
# notebook. For this initial fit, we will provide reasonable physical
# guesses as starting values.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/experiment/#peak-category)
# for more details about the peak profile types.

# %%
project_1.experiments['sim_si'].show_peak_profile_types()
# Out:
# Peak profile types
# <style type="text/css">
# #T_42a5e   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_42a5e thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_42a5e th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_42a5e  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_42a5e th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_42a5e tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_42a5e  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_42a5e th.col0 {
#   text-align: left;
# }
# #T_42a5e th.col1 {
#   text-align: left;
# }
# #T_42a5e th.col2 {
#   text-align: left;
# }
# #T_42a5e_row0_col0, #T_42a5e_row0_col1, #T_42a5e_row0_col2, #T_42a5e_row1_col0, #T_42a5e_row1_col1, #T_42a5e_row1_col2, #T_42a5e_row2_col0, #T_42a5e_row2_col1, #T_42a5e_row2_col2, #T_42a5e_row3_col0, #T_42a5e_row3_col1, #T_42a5e_row3_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_42a5e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42a5e_level0_col0" class="col_heading level0 col0" ></th>
#       <th id="T_42a5e_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_42a5e_level0_col2" class="col_heading level0 col2" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42a5e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_42a5e_row0_col0" class="data row0 col0" ></td>
#       <td id="T_42a5e_row0_col1" class="data row0 col1" >pseudo-voigt</td>
#       <td id="T_42a5e_row0_col2" class="data row0 col2" >TOF non-convoluted pseudo-Voigt profile</td>
#     </tr>
#     <tr>
#       <th id="T_42a5e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_42a5e_row1_col0" class="data row1 col0" >*</td>
#       <td id="T_42a5e_row1_col1" class="data row1 col1" >jorgensen</td>
#       <td id="T_42a5e_row1_col2" class="data row1 col2" >TOF Jorgensen profile: back-to-back exponentials ⊗ Gaussian</td>
#     </tr>
#     <tr>
#       <th id="T_42a5e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_42a5e_row2_col0" class="data row2 col0" ></td>
#       <td id="T_42a5e_row2_col1" class="data row2 col1" >jorgensen-von-dreele</td>
#       <td id="T_42a5e_row2_col2" class="data row2 col2" >TOF Jorgensen-Von Dreele profile: back-to-back exponentials ⊗ pseudo-Voigt</td>
#     </tr>
#     <tr>
#       <th id="T_42a5e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_42a5e_row3_col0" class="data row3 col0" ></td>
#       <td id="T_42a5e_row3_col1" class="data row3 col1" >double-jorgensen-von-dreele</td>
#       <td id="T_42a5e_row3_col2" class="data row3 col2" >TOF Double-Jorgensen-Von Dreele profile: double back-to-back exponentials ⊗ pseudo-Voigt (Z-Rietveld type0m)</td>
#     </tr>
#   </tbody>
# </table>

# %%
project_1.experiments['sim_si'].peak.broad_gauss_sigma_0 = 69498
project_1.experiments['sim_si'].peak.broad_gauss_sigma_1 = -55578
project_1.experiments['sim_si'].peak.broad_gauss_sigma_2 = 14560
project_1.experiments['sim_si'].peak.exp_decay_beta_0 = 0.0019
project_1.experiments['sim_si'].peak.exp_decay_beta_1 = 0.0137
project_1.experiments['sim_si'].peak.exp_rise_alpha_0 = -0.0055
project_1.experiments['sim_si'].peak.exp_rise_alpha_1 = 0.0147

# %% [markdown]
# #### Set Background
#
# The background of the diffraction pattern represents the portion of
# the pattern that is not related to the crystal structure of the
# sample. It's rather represents noise and other sources of scattering
# that can affect the measured intensities. This includes contributions
# from the instrument, the sample holder, the sample environment, and
# other sources of incoherent scattering.
#
# The background can be modeled in various ways. In this example, we
# will use a simple line segment background, which is a common approach
# for powder diffraction data. The background intensity at any point is
# defined by linear interpolation between neighboring points. The
# background points are selected to span the range of the diffraction
# pattern while avoiding the peaks.
#
# We will add several background points at specific TOF values (in μs)
# and corresponding intensity values. These points are chosen to
# represent the background level in the diffraction pattern free from
# any peaks.
#
# The background points are added using the `add` method of the
# `background` object. The `x` parameter represents the TOF value, and
# the `y` parameter represents the intensity value at that TOF.
#
# Let's set all the background points at a constant value of 0.01, which
# can be roughly estimated by the eye, and we will refine them later
# during the fitting process.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/experiment/#background-category)
# for more details about the background and its types.

# %%
project_1.experiments['sim_si'].show_background_types()
# Out:
# Background types
# <style type="text/css">
# #T_85e02   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_85e02 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_85e02 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_85e02  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_85e02 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_85e02 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_85e02  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_85e02 th.col0 {
#   text-align: left;
# }
# #T_85e02 th.col1 {
#   text-align: left;
# }
# #T_85e02 th.col2 {
#   text-align: left;
# }
# #T_85e02_row0_col0, #T_85e02_row0_col1, #T_85e02_row0_col2, #T_85e02_row1_col0, #T_85e02_row1_col1, #T_85e02_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_85e02" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85e02_level0_col0" class="col_heading level0 col0" ></th>
#       <th id="T_85e02_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_85e02_level0_col2" class="col_heading level0 col2" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85e02_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_85e02_row0_col0" class="data row0 col0" ></td>
#       <td id="T_85e02_row0_col1" class="data row0 col1" >chebyshev</td>
#       <td id="T_85e02_row0_col2" class="data row0 col2" >Chebyshev polynomial background</td>
#     </tr>
#     <tr>
#       <th id="T_85e02_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_85e02_row1_col0" class="data row1 col0" >*</td>
#       <td id="T_85e02_row1_col1" class="data row1 col1" >line-segment</td>
#       <td id="T_85e02_row1_col2" class="data row1 col2" >Linear interpolation between points</td>
#     </tr>
#   </tbody>
# </table>

# %%
project_1.experiments['sim_si'].background_type = 'line-segment'
project_1.experiments['sim_si'].background.create(id='1', x=50000, y=0.01)
project_1.experiments['sim_si'].background.create(id='2', x=60000, y=0.01)
project_1.experiments['sim_si'].background.create(id='3', x=70000, y=0.01)
project_1.experiments['sim_si'].background.create(id='4', x=80000, y=0.01)
project_1.experiments['sim_si'].background.create(id='5', x=90000, y=0.01)
project_1.experiments['sim_si'].background.create(id='6', x=100000, y=0.01)
project_1.experiments['sim_si'].background.create(id='7', x=110000, y=0.01)
# Out:
# Background type for experiment 'sim_si' already set to
# line-segment

# %% [markdown]
# ### 🧩 Create a Structure – Si
#
# After setting up the experiment, we need to create a structure that
# describes the crystal structure of the sample being analyzed.
#
# In this case, we will create a structure for silicon (Si) with a
# cubic crystal structure. The structure contains information about
# the space group, lattice parameters, atomic positions of the atoms in
# the unit cell, atom types, occupancies and atomic displacement
# parameters. The structure is essential for the fitting process, as
# it is used to calculate the expected diffraction pattern.
#
# EasyDiffraction refines the crystal structure of the sample, but does
# not solve it. Therefore, we need a good starting point with reasonable
# structural parameters.
#
# Here, we define the Si structure as a cubic structure. As this is a
# cubic structure, we only need to define the single lattice parameter,
# which is the length of the unit cell edge. The Si crystal structure
# has a single atom in the unit cell, which is located at the origin (0,
# 0, 0) of the unit cell. The symmetry of this site is defined by the
# Wyckoff letter 'a'. The atomic displacement parameter defines the
# thermal vibrations of the atoms in the unit cell and is presented as
# an isotropic parameter (B_iso).
#
# Sometimes, the initial crystal structure parameters can be obtained
# from one of the crystallographic databases, like for example the
# Crystallography Open Database (COD). In this case, we use the COD
# entry for silicon as a reference for the initial crystal structure
# model: https://www.crystallography.net/cod/4507226.html
#
# Usually, the crystal structure parameters are provided in a CIF file
# format, which is a standard format for crystallographic data. An
# example of a CIF file for silicon is shown below. The CIF file
# contains the space group information, unit cell parameters, and atomic
# positions.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/data-format/)
# for more details about the CIF format and its use in EasyDiffraction.

# %% [markdown]
# ```
# data_si
#
# _space_group.name_H-M_alt  "F d -3 m"
# _space_group.IT_coordinate_system_code  2
#
# _cell.length_a      5.43
# _cell.length_b      5.43
# _cell.length_c      5.43
# _cell.angle_alpha  90.0
# _cell.angle_beta   90.0
# _cell.angle_gamma  90.0
#
# loop_
# _atom_site.label
# _atom_site.type_symbol
# _atom_site.fract_x
# _atom_site.fract_y
# _atom_site.fract_z
# _atom_site.wyckoff_letter
# _atom_site.occupancy
# _atom_site.ADP_type
# _atom_site.B_iso_or_equiv
# Si Si   0 0 0   a  1.0   Biso 0.89
# ```

# %% [markdown]
# As with adding the experiment in the previous step, we will create a
# default structure and then modify its parameters to match the Si
# structure.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/structure/)
# for more details about structures and their purpose in the data
# analysis workflow.

# %% [markdown]
# #### Add Structure

# %%
project_1.structures.create(name='si')

# %% [markdown]
# #### Set Space Group

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/structure/#space-group-category)
# for more details about the space group.

# %%
project_1.structures['si'].space_group.name_h_m = 'F d -3 m'
project_1.structures['si'].space_group.it_coordinate_system_code = '2'

# %% [markdown]
# #### Set Lattice Parameters

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/structure/#cell-category)
# for more details about the unit cell parameters.

# %%
project_1.structures['si'].cell.length_a = 5.43

# %% [markdown]
# #### Set Atom Sites

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/structure/#atom-sites-category)
# for more details about the atom sites category.

# %%
project_1.structures['si'].atom_sites.create(
    label='Si',
    type_symbol='Si',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    adp_iso=0.89,
)

# %% [markdown]
# ### 🔗 Assign Structure to Experiment
#
# Now we need to assign, or link, this structure to the experiment
# created above. This linked crystallographic phase will be used to
# calculate the expected diffraction pattern based on the crystal
# structure defined in the structure.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/experiment/#linked-phases-category)
# for more details about linking a structure to an experiment.

# %%
project_1.experiments['sim_si'].linked_phases.create(id='si', scale=1.0)

# %% [markdown]
# ### 🚀 Analyze and Fit the Data
#
# After setting up the experiment and structure, we can now analyze
# the measured diffraction pattern and perform the fit. Building on the
# analogies from the EasyScience library and the previous notebooks, we
# can say that all the parameters we introduced earlier — those defining
# the structure (crystal structure parameters) and the experiment
# (instrument, background, and peak profile parameters) — together form
# the complete set of parameters that can be refined during the fitting
# process.
#
# Unlike in the previous analysis notebooks, we will not create a
# **math_model** object here. The mathematical model used to calculate
# the expected diffraction pattern is already defined in the library and
# will be applied automatically during the fitting process.

# %% [markdown]
# The fitting process involves comparing the measured diffraction
# pattern with the calculated diffraction pattern based on the crystal
# structure and instrument parameters. The goal is to adjust the
# parameters of the structure and the experiment to minimize the
# difference between the measured and calculated diffraction patterns.
# This is done by refining the parameters of the structure and the
# instrument settings to achieve a better fit.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/analysis/#minimization-optimization)
# for more details about the fitting process in EasyDiffraction.

# %% [markdown]
# #### Set Fit Parameters
#
# To perform the fit, we need to specify the refinement parameters.
# These are the parameters that will be adjusted during the fitting
# process to minimize the difference between the measured and calculated
# diffraction patterns. This is done by setting the `free` attribute of
# the corresponding parameters to `True`.
#
# Note: setting `param.free = True` is equivalent to using `param.fixed
# = False` in the EasyScience library.
#
# We will refine the scale factor of the Si phase, the intensities of
# the background points as well as the peak profile parameters. The
# structure parameters of the Si phase will not be refined, as this
# sample is considered a reference sample with known parameters.

# %%
project_1.experiments['sim_si'].linked_phases['si'].scale.free = True

for line_segment in project_1.experiments['sim_si'].background:
    line_segment.y.free = True

project_1.experiments['sim_si'].peak.broad_gauss_sigma_0.free = True
project_1.experiments['sim_si'].peak.broad_gauss_sigma_1.free = True
project_1.experiments['sim_si'].peak.broad_gauss_sigma_2.free = True
project_1.experiments['sim_si'].peak.exp_decay_beta_0.free = True
project_1.experiments['sim_si'].peak.exp_decay_beta_1.free = True
project_1.experiments['sim_si'].peak.exp_rise_alpha_0.free = True
project_1.experiments['sim_si'].peak.exp_rise_alpha_1.free = True

# %% [markdown]
# #### Show Free Parameters
#
# We can check which parameters are free to be refined by calling the
# `free_params` method of the `analysis.display` object of the project.

# %% [markdown]
# 📖 See
# [documentation](https://easyscience.github.io/diffraction-lib/user-guide/first-steps/#available-parameters)
# for more details on how to
# - show all parameters of the project,
# - show all fittable parameters, and
# - show only free parameters of the project.

# %%
project_1.analysis.display.free_params()
# Out:
# Free parameters for both structures (🧩 data blocks) and experiments (🔬 data blocks)
# <style type="text/css">
# #T_3abf7   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_3abf7 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_3abf7 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_3abf7  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_3abf7 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_3abf7 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_3abf7  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_3abf7 th.col0 {
#   text-align: left;
# }
# #T_3abf7 th.col1 {
#   text-align: left;
# }
# #T_3abf7 th.col2 {
#   text-align: left;
# }
# #T_3abf7 th.col3 {
#   text-align: left;
# }
# #T_3abf7 th.col4 {
#   text-align: right;
# }
# #T_3abf7 th.col5 {
#   text-align: right;
# }
# #T_3abf7 th.col6 {
#   text-align: right;
# }
# #T_3abf7 th.col7 {
#   text-align: right;
# }
# #T_3abf7 th.col8 {
#   text-align: left;
# }
# #T_3abf7_row0_col0, #T_3abf7_row0_col1, #T_3abf7_row0_col2, #T_3abf7_row0_col3, #T_3abf7_row0_col8, #T_3abf7_row1_col0, #T_3abf7_row1_col1, #T_3abf7_row1_col2, #T_3abf7_row1_col3, #T_3abf7_row1_col8, #T_3abf7_row2_col0, #T_3abf7_row2_col1, #T_3abf7_row2_col2, #T_3abf7_row2_col3, #T_3abf7_row2_col8, #T_3abf7_row3_col0, #T_3abf7_row3_col1, #T_3abf7_row3_col2, #T_3abf7_row3_col3, #T_3abf7_row3_col8, #T_3abf7_row4_col0, #T_3abf7_row4_col1, #T_3abf7_row4_col2, #T_3abf7_row4_col3, #T_3abf7_row4_col8, #T_3abf7_row5_col0, #T_3abf7_row5_col1, #T_3abf7_row5_col2, #T_3abf7_row5_col3, #T_3abf7_row5_col8, #T_3abf7_row6_col0, #T_3abf7_row6_col1, #T_3abf7_row6_col2, #T_3abf7_row6_col3, #T_3abf7_row6_col8, #T_3abf7_row7_col0, #T_3abf7_row7_col1, #T_3abf7_row7_col2, #T_3abf7_row7_col3, #T_3abf7_row7_col8, #T_3abf7_row8_col0, #T_3abf7_row8_col1, #T_3abf7_row8_col2, #T_3abf7_row8_col3, #T_3abf7_row8_col8, #T_3abf7_row9_col0, #T_3abf7_row9_col1, #T_3abf7_row9_col2, #T_3abf7_row9_col3, #T_3abf7_row9_col8, #T_3abf7_row10_col0, #T_3abf7_row10_col1, #T_3abf7_row10_col2, #T_3abf7_row10_col3, #T_3abf7_row10_col8, #T_3abf7_row11_col0, #T_3abf7_row11_col1, #T_3abf7_row11_col2, #T_3abf7_row11_col3, #T_3abf7_row11_col8, #T_3abf7_row12_col0, #T_3abf7_row12_col1, #T_3abf7_row12_col2, #T_3abf7_row12_col3, #T_3abf7_row12_col8, #T_3abf7_row13_col0, #T_3abf7_row13_col1, #T_3abf7_row13_col2, #T_3abf7_row13_col3, #T_3abf7_row13_col8, #T_3abf7_row14_col0, #T_3abf7_row14_col1, #T_3abf7_row14_col2, #T_3abf7_row14_col3, #T_3abf7_row14_col8 {
#   text-align: left;
# }
# #T_3abf7_row0_col4, #T_3abf7_row0_col5, #T_3abf7_row0_col6, #T_3abf7_row0_col7, #T_3abf7_row1_col4, #T_3abf7_row1_col5, #T_3abf7_row1_col6, #T_3abf7_row1_col7, #T_3abf7_row2_col4, #T_3abf7_row2_col5, #T_3abf7_row2_col6, #T_3abf7_row2_col7, #T_3abf7_row3_col4, #T_3abf7_row3_col5, #T_3abf7_row3_col6, #T_3abf7_row3_col7, #T_3abf7_row4_col4, #T_3abf7_row4_col5, #T_3abf7_row4_col6, #T_3abf7_row4_col7, #T_3abf7_row5_col4, #T_3abf7_row5_col5, #T_3abf7_row5_col6, #T_3abf7_row5_col7, #T_3abf7_row6_col4, #T_3abf7_row6_col5, #T_3abf7_row6_col6, #T_3abf7_row6_col7, #T_3abf7_row7_col4, #T_3abf7_row7_col5, #T_3abf7_row7_col6, #T_3abf7_row7_col7, #T_3abf7_row8_col4, #T_3abf7_row8_col5, #T_3abf7_row8_col6, #T_3abf7_row8_col7, #T_3abf7_row9_col4, #T_3abf7_row9_col5, #T_3abf7_row9_col6, #T_3abf7_row9_col7, #T_3abf7_row10_col4, #T_3abf7_row10_col5, #T_3abf7_row10_col6, #T_3abf7_row10_col7, #T_3abf7_row11_col4, #T_3abf7_row11_col5, #T_3abf7_row11_col6, #T_3abf7_row11_col7, #T_3abf7_row12_col4, #T_3abf7_row12_col5, #T_3abf7_row12_col6, #T_3abf7_row12_col7, #T_3abf7_row13_col4, #T_3abf7_row13_col5, #T_3abf7_row13_col6, #T_3abf7_row13_col7, #T_3abf7_row14_col4, #T_3abf7_row14_col5, #T_3abf7_row14_col6, #T_3abf7_row14_col7 {
#   text-align: right;
# }
# </style>
# <table id="T_3abf7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3abf7_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_3abf7_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_3abf7_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_3abf7_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_3abf7_level0_col4" class="col_heading level0 col4" >value</th>
#       <th id="T_3abf7_level0_col5" class="col_heading level0 col5" >uncertainty</th>
#       <th id="T_3abf7_level0_col6" class="col_heading level0 col6" >min</th>
#       <th id="T_3abf7_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_3abf7_level0_col8" class="col_heading level0 col8" >units</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3abf7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_3abf7_row0_col0" class="data row0 col0" >sim_si</td>
#       <td id="T_3abf7_row0_col1" class="data row0 col1" >linked_phases</td>
#       <td id="T_3abf7_row0_col2" class="data row0 col2" >si</td>
#       <td id="T_3abf7_row0_col3" class="data row0 col3" >scale</td>
#       <td id="T_3abf7_row0_col4" class="data row0 col4" >1.00000</td>
#       <td id="T_3abf7_row0_col5" class="data row0 col5" ></td>
#       <td id="T_3abf7_row0_col6" class="data row0 col6" >-inf</td>
#       <td id="T_3abf7_row0_col7" class="data row0 col7" >inf</td>
#       <td id="T_3abf7_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_3abf7_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_3abf7_row1_col0" class="data row1 col0" >sim_si</td>
#       <td id="T_3abf7_row1_col1" class="data row1 col1" >peak</td>
#       <td id="T_3abf7_row1_col2" class="data row1 col2" ></td>
#       <td id="T_3abf7_row1_col3" class="data row1 col3" >rise_alpha_0</td>
#       <td id="T_3abf7_row1_col4" class="data row1 col4" >-0.00550</td>
#       <td id="T_3abf7_row1_col5" class="data row1 col5" ></td>
#       <td id="T_3abf7_row1_col6" class="data row1 col6" >-inf</td>
#       <td id="T_3abf7_row1_col7" class="data row1 col7" >inf</td>
#       <td id="T_3abf7_row1_col8" class="data row1 col8" >μs</td>
#     </tr>
#     <tr>
#       <th id="T_3abf7_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_3abf7_row2_col0" class="data row2 col0" >sim_si</td>
#       <td id="T_3abf7_row2_col1" class="data row2 col1" >peak</td>
#       <td id="T_3abf7_row2_col2" class="data row2 col2" ></td>
#       <td id="T_3abf7_row2_col3" class="data row2 col3" >rise_alpha_1</td>
#       <td id="T_3abf7_row2_col4" class="data row2 col4" >0.01470</td>
#       <td id="T_3abf7_row2_col5" class="data row2 col5" ></td>
#       <td id="T_3abf7_row2_col6" class="data row2 col6" >-inf</td>
#       <td id="T_3abf7_row2_col7" class="data row2 col7" >inf</td>
#       <td id="T_3abf7_row2_col8" class="data row2 col8" >μs/Å</td>
#     </tr>
#     <tr>
#       <th id="T_3abf7_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_3abf7_row3_col0" class="data row3 col0" >sim_si</td>
#       <td id="T_3abf7_row3_col1" class="data row3 col1" >peak</td>
#       <td id="T_3abf7_row3_col2" class="data row3 col2" ></td>
#       <td id="T_3abf7_row3_col3" class="data row3 col3" >decay_beta_0</td>
#       <td id="T_3abf7_row3_col4" class="data row3 col4" >0.00190</td>
#       <td id="T_3abf7_row3_col5" class="data row3 col5" ></td>
#       <td id="T_3abf7_row3_col6" class="data row3 col6" >-inf</td>
#       <td id="T_3abf7_row3_col7" class="data row3 col7" >inf</td>
#       <td id="T_3abf7_row3_col8" class="data row3 col8" >μs</td>
#     </tr>
#     <tr>
#       <th id="T_3abf7_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_3abf7_row4_col0" class="data row4 col0" >sim_si</td>
#       <td id="T_3abf7_row4_col1" class="data row4 col1" >peak</td>
#       <td id="T_3abf7_row4_col2" class="data row4 col2" ></td>
#       <td id="T_3abf7_row4_col3" class="data row4 col3" >decay_beta_1</td>
#       <td id="T_3abf7_row4_col4" class="data row4 col4" >0.01370</td>
#       <td id="T_3abf7_row4_col5" class="data row4 col5" ></td>
#       <td id="T_3abf7_row4_col6" class="data row4 col6" >-inf<

# %% [markdown]
# #### Visualize Diffraction Patterns
#
# Before performing the fit, we can visually compare the measured
# diffraction pattern with the calculated diffraction pattern based on
# the initial parameters of the structure and the instrument. This
# provides an indication of how well the initial parameters match the
# measured data. The `plot_meas_vs_calc` method of the project allows
# this comparison.

# %%
project_1.display.plotter.plot_meas_vs_calc(expt_name='sim_si')
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="733983aa-b2cd-4275-9975-012cf4f5f38d" class="plotly-graph-div" style="height:600.0px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("733983aa-b2cd-4275-9975-012cf4f5f38d")) {                    Plotly.newPlot(                        "733983aa-b2cd-4275-9975-012cf4f5f38d",                        [{"customdata":{"dtype":"f8","bdata":"HymN\u002fpQCcz97FK5H4XqEP583qRpXkIQ\u002fH0bFNhkedr8EQ\u002fP83FicP3sUrkfheoQ\u002fUFWNUhPOhD9cmKxT0\u002fGRP7rfG90AHYQ\u002fexSuR+F6hD\u002frSKtChLqFPxCT9lg22Em\u002f3jY2baGerT97FK5H4XqEP8qrrywiO4k\u002f7EsK4thPpz+aIDulIMiCP3sUrkfheoQ\u002fOiCYXU0nkz\u002faH\u002fUVeoaDv1i1RZHnqLo\u002fexSuR+F6hD9nmQzZ3lOlP0nRfknw\u002fa8\u002fqMXqUFtzxD
u002fM3wVoT97FK5H4XqEP3Qfh+3Gi4Q\u002fpDi88BTllz\u002fnOB1VhB9wP3sUrkfheoQ\u002fUyxNzRB9hD+\u002fH31Fndp4v9g391njmGM\u002fexSuR+F6hD95wrSbK3uEPwbpbYrlKX+\u002fmyqfHU7gpj97FK5H4XqEP3iJf3PreoQ\u002fPUi\u002fQJPBoT+\u002fku0DYo+MP3sUrkfheoQ\u002fCFmstuJ6hD9uc4Ka\u002fihwP++xjz\u002fB2ZY\u002fexSuR+F6hD9s+u584XqEP3JpMAKhOIk\u002faHCo1uVJmT97FK5H4XqEPwlUok\u002fheoQ\u002fx4yuXeoYjj9TwXZISFF7P3sUrkfheoQ\u002fNrnoSOF6hD8yYrWS9Ehrv0unJZYA3aI\u002fexSuR+F6hD81PeZH4XqEP\u002fwvWIiQfJs\u002fden3sMWUiz97FK5H4XqEP8MwzUfheoQ\u002fyOKqpJFnbD9BSDByOQmaP3sUrkfheoQ\u002fGHb9R+F6hD9qGmOckZePPxcqgZmIRZ4\u002fexSuR+F6hD8VC7RI4XqEP4wkJ\u002fUXCJQ\u002fmt69mBRlnT97FK5H4XqEP4JUFUvheoQ\u002fWTQz86Mnkz9kEevVbIucP3sUrkfheoQ\u002fi33sUuF6hD+e0nQs\u002fE2SP65BT9\u002fFUI0\u002fexSuR+F6hD9r941s4XqEP4aUguXIq3E\u002f7xliSWOpoT97FK5H4XqEPwTRub\u002fheoQ\u002fXEvnslUVmT8fHNeNM1+HP3sUrkfheoQ\u002fHeyky+J6hD8QgJERhiJXPxKw3DYFeoQ\u002fexSuR+F6hD+HkGsk5nqEPwCgDtyxHby+iHPgbD9Emz97FK5H4XqEP8ihicTweoQ\u002fpKKbCscGkT8RVsD7tr6QP3sUrkfheoQ\u002f08N9QhJ7hD+e0AVqtwR6PygJhlsDepA\u002fexSuR+F6hD+8BU0Te3uEPygZfkcX8Xg\u002feBFJq9VSjD97FK5H4XqEP1BkGcfAfIQ\u002foLS+kFNYbz+7mmH+TH6gP3sUrkfheoQ\u002fdaOSua2AhD+84\u002fkfQ7yWP7M91f7+Ips\u002fexSuR+F6hD9mkR68tIyEPwD1xaCk3JA\u002fGX8IKC\u002fuoT97FK ...

# %% [markdown]
# #### Run Fitting
#
# We can now perform the fit using the `fit` method of the `analysis`
# object of the project.

# %% [markdown]
# 📖 See
# [documentation](https://docs.easydiffraction.org/lib/user-guide/analysis-workflow/analysis/#perform-fit)
# for more details about the fitting process.

# %%
project_1.analysis.fit()
project_1.analysis.display.fit_results()
# Out:
# Standard fitting
# 📋 Using experiment 🔬 'sim_si' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_3034a   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_3034a thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_3034a th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_3034a  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_3034a th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_3034a tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_3034a  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_3034a th.col0 {
#   text-align: center;
# }
# #T_3034a th.col1 {
#   text-align: center;
# }
# #T_3034a th.col2 {
#   text-align: center;
# }
# #T_3034a_row0_col0, #T_3034a_row0_col1, #T_3034a_row0_col2, #T_3034a_row1_col0, #T_3034a_row1_col1, #T_3034a_row1_col2, #T_3034a_row2_col0, #T_3034a_row2_col1, #T_3034a_row2_col2, #T_3034a_row3_col0, #T_3034a_row3_col1, #T_3034a_row3_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_3034a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3034a_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_3034a_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_3034a_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3034a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_3034a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_3034a_row0_col1" class="data row0 col1" >33.88</td>
#       <td id="T_3034a_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_3034a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_3034a_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_3034a_row1_col1" class="data row1 col1" >4.11</td>
#       <td id="T_3034a_row1_col2" class="data row1 col2" >87.9% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_3034a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_3034a_row2_col0" class="data row2 col0" >35</td>
#       <td id="T_3034a_row2_col1" class="data row2 col1" >2.33</td>
#       <td id="T_3034a_row2_col2" class="data row2 col2" >43.4% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_3034a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_3034a_row3_col0" class="data row3 col0" >116</td>
#       <td id="T_3034a_row3_col1" class="data row3 col1" >2.31</td>
#       <td id="T_3034a_row3_col2" class="data row3 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 2.31 at iteration 115
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 2.03 seconds
# 📏 Goodness-of-fit (reduced χ²): 2.31
# 📏 R-factor (Rf): 6.87%
# 📏 R-factor squared (Rf²): 5.52%
# 📏 Weighted R-factor (wR): 5.60%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_302c0   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_302c0 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_302c0 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_302c0  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_302c0 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_302c0 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_302c0  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_302c0 th.col0 {
#   text-align: left;
# }
# #T_302c0 th.col1 {
#   text-align: left;
# }
# #T_302c0 th.col2 {
#   text-align: left;
# }
# #T_302c0 th.col3 {
#   text-align: left;
# }
# #T_302c0 th.col4 {
#   text-align: right;
# }
# #T_302c0 th.col5 {
#   text-align: right;
# }
# #T_302c0 th.col6 {
#   text-align: right;
# }
# #T_302c0 th.col7 {
#   text-align: left;
# }
# #T_302c0 th.col8 {
#   text-align: right;
# }
# #T_302c0_row0_col0, #T_302c0_row0_col1, #T_302c0_row0_col2, #T_302c0_row0_col3, #T_302c0_row0_col7, #T_302c0_row1_col0, #T_302c0_row1_col1, #T_302c0_row1_col2, #T_302c0_row1_col3, #T_302c0_row1_col7, #T_302c0_row2_col0, #T_302c0_row2_col1, #T_302c0_row2_col2, #T_302c0_row2_col3, #T_302c0_row2_col7, #T_302c0_row3_col0, #T_302c0_row3_col1, #T_302c0_row3_col2, #T_302c0_row3_col3, #T_302c0_row3_col7, #T_302c0_row4_col0, #T_302c0_row4_col1, #T_302c0_row4_col2, #T_302c0_row4_col3, #T_302c0_row4_col7, #T_302c0_row5_col0, #T_302c0_row5_col1, #T_302c0_row5_col2, #T_302c0_row5_col3, #T_302c0_row5_col7, #T_302c0_row6_col0, #T_302c0_row6_col1, #T_302c0_row6_col2, #T_302c0_row6_col3, #T_302c0_row6_col7, #T_302c0_row7_col0, #T_302c0_row7_col1, #T_302c0_row7_col2, #T_302c0_row7_col3, #T_302c0_row7_col7, #T_302c0_row8_col0, #T_302c0_row8_col1, #T_302c0_row8_col2, #T_302c0_row8_col3, #T_302c0_row8_col7, #T_302c0_row9_col0, #T_302c0_row9_col1, #T_302c0_row9_col2, #T_302c0_row9_col3, #T_302c0_row9_col7, #T_302c0_row10_col0, #T_302c0_row10_col1, #T_302c0_row10_col2, #T_302c0_row10_col3, #T_302c0_row10_col7, #T_302c0_row11_col0, #T_302c0_row11_col1, #T_302c0_row11_col2, #T_302c0_row11_col3, #T_302c0_row11_col7, #T_302c0_row12_col0, #T_302c0_row12_col1, #T_302c0_row12_col2, #T_302c0_row12_col3, #T_302c0_row12_col7, #T_302c0_row13_col0, #T_302c0_row13_col1, #T_302c0_row13_col2, #T_302c0_row13_col3, #T_302c0_row13_col7, #T_302c0_row14_col0, #T_302c0_row14_col1, #T_302c0_row14_col2, #T_302c0_row14_col3, #T_302c0_row14_col7 {
#   text-align: left;
# }
# #T_302c0_row0_col4, #T_302c0_row0_col5, #T_302c0_row0_col6, #T_302c0_row0_col8, #T_302c0_row1_col4, #T_302c0_row1_col5, #T_302c0_row1_col6, #T_302c0_row1_col8, #T_302c0_row2_col4, #T_302c0_row2_col5, #T_302c0_row2_col6, #T_302c0_row2_col8, #T_302c0_row3_col4, #T_302c0_row3_col5, #T_302c0_row3_col6, #T_302c0_row3_col8, #T_302c0_row4_col4, #T_302c0_row4_col5, #T_302c0_row4_col6, #T_302c0_row4_col8, #T_302c0_row5_col4, #T_302c0_row5_col5, #T_302c0_row5_col6, #T_302c0_row5_col8, #T_302c0_row6_col4, #T_302c0_row6_col5, #T_302c0_row6_col6, #T_302c0_row6_col8, #T_302c0_row7_col4, #T_302c0_row7_col5, #T_302c0_row7_col6, #T_302c0_row7_col8, #T_302c0_row8_col4, #T_302c0_row8_col5, #T_302c0_row8_col6, #T_302c0_row8_col8, #T_302c0_row9_col4, #T_302c0_row9_col5, #T_302c0_row9_col6, #T_302c0_row9_col8, #T_302c0_row10_col4, #T_302c0_row10_col5, #T_302c0_row10_col6, #T_302c0_row10_col8, #T_302c0_row11_col4, #T_302c0_row11_col5, #T_302c0_row11_col6, #T_302c0_row11_col8, #T_302c0_row12_col4, #T_302c0_row12_col5, #T_302c0_row12_col6, #T_302c0_row12_col8, #T_302c0_row13_col4, #T_302c0_row13_col5, #T_302c0_row13_col6, #T_302c0_row13_col8, #T_302c0_row14_col4, #T_302c0_row14_col5, #T_302c0_row14_col6, #T_302c0_row14_col8 {
#   text-align: right;
# }
# </style>
# <table id="T_302c0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_302c0_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_302c0_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_302c0_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_302c0_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_302c0_level0_col4" class="col_heading level0 col4" >start</th>
#       <th id="T_302c0_level0_col5" class="col_heading level0 col5" >fitted</th>
#       <th id="T_302c0_level0_col6" class="col_heading level0 col6" >uncertainty</th>
#       <th id="T_302c0_level0_col7" class="col_heading level0 col7" >units</th>
#       <th id="T_302c0_level0_col8" class="col_heading level0 col8" >change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_302c0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_302c0_row0_col0" class="data row0 col0" >sim_si</td>
#       <td id="T_302c0_row0_col1" class="data row0 col1" >linked_phases</td>
#       <td id="T_302c0_row0_col2" class="data row0 col2" >si</td>
#       <td id="T_302c0_row0_col3" class="data row0 col3" >scale</td>
#       <td id="T_302c0_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_302c0_row0_col5" class="data row0 col5" >1.4540</td>
#       <td id="T_302c0_row0_col6" class="data row0 col6" >0.0071</td>
#       <td id="T_302c0_row0_col7" class="data row0 col7" ></td>
#       <td id="T_302c0_row0_col8" class="data row0 col8" >45.40 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_302c0_row1_col0" class="data row1 col0" >sim_si</td>
#       <td id="T_302c0_row1_col1" class="data row1 col1" >peak</td>
#       <td id="T_302c0_row1_col2" class="data row1 col2" ></td>
#       <td id="T_302c0_row1_col3" class="data row1 col3" >rise_alpha_0</td>
#       <td id="T_302c0_row1_col4" class="data row1 col4" >-0.0055</td>
#       <td id="T_302c0_row1_col5" class="data row1 col5" >-0.0066</td>
#       <td id="T_302c0_row1_col6" class="data row1 col6" >0.0005</td>
#       <td id="T_302c0_row1_col7" class="data row1 col7" >μs</td>
#       <td id="T_302c0_row1_col8" class="data row1 col8" >20.30 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_302c0_row2_col0" class="data row2 col0" >sim_si</td>
#       <td id="T_302c0_row2_col1" class="data row2 col1" >peak</td>
#       <td id="T_302c0_row2_col2" class="data row2 col2" ></td>
#       <td id="T_302c0_row2_col3" class="data row2 col3" >rise_alpha_1</td>
#       <td id="T_302c0_row2_col4" class="data row2 col4" >0.0147</td>
#       <td id="T_302c0_row2_col5" class="data row2 col5" >0.0159</td>
#       <td id="T_302c0_row2_col6" class="data row2 col6" >0.0007</td>
#       <td id="T_302c0_row2_col7" class="data row2 col7" >μs/Å</td>
#       <td id="T_302c0_row2_col8" class="data row2 col8" >7.87 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_302c0_row3_col0" class="data row3 col0" >sim_si</td>
#       <td id="T_302c0_row3_col1" class="data row3 col1" >peak</td>
#       <td id="T_302c0_row3_col2" class="data row3 col2" ></td>
#       <td id="T_302c0_row3_col3" class="data row3 col3" >decay_beta_0</td>
#       <td id="T_302c0_row3_col4" class="data row3 col4" >0.0019</td>
#       <td id="T_302c0_row3_col5" class="data row3 col5" >0.0008</td>
#       <td id="T_302c0_row3_col6" class="data row3 col6" >0.0001</td>
#       <td id="T_302c0_row3_col7" class="data row3 col7" >μs</td>
#       <td id="T_302c0_row3_col8" class="data row3 col8" >58.68 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_302c0_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_302c0_row4_col0" class="data row4 col0" >sim_si</td>
#       <td id="T_302c0_row4_col1" class="data row4 col1" >peak</td>
#       <td id="T_302c0_row4_col2" class="data row4 col2" ></td>
#       <td id="T_302c0_row4_col3" class="data row4 col3" >decay_beta_1</td>
#       <td id="T_302c0_row4_col4" class="data row4 col4" >0.0137</td>
#       <td id="T_302c0_row4_col5" class="data row4 col5" >0.0190</td>

# %% [markdown]
# #### Check Fit Results
#
# You can see that the agreement between the measured and calculated
# diffraction patterns is now much improved and that the intensities of
# the calculated peaks align much better with the measured peaks. To
# check the quality of the fit numerically, we can look at the
# goodness-of-fit χ² value and the reliability R-factors. The χ² value
# is a measure of how well the calculated diffraction pattern matches
# the measured pattern, and it is calculated as the sum of the squared
# differences between the measured and calculated intensities, divided
# by the number of data points. Ideally, the χ² value should be close to
# 1, indicating a good fit.

# %% [markdown]
# #### Visualize Fit Results
#
# After the fit is completed, we can plot the comparison between the
# measured and calculated diffraction patterns again to see how well the
# fit improved the agreement between the two. The calculated diffraction
# pattern is now based on the refined parameters.

# %%
project_1.display.plotter.plot_meas_vs_calc(expt_name='sim_si')
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="601affce-80a7-4880-9e32-787aca6ad2dc" class="plotly-graph-div" style="height:600.0px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("601affce-80a7-4880-9e32-787aca6ad2dc")) {                    Plotly.newPlot(                        "601affce-80a7-4880-9e32-787aca6ad2dc",                        [{"customdata":{"dtype":"f8","bdata":"HymN\u002fpQCcz8UhKJ8B1Rgv4oMEE+r+l6\u002fQixR0j\u002fBej8EQ\u002fP83FicP8i7r3O4vl2\u002f6frF0JgiV7+zov+JBsudP7rfG90AHYQ\u002fPG8a7mHVWr8gw7t59G0Rv0BXD8bcP4Q\u002f3jY2baGerT\u002fgIoVoC+xXvzVT+bJVn3I\u002fdwzXtrZKqz+aIDulIMiCP1g1rwq1AlW\u002fLEfoTWRTlT++bZX2p96Hv1i1RZH
kC4PQL+lC4kZqVOdP0SKpGNcxHI\u002fFNbHYGFvgj+bICVp+BuUP5okXuIcZZ4\u002fZt0JBbJ+cz85lYRJWdF1P0z\u002f\u002fI\u002fG8Jg\u002fL+S\u002fM3wVoT9+MG+mBzl0Pzg8O44LdXQ\u002fUPnwg7UNnT\u002fnOB1VhB9wPxj9e+yN\u002fXQ\u002fpg+INKkCdT\u002f8Wqt9k4xTv9g391njmGM\u002fTUcJ40HedT+76oXGp951P56dFDNsJGi\u002fmyqfHU7gpj+cOJLl9b52PxNGSbb9vnY\u002f2QHWZm4IpD+\u002fku0DYo+MP90pG+ipn3c\u002fqDthhaqfdz\u002fr9DzBjL+AP++xjz\u002fB2ZY\u002fHhuk6l2AeD9x+Hz3XYB4P9NzsMGpuZA\u002faHCo1uVJmT9uDC3tEWF5P8jvRu4RYXk\u002fdrQWW6Hxkj9TwXZISFF7P6\u002f9te\u002fFQXo\u002fq3vW78VBej+AWgSKJfgwP0unJZYA3aI\u002f8O4+8nkiez9H+VvyeSJ7P0RQtK9i8Z4\u002fden3sMWUiz8\u002f4Mf0LQN8P+cCJPUtA3w\u002fA9DLbF0mez9BSDByOQmaP3QqVevh43w\u002fyl2O7OHjfD\u002fOsAz3QNCSPxcqgZmIRZ4\u002ftBve7ZXEfT+LkwDylcR9PzQFAR1j1JY\u002fmt69mBRlnT\u002f2DGfwSaV+Pwy\u002fQ\u002f5JpX4\u002f1+4sGcK7lT9kEevVbIucP0X+7\u002fL9hX8\u002fbuMKIf6Ffz+IWKhN7amUP65BT9\u002fFUI0\u002fw3e8+lgzgD+NMs1GWTOAP0IeBDHZOno\u002f7xliSWOpoT9k8AD8sqOAP46MBPWzo4A\u002fl+1BmOwAmz8fHNeNM1+HPwtpRf0MFIE\u002fj2wWJhAUgT9AvgKfjSxpPxKw3DYFeoQ\u002fJg6M+GaEgT90UzUncYSBP\u002fDkOn2grFc\u002fiHPgbD9Emz\u002fGhtD5wPSBP6cSo4nh9IE\u002fNOoOqM5Jkj8RVsD7tr6QP2b\u002fFPsaZYI\u002fVrI5T4Jlgj+Y841Q1y9+PygJhlsDepA\u002fDnhZ\u002fHTVgj8jgqdfutaCP1ogya6YOnw\u002feBFJq9VSjD+u8J39zkWDPy5lud7HSYM\u002flFgfmRsScj+7mmH+TH6gP09p4v4otoM\u002fnXlP3nrCgz+oeJuNXB ...

# %% [markdown]
# #### TOF vs d-spacing
#
# The diffraction pattern is typically analyzed and plotted in the
# time-of-flight (TOF) axis, which represents the time it takes for
# neutrons to travel from the sample to the detector. However, it is
# sometimes more convenient to visualize the diffraction pattern in the
# d-spacing axis, which represents the distance between planes in the
# crystal lattice.
#
# The conversion from d-spacing to TOF was already introduced in the
# data reduction notebook. As a reminder, the two are related through
# the instrument calibration parameters according to the equation:
#
# $$ \text{TOF} = \text{offset} + \text{linear} \cdot d + \text{quad}
# \cdot d^{2}, $$
#
# where `offset`, `linear`, and `quad` are calibration parameters.
#
# In our case, only the `linear` term is used (the
# `calib_d_to_tof_linear` parameter we set earlier). The `offset` and
# `quad` terms were not part of the data reduction and are therefore set
# to 0 by default.
#
# The `plot_meas_vs_calc` method of the project allows us to plot the
# measured and calculated diffraction patterns in the d-spacing axis by
# setting the `d_spacing` parameter to `True`.

# %%
project_1.display.plotter.plot_meas_vs_calc(expt_name='sim_si', x='d_spacing')
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="
# %% [markdown]
# As you can see, the calculated diffraction pattern now matches the
# measured pattern much more closely. Typically, additional experimental
# parameters are included in the refinement process to further improve
# the fit. In this example, the structural parameters are not refined
# because the Si crystal structure is a well-known standard reference
# used to calibrate both the instrument and the experimental setup. The
# refined experimental parameters obtained here will then be applied
# when fitting the crystal structures of other materials.
#
# In the next part of the notebook, we will move to a more advanced case
# and fit a more complex crystal structure: La₀.₅Ba₀.₅CoO₃ (LBCO).
#
# #### Save Project
#
# Before moving on, we can save the project to disk for later use. This
# will preserve the entire project structure, including experiments,
# structures, and fitting results. The project is saved into a
# directory specified by the `dir_path` attribute of the project object.

# %%
project_1.save_as(dir_path='data/powder_diffraction_Si')
# Out:
# Saving project 📦 'reference' to
# /home/runner/work/diffraction-lib/diffraction-lib/docs/docs/tutorials/data/powder_diffraction_Si
# ├── 📄 project.cif
# ├── 📁 structures/
# │   └── 📄 si.cif
# ├── 📁 experiments/
# │   └── 📄 sim_si.cif
# ├── 📁 analysis/
# │   └── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# ## 💪 Exercise: Complex Fit – LBCO
#
# Now that you have a basic understanding of the fitting process, we
# will undertake a more complex fit of the La₀.₅Ba₀.₅CoO₃ (LBCO) crystal
# structure using simulated powder diffraction data from the data
# reduction notebook.
#
# You can use the same approach as in the previous part of the notebook,
# but this time we will refine a more complex crystal structure LBCO
# with multiple atoms in the unit cell.
#
# ### 📦 Exercise 1: Create a Project
#
# Create a new project for the LBCO fit.

# %% [markdown]
# **Hint:**

# %% [markdown]
# You can use the same approach as in the previous part of the notebook,
# but this time we will create a new project for the LBCO fit.

# %% [markdown]
# **Solution:**

# %%
project_2 = ed.Project(name='main')
project_2.info.title = 'La0.5Ba0.5CoO3 Fit'
project_2.info.description = 'Fitting simulated powder diffraction pattern of La0.5Ba0.5CoO3.'

# %% [markdown]
# ### 🔬 Exercise 2: Define an Experiment
#
# #### Exercise 2.1: Create an Experiment
#
# Create an experiment within the new project and load the reduced
# diffraction pattern for LBCO.

# %% [markdown]
# **Hint:**

# %% [markdown]
# You can use the same approach as in the previous part of the notebook,
# but this time you need to use the data file for LBCO.

# %% [markdown]
# **Solution:**

# %%
data_dir = 'data'
file_name = 'reduced_LBCO.xye'
lbco_xye_path = f'{data_dir}/{file_name}'

# Uncomment the following line if your data reduction failed and the
# reduced data file is missing.
lbco_xye_path = ed.download_data(id=18, destination=data_dir)

project_2.experiments.add_from_data_path(
    name='sim_lbco',
    data_path=lbco_xye_path,
    sample_form='powder',
    beam_mode='time-of-flight',
    radiation_probe='neutron',
)
# Out:
# Getting data...
# Data #18: La0.5Ba0.5CoO3 + Si, McStas simulation, DMSC Summer School 2025
# ✅ Data #18 downloaded to 'data/ed-18.xye'
# Data loaded successfully
# Experiment 🔬 'sim_lbco'. Number of data points: 900.

# %% [markdown]
# #### Exercise 2.1: Inspect Measured Data
#
# Check the measured data of the LBCO experiment. Are there any peaks
# with the shape similar to those excluded in the Si fit? If so, exclude
# them from this analysis as well.

# %% [markdown]
# **Hint:**

# %% [markdown]
# You can use the `plot_meas` method of the project to visualize the
# measured diffraction pattern. You can also use the `excluded_regions`
# attribute of the experiment to exclude specific regions from the
# analysis as we did in the previous part of the notebook.

# %% [markdown]
# **Solution:**

# %%
project_2.display.plotter.plot_meas(expt_name='sim_lbco')

project_2.experiments['sim_lbco'].excluded_regions.create(id='1', start=0, end=55000)
project_2.experiments['sim_lbco'].excluded_regions.create(id='2', start=105500, end=200000)

project_2.display.plotter.plot_meas(expt_name='sim_lbco')
# Out:
# Warning: No linked phases defined. Returning empty pattern.
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="d3e33754-2e4c-4224-b0c0-a5dafefc8160" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d3e33754-2e4c-4224-b0c0-a5dafefc8160")) {                    Plotly.newPlot(                        "d3e33754-2e4c-4224-b0c0-a5dafefc8160",                        [{"hovertemplate":"Measured (Imeas)\u003cbr\u003ex: %{x}\u003cbr\u003ey: %{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendrank":10,"line":{"color":"rgb(31, 119, 180)","width":2.0},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"rIvbaE4b5EDnjCjt\u002fSnkQCKOdXGtOORAXI\u002fC9VxH5ECXkA96DFbkQLraiv27ZORA9dvXgWtz5EAv3SQGG4LkQGrecYrKkORApN++Dnqf5EDHKTqSKa7kQAIrhxbZvORAPSzUmojL5EB3LSEfONrkQLIubqPn6ORA1XjpJpf35EAQejarRgblQEp7gy\u002f2FOVAhXzQs6Uj5UC\u002ffR04VTLlQOPHmLsEQeVAHcnlP7RP5UBYyjLEY17lQJLLf0gTbeVAzczMzMJ75UDwFkhQcorlQCsYldQhmeVAZRniWNGn5UCgGi\u002fdgLblQNobfGEwxeVA\u002fmX35N\u002fT5UA4Z0Rpj+LlQHNoke0+8eVArWnece7\u002f5UDoaiv2nQ7mQAu1pnlNHeZARrbz\u002ffwr5kCAt0CCrDrmQLu4jQZcSeZA9bnaigtY5kAZBFYOu2bmQFMFo5JqdeZAjgbwFhqE5kDIBz2byZLmQAMJih95oeZAJlMFoyiw5kBhVFIn2L7mQJtVn6uHzeZA1lbsLzfc5kAQWDm05urmQDSitDeW+eZAbqMBvEUI50CppE5A9RbnQOOlm8SkJedAB\u002fAWSFQ050BB8WPMA0PnQHzysFCzUedAtvP91GJg50Dx9EpZEm\u002fnQBQ\u002fxtzBfedAT0ATYXGM50CJQWDlIJvnQMRCrWnQqedA\u002fkP67X+450AijnVxL8fnQFyPwvXe1edAl5APeo7k50DRkVz+PfPnQAyTqYLtAehAL90kBp0Q6EBq3nGKTB\u002foQKTfvg78LehA3+ALk6s86EAZ4lgXW0voQD0s1JoKWuhAdy0hH7po6ECyLm6jaXfoQOwvuycZhuhAJzEIrMiU6EBKe4MveKPoQIV80LMnsuhAv30dONfA6ED6fmq8hs\u002foQDSAt0A23uhAWMoyxOXs6ECSy39IlfvoQM3MzMxECulAB84ZUfQY6UBCz2bVoyfpQGUZ4lhTNulAoBov3QJF6UDaG3xhslPpQBUdyeVhYulATx4WahFx6UBzaJHtwH\u002fpQK1p3nFwjulA6Gor9h+d6UAibHh6z6vpQF1txf5+uulAgLdAgi7J6UC7uI0G3tfpQPW52oqN5ulAMLsnDz316UBqvHST7APqQI4G8B
# **Hint:**

# %% [markdown]
# Use the values from the data reduction process for the LBCO and
# follow the same approach as in the previous part of the notebook.

# %% [markdown]
# **Solution:**

# %%
project_2.experiments['sim_lbco'].instrument.setup_twotheta_bank = ed.extract_metadata(
    lbco_xye_path, r'two_theta\s*=\s*(\d*\.?\d+)'
)
project_2.experiments['sim_lbco'].instrument.calib_d_to_tof_linear = ed.extract_metadata(
    lbco_xye_path, r'DIFC\s*=\s*(\d*\.?\d+)'
)

# %% [markdown]
# #### Exercise 2.3: Set Peak Profile Parameters
#
# Set the peak profile parameters for the LBCO experiment.

# %% [markdown]
# **Hint:**

# %% [markdown]
# Use the values from the
# previous part of the notebook. You can either manually copy the values
# from the Si fit or use the `value` attribute of the parameters from
# the Si experiment to set the initial values for the LBCO experiment.
# This will help us to have a good starting point for the fit.

# %% [markdown]
# **Solution:**

# %%
# Create a reference to the peak profile parameters from the Si...
sim_si_peak = project_1.experiments['sim_si'].peak

# ...and use their values to set the initial parameters for the LBCO
project_2.experiments['sim_lbco'].peak.broad_gauss_sigma_0 = sim_si_peak.broad_gauss_sigma_0.value
project_2.experiments['sim_lbco'].peak.broad_gauss_sigma_1 = sim_si_peak.broad_gauss_sigma_1.value
project_2.experiments['sim_lbco'].peak.broad_gauss_sigma_2 = sim_si_peak.broad_gauss_sigma_2.value
project_2.experiments['sim_lbco'].peak.exp_decay_beta_0 = sim_si_peak.exp_decay_beta_0.value
project_2.experiments['sim_lbco'].peak.exp_decay_beta_1 = sim_si_peak.exp_decay_beta_1.value
project_2.experiments['sim_lbco'].peak.exp_rise_alpha_0 = sim_si_peak.exp_rise_alpha_0.value
project_2.experiments['sim_lbco'].peak.exp_rise_alpha_1 = sim_si_peak.exp_rise_alpha_1.value

# %% [markdown]
# #### Exercise 2.4: Set Background
#
# Set the background points for the LBCO experiment. What would you
# suggest as the initial intensity value for the background points?

# %% [markdown]
# **Hint:**

# %% [markdown]
# Use the same approach as in the previous part of the notebook, but
# this time you need to set the background points for the LBCO
# experiment. You can zoom in on the measured diffraction pattern to
# determine the approximate background level.

# %% [markdown]
# **Solution:**

# %%
project_2.experiments['sim_lbco'].background.create(id='1', x=50000, y=0.2)
project_2.experiments['sim_lbco'].background.create(id='2', x=60000, y=0.2)
project_2.experiments['sim_lbco'].background.create(id='3', x=70000, y=0.2)
project_2.experiments['sim_lbco'].background.create(id='4', x=80000, y=0.2)
project_2.experiments['sim_lbco'].background.create(id='5', x=90000, y=0.2)
project_2.experiments['sim_lbco'].background.create(id='6', x=100000, y=0.2)
project_2.experiments['sim_lbco'].background.create(id='7', x=110000, y=0.2)

# %% [markdown]
# ### 🧩 Exercise 3: Define a Structure – LBCO
#
# The LBSO structure is not as simple as the Si one, as it contains
# multiple atoms in the unit cell. It is not in COD, so we give you the
# structural parameters in CIF format to create the structure.
#
# Note that those parameters are not necessarily the most accurate ones,
# but they are a good starting point for the fit. The aim of the study
# is to refine the LBCO lattice parameters.

# %% [markdown]
# ```
# data_lbco
#
# _space_group.name_H-M_alt  "P m -3 m"
# _space_group.IT_coordinate_system_code  1
#
# _cell.length_a      3.89
# _cell.length_b      3.89
# _cell.length_c      3.89
# _cell.angle_alpha  90.0
# _cell.angle_beta   90.0
# _cell.angle_gamma  90.0
#
# loop_
# _atom_site.label
# _atom_site.type_symbol
# _atom_site.fract_x
# _atom_site.fract_y
# _atom_site.fract_z
# _atom_site.wyckoff_letter
# _atom_site.occupancy
# _atom_site.ADP_type
# _atom_site.B_iso_or_equiv
# La La   0.0 0.0 0.0   a   0.5   Biso 0.95
# Ba Ba   0.0 0.0 0.0   a   0.5   Biso 0.95
# Co Co   0.5 0.5 0.5   b   1.0   Biso 0.80
# O  O    0.0 0.5 0.5   c   1.0   Biso 1.66
# ```

# %% [markdown]
# Note that the `occupancy` of the La and Ba atoms is 0.5
# and those atoms are located in the same position (0, 0, 0) in the unit
# cell. This means that an extra attribute `occupancy` needs to be set
# for those atoms later in the structure.
#
# We model the La/Ba site using the virtual crystal approximation. In
# this approach, the scattering is taken as a weighted average of La and
# Ba. This reproduces the average diffraction pattern well but does not
# capture certain real-world effects.
#
# The edge cases are:
# - **Random distribution**. La and Ba atoms are placed randomly. The
#    Bragg peaks still match the average structure, but the pattern also
#    shows extra background (diffuse scattering) between the peaks, but
#    this is usually neglected in the analysis.
# - **Perfect ordering**. La and Ba arrange themselves in a regular
#    pattern, creating a larger repeating unit. This gives rise to extra
#    peaks ("superlattice reflections") and changes the intensity of
#    some existing peaks.
# - **Virtual crystal approximation (our model)**. We replace the site
#    with a single "virtual atom" that averages La and Ba. This gives
#    the correct average Bragg peaks but leaves out the extra background
#    of the random case and the extra peaks of the ordered case.

# %% [markdown]
# #### Exercise 3.1: Create Structure
#
# Add a structure for LBCO to the project. The structure
# parameters will be set in the next exercises.

# %% [markdown]
# **Hint:**

# %% [markdown]
# You can use the same approach as in the previous part of the notebook,
# but this time you need to use the name corresponding to the LBCO
# structure, e.g. 'lbco'.

# %% [markdown]
# **Solution:**

# %%
project_2.structures.create(name='lbco')

# %% [markdown]
# #### Exercise 3.2: Set Space Group
#
# Set the space group for the LBCO structure.

# %% [markdown]
# **Hint:**

# %% [markdown]
# Use the space group name and IT coordinate system code from the CIF
# data.

# %% [markdown]
# **Solution:**

# %%
project_2.structures['lbco'].space_group.name_h_m = 'P m -3 m'
project_2.structures['lbco'].space_group.it_coordinate_system_code = '1'

# %% [markdown]
# #### Exercise 3.3: Set Lattice Parameters
#
# Set the lattice parameters for the LBCO structure.

# %% [markdown]
# **Hint:**

# %% [markdown]
# Use the lattice parameters from the CIF data.

# %% [markdown]
# **Solution:**

# %%
project_2.structures['lbco'].cell.length_a = 3.88

# %% [markdown]
# #### Exercise 3.4: Set Atom Sites
#
# Set the atom sites for the LBCO structure.

# %% [markdown]
# **Hint:**

# %% [markdown]
# Use the atom sites from the CIF data. You can use the `add` method of
# the `atom_sites` attribute of the structure to add the atom sites.

# %% [markdown]
# **Solution:**

# %%
project_2.structures['lbco'].atom_sites.create(
    label='La',
    type_symbol='La',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    adp_iso=0.95,
    occupancy=0.5,
)
project_2.structures['lbco'].atom_sites.create(
    label='Ba',
    type_symbol='Ba',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    adp_iso=0.95,
    occupancy=0.5,
)
project_2.structures['lbco'].atom_sites.create(
    label='Co',
    type_symbol='Co',
    fract_x=0.5,
    fract_y=0.5,
    fract_z=0.5,
    wyckoff_letter='b',
    adp_iso=0.80,
)
project_2.structures['lbco'].atom_sites.create(
    label='O',
    type_symbol='O',
    fract_x=0,
    fract_y=0.5,
    fract_z=0.5,
    wyckoff_letter='c',
    adp_iso=1.66,
)

# %% [markdown]
# ### 🔗 Exercise 4: Assign Structure to Experiment
#
# Now assign the LBCO structure to the experiment created above.

# %% [markdown]
# **Hint:**

# %% [markdown]
# Use the `linked_phases` attribute of the experiment to link the
# crystal structure.

# %% [markdown]
# **Solution:**

# %%
project_2.experiments['sim_lbco'].linked_phases.create(id='lbco', scale=1.0)

# %% [markdown]
# ### 🚀 Exercise 5: Analyze and Fit the Data
#
# #### Exercise 5.1: Set Fit Parameters
#
# Select the initial set of parameters to be refined during the fitting
# process.

# %% [markdown]
# **Hint:**

# %% [markdown]
# You can start with the scale factor and the background points, as in
# the Si fit.

# %% [markdown]
# **Solution:**

# %%
project_2.experiments['sim_lbco'].linked_phases['lbco'].scale.free = True

for line_segment in project_2.experiments['sim_lbco'].background:
    line_segment.y.free = True

# %% [markdown]
# #### Exercise 5.2: Run Fitting
#
# Visualize the measured and calculated diffraction patterns before
# fitting and then run the fitting process.

# %% [markdown]
# **Hint:**

# %% [markdown]
# Use the `plot_meas_vs_calc` method of the project to visualize the
# measured and calculated diffraction patterns before fitting. Then, use
# the `fit` method of the `analysis` object of the project to perform
# the fitting process.

# %% [markdown]
# **Solution:**

# %%
project_2.display.plotter.plot_meas_vs_calc(expt_name='sim_lbco')

project_2.analysis.fit()
project_2.analysis.display.fit_results()
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="0ba0c878-bfb6-4fd4-bdbd-8a426f9430ef" class="plotly-graph-div" style="height:600.0px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0ba0c878-bfb6-4fd4-bdbd-8a426f9430ef")) {                    Plotly.newPlot(                        "0ba0c878-bfb6-4fd4-bdbd-8a426f9430ef",                        [{"customdata":{"dtype":"f8","bdata":"Ro6RutwL0D+amZmZmZnJP0hqL5gMtck\u002fEMnOc7OKqT8+eTa7RpzSP5qZmZmZmck\u002f12Ox3O2+yT9KHXczP\u002fO2PwOlc1uRBtM\u002fmpmZmZmZyT8I9SgwUcDJP\u002fypfA2jmbg\u002fbbst91Am0z+amZmZmZnJP2Nsrs3Mt8k\u002f7hRaQaopuT9IdSTJCg7UP5qZmZmZmck\u002fmcLEnzGryT\u002fuTwjlx+G8P4Nj+6elmdI\u002fmpmZmZmZyT\u002fggg3NYaHJP0yI0gXTI7c\u002fMPXJL3U5zD+amZmZmZnJP+SBu67SnMk\u002fYJpzCBTllD\u002fshCSHPO\u002fTP5qZmZmZmck\u002fYxyNV+ecyT\u002fq2ndtI4O8PyqwfDWTKdE\u002fmpmZmZmZyT93kBjwsaLJP7qfwfXoYLE\u002fBoSfnKzizT+amZmZmZnJP7XHj5nQtsk\u002fRPE+DHCvoD\u002fPHD6XudLQP5qZmZmZmck\u002f6ha2vUr2yT\u002fQihjDobyuP2ct7xDz5NQ\u002fmpmZm
row1_col2" class="data row1 col2" >1</td>
#       <td id="T_45524_row1_col3" class="data row1 col3" >y</td>
#       <td id="T_45524_row1_col4" class="data row1 col4" >0.2000</td>
#       <td id="T_45524_row1_col5" class="data row1 col5" >0.2974</td>
#       <td id="T_45524_row1_col6" class="data row1 col6" >0.1893</td>
#       <td id="T_45524_row1_col7" class="data row1 col7" ></td>
#       <td id="T_45524_row1_col8" class="data row1 col8" >48.69 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_45524_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_45524_row2_col0" class="data row2 col0" >sim_lbco</td>
#       <td id="T_45524_row2_col1" class="data row2 col1" >background</td>
#       <td id="T_45524_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_45524_row2_col3" class="data row2 col3" >y</td>
#       <td id="T_45524_row2_col4" class="data row2 col4" >0.2000</td>
#       <td id="T_45524_row2_col5" class="data row2 col5" >0.2745</td>
#       <td id="T_45524_row2_col6" class="data row2 col6" >0.0387</td>
#       <td id="T_45524_row2_col7" class="data row2 col7" ></td>
#       <td id="T_45524_row2_col8" class="data row2 col8" >37.23 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_45524_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_45524_row3_col0" class="data row3 col0" >sim_lbco</td>
#       <td id="T_45524_row3_col1" class="data row3 col1" >background</td>
#       <td id="T_45524_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_45524_row3_col3" class="data row3 col3" >y</td>
#       <td id="T_45524_row3_col4" class="data row3 col4" >0.2000</td>
#       <td id="T_45524_row3_col5" class="data row3 col5" >0.2805</td>
#       <td id="T_45524_row3_col6" class="data row3 col6" >0.0251</td>
#       <td id="T_45524_row3_col7" class="data row3 col7" ></td>
#       <td id="T_45524_row3_col8" class="data row3 col8" >40.25 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_45524_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_45524_row4_col0" class="data row4 col0" >sim_lbco</td>
#       <td id="T_45524_row4_col1" class="data row4 col1" >background</td>
#       <td id="T_45524_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_45524_row4_col3" class="data row4 col3" >y</td>
#       <td id="T_45524_row4_col4" class="data row4 col4" >0.2000</td>
#       <td id="T_45524_row4_col5" class="data row4 col5" >0.2359</td>
#       <td id="T_45524_row4_col6" class="data row4 col6" >0.0193</td>
#       <td id="T_45524_row4_col7" class="data row4 col7" ></td>
#       <td id="T_45524_row4_col8" class="data row4 col8" >17.93 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_45524_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_45524_row5_col0" class="data row5 col0" >sim_lbco</td>
#       <td id="T_45524_row5_col1" class="data row5 col1" >background</td>
#       <td id="T_45524_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_45524_row5_col3" class="data row5 col3" >y</td>
#       <td id="T_45524_row5_col4" class="data row5 col4" >0.2000</td>
#       <td id="T_45524_row5_col5" class="data row5 col5" >0.2643</td>
#       <td id="T_45524_row5_col6" class="data row5 col6" >0.0138</td>
#       <td id="T_45524_row5_col7" class="data row5 col7" ></td>
#       <td id="T_45524_row5_col8" class="data row5 col8" >32.15 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_45524_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_45524_row6_col0" class="data row6 col0" >sim_lbco</td>
#       <td id="T_45524_row6_col1" class="data row6 col1" >background</td>
#       <td id="T_45524_row6_col2" class="data row6 col2" >6</td>
#       <td id="T_45524_row6_col3" class="data row6 col3" >y</td>
#       <td id="T_45524_row6_col4" class

# %% [markdown]
# #### Exercise 5.3: Find the Misfit in the Fit
#
# Visualize the measured and calculated diffraction patterns after the
# fit. As you can see, the fit shows noticeable discrepancies. If you
# zoom in on different regions of the pattern, you will observe that all
# the calculated peaks are shifted to the left.
#
# What could be the reason for the misfit?

# %% [markdown]
# **Hint:**

# %% [markdown]
# Consider the following options:
# 1. The conversion parameters from TOF to d-spacing are not correct.
# 2. The lattice parameters of the LBCO phase are not correct.
# 3. The peak profile parameters are not correct.
# 4. The background points are not correct.

# %% [markdown]
# **Solution:**

# %% [markdown]
# 1. ❌ The conversion parameters from TOF to d-spacing were set based
# on the data reduction step. While they are specific to each dataset
# and thus differ from those used for the Si data, the full reduction
# workflow has already been validated with the Si fit. Therefore, they
# are not the cause of the misfit in this case.
# 2. ✅ The lattice parameters of the LBCO phase were set based on the
# CIF data, which is a good starting point, but they are not necessarily
# as accurate as needed for the fit. The lattice parameters may need to
# be refined.
# 3. ❌ The peak profile parameters do not change the position of the
# peaks, but rather their shape.
# 4. ❌ The background points affect the background level, but not the
# peak positions.

# %%
project_2.display.plotter.plot_meas_vs_calc(expt_name='sim_lbco')
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="a062795d-357b-4350-a458-5dcd5757d1a5" class="plotly-graph-div" style="height:600.0px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a062795d-357b-4350-a458-5dcd5757d1a5")) {                    Plotly.newPlot(                        "a062795d-357b-4350-a458-5dcd5757d1a5",                        [{"customdata":{"dtype":"f8","bdata":"Ro6RutwL0D\u002f4+AYP+UrSP8wS\u002fnV4btI\u002fMCRk290Uo78+eTa7RpzSP5UkKh2QRtI\u002f+IoBZtZ20j8AI3eaKrhiPwOlc1uRBtM\u002fflYOKydC0j\u002fKaQ73OHTSPyBnp4wMS4I\u002fbbst91Am0z9niPI4vj3SP8\u002fGJ1HMZNI\u002fwJO+wJQwiD9IdSTJCg7UP1C61kZVOdI\u002fk5O08BVQ0j9QG\u002f6GTd+bP4Nj+6elmdI\u002fOOy6VOw00j+wFvGr\u002fD7SP8A0kwI\u002fqnY\u002fMPXJL3U5zD\u002fWF95igzDSP+SC1GSuNNI\u002fMCG+M89fsL\u002fshCSHPO\u002fTP79JwnAaLNI\u002fr7lKKmAw0j\u002fQs5zNxe2bPyqwfDWTKdE\u002fqHumfrEn0j9lkTWIdDPSP7ATjisVnpC\u002fBoSfnKzizT+QrYqMSCPSP4x2k30QSdI\u002fSKQdetG9qr\u002fPHD6XudLQPy7ZrZrfHtI\u002fJPx9cb6W0j9Q9f2jTUCcv2ct7xDz5NQ\u002fFwuSqHYa0j8WgQE5K4XTPxDF2n59\u002fJU\u002fR9vipM2Z0T8APXa2DRbSP38pfzBRANY\u002f4DhxLg6asb\u002fTVztgD03WP+luWsSkEdI\u002fimWseVVw2z\u002fcNsRlGI20v7L5CPz17No\u002f0qA+0jsN0j8qWEfeFkHiP0RtC4FvKsO\u002fBTTkpWo74j9vzGHg0gjSP8AR4hgSYOc\u002f7Hb3y52SxL8jH3quAFzxP1j+Re5pBNI\u002f88O3chsi6j+m9HjUyyvRP6EN9Bf4dPU\u002fQTAq\u002fAAA0j+E1mfBbFfoP75EgG6DkuI\u002fYPwGlWGp9j8qYg4KmPvRPz2kR8i2LuM\u002fg1TGYQwk6j\u002fQbQCKc7zxPxOU8hcv99E\u002fugu3Cnjv2z\u002fDVaUOK4HlP+FV\u002fYpmr+c\u002fsL8VJsby0T\u002f7WrtZzYjVP8dQP7z\u002f1dk\u002fnK\u002f5FipR4D+Z8fkzXe7RP+C50
c0\u002f79T3FwIa2D\u002f\u002fWYHLip7RP5t\u002fV9uhRtI\u002fUFWB8oBNtz8JWApgogLXPy9DYtOzn9E\u002fEx0YpmHG0T\u002fY68jnAvG0P+EtS4D6StM\u002fEr5T29yg0T\u002fu2vsNGqjRPzAv9SQHLpo\u002fBXgIISde0j\u002f1OEXjBaLRP8oHeG03o9E\u002fYAcOcvZdhz83rEWJgAPRP9izNusuo9E\u002fjMO9w2Cj0T+g6gJPB\u002fyDv7CVjV7uZdM\u002fuy4o81ek0T96nLifZaTRP2CTT+2LGJw\u002fBGD64UtByz\u002fsFwn7gKXRP2aExjWTpdE\u002fkFElE7UTsL8ymLoDgrjOP8+S+gKqptE\u002fAZy8Ydim0T9Af\u002 ...

# %% [markdown]
# #### Exercise 5.4: Refine the LBCO Lattice Parameter
#
# To improve the fit, refine the lattice parameters of the LBCO phase.

# %% [markdown]
# **Hint:**

# %% [markdown]
# To achieve this, we will set the `free` attribute of the `length_a`
# parameter of the LBCO cell to `True`.
#
# LBCO has a cubic crystal structure (space group `P m -3 m`), which
# means that `length_b` and `length_c` are constrained to be equal to
# `length_a`. Therefore, only `length_a` needs to be refined; the other
# two will be updated automatically. All cell angles are fixed at 90°,
# so they do not require refinement.

# %% [markdown]
# **Solution:**

# %%
project_2.structures['lbco'].cell.length_a.free = True

project_2.analysis.fit()
project_2.analysis.display.fit_results()

project_2.display.plotter.plot_meas_vs_calc(expt_name='sim_lbco')
# Out:
# Standard fitting
# 📋 Using experiment 🔬 'sim_lbco' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_0556b   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_0556b thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_0556b th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_0556b  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_0556b th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_0556b tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_0556b  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_0556b th.col0 {
#   text-align: center;
# }
# #T_0556b th.col1 {
#   text-align: center;
# }
# #T_0556b th.col2 {
#   text-align: center;
# }
# #T_0556b_row0_col0, #T_0556b_row0_col1, #T_0556b_row0_col2, #T_0556b_row1_col0, #T_0556b_row1_col1, #T_0556b_row1_col2, #T_0556b_row2_col0, #T_0556b_row2_col1, #T_0556b_row2_col2, #T_0556b_row3_col0, #T_0556b_row3_col1, #T_0556b_row3_col2, #T_0556b_row4_col0, #T_0556b_row4_col1, #T_0556b_row4_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_0556b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0556b_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_0556b_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_0556b_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0556b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_0556b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0556b_row0_col1" class="data row0 col1" >70.43</td>
#       <td id="T_0556b_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_0556b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_0556b_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_0556b_row1_col1" class="data row1 col1" >11.61</td>
#       <td id="T_0556b_row1_col2" class="data row1 col2" >83.5% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_0556b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_0556b_row2_col0" class="data row2 col0" >23</td>
#       <td id="T_0556b_row2_col1" class="data row2 col1" >5.07</td>
#       <td id="T_0556b_row2_col2" class="data row2 col2" >56.3% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_0556b_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_0556b_row3_col0" class="data row3 col0" >33</td>
#       <td id="T_0556b_row3_col1" class="data row3 col1" >4.84</td>
#       <td id="T_0556b_row3_col2" class="data row3 col2" >4.6% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_0556b_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_0556b_row4_col0" class="data row4 col0" >65</td>
#       <td id="T_0556b_row4_col1" class="data row4 col1" >4.84</td>
#       <td id="T_0556b_row4_col2" class="data row4 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 4.84 at iteration 53
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 2.06 seconds
# 📏 Goodness-of-fit (reduced χ²): 4.84
# 📏 R-factor (Rf): 6.84%
# 📏 R-factor squared (Rf²): 6.38%
# 📏 Weighted R-factor (wR): 5.62%
# 📈 Fitted parameters:
# <style type="text/css">
# #T
# %% [markdown]
# One of the main goals of this study was to refine the lattice
# parameter of the LBCO phase. As shown in the updated fit results, the
# overall fit has improved significantly, even though the change in cell
# length is less than 1% of the initial value. This demonstrates how
# even a small adjustment to the lattice parameter can have a
# substantial impact on the quality of the fit.

# %% [markdown]
# #### Exercise 5.5: Visualize the Fit Results in d-spacing
#
# Plot measured vs calculated diffraction patterns in d-spacing instead
# of TOF.

# %% [markdown]
# **Hint:**

# %% [markdown]
# Use the `plot_meas_vs_calc` method of the project and set the
# `d_spacing` parameter to `True`.

# %% [markdown]
# **Solution:**

# %%
project_2.display.plotter.plot_meas_vs_calc(expt_name='sim_lbco', x='d_spacing')
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="f7b76b52-5ecb-4b49-8617-48b16592e12f" class="plotly-graph-div" style="height:600.0px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f7b76b52-5ecb-4b49-8617-48b16592e12f")) {                    Plotly.newPlot(                        "f7b76b52-5ecb-4b49-8617-48b16592e12f",                        [{"customdata":{"dtype":"f8","bdata":"Ro6RutwL0D\u002f0W3l\u002fHA7RPx0REXkFKtE\u002fcC3454vikb8+eTa7RpzSP6OnCR8PC9E\u002fbNQ8+3pB0T8gTZr\u002fu6yVPwOlc1uRBtM\u002fAl1uvgEI0T96bpFzulvRP5BoI35urZo\u002fbbst91Am0z9gEtNd9ATRPzPzrp4HaNE\u002foIPsh5Xkmz9IdSTJCg7UP7\u002fHN\u002f3mAdE\u002fZT\u002ficIha0T8YrxHCEpylP4Nj+6elmdI\u002fHX2cnNn+0D84dTuHJDrRP7Dk\u002fgsS+JU\u002fMPXJL3U5zD\u002fNyCw8zPvQPw1wBaR2GdE\u002fqKsDYeDlp7\u002fshCSHPO\u002fTPyx+kdu++NA\u002fLs+A4pwE0T\u002fwrR0l\u002fVSnPyqwfDWTKdE\u002fijP2erH10D8B6wDjUvzQP4CU4j0poGY\u002fBoSfnKzizT\u002fo6FoapPLQP2lPvUNt\u002f9A\u002fMGtsq7dwoL\u002fPHD6XudLQP5g067mW79A\u002fsv8JZ1AX0T\u002fAuPjysyVxv2ct7xDz5NQ\u002f9+lPWYns0D93gaFFamvRP4BfbVpGzKs\u002fR9vipM2Z0T9Vn7T4e+nQP84FU4kTc9I\u002f4FAFjrwoi7\u002fTVztgD03WP7RUGZhu5tA\u002fAgWMrQFf1T8gWupVtsGNP7L5CPz17No\u002fEgp+N2Hj0D9y\u002fp0d1n3cPwBMUBkCDpm\u002fBTTkpWo74j\u002fCVQ7XU+DQP7CONbSLK+U\u002fWNWKcgiBt78jH3quAFzxPyELc3ZG3dA\u002f3sKvJgL27j9A2yOy+Q++P6EN9Bf4dPU\u002ff8DXFTna0D8E\u002fIuW3rXzP9AZgRaY8bs\u002fYPwGlWGp9j\u002fedTy1K9fQP1L11XytXvQ\u002fcDiIwaBVwj\u002fQbQCKc7zxPzwroVQe1NA\u002fNM52xAnE8D+A8zOxOA2vP+FV\u002fYpmr+c\u002f7HYx9BDR0D9f6Rr728\u002fmP0CQ
b9yWRn3TC0WQJuAzUC5584\u002fW0g38+8fFUBwESE+0NXQPwKQuTj7ISJARFlbTGTpzj9qf+lSuIMgQIAJAV0u5Ok\u002fTGNCUZhfJkBFBAFYD+vOPzjW6eNNVyVAQNGI1aaE4D+Ef31bs8UkQEavpmO67M4\u002fM3g3VKXKJEAAvOLn4seDvywSxI35jx1AR1pMb2Xuzj\u002fQDXuPgz4eQIB03zZA0cW\u002fTqMgkrrOD0BIBfJ6EPDOPxG6Ou7E0h ...

# %% [markdown]
# The peak profile parameters are determined based on both the
# instrument and the sample characteristics, so they can vary when
# analyzing different samples on the same instrument. Therefore, it is
# better to refine them as well.
#
# Select the peak profile parameters to be refined during the fitting
# process.

# %% [markdown]
# **Hint:**

# %% [markdown]
# You can set the `free` attribute of the peak profile parameters to
# `True` to allow the fitting process to adjust them. You can use the
# same approach as in the previous part of the notebook, but this time
# you will refine the peak profile parameters of the LBCO phase.

# %% [markdown]
# **Solution:**

# %%
project_2.experiments['sim_lbco'].peak.broad_gauss_sigma_0.free = True
project_2.experiments['sim_lbco'].peak.broad_gauss_sigma_1.free = True
project_2.experiments['sim_lbco'].peak.broad_gauss_sigma_2.free = True
project_2.experiments['sim_lbco'].peak.exp_decay_beta_0.free = True
project_2.experiments['sim_lbco'].peak.exp_decay_beta_1.free = True
project_2.experiments['sim_lbco'].peak.exp_rise_alpha_0.free = True
project_2.experiments['sim_lbco'].peak.exp_rise_alpha_1.free = True

project_2.analysis.fit()
project_2.analysis.display.fit_results()

project_2.display.plotter.plot_meas_vs_calc(
    expt_name='sim_lbco', x='d_spacing', x_min=1.35, x_max=1.40
)
# Out:
# Standard fitting
# 📋 Using experiment 🔬 'sim_lbco' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_04eac   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_04eac thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_04eac th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_04eac  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_04eac th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_04eac tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_04eac  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_04eac th.col0 {
#   text-align: center;
# }
# #T_04eac th.col1 {
#   text-align: center;
# }
# #T_04eac th.col2 {
#   text-align: center;
# }
# #T_04eac_row0_col0, #T_04eac_row0_col1, #T_04eac_row0_col2, #T_04eac_row1_col0, #T_04eac_row1_col1, #T_04eac_row1_col2, #T_04eac_row2_col0, #T_04eac_row2_col1, #T_04eac_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_04eac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04eac_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_04eac_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_04eac_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04eac_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_04eac_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_04eac_row0_col1" class="data row0 col1" >4.92</td>
#       <td id="T_04eac_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_04eac_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_04eac_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_04eac_row1_col1" class="data row1 col1" >4.51</td>
#       <td id="T_04eac_row1_col2" class="data row1 col2" >8.3% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_04eac_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_04eac_row2_col0" class="data row2 col0" >327</td>
#       <td id="T_04eac_row2_col1" class="data row2 col1" >4.49</td>
#       <td id="T_04eac_row2_col2" class="data row2 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 4.49 at iteration 326
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 6.45 seconds
# 📏 Goodness-of-fit (reduced χ²): 4.49
# 📏 R-factor (Rf): 5.67%
# 📏 R-factor squared (Rf²): 4.84%
# 📏 Weighted R-factor (wR): 4.04%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_5e512   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_5e512 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_5e512 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_5e512  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_5e512 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_5e512 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_5e512  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_5e512 th.col0 {
#   text-align: left;
# }
# #T_5e512 th.col1 {
#   text-align: left;
# }
# #T_5e512 th.col2 {
#   text-align: left;
# }
# #T_5e512 th.col3 {
#   text-align: left;
# }
# #T_5e512 th.col4 {
#   text-align: right;
# }
# #T_5e512 th.col5 {
#   text-align: right;
# }
# #T_5e512 th.col6 {
#   text-align: right;
# }
# #T_5e512 th.col7 {
#   text-align: left;
# }
# #T_5e512 th.col8 {
#   text-align: right;
# }
# #T_5e512_row0_col0, #T_5e512_row0_col1, #T_5e512_row0_col2, #T_5e512_row0_col3, #T_5e512_row0_col7, #T_5e512_row1_col0, #T_5e512_row1_col1, #T_5e512_row1_col2, #T_5e512_row1_col3, #T_5e512_row1_col7, #T_5e512_row2_col0, #T_5e512_row2_col1, #T_5e512_row2_col2, #T_5e512_row2_col3, #T_5e512_row2_col7, #T_5e512_row3_col0, #T_5e512_row3_col1, #T_5e512_row3_col2, #T_5e512_row3_col3, #T_5e512_row3_col7, #T_5e512_row4_col0, #T_5e512_row4_col1, #T_5e512_row4_col2, #T_5e512_row4_col3, #T_5e512_row4_col7, #T_5e512_row5_col0, #T_5e512_row5_col1, #T_5e512_row5_col2, #T_5e512_row5_col3, #T_5e512_row5_col7, #T_5e512_row6_col0, #T_5e512_row6_col1, #T_5e512_row6_col2, #T_5e512_row6_col3, #T_5e512_row6_col7, #T_5e512_row7_col0, #T_5e512_row7_col1, #T_5e512_row7_col2, #T_5e512_row7_col3, #T_5e512_row7_col7, #T_5e512_row8_col0, #T_5e512_row8_col1, #T_5e512_row8_col2, #T_5e512_row8_col3, #T_5e512_row8_col7, #T_5e512_row9_col0, #T_5e512_row9_col1, #T_5e512_row9_col2, #T_5e512_row9_col3, #T_5e512_row9_col7, #T_5e512_row10_col0, #T_5e512_row10_col1, #T_5e512_row10_col2, #T_5e512_row10_col3, #T_5e512_row10_col7, #T_5e512_row11_col0, #T_5e512_row11_col1, #T_5e512_row11_col2, #T_5e512_row11_col3, #T_5e512_row11_col7, #T_5e512_row12_col0, #T_5e512_row12_col1, #T_5e512_row12_col2, #T_5e512_row12_col3, #T_5e512_row12_col7, #T_5e512_row13_col0, #T_5e512_row13_col1, #T_5e512_row13_col2, #T_5e512_row13_col3, #T_5e512_row13_col7, #T_5e512_row14_col0, #T_5e512_row14_col1, #T_5e512_row14_col2, #T_5e512_row14_col3, #T_5e512_row14_col7, #T_5e512_row15_col0, #T_5e512_row15_col1, #T_5e512_row15_col2, #T_5e512_row15_col3, #T_5e512_row15_col7 {
#   text-align: left;
# }
# #T_5e512_row0_col4, #T_5e512_row0_col5, #T_5e512_row0_col6, #T_5e512_row0_col8, #T_5e512_row1_col4, #T_5e512_row1_col5, #T_5e512_row1_col6, #T_5e512_row1_col8, #T_5e512_row2_col4, #T_5e512_row2_col5, #T_5e512_row2_col6, #T_5e512_row2_col8, #T_5e512_row3_col4, #T_5e512_row3_col5, #T_5e512_row3_col6, #T_5e512_row3_col8, #T_5e512_row4_col4, #T_5e512_row4_col5, #T_5e512_row4_col6, #T_5e512_row4_col8, #T_5e512_row5_col4, #T_5e512_row5_col5, #T_5e512_row5_col6, #T_
J3M4\u002f0MrSE05Vsz+evabhTQfSPyiyYJK92c4\u002fAc2t0MrZzj\u002fsuH7KQ9OkP+EGvPi6nNE\u002fmGMPsQbXzj\u002fpeWU4D9fOP2RPSuSaiaE\u002fL1zpV8b4zj\u002fqUZfPT9TOP+JAoFFV1M4\u002fgKaNJIM4Uj\u002fu6q2T+JTPPzxAH+6Y0c4\u002fSNu7gJzRzj\u002fA9EFegmt4P4kYz96Fv80\u002fji6nDOLOzj9b37ti ...

# %% [markdown]
# #### Exercise 5.8: Identify the Cause of the Unexplained Peaks
#
# Analyze the residual peaks that remain after refining the LBCO phase
# and the peak-profile parameters. Based on their positions and
# characteristics, decide which potential cause best explains the
# misfit.

# %% [markdown]
# **Hint:**

# %% [markdown]
# Consider the following options:
# 1. The LBCO phase is not correctly modeled.
# 2. The LBCO phase is not the only phase present in the sample.
# 3. The data reduction process introduced artifacts.
# 4. The studied sample is not LBCO, but rather a different phase.

# %% [markdown]
# **Solution:**

# %% [markdown]
# 1. ❌ In principle, this could be the case, as sometimes the presence
# of extra peaks in the diffraction pattern can indicate lower symmetry
# than the one used in the model, or that the model is not complete.
# However, in this case, the LBCO phase is correctly modeled based on
# the CIF data.
# 2. ✅ The unexplained peaks are due to the presence of an impurity
# phase in the sample, which is not included in the current model.
# 3. ❌ The data reduction process is not likely to introduce such
# specific peaks, as it is tested and verified in the previous part of
# the notebook.
# 4. ❌ This could also be the case in real experiments, but in this
# case, we know that the sample is LBCO, as it was simulated based on
# the CIF data.

# %% [markdown]
# #### Exercise 5.9: Identify the impurity phase
#
# Use the positions of the unexplained peaks to identify the most likely
# secondary phase present in the sample.

# %% [markdown]
# **Hint:**

# %% [markdown]
# Check the positions of the unexplained peaks in the diffraction
# pattern. Compare them with the known diffraction patterns in the
# previous part of the notebook.

# %% [markdown]
# **Solution:**

# %% [markdown]
# The unexplained peaks are likely due to the presence of a small amount
# of Si in the LBCO sample. In real experiments, it might happen, e.g.,
# because the sample holder was not cleaned properly after the Si
# experiment.
#
# You can visalize both the patterns of the Si and LBCO phases to
# confirm this hypothesis.

# %%
project_1.display.plotter.plot_meas_vs_calc(expt_name='sim_si', x='d_spacing', x_min=1, x_max=1.7)
project_2.display.plotter.plot_meas_vs_calc(
    expt_name='sim_lbco', x='d_spacing', x_min=1, x_max=1.7
)
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="1845204f-bfd1-441d-b42b-c889ebfda6d0" class="plotly-graph-div" style="height:600.0px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1845204f-bfd1-441d-b42b-c889ebfda6d0")) {                    Plotly.newPlot(                        "1845204f-bfd1-441d-b42b-c889ebfda6d0",                        [{"customdata":{"dtype":"f8","bdata":"ZBHr1WyLnD9F\u002fu\u002fy\u002fYV\u002fP27jCiH+hX8\u002fiFioTe2plD+uQU\u002ffxVCNP8N3vPpYM4A\u002fjTLNRlkzgD9CHgQx2Tp6P+8ZYkljqaE\u002fZPAA\u002fLKjgD+OjAT1s6OAP5ftQZjsAJs\u002fHxzXjTNfhz8LaUX9DBSBP49sFiYQFIE\u002fQL4Cn40saT8SsNw2BXqEPyYOjPhmhIE\u002fdFM1J3GEgT\u002fw5D
9866y9eKXQP598dap\u002fUdE\u002f+CGvXZE0or94X\u002f5k2gTPP6U5mRcypdA\u002fbeQs2L8y0T8QS9taKgWbv9ud+CuSPM8\u002fz4eFceuk0D\u002f2jg1Le\u002fbQP4gAFFEjg5W\u002fhlEj\u002fIKJzj\u002f41XHLpKTQP7l7c4fbxtA\u002fYC8dlqAhmL\u002f4IL1le\u002fjQPwUVYiVepNA\u002f0sCM1bav0D+ACRgMJDFyPwNMWzkMH84\u002fLmNOfxek0D+7BMlobafQP5jrtcF0fpm\u002fEykGotZVzz9XsTrZ0KPQP6deuabUpNA\u002fsEPJtio9j78oupY9cAXSP4H\u002fJjOKo9A\u002fpXGp2wik0D8wiNQedhaWP3f2rmh4LdE\u002fqk0TjUOj0D9WbTTx8KPQPyAkUe\u002fuMIE\u002f1J+5jdn81T+2jAPn\u002fKLQP7l3csaLpNA\u002fbKAcHTdhtT+Tf31oItfRP+Da70C2otA\u002fxp7d\u002fpum0D\u002fQDP6ZZgiTP4XoLO5+mNA\u002fCSncmm+i0D87MnTCPKzQPwC2SUfUvVO\u002fBmik5iOa0z8yd8j0KKLQP5hDGVu1utA\u002fcCNZXHT7pj9suMnjKkvVPz+2uE7iodA\u002fzdrzTw3f0D98dldPdrCxPxpOHi69\u002fNg\u002faASlqJuh0D+mswxvOTnRP9BpRvwODr8\u002fTNFs7aUp2z+RUpECVaHQP3DBJLUtF9I\u002fuB+QcPAkwj9jPvkUZafbP7ugfVwOodA\u002fNTkxqwU21D+4FCCnfcW9P0PHY+tezNo\u002f5O5ptseg0D9uiXx6XVzZP1Ddcw4XAJc\u002fUzjUmCRf4z\u002fwLVoQgaDQP2gJdTey0+I\u002fYN3lK0xukT\u002fV9gFWOGLwPxp8Rmo6oNA\u002fgyP0FW5M8D8AUtMNQMp1P7j6wSQKjvs\u002fQ8oyxPOf0D8o0it12Cr9PwB3nQblzLm\u002fFitMx+P0BkBtGB8erZ\u002fQP+7CvFD8vwZAABS0R7tzmj\u002fo8RKs20UKQJZmC3hmn9A\u002f7E5+aa8HC0CAoGutdzq4v848AGxzXghAoqX70R+f0D8TH8cXr\u002fgGQLDbkUNFXMY\u002fyt3kKSge\u002fT\u002fM8+cr2Z7QP9GFbk36fPw\u002fIP\u002fKjrslpD823xNujk3tP\u002fVB1IW ...

# %% [markdown]
# #### Exercise 5.10: Create a Second Structure – Si as Impurity
#
# Create a second structure for the Si phase, which is the impurity
# phase identified in the previous step. Link this structure to the
# LBCO experiment.

# %% [markdown]
# **Hint:**

# %% [markdown]
# You can use the same approach as in the previous part of the notebook,
# but this time you need to create a structure for Si and link it to
# the LBCO experiment.

# %% [markdown]
# **Solution:**

# %%
# Set Space Group
project_2.structures.create(name='si')
project_2.structures['si'].space_group.name_h_m = 'F d -3 m'
project_2.structures['si'].space_group.it_coordinate_system_code = '2'

# Set Lattice Parameters
project_2.structures['si'].cell.length_a = 5.43

# Set Atom Sites
project_2.structures['si'].atom_sites.create(
    label='Si',
    type_symbol='Si',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    adp_iso=0.89,
)

# Assign Structure to Experiment
project_2.experiments['sim_lbco'].linked_phases.create(id='si', scale=1.0)

# %% [markdown]
# #### Exercise 5.11: Refine the Scale of the Si Phase
#
# Visualize the measured diffraction pattern and the calculated
# diffraction pattern. Check if the Si phase is contributing to the
# calculated diffraction pattern. Refine the scale factor of the Si
# phase to improve the fit.

# %% [markdown]
# **Hint:**

# %% [markdown]
# You can use the `plot_meas_vs_calc` method of the project to visualize
# the patterns. Then, set the `free` attribute of the `scale` parameter
# of the Si phase to `True` to allow the fitting process to adjust the
# scale factor.

# %% [markdown]
# **Solution:**

# %%
# Before optimizing the parameters, we can visualize the measured
# diffraction pattern and the calculated diffraction pattern based on
# the two phases: LBCO and Si.
project_2.display.plotter.plot_meas_vs_calc(expt_name='sim_lbco')

# As you can see, the calculated pattern is now the sum of both phases,
# and Si peaks are visible in the calculated pattern. However, their
# intensities are much too high. Therefore, we need to refine the scale
# factor of the Si phase.
project_2.experiments['sim_lbco'].linked_phases['si'].scale.free = True

# Now we can perform the fit with both phases included.
project_2.analysis.fit()
project_2.analysis.display.fit_results()

# Let's plot the measured diffraction pattern and the calculated
# diffraction pattern both for the full range and for a zoomed-in region
# around the previously unexplained peak near 95,000 μs. The calculated
# pattern will be the sum of the two phases.
project_2.display.plotter.plot_meas_vs_calc(expt_name='sim_lbco')
project_2.display.plotter.plot_meas_vs_calc(expt_name='sim_lbco', x_min=88000, x_max=101000)
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="b2e6d74c-57cf-4bd4-ad22-302a2b941bee" class="plotly-graph-div" style="height:618.936170212766px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b2e6d74c-57cf-4bd4-ad22-302a2b941bee")) {                    Plotly.newPlot(                        "b2e6d74c-57cf-4bd4-ad22-302a2b941bee",                        [{"customdata":{"dtype":"f8","bdata":"Ro6RutwL0D+wdgfxYCLRP0o0ep23PNE\u002fQGCKLq4Nk78+eTa7RpzSPwXg+HybH9E\u002fKo03HftV0T9Awe7fuWSUPwOlc1uRBtM\u002fILbCCNYc0T\u002f2hzjXI3bRP9DQsUPYBpk\u002fbbst91Am0z87jIyUEBrRP8jb1Wo\u002fj9E\u002fUPp9xRhxmT9IdSTJCg7UP1ZiViBLF9E\u002fHpzJZDii0T9QydYik16jP4Nj+6elmdI\u002fcDggrIUU0T+08xibF+bRP+D5TZzBcYY\u002fMPXJL3U5zD\u002fFoRE4wBHRP6b9cCzm9tI\u002fOAwwUq5os7\u002fshCSHPO\u002fTP+B328P6DtE\u002fXAnuwsIq1j+AI0zeMdyhvyqwfDWTKdE\u002f+02lTzUM0T+qMmzonMbdPwAF32UTOsm\u002fBoSfnKzizT8VJG\u002fbbwnRP9cPVAP+vuU\u002fq11YuKWM3L\u002fPHD6XudLQP2qNYGeqBtE\u002fuFseTCgc7j9QTX+Ay7Llv2ct7xDz5NQ\u002fhWMq8+QD0T9LL9QryJPxP+LHMM8Wtei\u002fR9vipM2Z0T+gOfR+HwHRP5Atz7\u002fofPA\u002ffO0sreos6L\u002fTVztgD03WP7sPvgpa\u002ftA\u002fGsHAAUP36T9
h7O40T8gkEmeDG2KP2rd\u002f4aFK9Q\u002fLeNxTxis0D\u002fgDcAeznzTP0Dx+Qft1oU\u002fU4UWvO+u1D9WMV6p0avQP\u002fKsHAqg3dc\u002f+DwxcIJ1qb+kXuKEnBHZP39\u002fSgOLq9A\u002f6GBIZfOs4D9YxlyLlJDAv1fFM4JFA+M\u002fjL46XUSr0D\u002ffqbLkKy7pPyCS+4mZq8i\u002fCjBUSEtG5D+1DCe3\u002farQP9P6a0+K3PI\u002fnMWDVsly4b8pip8xWg3mP95aExG3qtA\u002fTmVjiUl8+j9zQCfhOOvuv7TPMvFdQOE\u002fCKn\u002fanCq0D\u002fD43O4WXEAQKxfTniEQvi\u002f79T3FwIa2D8x9+vEKarQP+VtjZKHrQBAjuYcn45U+78JWApgogLXPz023B7jqdA\u002fmIsk+KYh+j+W9SFg\u002fmD0v+EtS4D6StM\u002fZ4TIeJyp0D+GojFyShXwPxyuPaQXhea\u002fBXgIISde0j+Q0rTSVanQP\u002ft4GnFO0OE\u002f8XkswXVC0b83rEWJgAPRP7ogoSwPqdA\u002fG6c+IeeH1j+Q6+NfmhG2v7CVjV7uZdM\u002f426Nhsio0D8Clz23fDXSP+Dq\u002f3QaB5M\u002fBGD64UtByz\u002fvrX3ggajQPx2bifCKCtE\u002f2Fhj\u002fCdPq78ymLoDgrjOPxn8aTo7qNA\u002f1NiYklHA0D+wy7gLCUGWv5jltZeZts8\u002fQkpWlPSn0D\u002fdLcGKFa7Q ...
# Standard fitting
# 📋 Using experiment 🔬 'sim_lbco' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_9d4f1   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_9d4f1 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_9d4f1 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_9d4f1  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_9d4f1 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_9d4f1 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_9d4f1  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_9d4f1 th.col0 {
#   text-align: center;
# }
# #T_9d4f1 th.col1 {
#   text-align: center;
# }
# #T_9d4f1 th.col2 {
#   text-align: center;
# }
# #T_9d4f1_row0_col0, #T_9d4f1_row0_col1, #T_9d4f1_row0_col2, #T_9d4f1_row1_col0, #T_9d4f1_row1_col1, #T_9d4f1_row1_col2, #T_9d4f1_row2_col0, #T_9d4f1_row2_col1, #T_9d4f1_row2_col2, #T_9d4f1_row3_col0, #T_9d4f1_row3_col1, #T_9d4f1_row3_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_9d4f1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d4f1_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_9d4f1_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_9d4f1_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d4f1_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9d4f1_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_9d4f1_row0_col1" class="data row0 col1" >2254.38</td>
#       <td id="T_9d4f1_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_9d4f1_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9d4f1_row1_col0" class="data row1 col0" >21</td>
#       <td id="T_9d4f1_row1_col1" class="data row1 col1" >1.56</td>
#       <td id="T_9d4f1_row1_col2" class="data row1 col2" >99.9% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_9d4f1_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9d4f1_row2_col0" class="data row2 col0" >39</td>
#       <td id="T_9d4f1_row2_col1" class="data row2 col1" >1.54</td>
#       <td id="T_9d4f1_row2_col2" class="data row2 col2" >1.5% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_9d4f1_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9d4f1_row3_col0" class="data row3 col0" >688</td>
#       <td id="T_9d4f1_row3_col1" class="data row3 col1" >1.54</td>
#       <td id="T_9d4f1_row3_col2" class="data row3 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 1.54 at iteration 687
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 17.51 seconds
# 📏 Goodness-of-fit (reduced χ²): 1.54
# 📏 R-factor (Rf): 4.62%
# 📏 R-factor squared (Rf²): 4.04%
# 📏 Weighted R-factor (wR): 3.54%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_31a45   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_31a45 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_31a45 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_31a45  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_31a45 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_31a45 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_31a45  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_31a45 th.col0 {
#   text-align: left;
# }
# #T_31a45 th.col1 {
#   text-align: left;
# }
# #T_31a45 th.col2 {
#   text-align: left;
# }
# #T_31a45 th.col3 {
#   text-align: left;
# }
# #T_31a45 th.col4 {
#   text-align: right;
# }
# #T_31a45 th.col5 {
#   text-align: right;
# }
# #T_31a45 th.col6 {
#   text-align: right;
# }
# #T_31a45 th.col7 {
#   text-align: left;
# }
# #T_31a45 th.col8 {
#   text-align: right;
# }
# #T_31a45_row0_col0, #T_31a45_row0_col1, #T_31a45_row0_col2, #T_31a45_row0_col3, #T_31a45_row0_col7, #T_31a45_row1_col0, #T_31a45_row1_col1, #T_31a45_row1_col2, #T_31a45_row1_col3, #T_31a45_row1_col7, #T_31a45_row2_col0, #T_31a45_row2_col1, #T_31a45_row2_col2, #T_31a45_row2_col3, #T_31a45_row2_col7, #T_31a45_row3_col0, #T_31a45_row3_col1, #T_31a45_row3_col2, #T_31a45_row3_col3, #T_31a45_row3_col7, #T_31a45_row4_col0, #T_31a45_row4_col1, #T_31a45_row4_col2, #T_31a45_row4_col3, #T_31a45_row4_col7, #T_31a45_row5_col0, #T_31a45_row5_col1, #T_31a45_row5_col2, #T_31a45_row5_col3, #T_31a45_row5_col7, #T_31a45_row6_col0, #T_31a45_row6_col1, #T_31a45_row6_col2, #T_31a45_row6_col3, #T_31a45_row6_col7, #T_31a45_row7_col0, #T_31a45_row7_col1, #T_31a45_row7_col2, #T_31a45_row7_col3, #T_31a45_row7_col7, #T_31a45_row8_col0, #T_31a45_row8_col1, #T_31a45_row8_col2, #T_31a45_row8_col3, #T_31a45_row8_col7, #T_31a45_row9_col0, #T_31a45_row9_col1, #T_31a45_row9_col2, #T_31a45_row9_col3, #T_31a45_row9_col7, #T_31a45_row10_col0, #T_31a45_row10_col1, #T_31a45_row10_col2, #T_31a45_row10_col3, #T_31a45_row10_col7, #T_31a45_row11_col0, #T_31a45_row11_col1, #T_31a45_row11_col2, #T_31a45_row11_col3, #T_31a45_row11_col7, #T_31a45_row12_col0, #T_31a45_row12_col1, #T_31a45_row12_col2, #T_31a45_row12_col3, #T_31a45_row12_col7, #T_31a45_row13_col0, #T_31a45_row13_col1, #T_31a45_row13_col2, #T_31a45_row13_col3, #T_31a45_row13_col7, #T_31a45_row14_col0, #T_31a45_row14_col1, #T_31a45_row14_col2, #T_31a45_row14_col3, #T_31a45_row14_col7, #T_31a45_row15_col0, #T_31a45_row15_col1, #T_31a45_row15_col2, #T_31a45_row15_col3, #T_31a45_row15_col7, #T_31a45_row16_col0, #T_31a45_row16_col1, #T_31a45_row16_col2, #T_31a45_row16_col3, #T_31a45_row16_col7 {
#   text-align: left;
# }
\u002fBF4ifIwEzj9hexix8XrWPwAOBH7V\u002fVY\u002frTlks8Wi0z+QcojpoPzNP5zQGf+UwNM\u002fAO+WtUvPXb9erAdz07XTPx2H7la19M0\u002f8IMlgt4F0j\u002fghiIOT\u002f+aP7SzawoMMNE\u002fqZtUxMnszT9CZzkNzezQP4Ack0y\u002fz3A\u002fCmak\u002fZvj0D81sLox3uTNP6oOkJ+qOtA\u002fAOyKwisehT\u002fKRhv3PqzOPyPfkZ\u002fy3M0\u002fg7eShPWVzz8gF+6u0TZ9vwDVl1CeyM0\u002frvP3DAfVzT+paDarzQ7PP5A66an1YoS\u002fDMG3dG3H0D87CF56G83NP6ULsHGpxc4\u002fmLP7vYtJlj9p8sZ8WwnNP8ccxOcvxc0\u002fO6g1bAetzj8gXev2vjqKv1XeYh2yg84\u002fVDEqVUS9zT9YuMABB8HOP4AB7S5yql6\u002fT19Am2sHzj9BYAHDWLXNP1ceUCtLBs8\u002fAOH3AfLbf78HzAWWee\u002fQP850ZzBtrc0\u002fK4T5xHy ...

# %% [markdown]
# All previously unexplained peaks are now accounted for in the pattern,
# and the fit is improved. Some discrepancies in the peak intensities
# remain, but further improvements would require more advanced data
# reduction and analysis, which are beyond the scope of this school.
#
# To review the analysis results, you can generate and print a summary
# report using the `show_report()` method, as demonstrated in the cell
# below. The report includes parameters related to the structure and
# the experiment, such as the refined unit cell parameter `a` of LBCO.
#
# Information about the crystal or magnetic structure, along with
# experimental details, fitting quality, and other relevant data, is
# often submitted to crystallographic journals as part of a scientific
# publication. It can also be deposited in crystallographic databases
# when relevant.

# %%
project_2.summary.show_report()
# Out:
# ————————————
# PROJECT INFO
# ————————————
# Title
# La0.5Ba0.5CoO3 Fit
# Description
# Fitting simulated powder diffraction pattern of
# La0.5Ba0.5CoO3.
# —————————————————————
# CRYSTALLOGRAPHIC DATA
# —————————————————————
# Phase datablock
# 🧩 lbco
# Space group
# P m -3 m
# <style type="text/css">
# #T_71a89   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_71a89 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_71a89 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_71a89  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_71a89 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_71a89 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_71a89  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_71a89 th.col0 {
#   text-align: left;
# }
# #T_71a89 th.col1 {
#   text-align: right;
# }
# #T_71a89 th.col2 {
#   text-align: right;
# }
# #T_71a89_row0_col0, #T_71a89_row1_col0, #T_71a89_row2_col0, #T_71a89_row3_col0, #T_71a89_row4_col0, #T_71a89_row5_col0 {
#   text-align: left;
# }
# #T_71a89_row0_col1, #T_71a89_row0_col2, #T_71a89_row1_col1, #T_71a89_row1_col2, #T_71a89_row2_col1, #T_71a89_row2_col2, #T_71a89_row3_col1, #T_71a89_row3_col2, #T_71a89_row4_col1, #T_71a89_row4_col2, #T_71a89_row5_col1, #T_71a89_row5_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_71a89" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71a89_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_71a89_level0_col1" class="col_heading level0 col1" >Value</th>
#       <th id="T_71a89_level0_col2" class="col_heading level0 col2" >Uncertainty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71a89_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_71a89_row0_col0" class="data row0 col0" >a</td>
#       <td id="T_71a89_row0_col1" class="data row0 col1" >3.89125178</td>
#       <td id="T_71a89_row0_col2" class="data row0 col2" >0.00015674</td>
#     </tr>
#     <tr>
#       <th id="T_71a89_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_71a89_row1_col0" class="data row1 col0" >b</td>
#       <td id="T_71a89_row1_col1" class="data row1 col1" >3.89125178</td>
#       <td id="T_71a89_row1_col2" class="data row1 col2" >0.00015674</td>
#     </tr>
#     <tr>
#       <th id="T_71a89_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_71a89_row2_col0" class="data row2 col0" >c</td>
#       <td id="T_71a89_row2_col1" class="data row2 col1" >3.89125178</td>
#       <td id="T_71a89_row2_col2" class="data row2 col2" >0.00015674</td>
#     </tr>
#     <tr>
#       <th id="T_71a89_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_71a89_row3_col0" class="data row3 col0" >α</td>
#       <td id="T_71a89_row3_col1" class="data row3 col1" >90.00000000</td>
#       <td id="T_71a89_row3_col2" class="data row3 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_71a89_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_71a89_row4_col0" class="data row4 col0" >β</td>
#       <td id="T_71a89_row4_col1" class="data row4 col1" >90.00000000</td>
#       <td id="T_71a89_row4_col2" class="data row4 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_71a89_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_71a89_row5_col0" class="data row5 col0" >γ</td>
#       <td id="T_71a89_row5_col1" class="data row5 col1" >90.00000000</td>
#       <td id="T_71a89_row5_col2" class="data row5 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# Atom sites
# <style type="text/css">
# #T_76784   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_76784 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_76784 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_76784  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_76784 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_76784 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_76784  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_76784 th.col0 {
#   text-align: left;
# }
# #T_76784 th.col1 {
#   text-align: left;
# }
# #T_76784 th.col2 {
#   text-align: right;
# }
# #T_76784 th.col3 {
#   text-align: right;
# }
# #T_76784 th.col4 {
#   text-align: right;
# }
# #T_76784 th.col5 {
#   text-align: right;
# }
# #T_76784 th.col6 {
#   text-align: right;
# }
# #T_76784_row0_col0, #T_76784_row0_col1, #T_76784_row1_col0, #T_76784_row1_col1, #T_76784_row2_col0, #T_76784_row2_col1, #T_76784_row3_col0, #T_76784_row3_col1 {
#   text-align: left;
# }
# #T_76784_row0_col2, #T_76784_row0_col3, #T_76784_row0_col4, #T_76784_row0_col5, #T_76784_row0_col6, #T_76784_row1_col2, #T_76784_row1_col3, #T_76784_row1_col4, #T_76784_row1_col5, #T_76784_row1_col6, #T_76784_row2_col2, #T_76784_row2_col3, #T_76784_row2_col4, #T_76784_row2_col5, #T_76784_row2_col6, #T_76784_row3_col2, #T_76784_row3_col3, #T_76784_row3_col4, #T_76784_row3_col5, #T_76784_row3_col6 {
#   text-align: right;
# }
# </style>
# <table id="T_76784" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76784_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_76784_level0_col1" class="col_heading level0 col1" >type</th>
#       <th id="T_76784_level0_col2" class="col_heading level0 col2" >x</th>
#       <th id="T_76784_level0_col3" class="col_heading level0 col3" >y</th>
#       <th id="T_76784_level0_col4" class="col_heading level0 col4" >z</th>
#       <th id="T_76784_level0_col5" class="col_heading level0 col5" >occ</th>
#       <th id="T_76784_level0_col6" class="col_heading level0 col6" >Biso</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76784_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_76784_row0_col0" class="data row0 col0" >La</td>
#       <td id="T_76784_row0_col1" class="data row0 col1" >La</td>
#       <td id="T_76784_row0_col2" class="data row0 col2" >0.00000000</td>
#       <td id="T_76784_row0_col3" class="data row0 col3" >0.00000000</td>
#       <td id="T_76784_row0_col4" class="data row0 col4" >0.00000000</td>
#       <td id="T_76784_row0_col5" class="data row0 col5" >0.50000000</td>
#       <td id="T_76784_row0_col6" class="data row0 col6" >0.95000000</td>
#     </tr>
#     <tr>
#       <th id="T_76784_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_76784_row1_col0" class="data row1 col0" >Ba</td>
#       <td id="T_76784_row1_col1" class="data row1 col1" >Ba</td>
#       <td id="T_76784_row1_col2" class="data row1 col2" >0.00000000</td>
#       <td id="T_76784_row1_col3" class="data row1 col3" >0.00000000</td>
#       <td id="T_76784_row1_col4" class="data row1 col4" >0.00000000</td>
#       <td id="T_76784_row1_col5" class="data row1 col5" >0.50000000</td>
#       <td id="T_76784_row1_col6" class="data row1 col6" >0.95000000</td>
#     </tr>
#     <tr>
#       <th id="T_76784_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T
col6 {
#   text-align: right;
# }
# </style>
# <table id="T_6e3f7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e3f7_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_6e3f7_level0_col1" class="col_heading level0 col1" >type</th>
#       <th id="T_6e3f7_level0_col2" class="col_heading level0 col2" >x</th>
#       <th id="T_6e3f7_level0_col3" class="col_heading level0 col3" >y</th>
#       <th id="T_6e3f7_level0_col4" class="col_heading level0 col4" >z</th>
#       <th id="T_6e3f7_level0_col5" class="col_heading level0 col5" >occ</th>
#       <th id="T_6e3f7_level0_col6" class="col_heading level0 col6" >Biso</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e3f7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6e3f7_row0_col0" class="data row0 col0" >Si</td>
#       <td id="T_6e3f7_row0_col1" class="data row0 col1" >Si</td>
#       <td id="T_6e3f7_row0_col2" class="data row0 col2" >0.12500000</td>
#       <td id="T_6e3f7_row0_col3" class="data row0 col3" >0.12500000</td>
#       <td id="T_6e3f7_row0_col4" class="data row0 col4" >0.12500000</td>
#       <td id="T_6e3f7_row0_col5" class="data row0 col5" >1.00000000</td>
#       <td id="T_6e3f7_row0_col6" class="data row0 col6" >0.89000000</td>
#     </tr>
#   </tbody>
# </table>
# ———————————
# EXPERIMENTS
# ———————————
# Experiment datablock
# 🔬 sim_lbco
# Experiment type
# powder, neutron, time-of-flight bragg
# Calculation engine
# cryspy
# Profile type
# jorgensen
# ———————
# FITTING
# ———————
# Minimization engine
# lmfit (leastsq)
# Fit quality
# <style type="text/css">
# #T_ce63f   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_ce63f thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_ce63f th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_ce63f  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_ce63f th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_ce63f tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_ce63f  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_ce63f th.col0 {
#   text-align: left;
# }
# #T_ce63f th.col1 {
#   text-align: right;
# }
# #T_ce63f_row0_col0 {
#   text-align: left;
# }
# #T_ce63f_row0_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_ce63f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce63f_level0_col0" class="col_heading level0 col0" >metric</th>
#       <th id="T_ce63f_level0_col1" class="col_heading level0 col1" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce63f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ce63f_row0_col0" class="data row0 col0" >Goodness-of-fit (reduced χ²)</td>
#       <td id="T_ce63f_row0_col1" class="data row0 col1" >1.54</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Finally, we save the project to disk to preserve the current state of
# the analysis.

# %%
project_2.save_as(dir_path='data/powder_diffraction_LBCO_Si')
# Out:
# Saving project 📦 'main' to
# /home/runner/work/diffraction-lib/diffraction-lib/docs/docs/tutorials/data/powder_diffraction_LBCO_Si
# ├── 📄 project.cif
# ├── 📁 structures/
# │   └── 📄 lbco.cif
# │   └── 📄 si.cif
# ├── 📁 experiments/
# │   └── 📄 sim_lbco.cif
# ├── 📁 analysis/
# │   └── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# #### Final Remarks
#
# In this part of the notebook, you learned how to use EasyDiffraction
# to refine lattice parameters of a more complex crystal structure,
# La₀.₅Ba₀.₅CoO₃ (LBCO).
#
# In real experiments, you might also refine
# additional parameters, such as atomic positions, occupancies, and
# atomic displacement factors, to achieve an even better fit. For our
# purposes, we'll stop here, as the goal was to give you a starting
# point for analyzing more complex crystal structures with
# EasyDiffraction.

# %% [markdown]
# ## 🎁 Bonus
#
# Congratulations — you've now completed the diffraction data analysis
# part of the DMSC Summer School!
#
# If you'd like to keep exploring, the EasyDiffraction library offers
# many additional tutorials and examples on the official documentation
# site: 👉 https://docs.easydiffraction.org/lib/tutorials/
#
# Besides the Python package, EasyDiffraction also comes with a
# graphical user interface (GUI) that lets you perform similar analyses
# without writing code. To be fair, it's not *quite* feature-complete
# compared to the Python library yet — but we're working on it! 🚧
#
# If you prefer a point-and-click interface over coding, the GUI
# provides a user-friendly way to analyze diffraction data. You can
# download it as a standalone application here: 👉
# https://easydiffraction.org
#
# We'd love to hear your feedback on EasyDiffraction — both the library
# and the GUI! 💬
