# %%
# Check if the easydiffraction library is installed.
# If not, install it with the 'visualization' extras.
# Needed when running remotely (e.g. Colab) where the lib is absent.
import builtins
import importlib.util

if (hasattr(builtins, '__IPYTHON__') and
    importlib.util.find_spec('easydiffraction') is None):
    # !pip install 'easydiffraction[visualization]'

# %% [markdown]
# # Structure Refinement: LBCO, HRPT
#
# This example demonstrates how to use the EasyDiffraction API in a
# simplified, user-friendly manner that closely follows the GUI workflow
# for a Rietveld refinement of La0.5Ba0.5CoO3 crystal structure using
# constant wavelength neutron powder diffraction data from HRPT at PSI.
#
# It is intended for users with minimal programming experience who want
# to learn how to perform standard crystal structure fitting using
# diffraction data. This script covers creating a project, adding sample
# models and experiments, performing analysis, and refining parameters.
#
# Only a single import of `easydiffraction` is required, and all
# operations are performed through high-level components of the
# `project` object, such as `project.sample_models`,
# `project.experiments`, and `project.analysis`. The `project` object is
# the main container for all information.

# %% [markdown]
# ## Import Library

# %%
import easydiffraction as ed

# %% [markdown]
# ## Step 1: Create a Project
#
# This section explains how to create a project and define its metadata.

# %% [markdown]
# #### Create Project

# %%
project = ed.Project(name='lbco_hrpt')

# %% [markdown]
# #### Set Project Metadata

# %%
project.info.title = 'La0.5Ba0.5CoO3 at HRPT@PSI'
project.info.description = """This project demonstrates a standard
refinement of La0.5Ba0.5CoO3, which crystallizes in a perovskite-type
structure, using neutron powder diffraction data collected in constant
wavelength mode at the HRPT diffractometer (PSI)."""

# %% [markdown]
# #### Show Project Metadata as CIF

# %%
project.info.show_as_cif()
# Out:
# Project 📦 'lbco_hrpt' info as CIF
# <style type="text/css">
# #T_7b293   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_7b293 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_7b293 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7b293  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7b293 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_7b293 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_7b293  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_7b293 th.col0 {
#   text-align: left;
# }
# #T_7b293_row0_col0, #T_7b293_row1_col0, #T_7b293_row2_col0, #T_7b293_row3_col0, #T_7b293_row4_col0, #T_7b293_row5_col0, #T_7b293_row6_col0, #T_7b293_row7_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_7b293" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b293_level0_col0" class="col_heading level0 col0" >CIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b293_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7b293_row0_col0" class="data row0 col0" >_project.id               lbco_hrpt</td>
#     </tr>
#     <tr>
#       <th id="T_7b293_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7b293_row1_col0" class="data row1 col0" >_project.title            'La0.5Ba0.5CoO3 at HRPT@PSI'</td>
#     </tr>
#     <tr>
#       <th id="T_7b293_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7b293_row2_col0" class="data row2 col0" >_project.description      </td>
#     </tr>
#     <tr>
#       <th id="T_7b293_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_7b293_row3_col0" class="data row3 col0" >;</td>
#     </tr>
#     <tr>
#       <th id="T_7b293_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_7b293_row4_col0" class="data row4 col0" >This project demonstrates a standard refinement of La0.5Ba0.5CoO3, which crystallizes in a perovskite-type structure, using neutron powder diffraction data collected in constant wavelength mode at the HRPT diffractometer (PSI).</td>
#     </tr>
#     <tr>
#       <th id="T_7b293_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_7b293_row5_col0" class="data row5 col0" >;</td>
#     </tr>
#     <tr>
#       <th id="T_7b293_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_7b293_row6_col0" class="data row6 col0" >_project.created          '30 Dec 2025 21:20:29'</td>
#     </tr>
#     <tr>
#       <th id="T_7b293_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_7b293_row7_col0" class="data row7 col0" >_project.last_modified    '30 Dec 2025 21:20:29'</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Save Project
#
# When saving the project for the first time, you need to specify the
# directory path. In the example below, the project is saved to a
# temporary location defined by the system.

# %%
project.save_as(dir_path='lbco_hrpt', temporary=True)
# Out:
# Saving project 📦 'lbco_hrpt' to
# /private/var/folders/sm/xrr7tmqj20s7hrsh1qhfl1d40000gn/T/lbco_hrpt
# ├── 📄 project.cif
# ├── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# #### Set Up Data Plotter

# %% [markdown]
# Show supported plotting engines.

# %%
project.plotter.show_supported_engines()
# Out:
# Supported engines
# <style type="text/css">
# #T_8ed5b   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_8ed5b thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_8ed5b th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_8ed5b  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_8ed5b th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_8ed5b tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_8ed5b  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_8ed5b th.col0 {
#   text-align: left;
# }
# #T_8ed5b th.col1 {
#   text-align: left;
# }
# #T_8ed5b_row0_col0, #T_8ed5b_row0_col1, #T_8ed5b_row1_col0, #T_8ed5b_row1_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_8ed5b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ed5b_level0_col0" class="col_heading level0 col0" >Engine</th>
#       <th id="T_8ed5b_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ed5b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8ed5b_row0_col0" class="data row0 col0" >asciichartpy</td>
#       <td id="T_8ed5b_row0_col1" class="data row0 col1" >Console ASCII line charts</td>
#     </tr>
#     <tr>
#       <th id="T_8ed5b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8ed5b_row1_col0" class="data row1 col0" >plotly</td>
#       <td id="T_8ed5b_row1_col1" class="data row1 col1" >Interactive browser-based graphing library</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Show current plotting configuration.

# %%
project.plotter.show_config()
# Out:
# Current plotter configuration
# <style type="text/css">
# #T_11196   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_11196 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_11196 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_11196  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_11196 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_11196 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_11196  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_11196 th.col0 {
#   text-align: left;
# }
# #T_11196 th.col1 {
#   text-align: left;
# }
# #T_11196_row0_col0, #T_11196_row0_col1, #T_11196_row1_col0, #T_11196_row1_col1, #T_11196_row2_col0, #T_11196_row2_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_11196" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11196_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_11196_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11196_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_11196_row0_col0" class="data row0 col0" >Plotting engine</td>
#       <td id="T_11196_row0_col1" class="data row0 col1" >plotly</td>
#     </tr>
#     <tr>
#       <th id="T_11196_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_11196_row1_col0" class="data row1 col0" >x-axis limits</td>
#       <td id="T_11196_row1_col1" class="data row1 col1" >[-inf, inf]</td>
#     </tr>
#     <tr>
#       <th id="T_11196_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_11196_row2_col0" class="data row2 col0" >Chart height</td>
#       <td id="T_11196_row2_col1" class="data row2 col1" >9</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Set plotting engine.

# %%
# Keep the auto-selected engine. Alternatively, you can uncomment the
# line below to explicitly set the engine to the required one.
# project.plotter.engine = 'plotly'

# %% [markdown]
# ## Step 2: Define Sample Model
#
# This section shows how to add sample models and modify their
# parameters.

# %% [markdown]
# #### Add Sample Model

# %%
project.sample_models.add(name='lbco')

# %% [markdown]
# #### Show Defined Sample Models
#
# Show the names of the models added. These names are used to access the
# model using the syntax: `project.sample_models['model_name']`. All
# model parameters can be accessed via the `project` object.

# %%
project.sample_models.show_names()
# Out:
# Defined sample models 🧩
# ['lbco']

# %% [markdown]
# #### Set Space Group
#
# Modify the default space group parameters.

# %%
project.sample_models['lbco'].space_group.name_h_m = 'P m -3 m'
project.sample_models['lbco'].space_group.it_coordinate_system_code = '1'

# %% [markdown]
# #### Set Unit Cell
#
# Modify the default unit cell parameters.

# %%
project.sample_models['lbco'].cell.length_a = 3.88

# %% [markdown]
# #### Set Atom Sites
#
# Add atom sites to the sample model.

# %%
project.sample_models['lbco'].atom_sites.add(
    label='La',
    type_symbol='La',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    b_iso=0.5,
    occupancy=0.5,
)
project.sample_models['lbco'].atom_sites.add(
    label='Ba',
    type_symbol='Ba',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    b_iso=0.5,
    occupancy=0.5,
)
project.sample_models['lbco'].atom_sites.add(
    label='Co',
    type_symbol='Co',
    fract_x=0.5,
    fract_y=0.5,
    fract_z=0.5,
    wyckoff_letter='b',
    b_iso=0.5,
)
project.sample_models['lbco'].atom_sites.add(
    label='O',
    type_symbol='O',
    fract_x=0,
    fract_y=0.5,
    fract_z=0.5,
    wyckoff_letter='c',
    b_iso=0.5,
)

# %% [markdown]
# #### Show Sample Model as CIF

# %%
project.sample_models['lbco'].show_as_cif()
# Out:
# Sample model 🧩 'lbco' as cif
# <style type="text/css">
# #T_26b78   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_26b78 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_26b78 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_26b78  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_26b78 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_26b78 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_26b78  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_26b78 th.col0 {
#   text-align: left;
# }
# #T_26b78_row0_col0, #T_26b78_row1_col0, #T_26b78_row2_col0, #T_26b78_row3_col0, #T_26b78_row4_col0, #T_26b78_row5_col0, #T_26b78_row6_col0, #T_26b78_row7_col0, #T_26b78_row8_col0, #T_26b78_row9_col0, #T_26b78_row10_col0, #T_26b78_row11_col0, #T_26b78_row12_col0, #T_26b78_row13_col0, #T_26b78_row14_col0, #T_26b78_row15_col0, #T_26b78_row16_col0, #T_26b78_row17_col0, #T_26b78_row18_col0, #T_26b78_row19_col0, #T_26b78_row20_col0, #T_26b78_row21_col0, #T_26b78_row22_col0, #T_26b78_row23_col0, #T_26b78_row24_col0, #T_26b78_row25_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_26b78" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26b78_level0_col0" class="col_heading level0 col0" >CIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26b78_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_26b78_row0_col0" class="data row0 col0" >data_lbco</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_26b78_row1_col0" class="data row1 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_26b78_row2_col0" class="data row2 col0" >_cell.length_a   3.8800</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_26b78_row3_col0" class="data row3 col0" >_cell.length_b   3.8800</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_26b78_row4_col0" class="data row4 col0" >_cell.length_c   3.8800</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_26b78_row5_col0" class="data row5 col0" >_cell.angle_alpha  90.0000</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_26b78_row6_col0" class="data row6 col0" >_cell.angle_beta  90.0000</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_26b78_row7_col0" class="data row7 col0" >_cell.angle_gamma  90.0000</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_26b78_row8_col0" class="data row8 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_26b78_row9_col0" class="data row9 col0" >_space_group.name_H-M_alt "P m -3 m"</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_26b78_row10_col0" class="data row10 col0" >_space_group.IT_coordinate_system_code        1</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_26b78_row11_col0" class="data row11 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_26b78_row12_col0" class="data row12 col0" >loop_</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_26b78_row13_col0" class="data row13 col0" >_atom_site.label</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_26b78_row14_col0" class="data row14 col0" >_atom_site.type_symbol</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_26b78_row15_col0" class="data row15 col0" >_atom_site.fract_x</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_26b78_row16_col0" class="data row16 col0" >_atom_site.fract_y</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_26b78_row17_col0" class="data row17 col0" >_atom_site.fract_z</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_26b78_row18_col0" class="data row18 col0" >_atom_site.Wyckoff_letter</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_26b78_row19_col0" class="data row19 col0" >_atom_site.occupancy</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row20" class="row_heading level0 row20" >21</th>
#       <td id="T_26b78_row20_col0" class="data row20 col0" >_atom_site.B_iso_or_equiv</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row21" class="row_heading level0 row21" >22</th>
#       <td id="T_26b78_row21_col0" class="data row21 col0" >_atom_site.adp_type</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_26b78_row22_col0" class="data row22 col0" >      La       La   0.0000   0.0000   0.0000        a   0.5000   0.5000     Biso</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row23" class="row_heading level0 row23" >24</th>
#       <td id="T_26b78_row23_col0" class="data row23 col0" >      Ba       Ba   0.0000   0.0000   0.0000        a   0.5000   0.5000     Biso</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row24" class="row_heading level0 row24" >25</th>
#       <td id="T_26b78_row24_col0" class="data row24 col0" >      Co       Co   0.5000   0.5000   0.5000        b   1.0000   0.5000     Biso</td>
#     </tr>
#     <tr>
#       <th id="T_26b78_level0_row25" class="row_heading level0 row25" >26</th>
#       <td id="T_26b78_row25_col0" class="data row25 col0" >       O        O   0.0000   0.5000   0.5000        c   1.0000   0.5000     Biso</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Show Sample Model Structure

# %%
project.sample_models['lbco'].show_structure()
# Out:
# Sample model 🧩 'lbco' structure view
# Not implemented yet.

# %% [markdown]
# #### Save Project State
#
# Save the project state after adding the sample model. This ensures
# that all changes are stored and can be accessed later. The project
# state is saved in the directory specified during project creation.

# %%
project.save()
# Out:
# Saving project 📦 'lbco_hrpt' to
# /private/var/folders/sm/xrr7tmqj20s7hrsh1qhfl1d40000gn/T/lbco_hrpt
# ├── 📄 project.cif
# ├── 📁 sample_models
# │   └── 📄 lbco.cif
# ├── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# ## Step 3: Define Experiment
#
# This section shows how to add experiments, configure their parameters,
# and link the sample models defined in the previous step.

# %% [markdown]
# #### Download Measured Data
#
# Download the data file from the EasyDiffraction repository on GitHub.

# %%
data_path = ed.download_data(id=3, destination='data')
# Out:
# Getting data...
# Data #3: La0.5Ba0.5CoO3, HRPT (PSI), 300 K
# ✅ Data #3 downloaded to 'data/ed-3.xye'

# %% [markdown]
# #### Add Diffraction Experiment

# %%
project.experiments.add(
    name='hrpt',
    data_path=data_path,
    sample_form='powder',
    beam_mode='constant wavelength',
    radiation_probe='neutron',
)
# Out:
# Data loaded successfully
# Experiment 🔬 'hrpt'. Number of data points: 3098

# %% [markdown]
# #### Show Defined Experiments

# %%
project.experiments.show_names()
# Out:
# Defined experiments 🔬
# ['hrpt']

# %% [markdown]
# #### Show Measured Data

# %%
project.plot_meas(expt_name='hrpt')
# Out:
# Warning: No linked phases defined. Returning empty pattern.
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="bb16a492-7ff7-4001-8f7a-93e87cf5c6f5" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bb16a492-7ff7-4001-8f7a-93e87cf5c6f5")) {                    Plotly.newPlot(                        "bb16a492-7ff7-4001-8f7a-93e87cf5c6f5",                        [{"line":{"color":"rgb(31, 119, 180)"},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"...\...\...\...\...\...\u002fQJqZmZmZGT9AZmZmZmYmP0AzMzMzMzM\u002fQAAAAAAAQD9AzczMzMxMP0CamZmZmVk\u002fQGZmZmZmZj9AMzMzMzNzP0AAAAAAAIA\u002fQM3MzMzMjD9AmpmZmZmZP0BmZmZmZqY\u002fQDMzMzMzsz9AAAAAAADAP0DNzMzMzMw\u002fQJqZmZmZ2T9AZmZmZmbmP0AzMzMzM\u002fM\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\u002fNgQM3MzMzM9GBAZmZmZmb2YEAAAAAAAPhgQJqZmZmZ+WBAMzMzMzP7YEDNzMzMzPxgQGZmZmZm\...\u002fthQM3MzMzM\...\u002fNjQM3MzMzM9GNAZmZmZmb2Y0AAAAAAAPhjQJqZmZmZ+WNAMzMzMzP7Y0DNzMzMzPxjQGZmZmZm\..."},"y":{"dtype":"f8","bdata":"..."},"type":"scatter"}],                        {"legend":{"x":1.0,"xanchor":"right","y":1.0,"yanchor":"top"},"margin":{"autoexpand":true,"b":45,"r":30,"t":40},"title":{"text":"Measured data for experiment \ud83d\udd2c 'hrpt'"},"xaxis":{"mirror":true,"showline":true,"title":{"text":"2\u03b8 (degree)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"yaxis":{"mirror":true,"showline":true,"title":{"text":"Intensity (arb. units)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter" ...

# %% [markdown]
# #### Set Instrument
#
# Modify the default instrument parameters.

# %%
project.experiments['hrpt'].instrument.setup_wavelength = 1.494
project.experiments['hrpt'].instrument.calib_twotheta_offset = 0.6

# %% [markdown]
# #### Set Peak Profile
#
# Show supported peak profile types.

# %%
project.experiments['hrpt'].show_supported_peak_profile_types()
# Out:
# Supported peak profile types
# <style type="text/css">
# #T_12b28   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_12b28 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_12b28 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_12b28  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_12b28 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_12b28 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_12b28  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_12b28 th.col0 {
#   text-align: left;
# }
# #T_12b28 th.col1 {
#   text-align: left;
# }
# #T_12b28_row0_col0, #T_12b28_row0_col1, #T_12b28_row1_col0, #T_12b28_row1_col1, #T_12b28_row2_col0, #T_12b28_row2_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_12b28" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12b28_level0_col0" class="col_heading level0 col0" >Peak profile type</th>
#       <th id="T_12b28_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12b28_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_12b28_row0_col0" class="data row0 col0" >pseudo-voigt</td>
#       <td id="T_12b28_row0_col1" class="data row0 col1" >Pseudo-Voigt profile</td>
#     </tr>
#     <tr>
#       <th id="T_12b28_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_12b28_row1_col0" class="data row1 col0" >split pseudo-voigt</td>
#       <td id="T_12b28_row1_col1" class="data row1 col1" >Split pseudo-Voigt profile with empirical asymmetry correction.</td>
#     </tr>
#     <tr>
#       <th id="T_12b28_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_12b28_row2_col0" class="data row2 col0" >thompson-cox-hastings</td>
#       <td id="T_12b28_row2_col1" class="data row2 col1" >Thompson-Cox-Hastings profile with FCJ asymmetry correction.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Show the current peak profile type.

# %%
project.experiments['hrpt'].show_current_peak_profile_type()
# Out:
# Current peak profile type
# PeakProfileTypeEnum.PSEUDO_VOIGT

# %% [markdown]
# Select the desired peak profile type.

# %%
project.experiments['hrpt'].peak_profile_type = 'pseudo-voigt'
# Out:
# Peak profile type for experiment 'hrpt' changed to
# pseudo-voigt

# %% [markdown]
# Modify default peak profile parameters.

# %%
project.experiments['hrpt'].peak.broad_gauss_u = 0.1
project.experiments['hrpt'].peak.broad_gauss_v = -0.1
project.experiments['hrpt'].peak.broad_gauss_w = 0.1
project.experiments['hrpt'].peak.broad_lorentz_x = 0
project.experiments['hrpt'].peak.broad_lorentz_y = 0.1

# %% [markdown]
# #### Set Background

# %% [markdown]
# Show supported background types.

# %%
project.experiments['hrpt'].show_supported_background_types()
# Out:
# Supported background types
# <style type="text/css">
# #T_a928b   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_a928b thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_a928b th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a928b  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a928b th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_a928b tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_a928b  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_a928b th.col0 {
#   text-align: left;
# }
# #T_a928b th.col1 {
#   text-align: left;
# }
# #T_a928b_row0_col0, #T_a928b_row0_col1, #T_a928b_row1_col0, #T_a928b_row1_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_a928b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a928b_level0_col0" class="col_heading level0 col0" >Background type</th>
#       <th id="T_a928b_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a928b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a928b_row0_col0" class="data row0 col0" >line-segment</td>
#       <td id="T_a928b_row0_col1" class="data row0 col1" >Linear interpolation between points</td>
#     </tr>
#     <tr>
#       <th id="T_a928b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a928b_row1_col0" class="data row1 col0" >chebyshev polynomial</td>
#       <td id="T_a928b_row1_col1" class="data row1 col1" >Chebyshev polynomial background</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Show current background type.

# %%
project.experiments['hrpt'].show_current_background_type()
# Out:
# Current background type
# BackgroundTypeEnum.LINE_SEGMENT

# %% [markdown]
# Select the desired background type.

# %%
project.experiments['hrpt'].background_type = 'line-segment'
# Out:
# Background type for experiment 'hrpt' changed to
# line-segment

# %% [markdown]
# Add background points.

# %%
project.experiments['hrpt'].background.add(id='10', x=10, y=170)
project.experiments['hrpt'].background.add(id='30', x=30, y=170)
project.experiments['hrpt'].background.add(id='50', x=50, y=170)
project.experiments['hrpt'].background.add(id='110', x=110, y=170)
project.experiments['hrpt'].background.add(id='165', x=165, y=170)

# %% [markdown]
# Show current background points.

# %%
project.experiments['hrpt'].background.show()
# Out:
# Line-segment background points
# <style type="text/css">
# #T_88ac5   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_88ac5 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_88ac5 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_88ac5  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_88ac5 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_88ac5 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_88ac5  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_88ac5 th.col0 {
#   text-align: left;
# }
# #T_88ac5 th.col1 {
#   text-align: left;
# }
# #T_88ac5_row0_col0, #T_88ac5_row0_col1, #T_88ac5_row1_col0, #T_88ac5_row1_col1, #T_88ac5_row2_col0, #T_88ac5_row2_col1, #T_88ac5_row3_col0, #T_88ac5_row3_col1, #T_88ac5_row4_col0, #T_88ac5_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_88ac5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88ac5_level0_col0" class="col_heading level0 col0" >X</th>
#       <th id="T_88ac5_level0_col1" class="col_heading level0 col1" >Intensity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88ac5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_88ac5_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_88ac5_row0_col1" class="data row0 col1" >170</td>
#     </tr>
#     <tr>
#       <th id="T_88ac5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_88ac5_row1_col0" class="data row1 col0" >30</td>
#       <td id="T_88ac5_row1_col1" class="data row1 col1" >170</td>
#     </tr>
#     <tr>
#       <th id="T_88ac5_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_88ac5_row2_col0" class="data row2 col0" >50</td>
#       <td id="T_88ac5_row2_col1" class="data row2 col1" >170</td>
#     </tr>
#     <tr>
#       <th id="T_88ac5_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_88ac5_row3_col0" class="data row3 col0" >110</td>
#       <td id="T_88ac5_row3_col1" class="data row3 col1" >170</td>
#     </tr>
#     <tr>
#       <th id="T_88ac5_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_88ac5_row4_col0" class="data row4 col0" >165</td>
#       <td id="T_88ac5_row4_col1" class="data row4 col1" >170</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Set Linked Phases
#
# Link the sample model defined in the previous step to the experiment.

# %%
project.experiments['hrpt'].linked_phases.add(id='lbco', scale=10.0)

# %% [markdown]
# #### Show Experiment as CIF

# %%
project.experiments['hrpt'].show_as_cif()
# Out:
# Experiment 🔬 'hrpt' as cif
# <style type="text/css">
# #T_8ddb9   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_8ddb9 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_8ddb9 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_8ddb9  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_8ddb9 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_8ddb9 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_8ddb9  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T
col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_8ddb9_level0_row21" class="row_heading level0 row21" >22</th>
#       <td id="T_8ddb9_row21_col0" class="data row21 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_8ddb9_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_8ddb9_row22_col0" class="data row22 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_8ddb9_level0_row23" class="row_heading level0 row23" >24</th>
#       <td id="T_8ddb9_row23_col0" class="data row23 col0" >loop_</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb9_level0_row24" class="row_heading level0 row24" >25</th>
#       <td id="T_8ddb9_row24_col0" class="data row24 col0" >_pd_proc.2theta_scan</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb9_level0_row25" class="row_heading level0 row25" >26</th>
#       <td id="T_8ddb9_row25_col0" class="data row25 col0" >_pd_data.point_id</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb9_level0_row26" class="row_heading level0 row26" >27</th>
#       <td id="T_8ddb9_row26_col0" class="data row26 col0" >_pd_proc.d_spacing</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb9_level0_row27" class="row_heading level0 row27" >28</th>
#       <td id="T_8ddb9_row27_col0" class="data row27 col0" >_pd_meas.intensity_total</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb9_level0_row28" class="row_heading level0 row28" >29</th>
#       <td id="T_8ddb9_row28_col0" class="data row28 col0" >_pd_meas.intensity_total_su</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb9_level0_row29" class="row_heading level0 row29" >30</th>
#       <td id="T_8ddb9_row29_col0" class="data row29 col0" >_pd_calc.intensity_total</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb9_level0_row30" class="row_heading level0 row30" >31</th>
#       <td id="T_8ddb9_row30_col0" class="data row30 col0" >_pd_calc.intensity_bkg</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb9_level0_row31" class="row_heading level0 row31" >32</th>
#       <td id="T_8ddb9_row31_col0" class="data row31 col0" >_pd_data.refinement_status</td>
#     </tr>
#     <tr>
#       <th id="T_8ddb9_level0_row32" class="row_hea

# %% [markdown]
# #### Save Project State

# %%
project.save()
# Out:
# Saving project 📦 'lbco_hrpt' to
# /private/var/folders/sm/xrr7tmqj20s7hrsh1qhfl1d40000gn/T/lbco_hrpt
# ├── 📄 project.cif
# ├── 📁 sample_models
# │   └── 📄 lbco.cif
# ├── 📁 experiments
# │   └── 📄 hrpt.cif
# ├── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# ## Step 4: Perform Analysis
#
# This section explains the analysis process, including how to set up
# calculation and fitting engines.
#
# #### Set Calculator
#
# Show supported calculation engines.

# %%
project.analysis.show_supported_calculators()
# Out:
# Supported calculators
# <style type="text/css">
# #T_e7aa9   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_e7aa9 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_e7aa9 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_e7aa9  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_e7aa9 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_e7aa9 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_e7aa9  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_e7aa9 th.col0 {
#   text-align: left;
# }
# #T_e7aa9 th.col1 {
#   text-align: left;
# }
# #T_e7aa9_row0_col0, #T_e7aa9_row0_col1, #T_e7aa9_row1_col0, #T_e7aa9_row1_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_e7aa9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7aa9_level0_col0" class="col_heading level0 col0" >Calculator</th>
#       <th id="T_e7aa9_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7aa9_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e7aa9_row0_col0" class="data row0 col0" >cryspy</td>
#       <td id="T_e7aa9_row0_col1" class="data row0 col1" >CrysPy library for crystallographic calculations</td>
#     </tr>
#     <tr>
#       <th id="T_e7aa9_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e7aa9_row1_col0" class="data row1 col0" >pdffit</td>
#       <td id="T_e7aa9_row1_col1" class="data row1 col1" >PDFfit2 library for pair distribution function calculations</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Show current calculation engine.

# %%
project.analysis.show_current_calculator()
# Out:
# Current calculator
# cryspy

# %% [markdown]
# Select the desired calculation engine.

# %%
project.analysis.current_calculator = 'cryspy'
# Out:
# Current calculator changed to
# cryspy

# %% [markdown]
# #### Show Calculated Data

# %%
project.plot_calc(expt_name='hrpt')
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="ecbac198-7617-4b69-97fd-75b3f98144ee" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ecbac198-7617-4b69-97fd-75b3f98144ee")) {                    Plotly.newPlot(                        "ecbac198-7617-4b69-97fd-75b3f98144ee",                        [{"line":{"color":"rgb(214, 39, 40)"},"mode":"lines","name":"Total calculated (Icalc)","x":{"dtype":"f8","bdata":"...\...\...\...\...\...\u002fQJqZmZmZGT9AZmZmZmYmP0AzMzMzMzM\u002fQAAAAAAAQD9AzczMzMxMP0CamZmZmVk\u002fQGZmZmZmZj9AMzMzMzNzP0AAAAAAAIA\u002fQM3MzMzMjD9AmpmZmZmZP0BmZmZmZqY\u002fQDMzMzMzsz9AAAAAAADAP0DNzMzMzMw\u002fQJqZmZmZ2T9AZmZmZmbmP0AzMzMzM\u002fM\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\u002fNgQM3MzMzM9GBAZmZmZmb2YEAAAAAAAPhgQJqZmZmZ+WBAMzMzMzP7YEDNzMzMzPxgQGZmZmZm\...\u002fthQM3MzMzM\...\u002fNjQM3MzMzM9GNAZmZmZmb2Y0AAAAAAAPhjQJqZmZmZ+WNAMzMzMzP7Y0DNzMzMzPxjQGZmZmZm\..."},"y":{"dtype":"f8","bdata":"Lo2iW32KZUADRUsL4IllQFzIAitFiWVAP+csrqyIZUCIYICIFohlQDVXBK6Ch2VA\u002fd4NE\u002fGGZUAznz2sYYZlQCGLfW7UhWVA6K7+TkmFZUApEDdDwIRlQJeh30A5hGVAxkjyPbSDZUBz9acwMYNlQJXJdg+wgmVAmVEQ0TCCZUAczF9ss4FlQJaAiNg3gWVAVCTkDL6AZUBHTQEBRoBlQA\u002fyoazPf2VA0fa5B1t\u002fZUBQxm0K6H5lQN32EK12fmVAp\u002fok6AZ+ZUAB21e0mH1lQDT+ggosfWVAf\u002fep48B8ZUDhYPk4V3xlQE2+xQP
},"type":"scatter"},{"line":{"color":"rgb(44, 160, 44)"},"mode":"lines","name":"Residual (Imeas - Icalc)","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"0Ctt97OIIUBAf0AY5W8owEDwOEiGmyTAGJOEXquAMMBAECsObawQQADwN+rACPs\u002fQGC+2MGyB8DACYsGyNAxwGAiFpT+zivAgPHbZEuKLMAAfJV4ptruv8CnLZM0MxjAAIhTQygn2T9wKCn1mXgvwCB4Uv1pvhlA4A942mqELsBA\u002fBEG9E0AwADwtLmAGUXAgFaaN\u002fMrPcDgAcz0blRHwBDHsgFrBELAoEVZx\u002fBTQ0AIXJKJVJ1ZQMj4l4FhMm9AcGMqWv42e0B2y2hjDcuGQEplw1V\u002f7ItATNdbMcHujUCk7JJazgeGQKDbpJDZ2W1A0Hvmbh+AecDI9Fds0qONwKKkuT3UbJfAAJ5n0ey+l8BwFsEGbNiVwAkgLj\u002f1V5DAvKlzj9zrhsAGTvhFnZN8wLTS50F3gXHAeA1BdwNgaMDYZ\u002f6ujhZdwHAcUDmAgErAIP9UvgzbOsCYRR4E+I9IwKQy1GecdUrAQDYiU2GFMMAYl3UokAtNwOB0xyhwjRTAUPaZ7WKsJsBA3ZVkwXIxwAAeg08omeY\u002fQG+pjcJ4KcCg8zyBeasSwHCHjvY+AibAQLf6YAFIFUCgdSGTibgqQFDnpqpYriHAcJJ05nF+LMAQ1DBpN1coQEBXR+cK3yJAANQ\u002fXWAjL0A="},"type":"scatter"}],                        {"legend":{"x":1.0,"xanchor":"right","y":1.0,"yanchor":"top"},"margin":{"autoexpand":true,"b":45,"r":30,"t":40},"title":{"text":"Measured vs Calculated data for experiment \ud83d\udd2c 'hrpt'"},"xaxis":{"mirror":true,"showline":true,"title":{"text":"2\u03b8 (degree)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"yaxis":{"mirror":true,"showline":true,"title":{"text":"Intensity (arb. units)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d08 ...

# %% [markdown]
# #### Show Parameters
#
# Show all parameters of the project.

# %%
# project.analysis.show_all_params()

# %% [markdown]
# Show all fittable parameters.

# %%
project.analysis.show_fittable_params()
# Out:
# Fittable parameters for all sample models (🧩 data blocks)
# <style type="text/css">
# #T_31801   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_31801 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_31801 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_31801  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_31801 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_31801 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_31801  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_31801 th.col0 {
#   text-align: left;
# }
# #T_31801 th.col1 {
#   text-align: left;
# }
# #T_31801 th.col2 {
#   text-align: left;
# }
# #T_31801 th.col3 {
#   text-align: left;
# }
# #T_31801 th.col4 {
#   text-align: right;
# }
# #T_31801 th.col5 {
#   text-align: right;
# }
# #T_31801 th.col6 {
#   text-align: left;
# }
# #T_31801 th.col7 {
#   text-align: left;
# }
# #T_31801_row0_col0, #T_31801_row0_col1, #T_31801_row0_col2, #T_31801_row0_col3, #T_31801_row0_col6, #T_31801_row0_col7, #T_31801_row1_col0, #T_31801_row1_col1, #T_31801_row1_col2, #T_31801_row1_col3, #T_31801_row1_col6, #T_31801_row1_col7, #T_31801_row2_col0, #T_31801_row2_col1, #T_31801_row2_col2, #T_31801_row2_col3, #T_31801_row2_col6, #T_31801_row2_col7, #T_31801_row3_col0, #T_31801_row3_col1, #T_31801_row3_col2, #T_31801_row3_col3, #T_31801_row3_col6, #T_31801_row3_col7, #T_31801_row4_col0, #T_31801_row4_col1, #T_31801_row4_col2,
  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_9a5a3 th.col0 {
#   text-align: left;
# }
# #T_9a5a3 th.col1 {
#   text-align: left;
# }
# #T_9a5a3 th.col2 {
#   text-align: left;
# }
# #T_9a5a3 th.col3 {
#   text-align: left;
# }
# #T_9a5a3 th.col4 {
#   text-align: right;
# }
# #T_9a5a3 th.col5 {
#   text-align: right;
# }
# #T_9a5a3 th.col6 {
#   text-align: left;
# }
# #T_9a5a3 th.col7 {
#   text-align: left;
# }
# #T_9a5a3_row0_col0, #T_9a5a3_row0_col1, #T_9a5a3_row0_col2, #T_9a5a3_row0_col3, #T_9a5a3_row0_col6, #T_9a5a3_row0_col7, #T_9a5a3_row1_col0, #T_9a5a3_row1_col1, #T_9a5a3_row1_col2, #T_9a5a3_row1_col3, #T_9a5a3_row1_col6, #T_9a5a3_row1_col7, #T_9a5a3_row2_col0, #T_9a5a3_row2_col1, #T_9a5a3_row2_col2, #T_9a5a3_row2_col3, #T_9a5a3_row2_col6, #T_9a5a3_row2_col7, #T_9a5a3_row3_col0, #T_9a5a3_row3_col1, #T_9a5a3_row3_col2, #T_9a5a3_row3_col3, #T_9a5a3_row3_col6, #T_9a5a3_row3_col7, #T_9a5a3_row4_col0, #T_9a5a3_row4_col1, #T_9a5a3_row4_col2, #T_9a5a3_row4_col3, #T_9a5a3_row4_col6, #T_9a5a3_row4_col7, #T_9a5a3_row5_col0, #T_9a5a3_row5_col1, #T_9a5a3_row5_col2, #T_9a5a3_row5_col3, #T_9a5a3_row5_col6, #T_9a5a3_row5_col7, #T_9a5a3_row6_col0, #T_9a5a3_row6_col1, #T_9a5a3_row6_col2, #T_9a5a3_row6_col3, #T_9a5a3_row6_col6, #T_9a5a3_row6_col7, #T_9a5a3_row7_col0, #T_9a5a3_row7_col1, #T_9a5a3_row7_col2, #T_9a5a3_row7_col3, #T_9a5a3_row7_col6, #T_9a5a3_row7_col7, #T_9a5a3_row8_col0, #T_9a5a3_row8_col1, #T_9a5a3_row8_col2, #T_9a5a3_row8_col3, #T_9a5a3_row8_col6, #T_9a5a3_row8_col7, #T_9a5a3_row9_col0, #T_9a5a3_row9_col1, #T_9a5a3_row9_col2, #T_9a5a3_row9_col3, #T_9a5a3_row9_col6, #T_9a5a3_row9_col7, #T_9a5a3_row10_col0, #T_9a5a3_row10_col1, #T_9a5a3_row10_col2, #T_9a5a3_row10_col3, #T_9a5a3_row10_col6, #T_9a5a3_row10_col7, #T_9a5a3_row11_col0, #T_9a5a3_row11_col1, #T_9a5a3_row11_col2, #T_9a5a3_row11_col3, #T_9a5a3_row11_col6, #T_9a5a3_row11_col7, #T_9a5a3_row12_col0, #T_9a5a3_row12_col1, #T_9a5a3_row12_col2, #T_9a5a3_row12_col3, #T_9a5a3_row12_col6, #T_9a5a3_row12_col7 {
#   text-align: left;
# }
# #T_9a5a3_row0_col4, #T_9a5a3_row0_col5, #T_9a5a3_row1_col4, #T_9a5a3_row1_col5, #T_9a5a3_row2_col4, #T_9a5a3_row2_col5, #T_9a5a3_row3_col4, #T_9a5a3_row3_col5, #T_9a5a3_row4_col4, #T_9a5a3_row4_col5, #T_9a5a3_row5_col4, #T_9a5a3_row5_col5, #T_9a5a3_row6_col4, #T_9a5a3_row6_col5, #T_9a5a3_row7_col4, #T_9a5a3_row7_col5, #T_9a5a3_row8_col4, #T_9a5a3_row8_col5, #T_9a5a3_row9_col4, #T_9a5a3_row9_col5, #T_9a5a3_row10_col4, #T_9a5a3_row10_col5, #T_9a5a3_row11_col4, #T_9a5a3_row11_col5, #T_9a5a3_row12_col4, #T_9a5a3_row12_col5 {
#   text-align: right;
# }
# </style>
# <table id="T_9a5a3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a5a3_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_9a5a3_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_9a5a3_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_9a5a3_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_9a5a3_level0_col4" class="col_heading level0 col4" >value</th>
#       <th id="T_9a5a3_level0_col5" class="col_heading level0 col5" >uncertainty</th>
#       <th id="T_9a5a3_level0_col6" class="col_heading level0 col6" >units</th>
#       <th id="T_9a5a3_level0_col7" class="col_heading level0 col7" >free</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a5a3_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9a5a3_row0_col0" class="data row0 col0" >hrpt</td>
#       <td id="T_9a5a3_row0_col1" class="data row0 col1" >linked_phases</td>
#       <td id="T_9a5a3_row0_col2" class="data row0 col2" >lbco</td>
#       <td id="T_9a5a3_row0_col3" class="data row0 col3" >scale</td>
#       <td id="T_9a5a3_row0_col4" class="data row0 col4" >10.00000</td>
#       <td id="T_9a5a3_row0_col5" class="data row0 col5" ></td>
#       <td id="T_9a5a3_row0_col6" class="data row0 col6" ></td>
#       <td id="T_9a5a3_row0_col7" class="data row0 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a5a3_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9a5a3_row1_col0" class="data row1 col0" >hrpt</td>
#       <td id="T_9a5a3_row1_col1" class="data row1 col1" >peak</td>
#       <td id="T_9a5a3_row1_col2" class="data row1 col2" ></td>
#       <td id="T_9a5a3_row1_col3" class="data row1 col3" >broad_gauss_u</td>
#       <td id="T_9a5a3_row1_col4" class="data row1 col4" >0.10000</td>
#       <td id="T_9a5a3_row1_col5" class="data row1 col5" ></td>
#       <td id="T_9a5a3_row1_col6" class="data row1 col6" >deg²</td>
#       <td id="T_9a5a3_row1_col7" class="data row1 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a5a3_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9a5a3_row2_col0" class="data row2 col0" >hrpt</td>
#       <td id="T_9a5a3_row2_col1" class="data row2 col1" >peak</td>
#       <td id="T_9a5a3_row2_col2" class="data row2 col2" ></td>
#       <td id="T_9a5a3_row2_col3" class="data row2 col3" >broad_gauss_v</td>
#       <td id="T_9a5a3_row2_col4" class="data row2 col4" >-0.10000</td>
#       <td id="T_9a5a3_row2_col5" class="data row2 col5" ></td>
#       <td id="T_9a5a3_row2_col6" class="data row2 col6" >deg²</td>
#       <td id="T_9a5a3_row2_col7" class="data row2 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a5a3_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9a5a3_row3_col0" class="data row3 col0" >hrpt</td>
#       <td id="T_9a5a3_row3_col1" class="data row3 col1" >peak</td>
#       <td id="T_9a5a3_row3_col2" class="data row3 col2" ></td>
#       <td id="T_9a5a3_row3_col3" class="data row3 col3" >broad_gauss_w</td>
#       <td id="T_9a5a3_row3_col4" class="data row3 col4" >0.10000</td>
#       <td id="T_9a5a3_row3_col5" class="data row3 col5" ></td>
#       <td id="T_9a5a3_row3_col6" class="data row3 col6" >deg²</td>
#       <td id="T_9a5a3_row3_col7" class="data row3 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a5a3_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_9a5a3_row4_col0" class="data row4 col0" >hrpt</td>
#       <td id="T_9a5a3_row4_col1" class="data row4 col1" >peak</td>
#       <td id="T_9a5a3_row4_col2" class="data row4 col2" ></td>
#       <td id="T_9a5a3_row4_col3" class="data row4 col3" >broad_lorentz_x</td>
#       <td id="T_9a5a3_row4_col4" class="data row4 col4" >0.00000</td>
#       <td id="T_9a5a3_row4_col5" class="data row4 col5" ></td>
#       <td id="T_9a5a3_row4_col6" class="data row4 col6" >deg</td>
#       <td id="T_9a5a3_row4_col7" class="data row4 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a5a3_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_9a5a3_row5_col0" class="data row5 col0" >hrpt</td>
#       <td id="T_9a5a3_row5_col1" class="data row5 col1" >peak</td>
#       <td id="T_9a5a3_row5_col2" class="data row5 col2" ></td>
#       <td id="T_9a5a3_row5_col3" class="data row5 col3" >broad_lorentz_y</td>
#       <td id="T_9a5a3_row5_col4" class="data row5 col4" >0.10000</td>
#       <td id="T_9a5a3_row5_col5" class="data row5 col5" ></td>
#       <td id="T_9a5a3_row5_col6" class="data row5 col6" >deg</td>
#       <td id="T_9a5a3_row5_col7" class="data row5 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a5a3_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_9a5a3_row6_col0" class="data row6 col0" >hrpt</td>
#       <td id="T_9a5a3_row6_col1" class="data row6 col1" >instrument</td>
#       <td id="T_9a5a3_row6_col2" class="data row6 col2" ></td>
#       <td id

# %% [markdown]
# Show only free parameters.

# %%
project.analysis.show_free_params()
# Out:
# ⚠️ No free parameters found.

# %% [markdown]
# Show how to access parameters in the code.

# %%
# project.analysis.how_to_access_parameters()

# %% [markdown]
# #### Set Fit Mode
#
# Show supported fit modes.

# %%
project.analysis.show_available_fit_modes()
# Out:
# Available fit modes
# <style type="text/css">
# #T_dba3f   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_dba3f thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_dba3f th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_dba3f  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_dba3f th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_dba3f tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_dba3f  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_dba3f th.col0 {
#   text-align: left;
# }
# #T_dba3f th.col1 {
#   text-align: left;
# }
# #T_dba3f_row0_col0, #T_dba3f_row0_col1, #T_dba3f_row1_col0, #T_dba3f_row1_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_dba3f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dba3f_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_dba3f_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dba3f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_dba3f_row0_col0" class="data row0 col0" >single</td>
#       <td id="T_dba3f_row0_col1" class="data row0 col1" >Independent fitting of each experiment; no shared parameters</td>
#     </tr>
#     <tr>
#       <th id="T_dba3f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_dba3f_row1_col0" class="data row1 col0" >joint</td>
#       <td id="T_dba3f_row1_col1" class="data row1 col1" >Simultaneous fitting of all experiments; some parameters are shared</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Show current fit mode.

# %%
project.analysis.show_current_fit_mode()
# Out:
# Current fit mode
# single

# %% [markdown]
# Select desired fit mode.

# %%
project.analysis.fit_mode = 'single'
# Out:
# Current fit mode changed to
# single

# %% [markdown]
# #### Set Minimizer
#
# Show supported fitting engines.

# %%
project.analysis.show_available_minimizers()
# Out:
# Supported minimizers
# <style type="text/css">
# #T_2709f   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_2709f thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_2709f th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_2709f  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_2709f th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_2709f tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_2709f  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_2709f th.col0 {
#   text-align: left;
# }
# #T_2709f th.col1 {
#   text-align: left;
# }
# #T_2709f_row0_col0, #T_2709f_row0_col1, #T_2709f_row1_col0, #T_2709f_row1_col1, #T_2709f_row2_col0, #T_2709f_row2_col1, #T_2709f_row3_col0, #T_2709f_row3_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_2709f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2709f_level0_col0" class="col_heading level0 col0" >Minimizer</th>
#       <th id="T_2709f_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2709f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2709f_row0_col0" class="data row0 col0" >lmfit</td>
#       <td id="T_2709f_row0_col1" class="data row0 col1" >LMFIT library using the default Levenberg-Marquardt least squares method</td>
#     </tr>
#     <tr>
#       <th id="T_2709f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2709f_row1_col0" class="data row1 col0" >lmfit (leastsq)</td>
#       <td id="T_2709f_row1_col1" class="data row1 col1" >LMFIT library with Levenberg-Marquardt least squares method</td>
#     </tr>
#     <tr>
#       <th id="T_2709f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2709f_row2_col0" class="data row2 col0" >lmfit (least_squares)</td>
#       <td id="T_2709f_row2_col1" class="data row2 col1" >LMFIT library with SciPy’s trust region reflective algorithm</td>
#     </tr>
#     <tr>
#       <th id="T_2709f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2709f_row3_col0" class="data row3 col0" >dfols</td>
#       <td id="T_2709f_row3_col1" class="data row3 col1" >DFO-LS library for derivative-free least-squares optimization</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Show current fitting engine.

# %%
project.analysis.show_current_minimizer()
# Out:
# Current minimizer
# lmfit (leastsq)

# %% [markdown]
# Select desired fitting engine.

# %%
project.analysis.current_minimizer = 'lmfit (leastsq)'
# Out:
# Current minimizer changed to
# lmfit (leastsq)

# %% [markdown]
# ### Perform Fit 1/5
#
# Set sample model parameters to be refined.

# %%
project.sample_models['lbco'].cell.length_a.free = True

# %% [markdown]
# Set experiment parameters to be refined.

# %%
project.experiments['hrpt'].linked_phases['lbco'].scale.free = True
project.experiments['hrpt'].instrument.calib_twotheta_offset.free = True
project.experiments['hrpt'].background['10'].y.free = True
project.experiments['hrpt'].background['30'].y.free = True
project.experiments['hrpt'].background['50'].y.free = True
project.experiments['hrpt'].background['110'].y.free = True
project.experiments['hrpt'].background['165'].y.free = True

# %% [markdown]
# Show free parameters after selection.

# %%
project.analysis.show_free_params()
# Out:
# Free parameters for both sample models (🧩 data blocks) and experiments (🔬 data blocks)
# <style type="text/css">
# #T_23385   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_23385 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_23385 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_23385  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_23385 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_23385 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_23385  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_23385 th.col0 {
#   text-align: left;
# }
# #T_23385 th.col1 {
#   text-align: left;
# }
# #T_23385 th.col2 {
#   text-align: left;
# }
# #T_23385 th.col3 {
#   text-align: left;
# }
# #T_23385 th.col4 {
#   text-align: right;
# }
# #T_23385 th.col5 {
#   text-align: right;
# }
# #T_23385 th.col6 {
#   text-align: right;
# }
# #T_23385 th.col7 {
#   text-align: right;
# }
# #T_23385 th.col8 {
#   text-align: left;
# }
# #T_23385_row0_col0, #T_23385_row0_col1, #T_23385_row0_col2, #T_23385_row0_col3, #T_23385_row0_col8, #T_23385_row1_col0, #T_23385_row1_col1, #T_23385_row1_col2, #T_23385_row1_col3, #T_23385_row1_col8, #T_23385_row2_col0, #T_23385_row2_col1, #T_23385_row2_col2, #T_23385_row2_col3, #T_23385_row2_col8, #T_23385_row3_col0, #T_23385_row3_col1, #T_23385_row3_col2, #T_23385_row3_col3, #T_23385_row3_col8, #T_23385_row4_col0, #T_23385_row4_col1, #T_23385_row4_col2, #T_23385_row4_col3, #T_23385_row4_col8, #T_23385_row5_col0, #T_23385_row5_col1, #T_23385_row5_col2, #T_23385_row5_col3, #T_23385_row5_col8, #T_23385_row6_col0, #T_23385_row6_col1, #T_23385_row6_col2, #T_23385_row6_col3, #T_23385_row6_col8, #T_23385_row7_col0, #T_23385_row7_col1, #T_23385_row7_col2, #T_23385_row7_col3, #T_23385_row7_col8 {
#   text-align: left;
# }
# #T_23385_row0_col4, #T_23385_row0_col5, #T_23385_row0_col6, #T_23385_row0_col7, #T_23385_row1_col4, #T_23385_row1_col5, #T_23385_row1_col6, #T_23385_row1_col7, #T_23385_row2_col4, #T_23385_row2_col5, #T_23385_row2_col6, #T_23385_row2_col7, #T_23385_row3_col4, #T_23385_row3_col5, #T_23385_row3_col6, #T_23385_row3_col7, #T_23385_row4_col4, #T_23385_row4_col5, #T_23385_row4_col6, #T_23385_row4_col7, #T_23385_row5_col4, #T_23385_row5_col5, #T_23385_row5_col6, #T_23385_row5_col7, #T_23385_row6_col4, #T_23385_row6_col5, #T_23385_row6_col6, #T_23385_row6_col7, #T_23385_row7_col4, #T_23385_row7_col5, #T_23385_row7_col6, #T_23385_row7_col7 {
#   text-align: right;
# }
# </style>
# <table id="T
  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_d8d3a th.col0 {
#   text-align: center;
# }
# #T_d8d3a th.col1 {
#   text-align: center;
# }
# #T_d8d3a th.col2 {
#   text-align: center;
# }
# #T_d8d3a_row0_col0, #T_d8d3a_row0_col1, #T_d8d3a_row0_col2, #T_d8d3a_row1_col0, #T_d8d3a_row1_col1, #T_d8d3a_row1_col2, #T_d8d3a_row2_col0, #T_d8d3a_row2_col1, #T_d8d3a_row2_col2, #T_d8d3a_row3_col0, #T_d8d3a_row3_col1, #T_d8d3a_row3_col2, #T_d8d3a_row4_col0, #T_d8d3a_row4_col1, #T_d8d3a_row4_col2, #T_d8d3a_row5_col0, #T_d8d3a_row5_col1, #T_d8d3a_row5_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_d8d3a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8d3a_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_d8d3a_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_d8d3a_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8d3a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d8d3a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d8d3a_row0_col1" class="data row0 col1" >164.59</td>
#       <td id="T_d8d3a_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_d8d3a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d8d3a_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_d8d3a_row1_col1" class="data row1 col1" >33.43</td>
#       <td id="T_d8d3a_row1_col2" class="data row1 col2" >79.7% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_d8d3a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d8d3a_row2_col0" class="data row2 col0" >21</td>
#       <td id="T_d8d3a_row2_col1" class="data row2 col1" >13.22</td>
#       <td id="T_d8d3a_row2_col2" class="data row2 col2" >60.4% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_d8d3a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d8d3a_row3_col0" class="data row3 col0" >30</td>
#       <td id="T_d8d3a_row3_col1" class="data row3 col1" >5.78</td>
#       <td id="T_d8d3a_row3_col2" class="data row3 col2" >56.3% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_d8d3a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d8d3a_row4_col0" class="data row4 col0" >39</td>
#       <td id="T_d8d3a_row4_col1" class="data row4 col1" >3.15</td>
#       <td id="T_d8d3a_row4_col2" class="data row4 col2" >45.6% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_d8d3a_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d8d3a_row5_col0" class="data row5 col0" >77</td>
#       <td id="T_d8d3a_row5_col1" class="data row5 col1" >3.14</td>
#       <td id="T_d8d3a_row5_col2" class="data row5 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 3.14 at iteration 69
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 7.32 seconds
# 📏 Goodness-of-fit (reduced χ²): 3.14
# 📏 R-factor (Rf): 8.42%
# 📏 R-factor squared (Rf²): 11.79%
# 📏 Weighted R-factor (wR): 11.63%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_c5376   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_c5376 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_c5376 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_c5376  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_c5376 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_c5376 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_c5376  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_c5376 th.col0 {
#   text-align: left;
# }
# #T_c5376 th.col1 {
#   text-align: left;
# }
# #T_c5376 th.col2 {
#   text-align: left;
# }
# #T_c5376 th.col3 {
#   text-align: left;
# }
# #T_c5376 th.col4 {
#   text-align: right;
# }
# #T_c5376 th.col5 {
#   text-align: right;
# }
# #T_c5376 th.col6 {
#   text-align: right;
# }
# #T_c5376 th.col7 {
#   text-align: left;
# }
# #T_c5376 th.col8 {
#   text-align: right;
# }
# #T_c5376_row0_col0, #T_c5376_row0_col1, #T_c5376_row0_col2, #T_c5376_row0_col3, #T_c5376_row0_col7, #T_c5376_row1_col0, #T_c5376_row1_col1, #T_c5376_row1_col2, #T_c5376_row1_col3, #T_c5376_row1_col7, #T_c5376_row2_col0, #T_c5376_row2_col1, #T_c5376_row2_col2, #T_c5376_row2_col3, #T_c5376_row2_col7, #T_c5376_row3_col0, #T_c5376_row3_col1, #T_c5376_row3_col2, #T_c5376_row3_col3, #T_c5376_row3_col7, #T_c5376_row4_col0, #T_c5376_row4_col1, #T_c5376_row4_col2, #T_c5376_row4_col3, #T_c5376_row4_col7, #T_c5376_row5_col0, #T_c5376_row5_col1, #T_c5376_row5_col2, #T_c5376_row5_col3, #T_c5376_row5_col7, #T_c5376_row6_col0, #T_c5376_row6_col1, #T_c5376_row6_col2, #T_c5376_row6_col3, #T_c5376_row6_col7, #T_c5376_row7_col0, #T_c5376_row7_col1, #T_c5376_row7_col2, #T_c5376_row7_col3, #T_c5376_row7_col7 {
},"type":"scatter"}],                        {"legend":{"x":1.0,"xanchor":"right","y":1.0,"yanchor":"top"},"margin":{"autoexpand":true,"b":45,"r":30,"t":40},"title":{"text":"Measured vs Calculated data for experiment \ud83d\udd2c 'hrpt'"},"xaxis":{"mirror":true,"showline":true,"title":{"text":"2\u03b8 (degree)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"yaxis":{"mirror":true,"showline":true,"title":{"text":"Intensity (arb. units)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111 ...

# %% [markdown]
# #### Save Project State

# %%
project.save_as(dir_path='lbco_hrpt', temporary=True)
# Out:
# Saving project 📦 'lbco_hrpt' to
# /private/var/folders/sm/xrr7tmqj20s7hrsh1qhfl1d40000gn/T/lbco_hrpt
# ├── 📄 project.cif
# ├── 📁 sample_models
# │   └── 📄 lbco.cif
# ├── 📁 experiments
# │   └── 📄 hrpt.cif
# ├── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# ### Perform Fit 2/5
#
# Set more parameters to be refined.

# %%
project.experiments['hrpt'].peak.broad_gauss_u.free = True
project.experiments['hrpt'].peak.broad_gauss_v.free = True
project.experiments['hrpt'].peak.broad_gauss_w.free = True
project.experiments['hrpt'].peak.broad_lorentz_y.free = True

# %% [markdown]
# Show free parameters after selection.

# %%
project.analysis.show_free_params()
# Out:
# Free parameters for both sample models (🧩 data blocks) and experiments (🔬 data blocks)
# <style type="text/css">
# #T_249b2   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_249b2 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_249b2 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_249b2  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_249b2 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_249b2 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_249b2  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_249b2 th.col0 {
#   text-align: left;
# }
# #T_249b2 th.col1 {
#   text-align: left;
# }
# #T_249b2 th.col2 {
#   text-align: left;
# }
# #T_249b2 th.col3 {
#   text-align: left;
# }
# #T_249b2 th.col4 {
#   text-align: right;
# }
# #T_249b2 th.col5 {
#   text-align: right;
# }
# #T_249b2 th.col6 {
#   text-align: right;
# }
# #T_249b2 th.col7 {
#   text-align: right;
# }
# #T_249b2 th.col8 {
#   text-align: left;
# }
# #T_249b2_row0_col0, #T_249b2_row0_col1, #T_249b2_row0_col2, #T_249b2_row0_col3, #T_249b2_row0_col8, #T_249b2_row1_col0, #T_249b2_row1_col1, #T_249b2_row1_col2, #T_249b2_row1_col3, #T_249b2_row1_col8, #T_249b2_row2_col0, #T_249b2_row2_col1, #T_249b2_row2_col2, #T_249b2_row2_col3, #T_249b2_row2_col8, #T_249b2_row3_col0, #T_249b2_row3_col1, #T_249b2_row3_col2, #T_249b2_row3_col3, #T_249b2_row3_col8, #T_249b2_row4_col0, #T_249b2_row4_col1, #T_249b2_row4_col2, #T_249b2_row4_col3, #T_249b2_row4_col8, #T_249b2_row5_col0, #T_249b2_row5_col1, #T_249b2_row5_col2, #T_249b2_row5_col3, #T_249b2_row5_col8, #T_249b2_row6_col0, #T_249b2_row6_col1, #T_249b2_row6_col2, #T_249b2_row6_col3, #T_249b2_row6_col8, #T_249b2_row7_col0, #T_249b2_row7_col1, #T_249b2_row7_col2, #T_249b2_row7_col3, #T_249b2_row7_col8, #T_249b2_row8_col0, #T_249b2_row8_col1, #T_249b2_row8_col2, #T_249b2_row8_col3, #T_249b2_row8_col8, #T_249b2_row9_col0, #T_249b2_row9_col1, #T_249b2_row9_col2, #T_249b2_row9_col3, #T_249b2_row9_col8, #T_249b2_row10_col0, #T_249b2_row10_col1, #T_249b2_row10_col2, #T_249b2_row10_col3, #T_249b2_row10_col8, #T_249b2_row11_col0, #T_249b2_row11_col1, #T_249b2_row11_col2, #T_249b2_row11_col3, #T_249b2_row11_col8 {
#   text-align: left;
# }
# %% [markdown]
# #### Run Fitting

# %%
project.analysis.fit()
project.analysis.show_fit_results()
# Out:
# Using experiment 🔬 'hrpt' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_7e601   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_7e601 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_7e601 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7e601  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7e601 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_7e601 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_7e601  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_7e601 th.col0 {
#   text-align: center;
# }
# #T_7e601 th.col1 {
#   text-align: center;
# }
# #T_7e601 th.col2 {
#   text-align: center;
# }
# #T_7e601_row0_col0, #T_7e601_row0_col1, #T_7e601_row0_col2, #T_7e601_row1_col0, #T_7e601_row1_col1, #T_7e601_row1_col2, #T_7e601_row2_col0, #T_7e601_row2_col1, #T_7e601_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_7e601" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e601_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_7e601_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_7e601_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e601_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7e601_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7e601_row0_col1" class="data row0 col1" >3.14</td>
#       <td id="T_7e601_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_7e601_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7e601_row1_col0" class="data row1 col0" >16</td>
#       <td id="T_7e601_row1_col1" class="data row1 col1" >2.85</td>
#       <td id="T_7e601_row1_col2" class="data row1 col2" >9.1% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_7e601_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7e601_row2_col0" class="data row2 col0" >69</td>
#       <td id="T_7e601_row2_col1" class="data row2 col1" >2.85</td>
#       <td id="T_7e601_row2_col2" class="data row2 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 2.85 at iteration 68
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 3.88 seconds
# 📏 Goodness-of-fit (reduced χ²): 2.85
# 📏 R-factor (Rf): 8.30%
# 📏 R-factor squared (Rf²): 11.85%
# 📏 Weighted R-factor (wR): 11.90%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_47b9b   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_47b9b thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_47b9b th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_47b9b  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_47b9b th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_47b9b tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_47b9b  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_47b9b th.col0 {
#   text-align: left;
# }
# #T_47b9b th.col1 {
#   text-align: left;
# }
# #T_47b9b th.col2 {
#   text-align: left;
# }
# #T_47b9b th.col3 {
#   text-align: left;
# }
# #T_47b9b th.col4 {
#   text-align: right;
# }
# #T_47b9b th.col5 {
#   text-align: right;
# }
# #T_47b9b th.col6 {
#   text-align: right;
# }
# #T_47b9b th.col7 {
#   text-align: left;
# }
# #T_47b9b th.col8 {
#   text-align: right;
# }
# #T_47b9b_row0_col0, #T_47b9b_row0_col1, #T_47b9b_row0_col2, #T_47b9b_row0_col3, #T_47b9b_row0_col7, #T_47b9b_row1_col0, #T_47b9b_row1_col1, #T_47b9b_row1_col2, #T_47b9b_row1_col3, #T_47b9b_row1_col7, #T_47b9b_row2_col0, #T_47b9b_row2_col1, #T_47b9b_row2_col2, #T_47b9b_row2_col3, #T_47b9b_row2_col7, #T_47b9b_row3_col0, #T_47b9b_row3_col1, #T_47b9b_row3_col2, #T_47b9b_row3_col3, #T_47b9b_row3_col7, #T_47b9b_row4_col0, #T_47b9b_row4_col1, #T_47b9b_row4_col2, #T_47b9b_row4_col3, #T_47b9b_row4_col7, #T_47b9b_row5_col0, #T_47b9b_row5_col1, #T_47b9b_row5_col2, #T_47b9b_row5_col3, #T_47b9b_row5_col7, #T_47b9b_row6_col0, #T_47b9b_row6_col1, #T_47b9b_row6_col2, #T_47b9b_row6_col3, #T_47b9b_row6_col7, #T_47b9b_row7_col0, #T_47b9b_row7_col1, #T_47b9b_row7_col2, #T_47b9b_row7_col3, #T_47b9b_row7_col7, #T_47b9b_row8_col0, #T_47b9b_row8_col1, #T_47b9b_row8_col2, #T_47b9b_row8_col3, #T_47b9b_row8_col7, #T_47b9b_row9_col0, #T_47b9b_row9_col1, #T_47b9b_row9_col2, #T_47b9b_row9_col3, #T_47b9b_row9_col7, #T_47b9b_row10_col0, #T_47b9b_row10_col1, #T_47b9b_row10_col2, #T_47b9b_row10_col3, #T_47b9b_row10_col7, #T_47b9b_row11_col0, #T_47b9b_row11_col1, #T_47b9b_row11_col2, #T_47b9b_row11_col3, #T_47b9b_row11_col7 {
#   text-align: left;
# }
# #T_47b9b_row0_col4, #T_47b9b_row0_col5, #T_47b9b_row0_col6, #T_47b9b_row0_col8, #T_47b9b_row1_col4, #T_47b9b_row1_col5, #T_47b9b_row1_col6, #T_47b9b_row1_col8, #T_47b9b_row2_col4, #T_47b9b_row2_col5, #T_47b9b_row2_col6, #T_47b9b_row2_col8, #T_47b9b_row3_col4, #T_47b9b_row3_col5, #T_47b9b_row3_col6, #T_47b9b_row3_col8, #T_47b9b_row4_col4, #T_47b9b_row4_col5, #T_47b9b_row4_col6, #T_47b9b_row4_col8, #T_47b9b_row5_col4, #T_47b9b_row5_col5, #T_47b9b_row5_col6, #T_47b9b_row5_col8, #T_47b9b_row6_col4, #T_47b9b_row6_col5, #T_47b9b_row6_col6, #T_47b9b_row6_col8, #T_47b9b_row7_col4, #T_47b9b_row7_col5, #T_47b9b_row7_col6, #T_47b9b_row7_col8, #T_47b9b_row8_col4, #T_47b9b_row8_col5, #T_47b9b_row8_col6, #T_47b9b_row8_col8, #T_47b9b_row9_col4, #T_47b9b_row9_col5, #T_47b9b_row9_col6, #T_47b9b_row9_col8, #T_47b9b_row10_col4, #T_47b9b_row10_col5, #T_47b9b_row10_col6, #T_47b9b_row10_col8, #T_47b9b_row11_col4, #T_47b9b_row11_col5, #T_47b9b_row11_col6, #T_47b9b_row11_col8 {
#   text-align: right;
# }
# </style>
# <table id="T_47b9b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47b9b_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_47b9b_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_47b9b_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_47b9b_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_47b9b_level0_col4" class="col_heading level0 col4" >start</th>
#       <th id="T_47b9b_level0_col5" class="col_heading level0 col5" >fitted</th>
#       <th id="T_47b9b_level0_col6" class="col_heading level0 col6" >uncertainty</th>
#       <th id="T_47b9b_level0_col7" class="col_heading level0 col7" >units</th>
#       <th id="T_47b9b_level0_col8" class="col_heading level0 col8" >change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47b9b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_47b9b_row0_col0" class="data row0 col0" >lbco</td>
#       <td id="T_47b9b_row0_col1" class="data row0 col1" >cell</td>
#       <td id="T_47b9b_row0_col2" class="data row0 col2" ></td>
#       <td id="T_47b9b_row0_col3" class="data row0 col3" >length_a</td>
#       <td id="T_47b9b_row0_col4" class="data row0 col4" >3.8910</td>
#       <td id="T_47b9b_row0_col5" class="data row0 col5" >3.8909</td>
#       <td id="T_47b9b_row0_col6" class="data row0 col6" >0.0001</td>
#       <td id="T_47b9b_row0_col7" class="data row0 col7" >Å</td>
#       <td id="T_47b9b_row0_col8" class="data row0 col8" >0.00 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_47b9b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_47b9b_row1_col0" class="data row1 col0" >hrpt</td>
#       <td id="T_47b9b_row1_col1" class="data row1 col1" >linked_phases</td>
#       <td id="T_47b9b_row1_col2" class="data row1 col2" >lbco</td>
#       <td id="T_47b9b_row1_col3" class="data row1 col3" >scale</td>
#       <td id="T_47b9b_row1_col4" class="data row1 col4" >7.3409</td>
#       <td id="T_47b9b_row1_col5" class="data row1 col5" >7.2120</td>
#       <td id="T_47b9b_row1_col6" class="data row1 col6" >0.0406</td>
#       <td id="T_47b9b_row1_col7" class="data row1 col7" ></td>
#       <td id="T_47b9b_row1_col8" class="data row1 col8" >1.76 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_47b9b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_47b9b_row2_col0" class="data row2 col0" >hrpt</td>
#       <td id="T_47b9b_row2_col1" class="data row2 col1" >peak</td>
#       <td id="T_47b9b_row2_col2" class="data row2 col2" ></td>
#       <td id="T_47b9b_row2_col3" class="data row2 col3" >broad_gauss_u</td>
#       <td id="T_47b9b_row2_col4" class="data row2 col4" >0.1000</td>
#       <td id="T_47b9b_row2_col5" class="data row2 col5" >0.0803</td>
#       <td id="T_47b9b_row2_col6" class="data row2 col6" >0.0047</td>
#       <td id="T_47b9b_row2_col7" class="data row2 col7" >deg²</td>
#       <td id="T_47b9b_row2_col8" class="data row2 col8" >19.74 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T
5AGStUU6mQAXU+fzexahANdtZeERIqEAuku9zMBKlQD\u002fJZKJlfqBAJPIZFeTLl0D3LGYuLDuQQPYHlb62wIVADkzS9RskfkAcRqQDCJl2QIzTAqhWl3JAnvkstwd2cECWIKm21HpuQLr19mXd5WxA+reGtrDAa0DV\u002fBoqBd1qQPRfDpSZJWpA28AInuGOaUAgEL++bxFpQFtKxwb5p2hASuLBpIhOaEBUyz+8FwJoQMhO47xMwGdA0LYQGU+HZ0BGHaGyp1VnQH4Q1uQpKmdADsdOluIDZ0B2HPKWC+JmQN+08BcCxGZAl5HsZz+pZkCRLbBbU5FmQCh6yPbfe2ZA3rM6BZZoZkA="},"type":"scatter"},{"line":{"color":"rgb(44, 160, 44)"},"mode":"lines","name":"Residual (Imeas - Icalc)","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"QOW3aqSCLUBAY7k21RkYwMA8YAvqGw\\u002ft+Ucj1wQNhfMRgIgXJAWCYxPdx9ekBIt0EwPv+DQAi22ezSPH5AcDeYq29AekBImM6MnoZqQCjgqwUlfWBAkJ9tUSBfRUCAPHeL\u002f94uQADGaQFUqwvA4JnPcntgPsBgCZJqS60lwDBSSNAU0TVAMEDKS3r6PkCAan4NlYL+v0D\u002f5UCZWSrAKPm5D\u002fOIMUAAgfj1fYs8wCitxck3wDRAYNvhs3UXJ0AAKw3wEHoHQMCJ5Ria\u002fTJAAEzSuzksDkCgK+7VhKUkQIDge8qGdQVAkMeJTevgMUBQHG9Io+84QICQpQf0\u002fv0\u002f4DKS\u002fewnEcB4k34iZXU1QMAuvEkAITJAEGEq1k+7N0A="},"type":"scatter"}],                        {"legend":{"x":1.0,"xanchor":"right","y":1.0,"yanchor":"top"},"margin":{"autoexpand":true,"b":45,"r":30,"t":40},"title":{"text":"Measured vs Calculated data for experiment \ud83d\udd2c 'hrpt'"},"xaxis":{"mirror":true,"showline":true,"title":{"text":"2\u03b8 (degree)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"yaxis":{"mirror":true,"showline":true,"title":{"text":"Intensity (arb. units)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"] ...

# %% [markdown]
# #### Save Project State

# %%
project.save_as(dir_path='lbco_hrpt', temporary=True)
# Out:
# Saving project 📦 'lbco_hrpt' to
# /private/var/folders/sm/xrr7tmqj20s7hrsh1qhfl1d40000gn/T/lbco_hrpt
# ├── 📄 project.cif
# ├── 📁 sample_models
# │   └── 📄 lbco.cif
# ├── 📁 experiments
# │   └── 📄 hrpt.cif
# ├── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# ### Perform Fit 3/5
#
# Set more parameters to be refined.

# %%
project.sample_models['lbco'].atom_sites['La'].b_iso.free = True
project.sample_models['lbco'].atom_sites['Ba'].b_iso.free = True
project.sample_models['lbco'].atom_sites['Co'].b_iso.free = True
project.sample_models['lbco'].atom_sites['O'].b_iso.free = True

# %% [markdown]
# Show free parameters after selection.

# %%
project.analysis.show_free_params()
# Out:
# Free parameters for both sample models (🧩 data blocks) and experiments (🔬 data blocks)
# <style type="text/css">
# #T_727b0   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_727b0 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_727b0 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_727b0  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_727b0 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_727b0 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_727b0  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_727b0 th.col0 {
#   text-align: left;
# }
# #T_727b0 th.col1 {
#   text-align: left;
# }
# #T_727b0 th.col2 {
#   text-align: left;
# }
# #T_727b0 th.col3 {
#   text-align: left;
# }
# #T_727b0 th.col4 {
#   text-align: right;
# }
# #T_727b0 th.col5 {
#   text-align: right;
# }
# #T_727b0 th.col6 {
#   text-align: right;
# }
# #T_727b0 th.col7 {
#   text-align: right;
# }
# #T_727b0 th.col8 {
#   text-align: left;
# }
# #T_727b0_row0_col0, #T_727b0_row0_col1, #T_727b0_row0_col2, #T_727b0_row0_col3, #T_727b0_row0_col8, #T_727b0_row1_col0, #T_727b0_row1_col1, #T_727b0_row1_col2, #T_727b0_row1_col3, #T_727b0_row1_col8, #T_727b0_row2_col0, #T_727b0_row2_col1, #T_727b0_row2_col2, #T_727b0_row2_col3, #T_727b0_row2_col8, #T_727b0_row3_col0, #T_727b0_row3_col1, #T_727b0_row3_col2, #T_727b0_row3_col3, #T_727b0_row3_col8, #T_727b0_row4_col0, #T_727b0_row4_col1, #T_727b0_row4_col2, #T_727b0_row4_col3, #T_727b0_row4_col8, #T_727b0_row5_col0, #T_727b0_row5_col1, #T_727b0_row5_col2, #T_727b0_row5_col3, #T_727b0_row5_col8, #T_727b0_row6_col0, #T_727b0_row6_col1, #T_727b0_row6_col2, #T_727b0_row6_col3, #T_727b0_row6_col8, #T_727b0_row7_col0, #T_727b0_row7_col1, #T_727b0_row7_col2, #T_727b0_row7_col3, #T_727b0_row7_col8, #T_727b0_row8_col0, #T_727b0_row8_col1, #T_727b0_row8_col2, #T_727b0_row8_col3, #T_727b0_row8_col8, #T_727b0_row9_col0, #T_727b0_row9_col1, #T_727b0_row9_col2, #T_727b0_row9_col3, #T_727b0_row9_col8, #T_727b0_row10_col0, #T_727b0_row10_col1, #T_727b0_row10_col2, #T_727b0_row10_col3, #T_727b0_row10_col8, #T_727b0_row11_col0, #T_727b0_row11_col1, #T_727b0_row11_col2, #T_727b0_row11_col3, #T_727b0_row11_col8, #T_727b0_row12_col0, #T_727b0_row12_col1, #T_727b0_row12_col2, #T_727b0_row12_col3, #T_727b0_row12_col8, #T_727b0_row13_col0, #T_727b0_row13_col1, #T_727b0_row13_col2, #T_727b0_row13_col3, #T_727b0_row13_col8, #T_727b0_row14_col0, #T_727b0_row14_col1, #T_727b0_row14_col2, #T_727b0_row14_col3, #T_727b0_row14_col8, #T_727b0_row15_col0, #T_727b0_row15_col1, #T_727b0_row15_col2, #T_727b0_row15_col3, #T_727b0_row15_col8 {
#   text-align: left;
# }
# #T_727b0_row0_col4, #T_727b0_row0_col5, #T_727b0_row0_col6, #T_727b0_row0_col7, #T_727b0_row1_col4, #T_727b0_row1_col5, #T_727b0_row1_col6, #T_727b0_row1_col7, #T_727b0_row2_col4, #T_727b0_row2_col5, #T_727b0_row2_col6, #T_727b0_row2_col7, #T_727b0_row3_col4, #T_727b0_row3_col5, #T_727b0_row3_col6, #T_727b0_row3_col7, #T_727b0_row4_col4, #T_727b0_row4_col5, #T_727b0_row4_col6, #T_727b0_row4_col7, #T_727b0_row5_col4, #T_727b0_row5_col5, #T_727b0_row5_col6, #T_727b0_row5_col7, #T_727b0_row6_col4, #T_727b0_row6_col5, #T_727b0_row6_col6, #T_727b0_row6_col7, #T_727b0_row7_col4, #T_727b0_row7_col5, #T_727b0_row7_col6, #T_727b0_row7_col7, #T_727b0_row8_col4, #T_727b0_row8_col5, #T_727b0_row8_col6, #T_727b0_row8_col7, #T_727b0_row9_col4, #T_727b0_row9_col5, #T_727b0_row9_col6, #T_727b0_row9_col7, #T_727b0_row10_col4, #T_727b0_row10_col5, #T_727b0_row10_col6, #T_727b0_row10_col7, #T_727b0_row11_col4, #T_727b0_row11_col5, #T_727b0_row11_col6, #T_727b0_row11_col7, #T_727b0_row12_col4, #T_727b0_row12_col5, #T_727b0_row12_col6, #T_727b0_row12_col7, #T_727b0_row13_col4, #T_727b0_row13_col5, #T_727b0_row13_col6, #T_727b0_row13_col7, #T_727b0_row14_col4, #T_727b0_row14_col5, #T_727b0_row14_col6, #T_727b0_row14_col7, #T_727b0_row15_col4, #T_727b0_row15_col5, #T_727b0_row15_col6, #T_727b0_row15_col7 {
#   text-align: right;
# }
# </style>
# <table id="T_727b0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_727b0_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_727b0_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_727b0_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_727b0_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_727b0_level0_col4" class="col_heading level0 col4" >value</th>
#       <th id="T_727b0_level0_col5" class="col_heading level0 col5" >uncertainty</th>
#       <th id="T_727b0_level0_col6" class="col_heading level0 col6" >min</th>
#       <th id="T_727b0_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_727b0_level0_col8" class="col_heading level0 col8" >units</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_727b0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_727b0_row0_col0" class="data row0 col0" >lbco</td>
#       <td id="T_727b0_row0_col1" class="data row0 col1" >cell</td>
#       <td id="T_727b0_row0_col2" class="data row0 col2" ></td>
#       <td id="T_727b0_row0_col3" class="data row0 col3" >length_a</td>
#       <td id="T_727b0_row0_col4" class="data row0 col4" >3.89091</td>
#       <td id="T_727b0_row0_col5" class="data row0 col5" >0.00005</td>
#       <td id="T_727b0_row0_col6" class="data row0 col6" >-inf</td>
#       <td id="T_727b0_row0_col7" class="data row0 col7" >inf</td>
#       <td id="T_727b0_row0_col8" class="data row0 col8" >Å</td>
#     </tr>
#     <tr>
#       <th id="T_727b0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_727b0_row1_col0" class="data row1 col0" >lbco</td>
#       <td id="T_727b0_row1_col1" class="data row1 col1" >atom_site</td>
#       <td id="T_727b0_row1_col2" class="data row1 col2" >La</td>
#       <td id="T_727b0_row1_col3" class="data row1 col3" >b_iso</td>
#       <td id="T_727b0_row1_col4" class="data row1 col4" >0.50000</td>
#       <td id="T_727b0_row1_col5" class="data row1 col5" ></td>
#       <td id="T_727b0_row1_col6" class="data row1 col6" >-inf</td>
#       <td id="T_727b0_row1_col7" class="data row1 col7" >inf</td>
#       <td id="T_727b0_row1_col8" class="data row1 col8" >Å²</td>
#     </tr>
#     <tr>
#       <th id="T_727b0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_727b0_row2_col0" class="data row2 col0" >lbco</td>
#       <td id="T_727b0_row2_col1" class="data row2 col1" >atom_site</td>
#       <td id="T_727b0_row2_col2" class="data row2 col2" >Ba</td>
#       <td id="T_727b0_row2_col3" class="data row2 col3" >b_iso</td>
#       <td id="T_727b0_row2_col4" class="data row2 col4" >0.50000</td>
#       <td id="T_727b0_row2_col5" class="data row2 col5" ></td>
#       <td id="T_727b0_row2_col6" class="data row2 col6" >-inf</td>
#       <td id="T_727b0_row2_col7" class="data row2 col7" >inf</td>
#       <td id="T_727b0_row2_col8" class="data row2 col8" >Å²</td>
#     </tr>
#     <tr>
#       <th id="T_727b0_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_727b0_row3_col0" class="data row3 col0" >lbco</td>
#       <td id="T_727b0_row3_col1" class="data row3 col1" >atom_site</td>
#       <td id="T_727b0_row3_col2" class="data row3 col2" >Co</td>
#       <td id="T_727b0_row3_col3" class="data row3 col3" >b_iso</td>
#       <td id="T_727b0_row3_col4" class="data row3 col4" >0.50000</td>
#       <td id="T_727b0_row3_col5" class="data row3 col5" ></td>
#       <td id="T_727b0_row3_col6" class="data row3 col6" >-inf</td>
#       <td id="T_727b0_row3_col7" class="data row3 col7" >inf</td>
#       <td id="T_727b0_row3_col8" class="data row3 col8" >Å²</td>
#     </tr>
#     <tr>
#       <th id="T_727b0_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_727b0_row4_col0" class="data row4 col0" >lbco</td>
#       <td id="T_727b0_row4_col1" class="data row4 col1" >atom_site</td>
#       <td id="T_727b0_row4_col2" class="data row4 col2" >O</td>
#       <td id="T_727b0_row4_col3" class="data row4 col3" >b_iso</td>
#       <td id="T_727b

# %% [markdown]
# #### Run Fitting

# %%
project.analysis.fit()
project.analysis.show_fit_results()
# Out:
# Using experiment 🔬 'hrpt' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_7e559   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_7e559 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_7e559 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7e559  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7e559 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_7e559 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_7e559  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_7e559 th.col0 {
#   text-align: center;
# }
# #T_7e559 th.col1 {
#   text-align: center;
# }
# #T_7e559 th.col2 {
#   text-align: center;
# }
# #T_7e559_row0_col0, #T_7e559_row0_col1, #T_7e559_row0_col2, #T_7e559_row1_col0, #T_7e559_row1_col1, #T_7e559_row1_col2, #T_7e559_row2_col0, #T_7e559_row2_col1, #T_7e559_row2_col2, #T_7e559_row3_col0, #T_7e559_row3_col1, #T_7e559_row3_col2, #T_7e559_row4_col0, #T_7e559_row4_col1, #T_7e559_row4_col2, #T_7e559_row5_col0, #T_7e559_row5_col1, #T_7e559_row5_col2, #T_7e559_row6_col0, #T_7e559_row6_col1, #T_7e559_row6_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_7e559" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e559_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_7e559_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_7e559_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e559_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7e559_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7e559_row0_col1" class="data row0 col1" >2.85</td>
#       <td id="T_7e559_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_7e559_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7e559_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_7e559_row1_col1" class="data row1 col1" >2.28</td>
#       <td id="T_7e559_row1_col2" class="data row1 col2" >19.9% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_7e559_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7e559_row2_col0" class="data row2 col0" >45</td>
#       <td id="T_7e559_row2_col1" class="data row2 col1" >1.62</td>
#       <td id="T_7e559_row2_col2" class="data row2 col2" >28.9% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_7e559_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_7e559_row3_col0" class="data row3 col0" >62</td>
#       <td id="T_7e559_row3_col1" class="data row3 col1" >1.47</td>
#       <td id="T_7e559_row3_col2" class="data row3 col2" >9.6% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_7e559_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_7e559_row4_col0" class="data row4 col0" >79</td>
#       <td id="T_7e559_row4_col1" class="data row4 col1" >1.36</td>
#       <td id="T_7e559_row4_col2" class="data row4 col2" >7.0% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_7e559_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_7e559_row5_col0" class="data row5 col0" >97</td>
#       <td id="T_7e559_row5_col1" class="data row5 col1" >1.29</td>
#       <td id="T_7e559_row5_col2" class="data row5 col2" >5.4% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_7e559_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_7e559_row6_col0" class="data row6 col0" >204</td>
#       <td id="T_7e559_row6_col1" class="data row6 col1" >1.29</td>
#       <td id="T_7e559_row6_col2" class="data row6 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 1.29 at iteration 187
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 14.06 seconds
# 📏 Goodness-of-fit (reduced χ²): 1.29
# 📏 R-factor (Rf): 5.65%
# 📏 R-factor squared (Rf²): 5.30%
# 📏 Weighted R-factor (wR): 4.47%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_a3c22   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_a3c22 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_a3c22 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a3c22  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a3c22 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_a3c22 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_a3c22  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_a3c22 th.col0 {
#   text-align: left;
# }
# #T_a3c22 th.col1 {
#   text-align: left;
# }
# #T_a3c22 th.col2 {
#   text-align: left;
# }
# #T_a3c22 th.col3 {
#   text-align: left;
# }
# #T_a3c22 th.col4 {
#   text-align: right;
# }
# #T_a3c22 th.col5 {
#   text-align: right;
# }
# #T_a3c22 th.col6 {
#   text-align: right;
# }
# #T_a3c22 th.col7 {
#   text-align: left;
# }
# #T_a3c22 th.col8 {
#   text-align: right;
# }
# #T_a3c22_row0_col0, #T_a3c22_row0_col1, #T_a3c22_row0_col2, #T_a3c22_row0_col3, #T_a3c22_row0_col7, #T_a3c22_row1_col0, #T_a3c22_row1_col1, #T_a3c22_row1_col2, #T_a3c22_row1_col3, #T_a3c22_row1_col7, #T_a3c22_row2_col0, #T_a3c22_row2_col1, #T_a3c22_row2_col2, #T_a3c22_row2_col3, #T_a3c22_row2_col7, #T_a3c22_row3_col0, #T_a3c22_row3_col1, #T_a3c22_row3_col2, #T_a3c22_row3_col3, #T_a3c22_row3_col7, #T_a3c22_row4_col0, #T_a3c22_row4_col1, #T_a3c22_row4_col2, #T_a3c22_row4_col3, #T_a3c22_row4_col7, #T_a3c22_row5_col0, #T_a3c22_row5_col1, #T_a3c22_row5_col2, #T_a3c22_row5_col3, #T_a3c22_row5_col7, #T_a3c22_row6_col0, #T_a3c22_row6_col1, #T_a3c22_row6_col2, #T_a3c22_row6_col3, #T_a3c22_row6_col7, #T_a3c22_row7_col0, #T_a3c22_row7_col1, #T_a3c22_row7_col2, #T_a3c22_row7_col3, #T_a3c22_row7_col7, #T_a3c22_row8_col0, #T_a3c22_row8_col1, #T_a3c22_row8_col2, #T_a3c22_row8_col3, #T_a3c22_row8_col7, #T_a3c22_row9_col0, #T_a3c22_row9_col1, #T_a3c22_row9_col2, #T_a3c22_row9_col3, #T_a3c22_row9_col7, #T_a3c22_row10_col0, #T_a3c22_row10_col1, #T_a3c22_row10_col2, #T_a3c22_row10_col3, #T_a3c22_row10_col7, #T_a3c22_row11_col0, #T_a3c22_row11_col1, #T_a3c22_row11_col2, #T_a3c22_row11_col3, #T_a3c22_row11_col7, #T_a3c22_row12_col0, #T_a3c22_row12_col1, #T_a3c22_row12_col2, #T_a3c22_row12_col3, #T_a3c22_row12_col7, #T_a3c22_row13_col0, #T_a3c22_row13_col1, #T_a3c22_row13_col2, #T_a3c22_row13_col3, #T_a3c22_row13_col7, #T_a3c22_row14_col0, #T_a3c22_row14_col1, #T_a3c22_row14_col2, #T_a3c22_row14_col3, #T_a3c22_row14_col7, #T_a3c22_row15_col0, #T_a3c22_row15_col1, #T_a3c22_row15_col2, #T_a3c22_row15_col3, #T_a3c22_row15_col7 {
JPkBPECAYg5uMgAQwODTowhCNy3AwII4qrmiMEAA+1FFyf88wFBj4N5irDRA8PHbkbCUJ0CAtu\u002fe+qYLQJjHC1jEwDNAYBDRYYX5EkCQeInCaPUmQGCtyVulABBAgAP5DS9XM0CgU66qpoY6QIDjvhO+oQxAwIOcj3vbA8BILA1dl1s3QHBKxASRHDRA4FRy\u002fj7KOUA="},"type":"scatter"}],                        {"legend":{"x":1.0,"xanchor":"right","y":1.0,"yanchor":"top"},"margin":{"autoexpand":true,"b":45,"r":30,"t":40},"title":{"text":"Measured vs Calculated data for experiment \ud83d\udd2c 'hrpt'"},"xaxis":{"mirror":true,"showline":true,"title":{"text":"2\u03b8 (degree)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"yaxis":{"mirror":true,"showline":true,"title":{"text":"Intensity (arb. units)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"] ...

# %% [markdown]
# #### Save Project State

# %%
project.save_as(dir_path='lbco_hrpt', temporary=True)
# Out:
# Saving project 📦 'lbco_hrpt' to
# /private/var/folders/sm/xrr7tmqj20s7hrsh1qhfl1d40000gn/T/lbco_hrpt
# ├── 📄 project.cif
# ├── 📁 sample_models
# │   └── 📄 lbco.cif
# ├── 📁 experiments
# │   └── 📄 hrpt.cif
# ├── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# ### Perform Fit 4/5
#
# #### Set Constraints
#
# Set aliases for parameters.

# %%
project.analysis.aliases.add(
    label='biso_La',
    param_uid=project.sample_models['lbco'].atom_sites['La'].b_iso.uid,
)
project.analysis.aliases.add(
    label='biso_Ba',
    param_uid=project.sample_models['lbco'].atom_sites['Ba'].b_iso.uid,
)

# %% [markdown]
# Set constraints.

# %%
project.analysis.constraints.add(lhs_alias='biso_Ba', rhs_expr='biso_La')

# %% [markdown]
# Show defined constraints.

# %%
project.analysis.show_constraints()
# Out:
# User defined constraints
# <style type="text/css">
# #T_d156a   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_d156a thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_d156a th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_d156a  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_d156a th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_d156a tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_d156a  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_d156a th.col0 {
#   text-align: left;
# }
# #T_d156a th.col1 {
#   text-align: left;
# }
# #T_d156a th.col2 {
#   text-align: left;
# }
# #T_d156a_row0_col0, #T_d156a_row0_col1, #T_d156a_row0_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_d156a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d156a_level0_col0" class="col_heading level0 col0" >lhs_alias</th>
#       <th id="T_d156a_level0_col1" class="col_heading level0 col1" >rhs_expr</th>
#       <th id="T_d156a_level0_col2" class="col_heading level0 col2" >full expression</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d156a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d156a_row0_col0" class="data row0 col0" >biso_Ba</td>
#       <td id="T_d156a_row0_col1" class="data row0 col1" >biso_La</td>
#       <td id="T_d156a_row0_col2" class="data row0 col2" >biso_Ba = biso_La</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Show free parameters before applying constraints.

# %%
project.analysis.show_free_params()
# Out:
# Free parameters for both sample models (🧩 data blocks) and experiments (🔬 data blocks)
# <style type="text/css">
# #T_7586b   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_7586b thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_7586b th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7586b  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7586b th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_7586b tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_7586b  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_7586b th.col0 {
#   text-align: left;
# }
# #T_7586b th.col1 {
#   text-align: left;
# }
# #T_7586b th.col2 {
#   text-align: left;
# }
# #T_7586b th.col3 {
#   text-align: left;
# }
# #T_7586b th.col4 {
#   text-align: right;
# }
# #T_7586b th.col5 {
#   text-align: right;
# }
# #T_7586b th.col6 {
#   text-align: right;
# }
# #T_7586b th.col7 {
#   text-align: right;
# }
# #T_7586b th.col8 {
#   text-align: left;
# }
# #T_7586b_row0_col0, #T_7586b_row0_col1, #T_7586b_row0_col2, #T_7586b_row0_col3, #T_7586b_row0_col8, #T_7586b_row1_col0, #T_7586b_row1_col1, #T_7586b_row1_col2, #T_7586b_row1_col3, #T_7586b_row1_col8, #T_7586b_row2_col0, #T_7586b_row2_col1, #T_7586b_row2_col2, #T_7586b_row2_col3, #T_7586b_row2_col8, #T_7586b_row3_col0, #T_7586b_row3_col1, #T_7586b_row3_col2, #T_7586b_row3_col3, #T_7586b_row3_col8, #T_7586b_row4_col0, #T_7586b_row4_col1, #T_7586b_row4_col2, #T_7586b_row4_col3, #T_7586b_row4_col8, #T_7586b_row5_col0, #T_7586b_row5_col1, #T_7586b_row5_col2, #T_7586b_row5_col3, #T_7586b_row5_col8, #T_7586b_row6_col0, #T_7586b_row6_col1, #T_7586b_row6_col2, #T_7586b_row6_col3, #T_7586b_row6_col8, #T_7586b_row7_col0, #T_7586b_row7_col1, #T_7586b_row7_col2, #T_7586b_row7_col3, #T_7586b_row7_col8, #T_7586b_row8_col0, #T_7586b_row8_col1, #T_7586b_row8_col2, #T_7586b_row8_col3, #T_7586b_row8_col8, #T_7586b_row9_col0, #T_7586b_row9_col1, #T_7586b_row9_col2, #T_7586b_row9_col3, #T_7586b_row9_col8, #T_7586b_row10_col0, #T_7586b_row10_col1, #T_7586b_row10_col2, #T_7586b_row10_col3, #T_7586b_row10_col8, #T_7586b_row11_col0, #T_7586b_row11_col1, #T_7586b_row11_col2, #T_7586b_row11_col3, #T_7586b_row11_col8, #T_7586b_row12_col0, #T_7586b_row12_col1, #T_7586b_row12_col2, #T_7586b_row12_col3, #T_7586b_row12_col8, #T_7586b_row13_col0, #T_7586b_row13_col1, #T_7586b_row13_col2, #T_7586b_row13_col3, #T_7586b_row13_col8, #T_7586b_row14_col0, #T_7586b_row14_col1, #T_7586b_row14_col2, #T_7586b_row14_col3, #T_7586b_row14_col8, #T_7586b_row15_col0, #T_7586b_row15_col1, #T_7586b_row15_col2, #T_7586b_row15_col3, #T_7586b_row15_col8 {
#   text-align: left;
# }
# #T_7586b_row0_col4, #T_7586b_row0_col5, #T_7586b_row0_col6, #T_7586b_row0_col7, #T_7586b_row1_col4, #T_7586b_row1_col5, #T_7586b_row1_col6, #T_7586b_row1_col7, #T_7586b_row2_col4, #T_7586b_row2_col5, #T_7586b_row2_col6, #T_7586b_row2_col7, #T_7586b_row3_col4, #T_7586b_row3_col5, #T_7586b_row3_col6, #T_7586b_row3_col7, #T_7586b_row4_col4, #T_7586b_row4_col5, #T_7586b_row4_col6, #T_7586b_row4_col7, #T_7586b_row5_col4, #T_7586b_row5_col5, #T_7586b_row5_col6, #T_7586b_row5_col7, #T_7586b_row6_col4, #T_7586b_row6_col5, #T_7586b_row6_col6, #T_7586b_row6_col7, #T_7586b_row7_col4, #T_7586b_row7_col5, #T_7586b_row7_col6, #T_7586b_row7_col7, #T_7586b_row8_col4, #T_7586b_row8_col5, #T_7586b_row8_col6, #T_7586b_row8_col7, #T_7586b_row9_col4, #T_7586b_row9_col5, #T_7586b_row9_col6, #T_7586b_row9_col7, #T_7586b_row10_col4, #T_7586b_row10_col5, #T_7586b_row10_col6, #T_7586b_row10_col7, #T_7586b_row11_col4, #T_7586b_row11_col5, #T_7586b_row11_col6, #T_7586b_row11_col7, #T_7586b_row12_col4, #T_7586b_row12_col5, #T_7586b_row12_col6, #T_7586b_row12_col7, #T_7586b_row13_col4, #T_7586b_row13_col5, #T_7586b_row13_col6, #T_7586b_row13_col7, #T_7586b_row14_col4, #T_7586b_row14_col5, #T_7586b_row14_col6, #T_7586b_row14_col7, #T_7586b_row15_col4, #T_7586b_row15_col5, #T_7586b_row15_col6, #T_7586b_row15_col7 {
#   text-align: right;
# }
# </style>
# <table id="T
row1_col6" class="data row1 col6" >-inf</td>
#       <td id="T_66dae_row1_col7" class="data row1 col7" >inf</td>
#       <td id="T_66dae_row1_col8" class="data row1 col8" >Å²</td>
#     </tr>
#     <tr>
#       <th id="T_66dae_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_66dae_row2_col0" class="data row2 col0" >lbco</td>
#       <td id="T_66dae_row2_col1" class="data row2 col1" >atom_site</td>
#       <td id="T_66dae_row2_col2" class="data row2 col2" >Co</td>
#       <td id="T_66dae_row2_col3" class="data row2 col3" >b_iso</td>
#       <td id="T_66dae_row2_col4" class="data row2 col4" >0.23707</td>
#       <td id="T_66dae_row2_col5" class="data row2 col5" >0.06119</td>
#       <td id="T_66dae_row2_col6" class="data row2 col6" >-inf</td>
#       <td id="T_66dae_row2_col7" class="data row2 col7" >inf</td>
#       <td id="T_66dae_row2_col8" class="data row2 col8" >Å²</td>
#     </tr>
#     <tr>
#       <th id="T_66dae_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_66dae_row3_col0" class="data row3 col0" >lbco</td>
#       <td id="T_66dae_row3_col1" class="data row3 col1" >atom_site</td>
#       <td id="T_66dae_row3_col2" class="data row3 col2" >O</td>
#       <td id="T_66dae_row3_col3" class="data row3 col3" >b_iso</td>
#       <td id="T_66dae_row3_col4" class="data row3 col4" >1.39354</td>
#       <td id="T_66dae_row3_col5" class="data row3 col5" >0.01668</td>
#       <td id="T_66dae_row3_col6" class="data row3 col6" >-inf</td>
#       <td id="T_66dae_row3_col7" class="data row3 col7" >inf</td>
#       <td id="T_66dae_row3_col8" class="data row3 col8" >Å²</td>
#     </tr>
#     <tr>
#       <th id="T_66dae_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_66dae_row4_col0" class="data row4 col0" >hrpt</td>
#       <td id="T_66dae_row4_col1" class="data row4 col1" >linked_phases</td>
#       <td id="T_66dae_row4_col2" class="data row4 col2" >lbco</td>
#       <td id="T_66dae_row4_col3" class="data row4 col3" >scale</td>
#       <td id="T_66dae_row4_col4" class="data row4 col4" >9.13503</td>
#       <td id="T_66dae_row4_col5" class="data row4 col5" >0.06407</td>
#       <td id="T_66dae_row4_col6" class=

# %% [markdown]
# #### Run Fitting

# %%
project.analysis.fit()
project.analysis.show_fit_results()
# Out:
# Using experiment 🔬 'hrpt' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_27c4c   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_27c4c thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_27c4c th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_27c4c  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_27c4c th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_27c4c tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_27c4c  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_27c4c th.col0 {
#   text-align: center;
# }
# #T_27c4c th.col1 {
#   text-align: center;
# }
# #T_27c4c th.col2 {
#   text-align: center;
# }
# #T_27c4c_row0_col0, #T_27c4c_row0_col1, #T_27c4c_row0_col2, #T_27c4c_row1_col0, #T_27c4c_row1_col1, #T_27c4c_row1_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_27c4c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27c4c_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_27c4c_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_27c4c_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27c4c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_27c4c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_27c4c_row0_col1" class="data row0 col1" >1.29</td>
#       <td id="T_27c4c_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_27c4c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_27c4c_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_27c4c_row1_col1" class="data row1 col1" >1.29</td>
#       <td id="T_27c4c_row1_col2" class="data row1 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 1.29 at iteration 19
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 2.47 seconds
# 📏 Goodness-of-fit (reduced χ²): 1.29
# 📏 R-factor (Rf): 5.65%
# 📏 R-factor squared (Rf²): 5.30%
# 📏 Weighted R-factor (wR): 4.47%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_237e6   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_237e6 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_237e6 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_237e6  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_237e6 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_237e6 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_237e6  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_237e6 th.col0 {
#   text-align: left;
# }
# #T_237e6 th.col1 {
#   text-align: left;
# }
# #T_237e6 th.col2 {
#   text-align: left;
# }
# #T_237e6 th.col3 {
#   text-align: left;
# }
# #T_237e6 th.col4 {
#   text-align: right;
# }
# #T_237e6 th.col5 {
#   text-align: right;
# }
# #T_237e6 th.col6 {
#   text-align: right;
# }
# #T_237e6 th.col7 {
#   text-align: left;
# }
# #T_237e6 th.col8 {
#   text-align: right;
# }
# #T_237e6_row0_col0, #T_237e6_row0_col1, #T_237e6_row0_col2, #T_237e6_row0_col3, #T_237e6_row0_col7, #T_237e6_row1_col0, #T_237e6_row1_col1, #T_237e6_row1_col2, #T_237e6_row1_col3, #T_237e6_row1_col7, #T_237e6_row2_col0, #T_237e6_row2_col1, #T_237e6_row2_col2, #T_237e6_row2_col3, #T_237e6_row2_col7, #T_237e6_row3_col0, #T_237e6_row3_col1, #T_237e6_row3_col2, #T_237e6_row3_col3, #T_237e6_row3_col7, #T_237e6_row4_col0, #T_237e6_row4_col1, #T_237e6_row4_col2, #T_237e6_row4_col3, #T_237e6_row4_col7, #T_237e6_row5_col0, #T_237e6_row5_col1, #T_237e6_row5_col2, #T_237e6_row5_col3, #T_237e6_row5_col7, #T_237e6_row6_col0, #T_237e6_row6_col1, #T_237e6_row6_col2, #T_237e6_row6_col3, #T_237e6_row6_col7, #T_237e6_row7_col0, #T_237e6_row7_col1, #T_237e6_row7_col2, #T_237e6_row7_col3, #T_237e6_row7_col7, #T_237e6_row8_
gn/T/lbco_hrpt
# ├── 📄 project.cif
# ├── 📁 sample_models
# │   └── 📄 lbco.cif
# ├── 📁 experiments
# │   └── 📄 hrpt.cif
# ├── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# ### Perform Fit 5/5
#
# #### Set Constraints
#
# Set more aliases for parameters.

# %%
project.analysis.aliases.add(
    label='occ_La',
    param_uid=project.sample_models['lbco'].atom_sites['La'].occupancy.uid,
)
project.analysis.aliases.add(
    label='occ_Ba',
    param_uid=project.sample_models['lbco'].atom_sites['Ba'].occupancy.uid,
)

# %% [markdown]
# Set more constraints.

# %%
project.analysis.constraints.add(
    lhs_alias='occ_Ba',
    rhs_expr='1 - occ_La',
)

# %% [markdown]
# Show defined constraints.

# %%
project.analysis.show_constraints()
# Out:
# User defined constraints
# <style type="text/css">
# #T_f3956   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_f3956 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_f3956 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_f3956  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_f3956 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_f3956 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_f3956  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_f3956 th.col0 {
#   text-align: left;
# }
# #T_f3956 th.col1 {
#   text-align: left;
# }
# #T_f3956 th.col2 {
#   text-align: left;
# }
# #T_f3956_row0_col0, #T_f3956_row0_col1, #T_f3956_row0_col2, #T_f3956_row1_col0, #T_f3956_row1_col1, #T_f3956_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_f3956" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3956_level0_col0" class="col_heading level0 col0" >lhs_alias</th>
#       <th id="T_f3956_level0_col1" class="col_heading level0 col1" >rhs_expr</th>
#       <th id="T_f3956_level0_col2" class="col_heading level0 col2" >full expression</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3956_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f3956_row0_col0" class="data row0 col0" >biso_Ba</td>
#       <td id="T_f3956_row0_col1" class="data row0 col1" >biso_La</td>
#       <td id="T_f3956_row0_col2" class="data row0 col2" >biso_Ba = biso_La</td>
#     </tr>
#     <tr>
#       <th id="T_f3956_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f3956_row1_col0" class="data row1 col0" >occ_Ba</td>
#       <td id="T_f3956_row1_col1" class="data row1 col1" >1 - occ_La</td>
#       <td id="T_f3956_row1_col2" class="data row1 col2" >occ_Ba = 1 - occ_La</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Apply constraints.

# %%
project.analysis.apply_constraints()

# %% [markdown]
# Set sample model parameters to be refined.

# %%
project.sample_models['lbco'].atom_sites['La'].occupancy.free = True

# %% [markdown]
# Show free parameters after selection.

# %%
project.analysis.show_free_params()
# Out:
# Free parameters for both sample models (🧩 data blocks) and experiments (🔬 data blocks)
# <style type="text/css">
# #T_674a7   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_674a7 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_674a7 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_674a7  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_674a7 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_674a7 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_674a7  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_674a7 th.col0 {
#   text-align: left;
# }
# #T_674a7 th.col1 {
#   text-align: left;
# }
# #T_674a7 th.col2 {
#   text-align: left;
# }
# #T_674a7 th.col3 {
#   text-align: left;
# }
# #T_674a7 th.col4 {
#   text-align: right;
# }
# #T_674a7 th.col5 {
#   text-align: right;
# }
# #T_674a7 th.col6 {
#   text-align: right;
# }
# #T_674a7 th.col7 {
#   text-align: right;
# }
# #T_674a7 th.col8 {
#   text-align: left;
# }
# #T_674a7_row0_col0, #T_674a7_row0_col1, #T_674a7_row0_col2, #T_674a7_row0_col3, #T_674a7_row0_col8, #T_674a7_row1_col0, #T_674a7_row1_col1, #T_674a7_row1_col2, #T_674a7_row1_col3, #T_674a7_row1_col8, #T_674a7_row2_col0, #T_674a7_row2_col1, #T_674a7_row2_col2, #T_674a7_row2_col3, #T_674a7_row2_col8, #T_674a7_row3_col0, #T_674a7_row3_col1, #T_674a7_row3_col2, #T_674a7_row3_col3, #T_674a7_row3_col8, #T_674a7_row4_col0, #T_674a7_row4_col1, #T_674a7_row4_col
wQKf+zwm4JXJAohKe9oyTdUBFHHXICwd8QExN3ota14NAovjs0GWHjUC0IoH5Z\u002fqVQDYcLZSPZ59AxwgZ6pP1pEDoF1Cx7KSpQPb0olyjQ6xAZIOxrUyzq0DA+1STQTSoQLuqjbFhJqNAkLN3HzDtm0AhvUiVqSmTQExIXwlHjIlACuH9V1RSgUDaBPVJpBV5QCBliOgQ6nNAr\u002fbZXUMtcUDyQJ25J1BvQDrPRVZ2bm1A3xh5h0EebEC495ETKx5rQLwwxGZaUWpAJXhIfVmpaUBSxoNlfh1pQK4n00nVp2hATm7ITPlDaEDP8jwwkO5nQBuf0X\u002f\u002fpGdAB8+YPjtlZ0C6NrYYoy1nQB0EfBvp\u002fGZAcaPSDP\u002fRZkAIy0p6CKxmQF8lOTFQimZANVqTNUBsZkAUGkqRW1FmQGr7u4Q5OWZAYUaVwYEjZkA="},"type":"scatter"},{"line":{"color":"rgb(44, 160, 44)"},"mode":"lines","name":"Residual (Imeas - Icalc)","x":{"dtype":"f8","bdata":"..."},"y":{"dtype":"f8","bdata":"YKITQeWEMEBg9s+Zm2cRwMDzCWj9gwLAcCeckOXEIMAAgWybBNgoQKBjXXKQKyRAYCJY0d1SFkCQe3mRXD0iwEDxfu1qNhTAIM6pUbgNFcAgZNf+R2MgQAD3F52f\\u002f4pKPcCgTVCfRFo4wABShogOoTjAeLXP7hrqRMCQB+rMPYExwDCG0U1NjDFACDk3xPMNPEAA7n3kxIoPwMALQ2ymFS3A2D68FTS1MECQMh4s8+s8wJDCZrFVwTRAIBt5M2vAJ0BATMPw81sMQCgHcwEE2DNAIB\u002fmLJhYE0BglJx0ziUnQGB8f5DcYhBAeORqmQdwM0DAp6ktvJ86QECotrHzaw1AQI3WZA0QA8BgL691I3U3QLAkINozNjRA+MxV8\u002fHjOUA="},"type":"scatter"}],                        {"legend":{"x":1.0,"xanchor":"right","y":1.0,"yanchor":"top"},"margin":{"autoexpand":true,"b":45,"r":30,"t":40},"title":{"text":"Measured vs Calculated data for experiment \ud83d\udd2c 'hrpt'"},"xaxis":{"mirror":true,"showline":true,"title":{"text":"2\u03b8 (degree)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"yaxis":{"mirror":true,"showline":true,"title":{"text":"Intensity (arb. units)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222 ...

# %% [markdown]
# #### Save Project State

# %%
project.save_as(dir_path='lbco_hrpt', temporary=True)
# Out:
# Saving project 📦 'lbco_hrpt' to
# /private/var/folders/sm/xrr7tmqj20s7hrsh1qhfl1d40000gn/T/lbco_hrpt
# ├── 📄 project.cif
# ├── 📁 sample_models
# │   └── 📄 lbco.cif
# ├── 📁 experiments
# │   └── 📄 hrpt.cif
# ├── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# ## Step 5: Summary
#
# This final section shows how to review the results of the analysis.

# %% [markdown]
# #### Show Project Summary

# %%
project.summary.show_report()
# Out:
# ————————————
# PROJECT INFO
# ————————————
# Title
# La0.5Ba0.5CoO3 at HRPT@PSI
# Description
# This project demonstrates a standard refinement of
# La0.5Ba0.5CoO3, which crystallizes in a perovskite-type
# structure, using neutron powder diffraction data collected
# in constant wavelength mode at the HRPT diffractometer
# (PSI).
# —————————————————————
# CRYSTALLOGRAPHIC DATA
# —————————————————————
# Phase datablock
# 🧩 lbco
# Space group
# P m -3 m
# Cell parameters
# <style type="text/css">
# #T_d678c   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_d678c thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_d678c th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_d678c  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_d678c th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_d678c tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_d678c  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_d678c th.col0 {
#   text-align: left;
# }
# #T_d678c th.col1 {
#   text-align: right;
# }
# #T_d678c_row0_col0, #T_d678c_row1_col0, #T_d678c_row2_col0, #T_d678c_row3_col0, #T_d678c_row4_col0, #T_d678c_row5_col0 {
#   text-align: left;
# }
# #T_d678c_row0_col1, #T_d678c_row1_col1, #T_d678c_row2_col1, #T_d678c_row3_col1, #T_d678c_row4_col1, #T_d678c_row5_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_d678c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d678c_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_d678c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d678c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d678c_row0_col0" class="data row0 col0" >a</td>
#       <td id="T_d678c_row0_col1" class="data row0 col1" >3.89087</td>
#     </tr>
#     <tr>
#       <th id="T_d678c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d678c_row1_col0" class="data row1 col0" >b</td>
#       <td id="T_d678c_row1_col1" class="data row1 col1" >3.89087</td>
#     </tr>
#     <tr>
#       <th id="T_d678c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d678c_row2_col0" class="data row2 col0" >c</td>
#       <td id="T_d678c_row2_col1" class="data row2 col1" >3.89087</td>
#     </tr>
#     <tr>
#       <th id="T_d678c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d678c_row3_col0" class="data row3 col0" >alpha</td>
#       <td id="T_d678c_row3_col1" class="data row3 col1" >90.00000</td>
#     </tr>
#     <tr>
#       <th id="T_d678c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d678c_row4_col0" class="data row4 col0" >beta</td>
#       <td id="T_d678c_row4_col1" class="data row4 col1" >90.00000</td>
#     </tr>
#     <tr>
#       <th id="T_d678c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d678c_row5_col0" class="data row5 col0" >gamma</td>
#       <td id="T_d678c_row5_col1" class="data row5 col1" >90.00000</td>
#     </tr>
#   </tbody>
# </table>
# Atom sites
# <style type="text/css">
# #T_81164   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_81164 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_81164 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_81164  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_81164 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_81164 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_81164  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_81164 th.col0 {
#   text-align: left;
# }
# #T_81164 th.col1 {
#   text-align: left;
# }
# #T_81164 th.col2 {
#   text-align: right;
# }
# #T_81164 th.col3 {
#   text-align: right;
# }
# #T_81164 th.col4 {
#   text-align: right;
# }
# #T_81164 th.col5 {
#   text-align: right;
# }
# #T_81164 th.col6 {
#   text-align: right;
# }
# #T_81164_row0_col0, #T_81164_row0_col1, #T_81164_row1_col0, #T_81164_row1_col1, #T_81164_row2_col0, #T_81164_row2_col1, #T_81164_row3_col0, #T_81164_row3_col1 {
#   text-align: left;
# }
# #T_81164_row0_col2, #T_81164_row0_col3, #T_81164_row0_col4, #T_81164_row0_col5, #T_81164_row0_col6, #T_81164_row1_col2, #T_81164_row1_col3, #T_81164_row1_col4, #T_81164_row1_col5, #T_81164_row1_col6, #T_81164_row2_col2, #T_81164_row2_col3, #T_81164_row2_col4, #T_81164_row2_col5, #T_81164_row2_col6, #T_81164_row3_col2, #T_81164_row3_col3, #T_81164_row3_col4, #T_81164_row3_col5, #T_81164_row3_col6 {
#   text-align: right;
# }
# </style>
# <table id="T_81164" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81164_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_81164_level0_col1" class="col_heading level0 col1" >type</th>
#       <th id="T_81164_level0_col2" class="col_heading level0 col2" >x</th>
#       <th id="T_81164_level0_col3" class="col_heading level0 col3" >y</th>
#       <th id="T_81164_level0_col4" class="col_heading level0 col4" >z</th>
#       <th id="T_81164_level0_col5" class="col_heading level0 col5" >occ</th>
#       <th id="T_81164_level0_col6" class="col_heading level0 col6" >Biso</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81164_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_81164_row0_col0" class="data row0 col0" >La</td>
#       <td id="T_81164_row0_col1" class="data row0 col1" >La</td>
#       <td id="T_81164_row0_col2" class="data row0 col2" >0.00000</td>
#       <td id="T_81164_row0_col3" class="data row0 col3" >0.00000</td>
#       <td id="T_81164_row0_col4" class="data row0 col4" >0.00000</td>
#       <td id="T_81164_row0_col5" class="data row0 col5" >0.58403</td>
#       <td id="T_81164_row0_col6" class="data row0 col6" >0.59832</td>
#     </tr>
#     <tr>
#       <th id="T_81164_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_81164_row1_col0" class="data row1 col0" >Ba</td>
#       <td id="T_81164_row1_col1" class="data row1 col1" >Ba</td>
#       <td id="T_81164_row1_col2" class="data row1 col2" >0.00000</td>
#       <td id="T_81164_row1_col3" class="data row1 col3" >0.00000</td>
#       <td id="T_81164_row1_col4" class="data row1 col4" >0.00000</td>
#       <td id="T_81164_row1_col5" class="data row1 col5" >0.41597</td>
#       <td id="T_81164_row1_col6" class="data row1 col6" >0.59832</td>
#     </tr>
#     <tr>
#       <th id="T_81164_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_81164_row2_col0" class="data row2 col0" >Co</td>
#       <td id="T_81164_row2_col1" class="data row2 col1" >Co</td>
#       <td id="T_81164_row2_col2" class="data row2 col2" >0.50000</td>
#       <td id="T_81164_row2_col3" class="data row2 col3" >0.50000</td>
#       <td id="T_81164_row2_col4" class="data row2 col4" >0.50000</td>
#       <td id="T_81164_row2_col5" class="data row2 col5" >1.00000</td>
#       <td id="T_81164_row2_col6" class="data row2 col6" >0.16651</td>
#     </tr>
#     <tr>
#       <th id="T_81164_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_81164_row3_col0" class="data row3 col0" >O</td>
#       <td id="T_81164_row3_col1" class="data row3 col1" >O</td>
#       <td id="T_81164_row3_col2" class="data row3 col2" >0.00000</td>
#       <td id="T_81164_row3_col3" class="data row3 col3" >0.50000</td>
#       <td id="T_81164_row3_col4" class="data row3 col4" >0.50000</td>
#       <td id="T_81164_row3_col5" class="data row3 col5" >1.00000</td>
#       <td id="T_81164_row3_col6" class="data row3 col6" >1.34914</td>
#     </tr>
#   </tbody>
# </table>
# ———————————
# EXPERIMENTS
# ———————————
# Experiment datablock
# 🔬 hrpt
# Experiment type
# powder, neutron, constant wavelength
# Wavelength
# 1.49400
# 2θ offset
# 0.62261
# Profile type
# PeakProfileTypeEnum.PSEUDO_VOIGT
# Peak broadening (Gaussian)
# <style type="text/css">
# #T_be9a3   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_be9a3 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_be9a3 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_be9a3  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_be9a3 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_be9a3 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_be9a3  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_be9a3 th.col0 {
#   text-align: left;
# }
# #T_be9a3 th.col1 {
#   text-align: right;
# }
# #T_be9a3_row0_col0, #T_be9a3_row1_col0, #T_be9a3_row2_col0 {
#   text-align: left;
# }
# #T_be9a3_row0_col1, #T_be9a3_row1_col1, #T_be9a3_row2_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_be9a3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be9a3_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_be9a3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be9a3_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_be9a3_row0_col0" class="data row0 col0" >U</td>
#       <td id="T_be9a3_row0_col1" class="data row0 col1" >0.08122</td>
#     </tr>
#     <tr>
#       <th id="T_be9a3_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_be9a3_row1_col0" class="data row1 col0" >V</td>
#       <td id="T_be9a3_row1_col1" class="data row1 col1" >-0.11537</td>
#     </tr>
#     <tr>
#       <th id="T_be9a3_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_be9a3_row2_col0" class="data row2 col0" >W</td>
#       <td id="T_be9a3_row2_col1" class="data row2 col1" >0.12028</td>
#     </tr>
#   </tbody>
# </table>
# Peak broadening (Lorentzian)
# <style type="text/css">
# #T_ade7a   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_ade7a thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_ade7a th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_ade7a  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_ade7a th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_ade7a tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_ade7a  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_ade7a th.col0 {
#   text-align: left;
# }
# #T_ade7a th.col1 {
#   text-align: right;
# }
# #T_ade7a_row0_col0, #T_ade7a_row1_col0 {
#   text-align: left;
# }
# #T_ade7a_row0_col1, #T_ade7a_row1_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_ade7a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ade7a_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_ade7a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ade7a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ade7a_row0_col0" class="data row0 col0" >X</td>
#       <td id="T_ade7a_row0_col1" class="data row0 col1" >0.00000</td>
#     </tr>
#     <tr>
#       <th id="T_ade7a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ade7a_row1_col0" class="data row1 col0" >Y</td>
#       <td id="T_ade7a_row1_col1" class="data row1 col1" >0.08460</td>
#     </tr>
#   </tbody>
# </table>
# ———————
# FITTING
# ———————
# Calculation engine
# cryspy
# Minimization engine
# lmfit (leastsq)
# Fit quality
# <style type="text/css">
# #T_a0950   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_a0950 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_a0950 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a0950  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a0950 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_a0950 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_a0950  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_a0950 th.col0 {
#   text-align: left;
# }
# #T_a0950 th.col1 {
#   text-align: right;
# }
# #T_a0950_row0_col0 {
#   text-align: left;
# }
# #T_a0950_row0_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_a0950" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0950_level0_col0" class="col_heading level0 col0" >metric</th>
#       <th id="T_a0950_level0_col1" class="col_heading level0 col1" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0950_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a0950_row0_col0" class="data row0 col0" >Goodness-of-fit (reduced χ²)</td>
#       <td id="T_a0950_row0_col1" class="data row0 col1" >1.28</td>
#     </tr>
#   </tbody>
# </table>
