# %%
# Check whether easydiffraction is installed; install it if needed.
# Required for remote environments such as Google Colab.
import importlib.util

if importlib.util.find_spec('easydiffraction') is None:
    # %pip install easydiffraction

# %% [markdown]
# # Structure Refinement: LBCO, HRPT
#
# This example demonstrates how to use the EasyDiffraction API in a
# simplified, user-friendly manner that closely follows the GUI workflow
# for a Rietveld refinement of La0.5Ba0.5CoO3 crystal structure using
# constant wavelength neutron powder diffraction data from HRPT at PSI.
#
# It is intended for users with minimal programming experience who want
# to learn how to perform standard crystal structure fitting using
# diffraction data. This script covers creating a project, adding
# crystal structures and experiments, performing analysis, and refining
# parameters.
#
# Only a single import of `easydiffraction` is required, and all
# operations are performed through high-level components of the
# `project` object, such as `project.structures`,
# `project.experiments`, and `project.analysis`. The `project` object is
# the main container for all information.

# %% [markdown]
# ## Import Library

# %%
import easydiffraction as ed

# %% [markdown]
# ## Step 1: Create a Project
#
# This section explains how to create a project and define its metadata.

# %% [markdown]
# #### Create Project

# %%
project = ed.Project(name='lbco_hrpt')

# %% [markdown]
# #### Set Project Metadata

# %%
project.info.title = 'La0.5Ba0.5CoO3 at HRPT@PSI'
project.info.description = """This project demonstrates a standard
refinement of La0.5Ba0.5CoO3, which crystallizes in a perovskite-type
structure, using neutron powder diffraction data collected in constant
wavelength mode at the HRPT diffractometer (PSI)."""

# %% [markdown]
# #### Show Project Metadata as CIF

# %%
project.info.show_as_cif()
# Out:
# Project 📦 'lbco_hrpt' info as CIF
# <style type="text/css">
# #T_3afc1   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_3afc1 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_3afc1 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_3afc1  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_3afc1 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_3afc1 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_3afc1  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_3afc1 th.col0 {
#   text-align: left;
# }
# #T_3afc1_row0_col0, #T_3afc1_row1_col0, #T_3afc1_row2_col0, #T_3afc1_row3_col0, #T_3afc1_row4_col0, #T_3afc1_row5_col0, #T_3afc1_row6_col0, #T_3afc1_row7_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_3afc1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3afc1_level0_col0" class="col_heading level0 col0" >CIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3afc1_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_3afc1_row0_col0" class="data row0 col0" >_project.id               lbco_hrpt</td>
#     </tr>
#     <tr>
#       <th id="T_3afc1_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_3afc1_row1_col0" class="data row1 col0" >_project.title            'La0.5Ba0.5CoO3 at HRPT@PSI'</td>
#     </tr>
#     <tr>
#       <th id="T_3afc1_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_3afc1_row2_col0" class="data row2 col0" >_project.description      </td>
#     </tr>
#     <tr>
#       <th id="T_3afc1_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_3afc1_row3_col0" class="data row3 col0" >;</td>
#     </tr>
#     <tr>
#       <th id="T_3afc1_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_3afc1_row4_col0" class="data row4 col0" >This project demonstrates a standard refinement of La0.5Ba0.5CoO3, which crystallizes in a perovskite-type structure, using neutron powder diffraction data collected in constant wavelength mode at the HRPT diffractometer (PSI).</td>
#     </tr>
#     <tr>
#       <th id="T_3afc1_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_3afc1_row5_col0" class="data row5 col0" >;</td>
#     </tr>
#     <tr>
#       <th id="T_3afc1_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_3afc1_row6_col0" class="data row6 col0" >_project.created          '11 Apr 2026 18:20:33'</td>
#     </tr>
#     <tr>
#       <th id="T_3afc1_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_3afc1_row7_col0" class="data row7 col0" >_project.last_modified    '11 Apr 2026 18:20:33'</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Save Project
#
# When saving the project for the first time, you need to specify the
# directory path. In the example below, the project is saved to a
# temporary location defined by the system.

# %%
project.save_as(dir_path='lbco_hrpt', temporary=True)
# Out:
# Saving project 📦 'lbco_hrpt' to
# /tmp/lbco_hrpt
# ├── 📄 project.cif
# ├── 📁 structures/
# ├── 📁 experiments/
# ├── 📁 analysis/
# │   └── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# #### Set Up Data Plotter

# %% [markdown]
# Show supported plotting engines.

# %%
project.plotter.show_supported_engines()
# Out:
# Supported engines
# <style type="text/css">
# #T_14021   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_14021 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_14021 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_14021  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_14021 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_14021 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_14021  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_14021 th.col0 {
#   text-align: left;
# }
# #T_14021 th.col1 {
#   text-align: left;
# }
# #T_14021_row0_col0, #T_14021_row0_col1, #T_14021_row1_col0, #T_14021_row1_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_14021" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14021_level0_col0" class="col_heading level0 col0" >Engine</th>
#       <th id="T_14021_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14021_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_14021_row0_col0" class="data row0 col0" >asciichartpy</td>
#       <td id="T_14021_row0_col1" class="data row0 col1" >Console ASCII line charts</td>
#     </tr>
#     <tr>
#       <th id="T_14021_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_14021_row1_col0" class="data row1 col0" >plotly</td>
#       <td id="T_14021_row1_col1" class="data row1 col1" >Interactive browser-based graphing library</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Show current plotting configuration.

# %%
project.plotter.show_config()
# Out:
# Current plotter configuration
# <style type="text/css">
# #T_914ad   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_914ad thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_914ad th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_914ad  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_914ad th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_914ad tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_914ad  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_914ad th.col0 {
#   text-align: left;
# }
# #T_914ad th.col1 {
#   text-align: left;
# }
# #T_914ad_row0_col0, #T_914ad_row0_col1, #T_914ad_row1_col0, #T_914ad_row1_col1, #T_914ad_row2_col0, #T_914ad_row2_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_914ad" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_914ad_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_914ad_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_914ad_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_914ad_row0_col0" class="data row0 col0" >Plotting engine</td>
#       <td id="T_914ad_row0_col1" class="data row0 col1" >plotly</td>
#     </tr>
#     <tr>
#       <th id="T_914ad_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_914ad_row1_col0" class="data row1 col0" >x-axis limits</td>
#       <td id="T_914ad_row1_col1" class="data row1 col1" >[-inf, inf]</td>
#     </tr>
#     <tr>
#       <th id="T_914ad_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_914ad_row2_col0" class="data row2 col0" >Chart height</td>
#       <td id="T_914ad_row2_col1" class="data row2 col1" >25</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Set plotting engine.

# %%
# Keep the auto-selected engine. Alternatively, you can uncomment the
# line below to explicitly set the engine to the required one.
# project.plotter.engine = 'plotly'

# %% [markdown]
# ## Step 2: Define Structure
#
# This section shows how to add structures and modify their
# parameters.

# %% [markdown]
# #### Add Structure

# %%
project.structures.create(name='lbco')

# %% [markdown]
# #### Show Defined Structures
#
# Show the names of the crystal structures added. These names are used
# to access the structure using the syntax:
# `project.structures[name]`. All structure parameters can be accessed
# via the `project` object.

# %%
project.structures.show_names()
# Out:
# Defined structures 🧩
# ['lbco']

# %% [markdown]
# #### Set Space Group
#
# Modify the default space group parameters.

# %%
project.structures['lbco'].space_group.name_h_m = 'P m -3 m'
project.structures['lbco'].space_group.it_coordinate_system_code = '1'

# %% [markdown]
# #### Set Unit Cell
#
# Modify the default unit cell parameters.

# %%
project.structures['lbco'].cell.length_a = 3.88

# %% [markdown]
# #### Set Atom Sites
#
# Add atom sites to the structure.

# %%
project.structures['lbco'].atom_sites.create(
    label='La',
    type_symbol='La',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    b_iso=0.5,
    occupancy=0.5,
)
project.structures['lbco'].atom_sites.create(
    label='Ba',
    type_symbol='Ba',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    b_iso=0.5,
    occupancy=0.5,
)
project.structures['lbco'].atom_sites.create(
    label='Co',
    type_symbol='Co',
    fract_x=0.5,
    fract_y=0.5,
    fract_z=0.5,
    wyckoff_letter='b',
    b_iso=0.5,
)
project.structures['lbco'].atom_sites.create(
    label='O',
    type_symbol='O',
    fract_x=0,
    fract_y=0.5,
    fract_z=0.5,
    wyckoff_letter='c',
    b_iso=0.5,
)

# %% [markdown]
# #### Show Structure as CIF

# %%
project.structures['lbco'].show_as_cif()
# Out:
# Structure 🧩 'lbco' as cif
# <style type="text/css">
# #T_5794e   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_5794e thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_5794e th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_5794e  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_5794e th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_5794e tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_5794e  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_5794e th.col0 {
#   text-align: left;
# }
# #T_5794e_row0_col0, #T_5794e_row1_col0, #T_5794e_row2_col0, #T_5794e_row3_col0, #T_5794e_row4_col0, #T_5794e_row5_col0, #T_5794e_row6_col0, #T_5794e_row7_col0, #T_5794e_row8_col0, #T_5794e_row9_col0, #T_5794e_row10_col0, #T_5794e_row11_col0, #T_5794e_row12_col0, #T_5794e_row13_col0, #T_5794e_row14_col0, #T_5794e_row15_col0, #T_5794e_row16_col0, #T_5794e_row17_col0, #T_5794e_row18_col0, #T_5794e_row19_col0, #T_5794e_row20_col0, #T_5794e_row21_col0, #T_5794e_row22_col0, #T_5794e_row23_col0, #T_5794e_row24_col0, #T_5794e_row25_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_5794e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5794e_level0_col0" class="col_heading level0 col0" >CIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5794e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5794e_row0_col0" class="data row0 col0" >data_lbco</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_5794e_row1_col0" class="data row1 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_5794e_row2_col0" class="data row2 col0" >_cell.length_a   3.88000000</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_5794e_row3_col0" class="data row3 col0" >_cell.length_b   3.88000000</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_5794e_row4_col0" class="data row4 col0" >_cell.length_c   3.88000000</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_5794e_row5_col0" class="data row5 col0" >_cell.angle_alpha  90.00000000</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_5794e_row6_col0" class="data row6 col0" >_cell.angle_beta  90.00000000</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_5794e_row7_col0" class="data row7 col0" >_cell.angle_gamma  90.00000000</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_5794e_row8_col0" class="data row8 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_5794e_row9_col0" class="data row9 col0" >_space_group.name_H-M_alt   "P m -3 m"</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_5794e_row10_col0" class="data row10 col0" >_space_group.IT_coordinate_system_code            1</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_5794e_row11_col0" class="data row11 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_5794e_row12_col0" class="data row12 col0" >loop_</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_5794e_row13_col0" class="data row13 col0" >_atom_site.label</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_5794e_row14_col0" class="data row14 col0" >_atom_site.type_symbol</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_5794e_row15_col0" class="data row15 col0" >_atom_site.fract_x</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_5794e_row16_col0" class="data row16 col0" >_atom_site.fract_y</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_5794e_row17_col0" class="data row17 col0" >_atom_site.fract_z</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_5794e_row18_col0" class="data row18 col0" >_atom_site.Wyckoff_letter</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_5794e_row19_col0" class="data row19 col0" >_atom_site.occupancy</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row20" class="row_heading level0 row20" >21</th>
#       <td id="T_5794e_row20_col0" class="data row20 col0" >_atom_site.B_iso_or_equiv</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row21" class="row_heading level0 row21" >22</th>
#       <td id="T_5794e_row21_col0" class="data row21 col0" >_atom_site.adp_type</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_5794e_row22_col0" class="data row22 col0" >          La           La   0.00000000   0.00000000   0.00000000            a   0.50000000   0.50000000         Biso</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row23" class="row_heading level0 row23" >24</th>
#       <td id="T_5794e_row23_col0" class="data row23 col0" >          Ba           Ba   0.00000000   0.00000000   0.00000000            a   0.50000000   0.50000000         Biso</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row24" class="row_heading level0 row24" >25</th>
#       <td id="T_5794e_row24_col0" class="data row24 col0" >          Co           Co   0.50000000   0.50000000   0.50000000            b   1.00000000   0.50000000         Biso</td>
#     </tr>
#     <tr>
#       <th id="T_5794e_level0_row25" class="row_heading level0 row25" >26</th>
#       <td id="T_5794e_row25_col0" class="data row25 col0" >           O            O   0.00000000   0.50000000   0.50000000            c   1.00000000   0.50000000         Biso</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Show Structure Structure

# %%
project.structures['lbco'].show()
# Out:
# Structure 🧩 'lbco'
# Not implemented yet.

# %% [markdown]
# #### Save Project State
#
# Save the project state after adding the structure. This ensures
# that all changes are stored and can be accessed later. The project
# state is saved in the directory specified during project creation.

# %%
project.save()
# Out:
# Saving project 📦 'lbco_hrpt' to
# /tmp/lbco_hrpt
# ├── 📄 project.cif
# ├── 📁 structures/
# │   └── 📄 lbco.cif
# ├── 📁 experiments/
# ├── 📁 analysis/
# │   └── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# ## Step 3: Define Experiment
#
# This section shows how to add experiments, configure their parameters,
# and link the structures defined in the previous step.

# %% [markdown]
# #### Download Measured Data
#
# Download the data file from the EasyDiffraction repository on GitHub.

# %%
data_path = ed.download_data(id=3, destination='data')
# Out:
# Getting data...
# Data #3: La0.5Ba0.5CoO3, HRPT (PSI), 300 K
# ✅ Data #3 already present at 'data/ed-3.xye'. Keeping existing file.

# %% [markdown]
# #### Add Diffraction Experiment

# %%
project.experiments.add_from_data_path(
    name='hrpt',
    data_path=data_path,
    sample_form='powder',
    beam_mode='constant wavelength',
    radiation_probe='neutron',
)
# Out:
# Data loaded successfully
# Experiment 🔬 'hrpt'. Number of data points: 3098.

# %% [markdown]
# #### Show Defined Experiments

# %%
project.experiments.show_names()
# Out:
# Defined experiments 🔬
# ['hrpt']

# %% [markdown]
# #### Show Measured Data

# %%
project.plotter.plot_meas(expt_name='hrpt')
# Out:
# Warning: No linked phases defined. Returning empty pattern.
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="7850cab0-9806-42de-abe7-9df35e43008e" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7850cab0-9806-42de-abe7-9df35e43008e")) {                    Plotly.newPlot(                        "7850cab0-9806-42de-abe7-9df35e43008e",                        [{"line":{"color":"rgb(31, 119, 180)"},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"...\...\...\...\...\...\u002fQJqZmZmZGT9AZmZmZmYmP0AzMzMzMzM\u002fQAAAAAAAQD9AzczMzMxMP0CamZmZmVk\u002fQGZmZmZmZj9AMzMzMzNzP0AAAAAAAIA\u002fQM3MzMzMjD9AmpmZmZmZP0BmZmZmZqY\u002fQDMzMzMzsz9AAAAAAADAP0DNzMzMzMw\u002fQJqZmZmZ2T9AZmZmZmbmP0AzMzMzM\u002fM\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\u002fNgQM3MzMzM9GBAZmZmZmb2YEAAAAAAAPhgQJqZmZmZ+WBAMzMzMzP7YEDNzMzMzPxgQGZmZmZm\...\u002fthQM3MzMzM\...\u002fNjQM3MzMzM9GNAZmZmZmb2Y0AAAAAAAPhjQJqZmZmZ+WNAMzMzMzP7Y0DNzMzMzPxjQGZmZmZm\..."},"y":{"dtype":"f8","bdata":"..."},"type":"scatter"}],                        {"legend":{"x":1.0,"xanchor":"right","y":1.0,"yanchor":"top"},"margin":{"autoexpand":true,"b":45,"r":30,"t":40},"title":{"text":"Measured data for experiment \ud83d\udd2c 'hrpt'"},"xaxis":{"mirror":true,"showline":true,"title":{"text":"2\u03b8 (degree)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"yaxis":{"mirror":true,"showline":true,"title":{"text":"Intensity (arb. units)"},"zeroline":false,"tickformat":",.6~g","separatethousands":true},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type" ...

# %% [markdown]
# #### Set Instrument
#
# Modify the default instrument parameters.

# %%
project.experiments['hrpt'].instrument.setup_wavelength = 1.494
project.experiments['hrpt'].instrument.calib_twotheta_offset = 0.6

# %% [markdown]
# #### Set Peak Profile
#
# Show supported peak profile types.

# %%
project.experiments['hrpt'].show_supported_peak_profile_types()
# Out:
# Supported types
# <style type="text/css">
# #T_b5c0f   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_b5c0f thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_b5c0f th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_b5c0f  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_b5c0f th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_b5c0f tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_b5c0f  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_b5c0f th.col0 {
#   text-align: left;
# }
# #T_b5c0f th.col1 {
#   text-align: left;
# }
# #T_b5c0f_row0_col0, #T_b5c0f_row0_col1, #T_b5c0f_row1_col0, #T_b5c0f_row1_col1, #T_b5c0f_row2_col0, #T_b5c0f_row2_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_b5c0f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5c0f_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_b5c0f_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5c0f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b5c0f_row0_col0" class="data row0 col0" >pseudo-voigt</td>
#       <td id="T_b5c0f_row0_col1" class="data row0 col1" >Pseudo-Voigt profile</td>
#     </tr>
#     <tr>
#       <th id="T_b5c0f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b5c0f_row1_col0" class="data row1 col0" >pseudo-voigt + empirical asymmetry</td>
#       <td id="T_b5c0f_row1_col1" class="data row1 col1" >Pseudo-Voigt with empirical asymmetry correction</td>
#     </tr>
#     <tr>
#       <th id="T_b5c0f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b5c0f_row2_col0" class="data row2 col0" >thompson-cox-hastings</td>
#       <td id="T_b5c0f_row2_col1" class="data row2 col1" >Thompson-Cox-Hastings with FCJ asymmetry correction</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Show the current peak profile type.

# %%
project.experiments['hrpt'].show_current_peak_profile_type()
# Out:
# Current peak profile type
# pseudo-voigt

# %% [markdown]
# Select the desired peak profile type.

# %%
project.experiments['hrpt'].peak_profile_type = 'pseudo-voigt'
# Out:
# ⚠️ Switching peak profile type discards existing peak parameters.
# Peak profile type for experiment 'hrpt' changed to
# pseudo-voigt

# %% [markdown]
# Modify default peak profile parameters.

# %%
project.experiments['hrpt'].peak.broad_gauss_u = 0.1
project.experiments['hrpt'].peak.broad_gauss_v = -0.1
project.experiments['hrpt'].peak.broad_gauss_w = 0.1
project.experiments['hrpt'].peak.broad_lorentz_x = 0
project.experiments['hrpt'].peak.broad_lorentz_y = 0.1

# %% [markdown]
# #### Set Background

# %% [markdown]
# Show supported background types.

# %%
project.experiments['hrpt'].show_supported_background_types()
# Out:
# Supported types
# <style type="text/css">
# #T_61400   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_61400 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_61400 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_61400  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_61400 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_61400 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_61400  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_61400 th.col0 {
#   text-align: left;
# }
# #T_61400 th.col1 {
#   text-align: left;
# }
# #T_61400_row0_col0, #T_61400_row0_col1, #T_61400_row1_col0, #T_61400_row1_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_61400" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61400_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_61400_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61400_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_61400_row0_col0" class="data row0 col0" >chebyshev</td>
#       <td id="T_61400_row0_col1" class="data row0 col1" >Chebyshev polynomial background</td>
#     </tr>
#     <tr>
#       <th id="T_61400_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_61400_row1_col0" class="data row1 col0" >line-segment</td>
#       <td id="T_61400_row1_col1" class="data row1 col1" >Linear interpolation between points</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Show current background type.

# %%
project.experiments['hrpt'].show_current_background_type()
# Out:
# Current background type
# line-segment

# %% [markdown]
# Select the desired background type.

# %%
project.experiments['hrpt'].background_type = 'line-segment'
# Out:
# Background type for experiment 'hrpt' already set to
# line-segment

# %% [markdown]
# Add background points.

# %%
project.experiments['hrpt'].background.create(id='10', x=10, y=170)
project.experiments['hrpt'].background.create(id='30', x=30, y=170)
project.experiments['hrpt'].background.create(id='50', x=50, y=170)
project.experiments['hrpt'].background.create(id='110', x=110, y=170)
project.experiments['hrpt'].background.create(id='165', x=165, y=170)

# %% [markdown]
# Show current background points.

# %%
project.experiments['hrpt'].background.show()
# Out:
# Line-segment background points
# <style type="text/css">
# #T_6a73e   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_6a73e thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_6a73e th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_6a73e  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_6a73e th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_6a73e tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_6a73e  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_6a73e th.col0 {
#   text-align: left;
# }
# #T_6a73e th.col1 {
#   text-align: left;
# }
# #T_6a73e_row0_col0, #T_6a73e_row0_col1, #T_6a73e_row1_col0, #T_6a73e_row1_col1, #T_6a73e_row2_col0, #T_6a73e_row2_col1, #T_6a73e_row3_col0, #T_6a73e_row3_col1, #T_6a73e_row4_col0, #T_6a73e_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_6a73e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a73e_level0_col0" class="col_heading level0 col0" >X</th>
#       <th id="T_6a73e_level0_col1" class="col_heading level0 col1" >Intensity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a73e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6a73e_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_6a73e_row0_col1" class="data row0 col1" >170</td>
#     </tr>
#     <tr>
#       <th id="T_6a73e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6a73e_row1_col0" class="data row1 col0" >30</td>
#       <td id="T_6a73e_row1_col1" class="data row1 col1" >170</td>
#     </tr>
#     <tr>
#       <th id="T_6a73e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6a73e_row2_col0" class="data row2 col0" >50</td>
#       <td id="T_6a73e_row2_col1" class="data row2 col1" >170</td>
#     </tr>
#     <tr>
#       <th id="T_6a73e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_6a73e_row3_col0" class="data row3 col0" >110</td>
#       <td id="T_6a73e_row3_col1" class="data row3 col1" >170</td>
#     </tr>
#     <tr>
#       <th id="T_6a73e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6a73e_row4_col0" class="data row4 col0" >165</td>
#       <td id="T_6a73e_row4_col1" class="data row4 col1" >170</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Set Linked Phases
#
# Link the structure defined in the previous step to the experiment.

# %%
project.experiments['hrpt'].linked_phases.create(id='lbco', scale=10.0)

# %% [markdown]
# #### Show Experiment as CIF

# %%
project.experiments['hrpt'].show_as_cif()
# Out:
# Experiment 🔬 'hrpt' as cif
# <style type="text/css">
# #T_b674c   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_b674c thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_b674c th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_b674c  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_b674c th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_b674c tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_b674c  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_b674c th.col0 {
#   text-align: left;
# }
# #T_b674c_row0_col0, #T_b674c_row1_col0, #T_b674c_row2_col0, #T_b674c_row3_col0, #T_b674c_row4_col0, #T_b674c_row5_col0, #T_b674c_row6_col0, #T_b674c_row7_col0, #T_b674c_row8_col0, #T_b674c_row9_col0, #T_b674c_row10_col0, #T_b674c_row11_col0, #T_b674c_row12_col0, #T_b674c_row13_col0, #T_b674c_row14_col0, #T_b674c_row15_col0, #T_b674c_row16_col0, #T_b674c_row17_col0, #T_b674c_row18_col0, #T_b674c_row19_col0, #T_b674c_row20_col0, #T_b674c_row21_col0, #T_b674c_row22_col0, #T_b674c_row23_col0, #T_b674c_row24_col0, #T_b674c_row25_col0, #T_b674c_row26_col0, #T_b674c_row27_col0, #T_b674c_row28_col0, #T_b674c_row29_col0, #T_b674c_row30_col0, #T_b674c_row31_col0, #T_b674c_row32_col0, #T_b674c_row33_col0, #T_b674c_row34_col0, #T_b674c_row35_col0, #T_b674c_row36_col0, #T_b674c_row37_col0, #T_b674c_row38_col0, #T_b674c_row39_col0, #T_b674c_row40_col0, #T_b674c_row41_col0, #T_b674c_row42_col0, #T_b674c_row43_col0, #T_b674c_row44_col0, #T_b674c_row45_col0, #T_b674c_row46_col0, #T_b674c_row47_col0, #T_b674c_row48_col0, #T_b674c_row49_col0, #T_b674c_row50_col0, #T_b674c_row51_col0, #T_b674c_row52_col0, #T_b674c_row53_col0, #T_b674c_row54_col0, #T_b674c_row55_col0, #T_b674c_row56_col0, #T_b674c_row57_col0, #T_b674c_row58_col0, #T_b674c_row59_col0, #T_b674c_row60_col0, #T_b674c_row61_col0, #T_b674c_row62_col0, #T_b674c_row63_col0, #T_b674c_row64_col0, #T_b674c_row65_col0, #T_b674c_row66_col0, #T_b674c_row67_col0, #T_b674c_row68_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_b674c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b674c_level0_col0" class="col_heading level0 col0" >CIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b674c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b674c_row0_col0" class="data row0 col0" >data_hrpt</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b674c_row1_col0" class="data row1 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b674c_row2_col0" class="data row2 col0" >_expt_type.sample_form       powder</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b674c_row3_col0" class="data row3 col0" >_expt_type.beam_mode "constant wavelength"</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_b674c_row4_col0" class="data row4 col0" >_expt_type.radiation_probe      neutron</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_b674c_row5_col0" class="data row5 col0" >_expt_type.scattering_type        bragg</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b674c_row6_col0" class="data row6 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_b674c_row7_col0" class="data row7 col0" >_diffrn.ambient_temperature            ?</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_b674c_row8_col0" class="data row8 col0" >_diffrn.ambient_pressure            ?</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_b674c_row9_col0" class="data row9 col0" >_diffrn.ambient_magnetic_field            ?</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_b674c_row10_col0" class="data row10 col0" >_diffrn.ambient_electric_field            ?</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_b674c_row11_col0" class="data row11 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_b674c_row12_col0" class="data row12 col0" >_peak.broad_gauss_u   0.10000000</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_b674c_row13_col0" class="data row13 col0" >_peak.broad_gauss_v  -0.10000000</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_b674c_row14_col0" class="data row14 col0" >_peak.broad_gauss_w   0.10000000</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_b674c_row15_col0" class="data row15 col0" >_peak.broad_lorentz_x   0.00000000</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_b674c_row16_col0" class="data row16 col0" >_peak.broad_lorentz_y   0.10000000</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_b674c_row17_col0" class="data row17 col0" >_peak.profile_type pseudo-voigt</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_b674c_row18_col0" class="data row18 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_b674c_row19_col0" class="data row19 col0" >_instr.wavelength   1.49400000</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row20" class="row_heading level0 row20" >21</th>
#       <td id="T_b674c_row20_col0" class="data row20 col0" >_instr.2theta_offset   0.60000000</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row21" class="row_heading level0 row21" >22</th>
#       <td id="T_b674c_row21_col0" class="data row21 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_b674c_row22_col0" class="data row22 col0" >loop_</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row23" class="row_heading level0 row23" >24</th>
#       <td id="T_b674c_row23_col0" class="data row23 col0" >_pd_phase_block.id</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row24" class="row_heading level0 row24" >25</th>
#       <td id="T_b674c_row24_col0" class="data row24 col0" >_pd_phase_block.scale</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row25" class="row_heading level0 row25" >26</th>
#       <td id="T_b674c_row25_col0" class="data row25 col0" >        lbco  10.00000000</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row26" class="row_heading level0 row26" >27</th>
#       <td id="T_b674c_row26_col0" class="data row26 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row27" class="row_heading level0 row27" >28</th>
#       <td id="T_b674c_row27_col0" class="data row27 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row28" class="row_heading level0 row28" >29</th>
#       <td id="T_b674c_row28_col0" class="data row28 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row29" class="row_heading level0 row29" >30</th>
#       <td id="T_b674c_row29_col0" class="data row29 col0" >loop_</td>
#     </tr>
#     <tr>
#       <th id="T_b674c_level0_row30" class="row_heading level0 row30" >31</th>
#       <td id="T_b674c_row30_col0" class="data row30 col0" >_pd_proc.2theta_scan</td>
#     </tr>
#     <tr>

# %% [markdown]
# #### Save Project State

# %%
project.save()
# Out:
# Saving project 📦 'lbco_hrpt' to
# /tmp/lbco_hrpt
# ├── 📄 project.cif
# ├── 📁 structures/
# │   └── 📄 lbco.cif
# ├── 📁 experiments/
# │   └── 📄 hrpt.cif
# ├── 📁 analysis/
# │   └── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# ## Step 4: Perform Analysis
#
# This section explains the analysis process, including how to set up
# calculation and fitting engines.
#
# #### Set Calculator
#
# Show supported calculation engines for this experiment.

# %%
project.experiments['hrpt'].show_supported_calculator_types()
# Out:
# Supported calculator types
# <style type="text/css">
# #T_c313f   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_c313f thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_c313f th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_c313f  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_c313f th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_c313f tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_c313f  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_c313f th.col0 {
#   text-align: left;
# }
# #T_c313f th.col1 {
#   text-align: left;
# }
# #T_c313f_row0_col0, #T_c313f_row0_col1, #T_c313f_row1_col0, #T_c313f_row1_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_c313f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c313f_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_c313f_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c313f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c313f_row0_col0" class="data row0 col0" >crysfml</td>
#       <td id="T_c313f_row0_col1" class="data row0 col1" >CrysFML library for crystallographic calculations</td>
#     </tr>
#     <tr>
#       <th id="T_c313f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c313f_row1_col0" class="data row1 col0" >cryspy</td>
#       <td id="T_c313f_row1_col1" class="data row1 col1" >CrysPy library for crystallographic calculations</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Show current calculation engine for this experiment.

# %%
project.experiments['hrpt'].show_current_calculator_type()
# Out:
# Current calculator type
# cryspy

# %% [markdown]
# Select the desired calculation engine.

# %%
project.experiments['hrpt'].calculator_type = 'cryspy'
# Out:
# Calculator for experiment 'hrpt' changed to
# cryspy

# %% [markdown]
# #### Show Calculated Data

# %%
project.plotter.plot_calc(expt_name='hrpt')
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="115b5e91-3c67-45b1-958c-bb5b676594d8" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("115b5e91-3c67-45b1-958c-bb5b676594d8")) {                    Plotly.newPlot(                        "115b5e91-3c67-45b1-958c-bb5b676594d8",                        [{"line":{"color":"rgb(214, 39, 40)"},"mode":"lines","name":"Total calculated (Icalc)","x":{"dtype":"f8","bdata":"...\...\...\...\...\...\u002fQJqZmZmZGT9AZmZmZmYmP0AzMzMzMzM\u002fQAAAAAAAQD9AzczMzMxMP0CamZmZmVk\u002fQGZmZmZmZj9AMzMzMzNzP0AAAAAAAIA\u002fQM3MzMzMjD9AmpmZmZmZP0BmZmZmZqY\u002fQDMzMzMzsz9AAAAAAADAP0DNzMzMzMw\u002fQJqZmZmZ2T9AZmZmZmbmP0AzMzMzM\u002fM\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\...\u002
row0_col3" class="data row0 col3" >length_a</td>
#       <td id="T_25837_row0_col4" class="data row0 col4" >3.88000</td>
#       <td id="T_25837_row0_col5" class="data row0 col5" ></td>
#       <td id="T_25837_row0_col6" class="data row0 col6" >Å</td>
#       <td id="T_25837_row0_col7" class="data row0 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_25837_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_25837_row1_col0" class="data row1 col0" >lbco</td>
#       <td id="T_25837_row1_col1" class="data row1 col1" >cell</td>
#       <td id="T_25837_row1_col2" class="data row1 col2" ></td>
#       <td id="T_25837_row1_col3" class="data row1 col3" >length_b</td>
#       <td id="T_25837_row1_col4" class="data row1 col4" >3.88000</td>
#       <td id="T_25837_row1_col5" class="data row1 col5" ></td>
#       <td id="T_25837_row1_col6" class="data row1 col6" >Å</td>
#       <td id="T_25837_row1_col7" class="data row1 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_25837_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_25837_row2_col0" class="data row2 col0" >lbco</td>
#       <td id="T_25837_row2_col1" class="data row2 col1" >cell</td>
#       <td id="T_25837_row2_col2" class="data row2 col2" ></td>
#       <td id="T_25837_row2_col3" class="data row2 col3" >length_c</td>
#       <td id="T_25837_row2_col4" class="data row2 col4" >3.88000</td>
#       <td id="T_25837_row2_col5" class="data row2 col5" ></td>
#       <td id="T_25837_row2_col6" class="data row2 col6" >Å</td>
#       <td id="T_25837_row2_col7" class="data row2 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_25837_level0_row3" class
# Fittable parameters for all experiments (🔬 data blocks)
# <style type="text/css">
# #T_b8727   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_b8727 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_b8727 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_b8727  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_b8727 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_b8727 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_b8727  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_b8727 th.col0 {
#   text-align: left;
# }
# #T_b8727 th.col1 {
#   text-align: left;
# }
# #T_b8727 th.col2 {
#   text-align: left;
# }
# #T_b8727 th.col3 {
#   text-align: left;
# }
# #T_b8727 th.col4 {
#   text-align: right;
# }
# #T_b8727 th.col5 {
#   text-align: right;
# }
# #T_b8727 th.col6 {
#   text-align: left;
# }
# #T_b8727 th.col7 {
#   text-align: left;
# }
# #T_b8727_row0_col0, #T_b8727_row0_col1, #T_b8727_row0_col2, #T_b8727_row0_col3, #T_b8727_row0_col6, #T_b8727_row0_col7, #T_b8727_row1_col0, #T_b8727_row1_col1, #T_b8727_row1_col2, #T_b8727_row1_col3, #T_b8727_row1_col6, #T_b8727_row1_col7, #T_b8727_row2_col0, #T_b8727_row2_col1, #T_b8727_row2_col2, #T_b8727_row2_col3, #T_b8727_row2_col6, #T_b8727_row2_col7, #T_b8727_row3_col0, #T_b8727_row3_col1, #T_b8727_row3_col2, #T_b8727_row3_col3, #T_b8727_row3_col6, #T_b8727_row3_col7, #T_b8727_row4_col0, #T_b8727_row4_col1, #T_b8727_row4_col2, #T_b8727_row4_col3, #T_b8727_row4_col6, #T_b8727_row4_col7, #T_b8727_row5_col0, #T_b8727_row5_col1, #T_b8727_row5_col2, #T_b8727_row5_col3, #T_b8727_row5_col6, #T_b8727_row5_col7, #T_b8727_row6_col0, #T_b8727_row6_col1, #T_b8727_row6_col2, #T_b8727_row6_col3, #T_b8727_row6_col6, #T_b8727_row6_col7, #T_b8727_row7_col0, #T_b8727_row7_col1, #T_b8727_row7_col2, #T_b8727_row7_col3, #T_b8727_row7_col6, #T_b8727_row7_col7, #T_b8727_row8_col0, #T_b8727_row8_col1, #T_b8727_row8_col2, #T_b8727_row8_col3, #T_b8727_row8_col6, #T_b8727_row8_col7, #T_b8727_row9_col0, #T_b8727_row9_col1, #T_b8727_row9_col2, #T_b8727_row9_col3, #T_b8727_row9_col6, #T_b8727_row9_col7, #T_b8727_row10_col0, #T_b8727_row10_col1, #T_b8727_row10_col2, #T_b8727_row10_col3, #T_b8727_row10_col6, #T_b8727_row10_col7, #T_b8727_row11_col0, #T_b8727_row11_col1, #T_b8727_row11_col2, #T_b8727_row11_col3, #T_b8727_row11_col6, #T_b8727_row11_col7, #T_b8727_row12_col0, #T_b8727_row12_col1, #T_b8727_row12_col2, #T_b8727_row12_col3, #T_b8727_row12_col6, #T_b8727_row12_col7 {
#   text-align: left;
# }
# #T_b8727_row0_col4, #T_b8727_row0_col5, #T_b8727_row1_col4, #T_b8727_row1_col5, #T_b8727_row2_col4, #T_b8727_row2_col5, #T_b8727_row3_col4, #T_b8727_row3_col5, #T_b8727_row4_col4, #T_b8727_row4_col5, #T_b8727_row5_col4, #T_b8727_row5_col5, #T_b8727_row6_col4, #T_b8727_row6_col5, #T_b8727_row7_col4, #T_b8727_row7_col5, #T_b8727_row8_col4, #T_b8727_row8_col5, #T_b8727_row9_col4, #T_b8727_row9_col5, #T_b8727_row10_col4, #T_b8727_row10_col5, #T_b8727_row11_col4, #T_b8727_row11_col5, #T_b8727_row12_col4, #T_b8727_row12_col5 {
#   text-align: right;
# }
# </style>
# <table id="T_b8727" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8727_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_b8727_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_b8727_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_b8727_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_b8727_level0_col4" class="col_heading level0 col4" >value</th>
#       <th id="T_b8727_level0_col5" class="col_heading level0 col5" >uncertainty</th>
#       <th id="T_b8727_level0_col6" class="col_heading level0 col6" >units</th>
#       <th id="T_b8727_level0_col7" class="col_heading level0 col7" >free</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8727_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b8727_row0_col0" class="data row0 col0" >hrpt</td>
#       <td id="T_b8727_row0_col1" class="data row0 col1" >linked_phases</td>
#       <td id="T_b8727_row0_col2" class="data row0 col2" >lbco</td>
#       <td id="T_b8727_row0_col3" class="data row0 col3" >scale</td>
#       <td id="T_b8727_row0_col4" class="data row0 col4" >10.00000</td>
#       <td id="T_b8727_row0_col5" class="data row0 col5" ></td>
#       <td id="T_b8727_row0_col6" class="data row0 col6" ></td>
#       <td id="T_b8727_row0_col7" class="data row0 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b8727_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b8727_row1_col0" class="data row1 col0" >hrpt</td>
#       <td id="T_b8727_row1_col1" class="data row1 col1" >peak</td>
#       <td id="T_b8727_row1_col2" class="data row1 col2" ></td>
#       <td id="T_b8727_row1_col3" class="data row1 col3" >broad_gauss_u</td>
#       <td id="T_b8727_row1_col4" class="data row1 col4" >0.10000</td>
#       <td id="T_b8727_row1_col5" class="data row1 col5" ></td>
#       <td id="T_b8727_row1_col6" class="data row1 col6" >deg²</td>
#       <td id="T_b8727_row1_col7" class="data row1 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b8727_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b8727_row2_col0" class="data row2 col0" >hrpt</td>
#       <td id="T_b8727_row2_col1" class="data row2 col1" >peak</td>
#       <td id="T_b8727_row2_col2" class="data row2 col2" ></td>
#       <td id="T_b8727_row2_col3" class="data row2 col3" >broad_gauss_v</td>
#       <td id="T_b8727_row2_col4" class="data row2 col4" >-0.10000</td>
#       <td id="T_b8727_row2_col5" class="data row2 col5" ></td>
#       <td id="T_b8727_row2_col6" class="data row2 col6" >deg²</td>
#       <td id="T_b8727_row2_col7" class="data row2 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b8727_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b8727_row3_col0" class="data row3 col0" >hrpt</td>
#       <td id="T_b8727_row3_col1" class="data row3 col1" >peak</td>
#       <td id="T_b8727_row3_col2" class="data row3 col2" ></td>
#       <td id="T_b8727_row3_col3" class="data row3 col3" >broad_gauss_w</td>
#       <td id="T_b8727_row3_col4" class="data row3 col4" >0.10000</td>
#       <td id="T_b8727_row3_col5" class="data row3 col5" ></td>
#       <td id="T_b8727_row3_col6" class="data row3 col6" >deg²</td>
#       <td id="T_b8727_row3_col7" class="data row3 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b8727_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_b8727_row4_col0" class="data row4 col0" >hrpt</td>
#       <td id="T_b8727_row4_col1" class="data row4 col1" >peak</td>
#       <td id="T_b8727_row4_col2" class="data row4 col2" ></td>
#       <td id="T_b8727_row4_col3" class="data row4 col3" >broad_lorentz_x</td>
#       <td id="T_b8727_row4_col4" class="data row4 col4" >0.00000</td>
#       <td id="T_b8727_row4_col5" class="data row4 col5" ></td>
#       <td id="T_b8727_row4_col6" class="data row4 col6" >deg</td>
#       <td id="T_b8727_row4_col7" class="data row4 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b8727_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_b8727_row5_col0" class="data row5 col0" >hrpt</td>
#       <td id="T_b8727_row5_col1" class="data row5 col1" >peak</td>
#       <td id="T_b8727_row5_col2" class="data row5 col2" ></td>
#       <td id="T_b8727_row5_col3" class="data row5 col3" >broad_lorentz_y</td>
#       <td id="T_b8727_row5_col4" class="data row5 col4" >0.10000</td>
#       <td id="T_b8727_row5_col5" class="data row5 col5" ></td>
#       <td id="T_b8727_row5_col6" class="data row5 col6" >deg</td>
#       <td id="T_b8727_row5_col7" class="data row5 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b8727_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b8727_row6_col0" class="data row6 col0" >hrpt</td>
#       <td id="T_b8727_row6_col1" class="data row6 col1" >instrument</td>
#       <td id="T_b8727_row6_col2" class="data row6 col2" ></td>
#       <td id

# %% [markdown]
# Show only free parameters.

# %%
project.analysis.display.free_params()
# Out:
# ⚠️ No free parameters found.

# %% [markdown]
# Show how to access parameters in the code.

# %%
# project.analysis.display.how_to_access_parameters()

# %% [markdown]
# #### Set Fit Mode
#
# Show supported fit modes.

# %%
project.analysis.show_supported_fit_mode_types()
# Out:
# ❌ 'Analysis' object has no attribute 'show_supported_fit_mode_types'

# %% [markdown]
# Show current fit mode.

# %%
project.analysis.show_current_fit_mode_type()

# %% [markdown]
# Select desired fit mode.

# %%
project.analysis.fit_mode.mode = 'single'

# %% [markdown]
# #### Set Minimizer
#
# Show supported fitting engines.

# %%
project.analysis.show_available_minimizers()

# %% [markdown]
# Show current fitting engine.

# %%
project.analysis.show_current_minimizer()

# %% [markdown]
# Select desired fitting engine.

# %%
project.analysis.current_minimizer = 'lmfit'

# %% [markdown]
# ### Perform Fit 1/5
#
# Set structure parameters to be refined.

# %%
project.structures['lbco'].cell.length_a.free = True

# %% [markdown]
# Set experiment parameters to be refined.

# %%
project.experiments['hrpt'].linked_phases['lbco'].scale.free = True
project.experiments['hrpt'].instrument.calib_twotheta_offset.free = True
project.experiments['hrpt'].background['10'].y.free = True
project.experiments['hrpt'].background['30'].y.free = True
project.experiments['hrpt'].background['50'].y.free = True
project.experiments['hrpt'].background['110'].y.free = True
project.experiments['hrpt'].background['165'].y.free = True

# %% [markdown]
# Show free parameters after selection.

# %%
project.analysis.display.free_params()

# %% [markdown]
# #### Run Fitting

# %%
project.analysis.fit()
project.analysis.display.fit_results()

# %% [markdown]
# #### Plot Measured vs Calculated

# %%
project.plotter.plot_meas_vs_calc(expt_name='hrpt', show_residual=True)

# %%
project.plotter.plot_meas_vs_calc(expt_name='hrpt', x_min=38, x_max=41, show_residual=True)

# %% [markdown]
# #### Save Project State

# %%
project.save_as(dir_path='lbco_hrpt', temporary=True)

# %% [markdown]
# ### Perform Fit 2/5
#
# Set more parameters to be refined.

# %%
project.experiments['hrpt'].peak.broad_gauss_u.free = True
project.experiments['hrpt'].peak.broad_gauss_v.free = True
project.experiments['hrpt'].peak.broad_gauss_w.free = True
project.experiments['hrpt'].peak.broad_lorentz_y.free = True

# %% [markdown]
# Show free parameters after selection.

# %%
project.analysis.display.free_params()

# %% [markdown]
# #### Run Fitting

# %%
project.analysis.fit()
project.analysis.display.fit_results()

# %% [markdown]
# #### Plot Measured vs Calculated

# %%
project.plotter.plot_meas_vs_calc(expt_name='hrpt', show_residual=True)

# %%
project.plotter.plot_meas_vs_calc(expt_name='hrpt', x_min=38, x_max=41, show_residual=True)

# %% [markdown]
# #### Save Project State

# %%
project.save_as(dir_path='lbco_hrpt', temporary=True)

# %% [markdown]
# ### Perform Fit 3/5
#
# Set more parameters to be refined.

# %%
project.structures['lbco'].atom_sites['La'].b_iso.free = True
project.structures['lbco'].atom_sites['Ba'].b_iso.free = True
project.structures['lbco'].atom_sites['Co'].b_iso.free = True
project.structures['lbco'].atom_sites['O'].b_iso.free = True

# %% [markdown]
# Show free parameters after selection.

# %%
project.analysis.display.free_params()

# %% [markdown]
# #### Run Fitting

# %%
project.analysis.fit()
project.analysis.display.fit_results()

# %% [markdown]
# #### Plot Measured vs Calculated

# %%
project.plotter.plot_meas_vs_calc(expt_name='hrpt', show_residual=True)

# %%
project.plotter.plot_meas_vs_calc(expt_name='hrpt', x_min=38, x_max=41, show_residual=True)

# %% [markdown]
# #### Save Project State

# %%
project.save_as(dir_path='lbco_hrpt', temporary=True)

# %% [markdown]
# ### Perform Fit 4/5
#
# #### Set Constraints
#
# Set aliases for parameters.

# %%
project.analysis.aliases.create(
    label='biso_La',
    param=project.structures['lbco'].atom_sites['La'].b_iso,
)
project.analysis.aliases.create(
    label='biso_Ba',
    param=project.structures['lbco'].atom_sites['Ba'].b_iso,
)

# %% [markdown]
# Set constraints.

# %%
project.analysis.constraints.create(expression='biso_Ba = biso_La')

# %% [markdown]
# Show defined constraints.

# %%
project.analysis.display.constraints()

# %% [markdown]
# Show free parameters.

# %%
project.analysis.display.free_params()

# %% [markdown]
# #### Run Fitting

# %%
project.analysis.fit()
project.analysis.display.fit_results()

# %% [markdown]
# #### Plot Measured vs Calculated

# %%
project.plotter.plot_meas_vs_calc(expt_name='hrpt', show_residual=True)

# %%
project.plotter.plot_meas_vs_calc(expt_name='hrpt', x_min=38, x_max=41, show_residual=True)

# %% [markdown]
# #### Save Project State

# %%
project.save_as(dir_path='lbco_hrpt', temporary=True)

# %% [markdown]
# ### Perform Fit 5/5
#
# #### Set Constraints
#
# Set more aliases for parameters.

# %%
project.analysis.aliases.create(
    label='occ_La',
    param=project.structures['lbco'].atom_sites['La'].occupancy,
)
project.analysis.aliases.create(
    label='occ_Ba',
    param=project.structures['lbco'].atom_sites['Ba'].occupancy,
)

# %% [markdown]
# Set more constraints.

# %%
project.analysis.constraints.create(
    expression='occ_Ba = 1 - occ_La',
)

# %% [markdown]
# Show defined constraints.

# %%
project.analysis.display.constraints()

# %% [markdown]
# Set structure parameters to be refined.

# %%
project.structures['lbco'].atom_sites['La'].occupancy.free = True

# %% [markdown]
# Show free parameters after selection.

# %%
project.analysis.display.free_params()

# %% [markdown]
# #### Run Fitting

# %%
project.analysis.fit()
project.analysis.display.fit_results()

# %% [markdown]
# #### Plot Measured vs Calculated

# %%
project.plotter.plot_meas_vs_calc(expt_name='hrpt', show_residual=True)

# %%
project.plotter.plot_meas_vs_calc(expt_name='hrpt', x_min=38, x_max=41, show_residual=True)

# %% [markdown]
# #### Save Project State

# %%
project.save_as(dir_path='lbco_hrpt', temporary=True)

# %% [markdown]
# ## Step 5: Summary
#
# This final section shows how to review the results of the analysis.

# %% [markdown]
# #### Show Project Summary

# %%
project.summary.show_report()
