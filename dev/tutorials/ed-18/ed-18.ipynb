# %%
# Check whether easydiffraction is installed; install it if needed.
# Required for remote environments such as Google Colab.
import importlib.util

if importlib.util.find_spec('easydiffraction') is None:
    # %pip install easydiffraction

# %% [markdown]
# # Load Project and Fit: LBCO, HRPT
#
# This is the most minimal example of using EasyDiffraction. It shows
# how to load a previously saved project from a directory and run
# refinement — all in just a few lines of code.
#
# For this example, constant-wavelength neutron powder diffraction data
# for La0.5Ba0.5CoO3 from HRPT at PSI is used.
#
# It does not contain any advanced features or options, and includes no
# comments or explanations — these can be found in the other tutorials.

# %% [markdown]
# ## Import Modules

# %%
from easydiffraction import Project
from easydiffraction import download_data

# %% [markdown]
# ## Download Saved Project

# %%
project_dir = download_data(id=36, destination='projects')
# Out:
# Getting data...
# Data #36: La0.5Ba0.5CoO3, HRPT (PSI), 300 K - Updated #30
# ✅ Data #36 downloaded and extracted to '/home/runner/work/diffraction-lib/diffraction-lib/tmp/tutorials/projects/ed-36/lbco_hrpt'

# %% [markdown]
# ## Load Project

# %%
project = Project.load(project_dir)

# %% [markdown]
# ## Perform Analysis

# %%
project.analysis.fit()
# Out:
# Standard fitting
# 📋 Using experiment 🔬 'hrpt' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit progress:
# <style>.ed-activity-stack {display: flex;flex-direction: column;align-items: flex-start;gap: 0.35rem;margin-top: 0.5rem;}.ed-activity {display: inline-flex;align-items: center;gap: 0.45rem;color: #d97706;font-size: 0.95rem;font-weight: 400;line-height: 1.1;}.ed-activity-label {font-family: var(--jp-ui-font-family, -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif);}.ed-activity-pre {margin: 0;font-family: ui-monospace, SFMono-Regular, Menlo, monospace;white-space: pre-wrap;}.ed-activity-spinner {font-family: ui-monospace, SFMono-Regular, Menlo, monospace;}.ed-activity-spinner::before {animation: ed-activity-frames 1.0s steps(1) infinite;content: "⠋";display: inline-block;width: 1ch;}@keyframes ed-activity-frames { 0% { content: "⠋"; } 10% { content: "⠙"; } 20% { content: "⠹"; } 30% { content: "⠸"; } 40% { content: "⠼"; } 50% { content: "⠴"; } 60% { content: "⠦"; } 70% { content: "⠧"; } 80% { content: "⠇"; } 90% { content: "⠏"; } 100% { content: "⠋"; } }</style><div class="ed-activity-stack"><style type="text/css">
# #T_3f967   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_3f967 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_3f967 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_3f967  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_3f967 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_3f967 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_3f967  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_3f967 th.col0 {
#   text-align: center;
# }
# #T_3f967 th.col1 {
#   text-align: center;
# }
# #T_3f967 th.col2 {
#   text-align: center;
# }
# #T_3f967 th.col3 {
#   text-align: center;
# }
# #T_3f967_row0_col0, #T_3f967_row0_col1, #T_3f967_row0_col2, #T_3f967_row0_col3, #T_3f967_row1_col0, #T_3f967_row1_col1, #T_3f967_row1_col2, #T_3f967_row1_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_3f967" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f967_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_3f967_level0_col1" class="col_heading level0 col1" >time (s)</th>
#       <th id="T_3f967_level0_col2" class="col_heading level0 col2" >χ²</th>
#       <th id="T_3f967_level0_col3" class="col_heading level0 col3" >change / status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f967_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_3f967_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_3f967_row0_col1" class="data row0 col1" >0.05</td>
#       <td id="T_3f967_row0_col2" class="data row0 col2" >1.29</td>
#       <td id="T_3f967_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_3f967_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_3f967_row1_col0" class="data row1 col0" >27</td>
#       <td id="T_3f967_row1_col1" class="data row1 col1" >1.58</td>
#       <td id="T_3f967_row1_col2" class="data row1 col2" >1.29</td>
#       <td id="T_3f967_row1_col3" class="data row1 col3" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>
# 🏆 Best goodness-of-fit (reduced χ²) is 1.29 at iteration 11
# ✅ Fitting complete.
# Saving project 📦 'lbco_hrpt' to
# /home/runner/work/diffraction-lib/diffraction-lib/tmp/tutorials/projects/ed-36/lbco_hrpt
# ├── 📄 project.cif
# ├── 📁 structures/
# │   └── 📄 lbco.cif
# ├── 📁 experiments/
# │   └── 📄 hrpt.cif
# ├── 📁 analysis/
# │   └── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# ## Show Results

# %%
project.display.fit.results()
# Out:
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 1.58 seconds
# 📏 Goodness-of-fit (reduced χ²): 1.29
# 📏 R-factor (Rf): 5.62%
# 📏 R-factor squared (Rf²): 5.26%
# 📏 Weighted R-factor (wR): 4.42%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_0cfaa   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_0cfaa thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_0cfaa th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_0cfaa  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_0cfaa th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_0cfaa tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_0cfaa  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_0cfaa th.col0 {
#   text-align: left;
# }
# #T_0cfaa th.col1 {
#   text-align: left;
# }
# #T_0cfaa th.col2 {
#   text-align: left;
# }
# #T_0cfaa th.col3 {
#   text-align: left;
# }
# #T_0cfaa th.col4 {
#   text-align: left;
# }
# #T_0cfaa th.col5 {
#   text-align: right;
# }
# #T_0cfaa th.col6 {
#   text-align: right;
# }
# #T_0cfaa th.col7 {
#   text-align: right;
# }
# #T_0cfaa th.col8 {
#   text-align: right;
# }
# #T_0cfaa_row0_col0, #T_0cfaa_row0_col1, #T_0cfaa_row0_col2, #T_0cfaa_row0_col3, #T_0cfaa_row0_col4, #T_0cfaa_row1_col0, #T_0cfaa_row1_col1, #T_0cfaa_row1_col2, #T_0cfaa_row1_col3, #T_0cfaa_row1_col4, #T_0cfaa_row2_col0, #T_0cfaa_row2_col1, #T_0cfaa_row2_col2, #T_0cfaa_row2_col3, #T_0cfaa_row2_col4, #T_0cfaa_row3_col0, #T_0cfaa_row3_col1, #T_0cfaa_row3_col2, #T_0cfaa_row3_col3, #T_0cfaa_row3_col4, #T_0cfaa_row4_col0, #T_0cfaa_row4_col1, #T_0cfaa_row4_col2, #T_0cfaa_row4_col3, #T_0cfaa_row4_col4, #T_0cfaa_row5_col0, #T_0cfaa_row5_col1, #T_0cfaa_row5_col2, #T_0cfaa_row5_col3, #T_0cfaa_row5_col4, #T_0cfaa_row6_col0, #T_0cfaa_row6_col1, #T_0cfaa_row6_col2, #T_0cfaa_row6_col3, #T_0cfaa_row6_col4, #T_0cfaa_row7_col0, #T_0cfaa_row7_col1, #T_0cfaa_row7_col2, #T_0cfaa_row7_col3, #T_0cfaa_row7_col4, #T_0cfaa_row8_col0, #T_0cfaa_row8_col1, #T_0cfaa_row8_col2, #T_0cfaa_row8_col3, #T_0cfaa_row8_col4, #T_0cfaa_row9_col0, #T_0cfaa_row9_col1, #T_0cfaa_row9_col2, #T_0cfaa_row9_col3, #T_0cfaa_row9_col4, #T_0cfaa_row10_col0, #T_0cfaa_row10_col1, #T_0cfaa_row10_col2, #T_0cfaa_row10_col3, #T_0cfaa_row10_col4, #T_0cfaa_row11_col0, #T_0cfaa_row11_col1, #T_0cfaa_row11_col2, #T_0cfaa_row11_col3, #T_0cfaa_row11_col4, #T_0cfaa_row12_col0, #T_0cfaa_row12_col1, #T_0cfaa_row12_col2, #T_0cfaa_row12_col3, #T_0cfaa_row12_col4, #T_0cfaa_row13_col0, #T_0cfaa_row13_col1, #T_0cfaa_row13_col2, #T_0cfaa_row13_col3, #T_0cfaa_row13_col4, #T_0cfaa_row14_col0, #T_0cfaa_row14_col1, #T_0cfaa_row14_col2, #T_0cfaa_row14_col3, #T_0cfaa_row14_col4 {
#   text-align: left;
# }
# #T_0cfaa_row0_col5, #T_0cfaa_row0_col6, #T_0cfaa_row0_col7, #T_0cfaa_row0_col8, #T_0cfaa_row1_col5, #T_0cfaa_row1_col6, #T_0cfaa_row1_col7, #T_0cfaa_row1_col8, #T_0cfaa_row2_col5, #T_0cfaa_row2_col6, #T_0cfaa_row2_col7, #T_0cfaa_row2_col8, #T_0cfaa_row3_col5, #T_0cfaa_row3_col6, #T_0cfaa_row3_col7, #T_0cfaa_row3_col8, #T_0cfaa_row4_col5, #T_0cfaa_row4_col6, #T_0cfaa_row4_col7, #T_0cfaa_row4_col8, #T_0cfaa_row5_col5, #T_0cfaa_row5_col6, #T_0cfaa_row5_col7, #T_0cfaa_row5_col8, #T_0cfaa_row6_col5, #T_0cfaa_row6_col6, #T_0cfaa_row6_col7, #T_0cfaa_row6_col8, #T_0cfaa_row7_col5, #T_0cfaa_row7_col6, #T_0cfaa_row7_col7, #T_0cfaa_row7_col8, #T_0cfaa_row8_col5, #T_0cfaa_row8_col6, #T_0cfaa_row8_col7, #T_0cfaa_row8_col8, #T_0cfaa_row9_col5, #T_0cfaa_row9_col6, #T_0cfaa_row9_col7, #T_0cfaa_row9_col8, #T_0cfaa_row10_col5, #T_0cfaa_row10_col6, #T_0cfaa_row10_col7, #T_0cfaa_row10_col8, #T_0cfaa_row11_col5, #T_0cfaa_row11_col6, #T_0cfaa_row11_col7, #T_0cfaa_row11_col8, #T_0cfaa_row12_col5, #T_0cfaa_row12_col6, #T_0cfaa_row12_col7, #T_0cfaa_row12_col8, #T_0cfaa_row13_col5, #T_0cfaa_row13_col6, #T_0cfaa_row13_col7, #T_0cfaa_row13_col8, #T_0cfaa_row14_col5, #T_0cfaa_row14_col6, #T_0cfaa_row14_col7, #T_0cfaa_row14_col8 {
#   text-align: right;
# }
# </style>
# <table id="T_0cfaa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cfaa_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_0cfaa_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_0cfaa_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_0cfaa_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_0cfaa_level0_col4" class="col_heading level0 col4" >units</th>
#       <th id="T_0cfaa_level0_col5" class="col_heading level0 col5" >start</th>
#       <th id="T_0cfaa_level0_col6" class="col_heading level0 col6" >fitted</th>
#       <th id="T_0cfaa_level0_col7" class="col_heading level0 col7" >uncertainty</th>
#       <th id="T_0cfaa_level0_col8" class="col_heading level0 col8" >change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cfaa_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_0cfaa_row0_col0" class="data row0 col0" >lbco</td>
#       <td id="T_0cfaa_row0_col1" class="data row0 col1" >cell</td>
#       <td id="T_0cfaa_row0_col2" class="data row0 col2" ></td>
#       <td id="T_0cfaa_row0_col3" class="data row0 col3" >length_a</td>
#       <td id="T