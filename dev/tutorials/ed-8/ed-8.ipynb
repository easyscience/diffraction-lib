# %%
# Check whether easydiffraction is installed; install it if needed.
# Required for remote environments such as Google Colab.
import importlib.util

if importlib.util.find_spec('easydiffraction') is None:
    # %pip install easydiffraction

# %% [markdown]
# # Structure Refinement: NCAF, WISH
#
# This example demonstrates a Rietveld refinement of Na2Ca3Al2F14
# crystal structure using time-of-flight neutron powder diffraction data
# from WISH at ISIS.
#
# Two datasets from detector banks 5+6 and 4+7 are used for joint
# fitting.

# %% [markdown]
# ## Import Library

# %%
from easydiffraction import ExperimentFactory
from easydiffraction import Project
from easydiffraction import StructureFactory
from easydiffraction import download_data

# %% [markdown]
# ## Define Structure
#
# This section covers how to add structures and modify their
# parameters.
#
# #### Create Structure

# %%
structure = StructureFactory.from_scratch(name='ncaf')

# %% [markdown]
# #### Set Space Group

# %%
structure.space_group.name_h_m = 'I 21 3'
structure.space_group.it_coordinate_system_code = '1'

# %% [markdown]
# #### Set Unit Cell

# %%
structure.cell.length_a = 10.250256

# %% [markdown]
# #### Set Atom Sites

# %%
structure.atom_sites.create(
    label='Ca',
    type_symbol='Ca',
    fract_x=0.4663,
    fract_y=0.0,
    fract_z=0.25,
    wyckoff_letter='b',
    adp_iso=0.92,
)
structure.atom_sites.create(
    label='Al',
    type_symbol='Al',
    fract_x=0.2521,
    fract_y=0.2521,
    fract_z=0.2521,
    wyckoff_letter='a',
    adp_iso=0.73,
)
structure.atom_sites.create(
    label='Na',
    type_symbol='Na',
    fract_x=0.0851,
    fract_y=0.0851,
    fract_z=0.0851,
    wyckoff_letter='a',
    adp_iso=2.08,
)
structure.atom_sites.create(
    label='F1',
    type_symbol='F',
    fract_x=0.1377,
    fract_y=0.3054,
    fract_z=0.1195,
    wyckoff_letter='c',
    adp_iso=0.90,
)
structure.atom_sites.create(
    label='F2',
    type_symbol='F',
    fract_x=0.3625,
    fract_y=0.3633,
    fract_z=0.1867,
    wyckoff_letter='c',
    adp_iso=1.37,
)
structure.atom_sites.create(
    label='F3',
    type_symbol='F',
    fract_x=0.4612,
    fract_y=0.4612,
    fract_z=0.4612,
    wyckoff_letter='a',
    adp_iso=0.88,
)

# %% [markdown]
# ## Define Experiment
#
# This section shows how to add experiments, configure their parameters,
# and link the structures defined in the previous step.
#
# #### Download Measured Data

# %%
data_path56 = download_data(id=9, destination='data')
# Out:
# Getting data...
# Data #9: NCAF, WISH (ISIS), Detector banks 5 & 6
# ✅ Data #9 downloaded to 'data/ed-9.xys'

# %%
data_path47 = download_data(id=10, destination='data')
# Out:
# Getting data...
# Data #10: NCAF, WISH (ISIS), Detector banks 4 & 7
# ✅ Data #10 downloaded to 'data/ed-10.xys'

# %% [markdown]
# #### Create Experiment

# %%
expt56 = ExperimentFactory.from_data_path(
    name='wish_5_6',
    data_path=data_path56,
    beam_mode='time-of-flight',
)

# %%
expt47 = ExperimentFactory.from_data_path(
    name='wish_4_7',
    data_path=data_path47,
    beam_mode='time-of-flight',
)

# %% [markdown]
# #### Set Instrument

# %%
expt56.instrument.setup_twotheta_bank = 152.827
expt56.instrument.calib_d_to_tof_offset = -13.5
expt56.instrument.calib_d_to_tof_linear = 20773.0
expt56.instrument.calib_d_to_tof_quad = -1.08308

# %%
expt47.instrument.setup_twotheta_bank = 121.660
expt47.instrument.calib_d_to_tof_offset = -15.0
expt47.instrument.calib_d_to_tof_linear = 18660.0
expt47.instrument.calib_d_to_tof_quad = -0.47488

# %% [markdown]
# #### Set Peak Profile

# %%
expt56.show_peak_profile_types()
expt56.peak.broad_gauss_sigma_0 = 0.0
expt56.peak.broad_gauss_sigma_1 = 0.0
expt56.peak.broad_gauss_sigma_2 = 15.5
expt56.peak.exp_decay_beta_0 = 0.007
expt56.peak.exp_decay_beta_1 = 0.01
expt56.peak.exp_rise_alpha_0 = -0.0094
expt56.peak.exp_rise_alpha_1 = 0.1
# Out:
# Peak profile types
# <style type="text/css">
# #T_64ec6   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_64ec6 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_64ec6 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_64ec6  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_64ec6 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_64ec6 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_64ec6  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_64ec6 th.col0 {
#   text-align: left;
# }
# #T_64ec6 th.col1 {
#   text-align: left;
# }
# #T_64ec6 th.col2 {
#   text-align: left;
# }
# #T_64ec6_row0_col0, #T_64ec6_row0_col1, #T_64ec6_row0_col2, #T_64ec6_row1_col0, #T_64ec6_row1_col1, #T_64ec6_row1_col2, #T_64ec6_row2_col0, #T_64ec6_row2_col1, #T_64ec6_row2_col2, #T_64ec6_row3_col0, #T_64ec6_row3_col1, #T_64ec6_row3_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_64ec6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64ec6_level0_col0" class="col_heading level0 col0" ></th>
#       <th id="T_64ec6_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_64ec6_level0_col2" class="col_heading level0 col2" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64ec6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_64ec6_row0_col0" class="data row0 col0" ></td>
#       <td id="T_64ec6_row0_col1" class="data row0 col1" >pseudo-voigt</td>
#       <td id="T_64ec6_row0_col2" class="data row0 col2" >TOF non-convoluted pseudo-Voigt profile</td>
#     </tr>
#     <tr>
#       <th id="T_64ec6_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_64ec6_row1_col0" class="data row1 col0" >*</td>
#       <td id="T_64ec6_row1_col1" class="data row1 col1" >jorgensen</td>
#       <td id="T_64ec6_row1_col2" class="data row1 col2" >TOF Jorgensen profile: back-to-back exponentials ⊗ Gaussian</td>
#     </tr>
#     <tr>
#       <th id="T_64ec6_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_64ec6_row2_col0" class="data row2 col0" ></td>
#       <td id="T_64ec6_row2_col1" class="data row2 col1" >jorgensen-von-dreele</td>
#       <td id="T_64ec6_row2_col2" class="data row2 col2" >TOF Jorgensen-Von Dreele profile: back-to-back exponentials ⊗ pseudo-Voigt</td>
#     </tr>
#     <tr>
#       <th id="T_64ec6_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_64ec6_row3_col0" class="data row3 col0" ></td>
#       <td id="T_64ec6_row3_col1" class="data row3 col1" >double-jorgensen-von-dreele</td>
#       <td id="T_64ec6_row3_col2" class="data row3 col2" >TOF Double-Jorgensen-Von Dreele profile: double back-to-back exponentials ⊗ pseudo-Voigt (Z-Rietveld type0m)</td>
#     </tr>
#   </tbody>
# </table>

# %%
expt47.peak.broad_gauss_sigma_0 = 0.0
expt47.peak.broad_gauss_sigma_1 = 29.8
expt47.peak.broad_gauss_sigma_2 = 18.0
expt47.peak.exp_decay_beta_0 = 0.006
expt47.peak.exp_decay_beta_1 = 0.015
expt47.peak.exp_rise_alpha_0 = -0.0115
expt47.peak.exp_rise_alpha_1 = 0.1

# %% [markdown]
# #### Set Background

# %%
expt56.show_background_types()
expt56.background_type = 'line-segment'
for idx, (x, y) in enumerate(
    [
        (9162, 465),
        (11136, 593),
        (13313, 497),
        (14906, 546),
        (16454, 533),
        (17352, 496),
        (18743, 428),
        (20179, 452),
        (21368, 397),
        (22176, 468),
        (22827, 477),
        (24644, 380),
        (26439, 381),
        (28257, 378),
        (31196, 343),
        (34034, 328),
        (37265, 310),
        (41214, 323),
        (44827, 283),
        (49830, 273),
        (52905, 257),
        (58204, 260),
        (62916, 261),
        (70186, 262),
        (74204, 262),
        (82103, 268),
        (91958, 268),
        (102712, 262),
    ],
    start=1,
):
    expt56.background.create(id=str(idx), x=x, y=y)
# Out:
# Background types
# <style type="text/css">
# #T_eaa4d   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_eaa4d thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_eaa4d th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_eaa4d  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_eaa4d th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_eaa4d tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_eaa4d  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_eaa4d th.col0 {
#   text-align: left;
# }
# #T_eaa4d th.col1 {
#   text-align: left;
# }
# #T_eaa4d th.col2 {
#   text-align: left;
# }
# #T_eaa4d_row0_col0, #T_eaa4d_row0_col1, #T_eaa4d_row0_col2, #T_eaa4d_row1_col0, #T_eaa4d_row1_col1, #T_eaa4d_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_eaa4d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eaa4d_level0_col0" class="col_heading level0 col0" ></th>
#       <th id="T_eaa4d_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_eaa4d_level0_col2" class="col_heading level0 col2" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eaa4d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_eaa4d_row0_col0" class="data row0 col0" ></td>
#       <td id="T_eaa4d_row0_col1" class="data row0 col1" >chebyshev</td>
#       <td id="T_eaa4d_row0_col2" class="data row0 col2" >Chebyshev polynomial background</td>
#     </tr>
#     <tr>
#       <th id="T_eaa4d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_eaa4d_row1_col0" class="data row1 col0" >*</td>
#       <td id="T_eaa4d_row1_col1" class="data row1 col1" >line-segment</td>
#       <td id="T_eaa4d_row1_col2" class="data row1 col2" >Linear interpolation between points</td>
#     </tr>
#   </tbody>
# </table>
# Background type for experiment 'wish_5_6' already set to
# line-segment

# %%
expt47.background_type = 'line-segment'
for idx, (x, y) in enumerate(
    [
        (9090, 488),
        (10672, 566),
        (12287, 494),
        (14037, 559),
        (15451, 529),
        (16764, 445),
        (18076, 460),
        (19456, 413),
        (20466, 511),
        (21880, 396),
        (23798, 391),
        (25447, 385),
        (28073, 349),
        (30058, 332),
        (32583, 309),
        (34804, 355),
        (37160, 318),
        (40324, 290),
        (46895, 260),
        (50631, 256),
        (54602, 246),
        (58439, 264),
        (66520, 250),
        (75002, 258),
        (83649, 257),
        (92770, 255),
        (101524, 260),
    ],
    start=1,
):
    expt47.background.create(id=str(idx), x=x, y=y)
# Out:
# Background type for experiment 'wish_4_7' already set to
# line-segment

# %% [markdown]
# #### Set Linked Phases

# %%
expt56.linked_phases.create(id='ncaf', scale=1.0)

# %%
expt47.linked_phases.create(id='ncaf', scale=2.0)

# %% [markdown]
# #### Set Excluded Regions

# %%
expt56.excluded_regions.create(id='1', start=0, end=10010)
expt56.excluded_regions.create(id='2', start=100010, end=200000)

# %%
expt47.excluded_regions.create(id='1', start=0, end=10006)
expt47.excluded_regions.create(id='2', start=100004, end=200000)

# %% [markdown]
# ## Define Project
#
# The project object is used to manage the structure, experiments,
# and analysis
#
# #### Create Project

# %%
project = Project()

# %% [markdown]
# #### Add Structure

# %%
project.structures.add(structure)

# %% [markdown]
# #### Add Experiment

# %%
project.experiments.add(expt56)
project.experiments.add(expt47)

# %% [markdown]
# ## Perform Analysis
#
# This section shows the analysis process, including how to set up
# calculation and fitting engines.
#
# #### Set Fit Mode

# %%
project.analysis.fit.show_modes()
project.analysis.fit.mode = 'joint'
# Out:
# Fit modes
# <style type="text/css">
# #T_a6abb   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_a6abb thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_a6abb th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a6abb  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a6abb th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_a6abb tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_a6abb  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_a6abb th.col0 {
#   text-align: left;
# }
# #T_a6abb th.col1 {
#   text-align: left;
# }
# #T_a6abb th.col2 {
#   text-align: left;
# }
# #T_a6abb_row0_col0, #T_a6abb_row0_col1, #T_a6abb_row0_col2, #T_a6abb_row1_col0, #T_a6abb_row1_col1, #T_a6abb_row1_col2, #T_a6abb_row2_col0, #T_a6abb_row2_col1, #T_a6abb_row2_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_a6abb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6abb_level0_col0" class="col_heading level0 col0" ></th>
#       <th id="T_a6abb_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_a6abb_level0_col2" class="col_heading level0 col2" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6abb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a6abb_row0_col0" class="data row0 col0" >*</td>
#       <td id="T_a6abb_row0_col1" class="data row0 col1" >single</td>
#       <td id="T_a6abb_row0_col2" class="data row0 col2" >Independent fitting of each experiment</td>
#     </tr>
#     <tr>
#       <th id="T_a6abb_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a6abb_row1_col0" class="data row1 col0" ></td>
#       <td id="T_a6abb_row1_col1" class="data row1 col1" >joint</td>
#       <td id="T_a6abb_row1_col2" class="data row1 col2" >Simultaneous fitting of all experiments with weights</td>
#     </tr>
#     <tr>
#       <th id="T_a6abb_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a6abb_row2_col0" class="data row2 col0" ></td>
#       <td id="T_a6abb_row2_col1" class="data row2 col1" >sequential</td>
#       <td id="T_a6abb_row2_col2" class="data row2 col2" >Sequential fitting over data files in a directory</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Set Free Parameters

# %%
structure.atom_sites['Ca'].adp_iso.free = True
structure.atom_sites['Al'].adp_iso.free = True
structure.atom_sites['Na'].adp_iso.free = True
structure.atom_sites['F1'].adp_iso.free = True
structure.atom_sites['F2'].adp_iso.free = True
structure.atom_sites['F3'].adp_iso.free = True

# %%
expt56.linked_phases['ncaf'].scale.free = True
expt56.instrument.calib_d_to_tof_offset.free = True
expt56.instrument.calib_d_to_tof_linear.free = True
expt56.peak.broad_gauss_sigma_2.free = True
expt56.peak.exp_decay_beta_0.free = True
expt56.peak.exp_decay_beta_1.free = True
expt56.peak.exp_rise_alpha_1.free = True

expt47.linked_phases['ncaf'].scale.free = True
expt47.instrument.calib_d_to_tof_linear.free = True
expt47.instrument.calib_d_to_tof_offset.free = True
expt47.peak.broad_gauss_sigma_2.free = True
expt47.peak.exp_decay_beta_0.free = True
expt47.peak.exp_decay_beta_1.free = True
expt47.peak.exp_rise_alpha_1.free = True

# %% [markdown]
# #### Plot Measured vs Calculated

# %%
project.display.plotter.plot_meas_vs_calc(expt_name='wish_5_6')
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="8aa5f631-0094-4460-9c6a-e02925ce65e1" class="plotly-graph-div" style="height:600.0px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8aa5f631-0094-4460-9c6a-e02925ce65e1")) {                    Plotly.newPlot(                        "8aa5f631-0094-4460-9c6a-e02925ce65e1",                        [{"customdata":{"dtype":"f8","bdata":"PE7RkVyHeEAT1t8\u002fTECAQILTax\u002f1noBAkLEMWhttYcCBBMWPMcB\u002fQEiFWRelQ4BAttUVPKOWgUBYNzVDp2hLwLIubqOB+YBAgvYBkv5GgECP0HdwPG2EQOgOTWjWnVvAvJaQD3rRg0AWtKaUWEqAQCARHwXEvY
RVwC6QoPgx+YBAshn0m8I2gUCQTiQqgzKCQCDmOxgTlUPAOPjCZKqogkDUeaQceTmBQH2MVAD8EoJAYHfNjcy1MkCmCkYl9buDQH\u002fn\u002fhswPIFACvyuhDgrg0CA0+ESlBcyQGgibHh6UpBA4NIpgOc+gUBCJpsCg0iGQBw9etzjuHRAzojS3uDXi0DLy\u002f5in0GBQPGaxKRLMYZAdLc36FSaZkA1XrpJDCGKQD3SfcRXRIFAPyR9So8ig0DY5\u002fT88\u002flrQO5aQj7ofolAOuampBBHgUAyaZKaPu6BQPDGv46mQm5AaW\u002fwhclKgUDsd6DpyUmBQPvcavRrm4FAgGSbnpsoJMDufD813sSAQJJVrqqDTIFAYsBDH8qWgUCAbohAfT06wEMc6+I2sIRAVgL87D1PgUCIByNJpY2BQNilQM6MFFlAjSjtDT6ygUA7a4SR+FGBQNsDKG60wYFAAJy2dcDs\u002fr+t+lxtxUB\u002fQKjhtrSzVIFAgK73uNiZgkBMiUkSsMtXwIj029cBGIFAoGWTVm9XgUDm+zAQzbuEQPA6qMJZHl3AiPTb1wHcg0DiKNZfK1qBQBnZ+ZPSp4RAIJK8gxd6OcBBguLHmAKCQFYGcfznXIFAPhvy0oasgkCgH\u002fNhwT01wOXQItv5gX5AQpOY5qRfgUBCP9cJGv6BQHy2LuLo6FXAJzEIrJxOg0CKvUNpYmKBQDQ8ANRjI4JAME9\u002fgI2zQkCX\u002f5B++wCCQIhlv1AgZYFAByBMZlOcgkAADmT3\u002fGozwNSa5h0nPIRAellPtN5ngUBX6a+kwS2CQOiLtckrc1BA8KfGS7cDg0CKHB+ZnWqBQEF0rouNDoJA4HUGAzilPkBrK\u002faXXcWDQI4 ...

# %% [markdown]
# #### Run Fitting

# %%
project.analysis.fit()
project.analysis.display.fit_results()
project.display.plotter.plot_param_correlations()
# Out:
# Using all experiments 🔬 ['wish_5_6', 'wish_4_7'] for 'joint' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_0b03b   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_0b03b thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_0b03b th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_0b03b  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_0b03b th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_0b03b tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_0b03b  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_0b03b th.col0 {
#   text-align: center;
# }
# #T_0b03b th.col1 {
#   text-align: center;
# }
# #T_0b03b th.col2 {
#   text-align: center;
# }
# #T_0b03b_row0_col0, #T_0b03b_row0_col1, #T_0b03b_row0_col2, #T_0b03b_row1_col0, #T_0b03b_row1_col1, #T_0b03b_row1_col2, #T_0b03b_row2_col0, #T_0b03b_row2_col1, #T_0b03b_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_0b03b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b03b_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_0b03b_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_0b03b_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b03b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_0b03b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0b03b_row0_col1" class="data row0 col1" >47.53</td>
#       <td id="T_0b03b_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_0b03b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_0b03b_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_0b03b_row1_col1" class="data row1 col1" >15.57</td>
#       <td id="T_0b03b_row1_col2" class="data row1 col2" >67.2% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_0b03b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_0b03b_row2_col0" class="data row2 col0" >109</td>
#       <td id="T_0b03b_row2_col1" class="data row2 col1" >15.49</td>
#       <td id="T_0b03b_row2_col2" class="data row2 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 15.49 at iteration 98
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 142.64 seconds
# 📏 Goodness-of-fit (reduced χ²): 15.49
# 📏 R-factor (Rf): 6.98%
# 📏 R-factor squared (Rf²): 8.05%
# 📏 Weighted R-factor (wR): 9.15%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_4453b   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_4453b thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_4453b th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_4453b  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_4453b th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_4453b tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_4453b  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_4453b th.col0 {
#   text-align: left;
# }
# #T_4453b th.col1 {
#   text-align: left;
# }
# #T_4453b th.col2 {
#   text-align: left;
# }
# #T_4453b th.col3 {
#   text-align: left;
# }
# #T_4453b th.col4 {
#   text-align: right;
# }
# #T_4453b th.col5 {
#   text-align: right;
# }
# #T_4453b th.col6 {
#   text-align: right;
# }
# #T_4453b th.col7 {
#   text-align: left;
# }
# #T_4453b th.col8 {
#   text-align: right;
# }
# #T_4453b_row0_col0, #T_4453b_row0_col1, #T_4453b_row0_col2, #T_4453b_row0_col3, #T_4453b_row0_col7, #T_4453b_row1_col0, #T_4453b_row1_col1, #T_4453b_row1_col2, #T_4453b_row1_col3, #T_4453b_row1_col7, #T_4453b_row2_col0, #T_4453b_row2_col1, #T_4453b_row2_col2, #T_4453b_row2_col3, #T_4453b_row2_col7, #T_4453b_row3_col0, #T_4453b_row3_col1, #T_4453b_row3_col2, #T_4453b_row3_col3, #T_4453b_row3_col7, #T_4453b_row4_col0, #T_4453b_row4_col1, #T_4453b_row4_col2, #T_4453b_row4_col3, #T_4453b_row4_col7, #T_4453b_row5_col0, #T_4453b_row5_col1, #T_4453b_row5_col2, #T_4453b_row5_col3, #T_4453b_row5_col7, #T_4453b_row6_col0, #T_4453b_row6_col1, #T_4453b_row6_col2, #T_4453b_row6_col3, #T_4453b_row6_col7, #T_4453b_row7_col0, #T_4453b_row7_col1, #T_4453b_row7_col2, #T_4453b_row7_col3, #T_4453b_row7_col7, #T_4453b_row8_col0, #T_4453b_row8_col1, #T_4453b_row8_col2, #T_4453b_row8_col3, #T_4453b_row8_col7, #T_4453b_row9_col0, #T_4453b_row9_col1, #T_4453b_row9_col2, #T_4453b_row9_col3, #T_4453b_row9_col7, #T_4453b_row10_col0, #T_4453b_row10_col1, #T_4453b_row10_col2, #T_4453b_row10_col3, #T_4453b_row10_col7, #T_4453b_row11_col0, #T_4453b_row11_col1, #T_4453b_row11_col2, #T_4453b_row11_col3, #T_4453b_row11_col7, #T_4453b_row12_col0, #T_4453b_row12_col1, #T_4453b_row12_col2, #T_4453b_row12_col3, #T_4453b_row12_col7, #T_4453b_row13_col0, #T_4453b_row13_col1, #T_4453b_row13_col2, #T_4453b_row13_col3, #T_4453b_row13_col7, #T_4453b_row14_col0, #T_4453b_row14_col1, #T_4453b_row14_col2, #T_4453b_row14_col3, #T_4453b_row14_col7, #T_4453b_row15_col0, #T_4453b_row15_col1, #T_4453b_row15_col2, #T_4453b
>change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4453b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4453b_row0_col0" class="data row0 col0" >ncaf</td>
#       <td id="T_4453b_row0_col1" class="data row0 col1" >atom_site</td>
#       <td id="T_4453b_row0_col2" class="data row0 col2" >Ca</td>
#       <td id="T_4453b_row0_col3" class="data row0 col3" >adp_iso</td>
#       <td id="T_4453b_row0_col4" class="data row0 col4" >0.9200</td>
#       <td id="T_4453b_row0_col5" class="data row0 col5" >0.9340</td>
#       <td id="T_4453b_row0_col6" class="data row0 col6" >0.0448</td>
#       <td id="T_4453b_row0_col7" class="data row0 col7" >Å²</td>
#       <td id="T_4453b_row0_col8" class="data row0 col8" >1.52 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_4453b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4453b_row1_col0" class="data row1 col0" >ncaf</td>
#       <td id="T_4453b_row1_col1" class="data row1 col1" >atom_site</td>
#       <td id="T_4453b_row1_col2" class="data row1 col2" >Al</td>
#       <td id="T_4453b_row1_col3" class="data row1 col3" >adp_iso</td>
#       <td id="T_4453b_row1_col4" class="data row1 col4" >0.7300</td>
#       <td id="T_4453b_row1_col5" class="data row1 col5" >0.7330</td>
#       <td id="T_4453b_row1_col6" class="data row1 col6" >0.0569</td>
#       <td id="T_4453b_row1_col7" class="data row1 col7" >Å²</td>
#       <td id="T_4453b_row1_col8" class="data row1 col8" >0.41 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_4453b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4453b_row2_col0" class="data row2 col0" >ncaf</td>
#       <td id="T_4453b_row2_col1" class="data row2 col1" >atom_site</td>
#       <td id="T_4453b_row2_col2" class="data row2 col2" >Na</td>
#       <td id="T_4453b_row2_col3" class="data row2 col3" >adp_iso</td>
#       <td id="T_4453b_row2_col4" class="data row2 col4" >2.0800</td>
#       <td id="T_4453b_row2_col5" class="data row2 col5" >2.0474</td>
#       <td id="T_4453b_row2_col6" class="data row2 col6" >0.1082</td>
#       <td id="T_4453b_row2_col7" class="data row2 col7" >Å²</td>
#       <td id="T_4453b_row2_col8" class="data row2 col8" >1.57 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_4453b_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_4453b_row3_col0" class="data row3 col0" >ncaf</td>
#       <td id="T_4453b_row3_col1" class="data row3 col1" >atom_site</td>
#       <td id="T_4453b_row3_col2" class="data ro
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="f2f1ab2a-141b-401a-aeda-7fde5c1cac02" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f2f1ab2a-141b-401a-aeda-7fde5c1cac02")) {                    Plotly.newPlot(                        "f2f1ab2a-141b-401a-aeda-7fde5c1cac02",                        [{"colorbar":{"len":1.0,"lenmode":"fraction","title":{"text":""},"y":0.5,"yanchor":"middle"},"colorscale":[[0.0,"#d73027"],[0.5,"#f7f7f7"],[1.0,"#4575b4"]],"hoverongaps":false,"hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecorr: %{z:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","x":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRA"},"y":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRA"},"z":{"dtype":"f8","bdata":"3OcPJWpX7L8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f+6X2Tgv1x0\u002fQZ6XTF9eGL8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H+7ow1J\u002fEQEv8O\u002fQwRmLvg+gfsXS9rM5z8AAAAAAAD4fwAAAAAAAPh\u002ffMenONlKeT+al9vjwhF0v55GFqTvwcc\u002fFy9nqp1miT8AAAAAAAD4f+OXd+FiYnK\u002fR0wEcXIwbT8SkgcSekzivynJRVK0RdC\u002fB\u002fAYeeXS678=","shape":"5, 5"},"zmax":1.0,"zmid":0.0,"zmin":-1.0,"type":"heatmap"},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":["-0.89","0.74","-0.87"],"textfont":{"color":"#f5f5f5"},"textposition":"middle center","x":[0.5,2.5,4.5],"y":[0.5,2.5,4.5],"type":"scatter"}],                        {"legend":{"bgcolor":"rgba(255, 255, 255, 0.5)","x":1.0,"xanchor":"right","y":1.0,"yanchor":"top"},"margin":{"autoexpand":true,"b":45,"r":30,"t":40},"shapes":[{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":1.0,"x1":1.0,"xref":"x","y0":0.0,"y1":5.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":2.0,"x1":2.0,"xref":"x","y0":0.0,"y1":5.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":3.0,"x1":3.0,"xref":"x","y0":0.0,"y1":5.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":4.0,"x1":4.0,"xref":"x","y0":0.0,"y1":5.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":0.0,"x1":5.0,"xref":"x","y0":1.0,"y1":1.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":0.0,"x1":5.0,"xref":"x","y0":2.0,"y1":2.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":0.0,"x1":5.0,"xref":"x","y0":3.0,"y1":3.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":0.0,"x1":5.0,"xref":"x","y0":4.0,"y1":4.0,"yref":"y"},{"fillcolor":"rgba(0, 0, 0, 0)","layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"rect","x0":0.0,"x1":1.0,"xref":"paper","y0":0.0,"y1":1.0,"yref":"paper"}],"title":{"text":"Refined parameter correlation matrix with |correlation| \u003e= 0.70"},"xaxis":{"mirror":false,"showline":false,"title":{"text":"Parameter"},"zeroline":false,"tickformat":",.6~g","separatethousands":true,"side":"bottom","tickangle":-10,"automargin":true,"tickmode":"array","tickvals":[0.5,1.5,2.5,3.5,4.5],"ticktext":["wish_5_6.instrument.d_to_tof_offset","wish_5_6.instrument.d_to_tof_linear","wish_4_7.peak.rise_alpha_1","wish_4_7.peak.gauss_sigma_2","wish_4_7.instrument.d_to_tof_offset"],"range":[0.0,5.0],"showgrid":false,"ticks":"","layer":"above traces"},"yaxis":{"mirror":false,"showline":false,"title":{"text":"Parameter"},"zeroline":false,"tickformat":",.6~g","separatethousands":true,"autorange":"reversed","automargin":true,"tickmode":"array","t ...

# %% [markdown]
# #### Plot Measured vs Calculated

# %%
project.display.plotter.plot_meas_vs_calc(expt_name='wish_5_6')
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="3dc8ada9-9394-47a5-b33b-4744fd9feb94" class="plotly-graph-div" style="height:600.0px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3dc8ada9-9394-47a5-b33b-4744fd9feb94")) {                    Plotly.newPlot(                        "3dc8ada9-9394-47a5-b33b-4744fd9feb94",                        [{"customdata":{"dtype":"f8","bdata":"PE7RkVyHeEAT1t8\u002fTECAQNAHPYfOlIBAyIJR+YBEYcCBBMWPMcB\u002fQEiFWRelQ4BA8MqDFvmagUD4ihTqBK5LwLIubqOB+YBAgvYBkv5GgECoyAlWheWEQLDP3JQdYF\u002fAvJaQD3rRg0AWtKaUWEqAQA2vXM6N24FA8Ho+E8ReT0AtIR\u002f0bBGCQJogexizTYBALzuJeYnFgEDgX16pN75EQM6qz9VWr4FAdtlLJA5RgEBLQ9CsloKAQDB49o8CzEJA24r9ZfdJgkBYVEvTaVSAQH7h8qJonoBA0JWqMOy4SkDXo3A9ijOCQN7M4AbGV4BAl\u002fzUv0xfgUAA6HSzr4c6QC7\u002fIf32qHpAvpFywiJbgEDS5nnCdH6EQOycow\u002flp2zAqz5XW7Hch0CNBTT\u002ff16A
fQKjhtrSzVIFAEmxUZpiPgkDcdS99rXlXwIj029cBGIFAoGWTVm9XgUCokOthSneFQIBwPigifWHAiPTb1wHcg0DiKNZfK1qBQE4fJqfCzYVAYKyi9AwcT8BBguLHmAKCQFYGcfznXIFAWp8qVZkig0CQ0YHUCABCwOXQItv5gX5AQpOY5qRfgUB6LFOJkiKCQDwgDt6sDFfAJzEIrJxOg0CKvUNpYmKBQJdcOS3ERYJAAEnt7IeNQECX\u002f5B++wCCQIhlv1AgZYFAQGb\u002fC+gCg0CQaubWyB5AwNSa5h0nPIRAellPtN5ngUBFcijAd2aCQPCI4tv1Wk1A8KfGS7cDg0CKHB+ZnWqBQApCumE9CoJAwLyMQT0vP0BrK\u002faXXc ...

# %% [markdown]
# ## Summary
#
# This final section shows how to review the results of the analysis.

# %% [markdown]
# #### Show Project Summary

# %%
project.summary.show_report()
# Out:
# ————————————
# PROJECT INFO
# ————————————
# Title
# Untitled Project
# —————————————————————
# CRYSTALLOGRAPHIC DATA
# —————————————————————
# Phase datablock
# 🧩 ncaf
# Space group
# I 21 3
# <style type="text/css">
# #T_77692   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_77692 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_77692 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_77692  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_77692 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_77692 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_77692  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_77692 th.col0 {
#   text-align: left;
# }
# #T_77692 th.col1 {
#   text-align: right;
# }
# #T_77692 th.col2 {
#   text-align: right;
# }
# #T_77692_row0_col0, #T_77692_row1_col0, #T_77692_row2_col0, #T_77692_row3_col0, #T_77692_row4_col0, #T_77692_row5_col0 {
#   text-align: left;
# }
# #T_77692_row0_col1, #T_77692_row0_col2, #T_77692_row1_col1, #T_77692_row1_col2, #T_77692_row2_col1, #T_77692_row2_col2, #T_77692_row3_col1, #T_77692_row3_col2, #T_77692_row4_col1, #T_77692_row4_col2, #T_77692_row5_col1, #T_77692_row5_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_77692" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77692_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_77692_level0_col1" class="col_heading level0 col1" >Value</th>
#       <th id="T_77692_level0_col2" class="col_heading level0 col2" >Uncertainty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77692_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_77692_row0_col0" class="data row0 col0" >a</td>
#       <td id="T_77692_row0_col1" class="data row0 col1" >10.25025600</td>
#       <td id="T_77692_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_77692_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_77692_row1_col0" class="data row1 col0" >b</td>
#       <td id="T_77692_row1_col1" class="data row1 col1" >10.25025600</td>
#       <td id="T_77692_row1_col2" class="data row1 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_77692_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_77692_row2_col0" class="data row2 col0" >c</td>
#       <td id="T_77692_row2_col1" class="data row2 col1" >10.25025600</td>
#       <td id="T_77692_row2_col2" class="data row2 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_77692_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_77692_row3_col0" class="data row3 col0" >α</td>
#       <td id="T_77692_row3_col1" class="data row3 col1" >90.00000000</td>
#       <td id="T_77692_row3_col2" class="data row3 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_77692_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_77692_row4_col0" class="data row4 col0" >β</td>
#       <td id="T_77692_row4_col1" class="data row4 col1" >90.00000000</td>
#       <td id="T_77692_row4_col2" class="data row4 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_77692_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_77692_row5_col0" class="data row5 col0" >γ</td>
#       <td id="T_77692_row5_col1" class="data row5 col1" >90.00000000</td>
#       <td id="T_77692_row5_col2" class="data row5 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# Atom sites
# <style type="text/css">
# #T_318c8   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_318c8 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_318c8 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_318c8  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_318c8 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_318c8 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_318c8  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_318c8 th.col0 {
#   text-align: left;
# }
# #T_318c8 th.col1 {
#   text-align: left;
# }
# #T_318c8 th.col2 {
#   text-align: right;
# }
# #T_318c8 th.col3 {
#   text-align: right;
# }
# #T_318c8 th.col4 {
#   text-align: right;
# }
# #T_318c8 th.col5 {
#   text-align: right;
# }
# #T_318c8 th.col6 {
#   text-align: right;
# }
# #T_318c8_row0_col0, #T_318c8_row0_col1, #T_318c8_row1_col0, #T_318c8_row1_col1, #T_318c8_row2_col0, #T_318c8_row2_col1, #T_318c8_row3_col0, #T_318c8_row3_col1, #T_318c8_row4_col0, #T_318c8_row4_col1, #T_318c8_row5_col0, #T_318c8_row5_col1 {
#   text-align: left;
# }
# #T_318c8_row0_col2, #T_318c8_row0_col3, #T_318c8_row0_col4, #T_318c8_row0_col5, #T_318c8_row0_col6, #T_318c8_row1_col2, #T_318c8_row1_col3, #T_318c8_row1_col4, #T_318c8_row1_col5, #T_318c8_row1_col6, #T_318c8_row2_col2, #T_318c8_row2_col3, #T_318c8_row2_col4, #T_318c8_row2_col5, #T_318c8_row2_col6, #T_318c8_row3_col2, #T_318c8_row3_col3, #T_318c8_row3_col4, #T_318c8_row3_col5, #T_318c8_row3_col6, #T_318c8_row4_col2, #T_318c8_row4_col3, #T_318c8_row4_col4, #T_318c8_row4_col5, #T_318c8_row4_col6, #T_318c8_row5_col2, #T_318c8_row5_col3, #T_318c8_row5_col4, #T_318c8_row5_col5, #T_318c8_row5_col6 {
#   text-align: right;
# }
# </style>
# <table id="T_318c8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_318c8_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_318c8_level0_col1" class="col_heading level0 col1" >type</th>
#       <th id="T_318c8_level0_col2" class="col_heading level0 col2" >x</th>
#       <th id="T_318c8_level0_col3" class="col_heading level0 col3" >y</th>
#       <th id="T_318c8_level0_col4" class="col_heading level0 col4" >z</th>
#       <th id="T_318c8_level0_col5" class="col_heading level0 col5" >occ</th>
#       <th id="T_318c8_level0_col6" class="col_heading level0 col6" >Biso</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_318c8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_318c8_row0_col0" class="data row0 col0" >Ca</td>
#       <td id="T_318c8_row0_col1" class="data row0 col1" >Ca</td>
#       <td id="T_318c8_row0_col2" class="data row0 col2" >0.46630000</td>
#       <td id="T_318c8_row0_col3" class="data row0 col3" >0.00000000</td>
#       <td id="T_318c8_row0_col4" class="data row0 col4" >0.25000000</td>
#       <td id="T_318c8_row0_col5" class="data row0 col5" >1.00000000</td>
#       <td id="T_318c8_row0_col6" class="data row0 col6" >0.93399933</td>
#     </tr>
#     <tr>
#       <th id="T_318c8_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_318c8_row1_col0" class="data row1 col0" >Al</td>
#       <td id="T_318c8_row1_col1" class="data row1 col1" >Al</td>
#       <td id="T_318c8_row1_col2" class="data row1 col2" >0.25210000</td>
#       <td id="T_318c8_row1_col3" class="data row1 col3" >0.25210000</td>
#       <td id="T_318c8_row1_col4" class="data row1 col4" >0.25210000</td>
#       <td id="T_318c8_row1_col5" class="data row1 col5" >1.00000000</td>
#       <td id="T_318c8_row1_col6" class="data row1 col6" >0.73301211</td>
#     </tr>
#     <tr>
#       <th id="T_318c8_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_318c8_row2_col0" class="data row2 col0" >Na</td>
#       <td id="T_318c8_row2_col1" class="data row2 col1" >Na</td>
#       <td id="T_318c8_row2_col2" class="data row2 col2" >0.08510000</td>
#       <td id="T_318c8_row2_col3" class="data row2 col3" >0.08510000</td>
#       <td id="T_318c8_row2_col4" class="data row2 col4" >0.08510000</td>
#       <td id="T_318c8_row2_col5" class="data row2 col5" >1.00000000</td>
#       <td id="T_318c8_row2_col6" class="data row2 col6" >2.04740410</td>
#     </tr>
#     <tr>
#       <th id="T_318c8_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_318c8_row3_col0" class="data row3 col0" >F1</td>
#       <td id="T_318c8_row3_col1" class="data row3 col1" >F</td>
#       <td id="T_318c8_row3_col2" class="data row3 col2" >0.13770000</td>
#       <td id="T_318c8_row3_col3" class="data row3 col3" >0.30540000</td>
#       <td id="T_318c8_row3_col4" class="data row3 col4" >0.11950000</td>
#       <td id="T_318c8_row3_col5" class="data row3 col5" >1.00000000</td>
#       <td id="T_318c8_row3_col6" class="data row3 col6" >0.93890494</td>
#     </tr>
#     <tr>
#       <th id="T_318c8_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_318c8_row4_col0" class="data row4 col0" >F2</td>
#       <td id="T_318c8_row4_col1" class="data row4 col1" >F</td>
#       <td id="T_318c8_row4_col2" class="data row4 col2" >0.36250000</td>
#       <td id="T_318c8_row4_col3" class="data row4 col3" >0.36330000</td>
#       <td id="T_318c8_row4_col4" class="data row4 col4" >0.18670000</td>
#       <td id="T_318c8_row4_col5" class="data row4 col5" >1.00000000</td>
#       <td id="T_318c8_row4_col6" class="data row4 col6" >1.34423537</td>
#     </tr>
#     <tr>
#       <th id="T_318c8_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_318c8_row5_col0" class="data row5 col0" >F3</td>
#       <td id="T_318c8_row5_col1" class="data row5 col1" >F</td>
#       <td id="T_318c8_row5_col2" class="data row5 col2" >0.46120000</td>
#       <td id="T_318c8_row5_col3" class="data row5 col3" >0.46120000</td>
#       <td id="T_318c8_row5_col4" class="data row5 col4" >0.46120000</td>
#       <td id="T_318c8_row5_col5" class="data row5 col5" >1.00000000</td>
#       <td id="T_318c8_row5_col6" class="data row5 col6" >0.84813939</td>
#     </tr>
#   </tbody>
# </table>
# ———————————
# EXPERIMENTS
# ———————————
# Experiment datablock
# 🔬 wish_5_6
# Experiment type
# powder, neutron, time-of-flight bragg
# Calculation engine
# cryspy
# Profile type
# jorgensen
# Experiment datablock
# 🔬 wish_4_7
# Experiment type
# powder, neutron, time-of-flight bragg
# Calculation engine
# cryspy
# Profile type
# jorgensen
# ———————
# FITTING
# ———————
# Minimization engine
# lmfit (leastsq)
# Fit quality
# <style type="text/css">
# #T_46afb   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_46afb thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_46afb th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_46afb  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_46afb th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_46afb tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_46afb  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_46afb th.col0 {
#   text-align: left;
# }
# #T_46afb th.col1 {
#   text-align: right;
# }
# #T_46afb_row0_col0 {
#   text-align: left;
# }
# #T_46afb_row0_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_46afb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46afb_level0_col0" class="col_heading level0 col0" >metric</th>
#       <th id="T_46afb_level0_col1" class="col_heading level0 col1" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46afb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_46afb_row0_col0" class="data row0 col0" >Goodness-of-fit (reduced χ²)</td>
#       <td id="T_46afb_row0_col1" class="data row0 col1" >15.49</td>
#     </tr>
#   </tbody>
# </table>
