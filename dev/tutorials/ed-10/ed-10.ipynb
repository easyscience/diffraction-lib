# %%
# Check whether easydiffraction is installed; install it if needed.
# Required for remote environments such as Google Colab.
import importlib.util

if importlib.util.find_spec('easydiffraction') is None:
    # %pip install easydiffraction

# %% [markdown]
# # Pair Distribution Function: Ni, NPD
#
# This example demonstrates a pair distribution function (PDF) analysis
# of Ni, based on data collected from a constant wavelength neutron
# powder diffraction experiment.
#
# The dataset is taken from:
# https://github.com/diffpy/cmi_exchange/tree/main/cmi_scripts/fitNiPDF

# %% [markdown]
# ## Import Library

# %%
import easydiffraction as ed

# %% [markdown]
# ## Create Project

# %%
project = ed.Project()

# %% [markdown]
# ## Add Structure

# %%
project.structures.create(name='ni')

# %%
project.structures['ni'].space_group.name_h_m = 'F m -3 m'
project.structures['ni'].space_group.it_coordinate_system_code = '1'
project.structures['ni'].cell.length_a = 3.52387
project.structures['ni'].atom_sites.create(
    label='Ni',
    type_symbol='Ni',
    fract_x=0.0,
    fract_y=0.0,
    fract_z=0.0,
    wyckoff_letter='a',
    adp_iso=0.5,
)

# %% [markdown]
# ## Add Experiment

# %%
data_path = ed.download_data(id=6, destination='data')
# Out:
# Getting data...
# Data #6: ni-q27r100-neutron_from-2.gr
# ✅ Data #6 downloaded to 'data/ed-6.gr'

# %%
project.experiments.add_from_data_path(
    name='pdf',
    data_path=data_path,
    sample_form='powder',
    beam_mode='constant wavelength',
    radiation_probe='neutron',
    scattering_type='total',
)
# Out:
# ⚠️ No uncertainty (sy) column provided. Defaulting to 0.03.
# Data loaded successfully
# Experiment 🔬 'pdf'. Number of data points: 9801.

# %%
project.experiments['pdf'].linked_phases.create(id='ni', scale=1.0)
project.experiments['pdf'].peak.damp_q = 0
project.experiments['pdf'].peak.broad_q = 0.03
project.experiments['pdf'].peak.cutoff_q = 27.0
project.experiments['pdf'].peak.sharp_delta_1 = 0.0
project.experiments['pdf'].peak.sharp_delta_2 = 2.0
project.experiments['pdf'].peak.damp_particle_diameter = 0

# %% [markdown]
# ## Select Fitting Parameters

# %%
project.structures['ni'].cell.length_a.free = True
project.structures['ni'].atom_sites['Ni'].adp_iso.free = True

# %%
project.experiments['pdf'].linked_phases['ni'].scale.free = True
project.experiments['pdf'].peak.broad_q.free = True
project.experiments['pdf'].peak.sharp_delta_2.free = True

# %% [markdown]
# ## Run Fitting

# %%
project.analysis.fit()
project.analysis.display.fit_results()
project.plotter.plot_param_correlations()
# Out:
# Standard fitting
# 📋 Using experiment 🔬 'pdf' for 'single' fitting
# 🚀 Starting fit process with 'bumps (lm)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_73b14   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_73b14 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_73b14 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_73b14  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_73b14 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_73b14 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_73b14  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_73b14 th.col0 {
#   text-align: center;
# }
# #T_73b14 th.col1 {
#   text-align: center;
# }
# #T_73b14 th.col2 {
#   text-align: center;
# }
# #T_73b14_row0_col0, #T_73b14_row0_col1, #T_73b14_row0_col2, #T_73b14_row1_col0, #T_73b14_row1_col1, #T_73b14_row1_col2, #T_73b14_row2_col0, #T_73b14_row2_col1, #T_73b14_row2_col2, #T_73b14_row3_col0, #T_73b14_row3_col1, #T_73b14_row3_col2, #T_73b14_row4_col0, #T_73b14_row4_col1, #T_73b14_row4_col2, #T_73b14_row5_col0, #T_73b14_row5_col1, #T_73b14_row5_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_73b14" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73b14_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_73b14_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_73b14_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73b14_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_73b14_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_73b14_row0_col1" class="data row0 col1" >2334.39</td>
#       <td id="T_73b14_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_73b14_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_73b14_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_73b14_row1_col1" class="data row1 col1" >2039.40</td>
#       <td id="T_73b14_row1_col2" class="data row1 col2" >12.6% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_73b14_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_73b14_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_73b14_row2_col1" class="data row2 col1" >424.14</td>
#       <td id="T_73b14_row2_col2" class="data row2 col2" >79.2% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_73b14_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_73b14_row3_col0" class="data row3 col0" >14</td>
#       <td id="T_73b14_row3_col1" class="data row3 col1" >213.29</td>
#       <td id="T_73b14_row3_col2" class="data row3 col2" >49.7% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_73b14_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_73b14_row4_col0" class="data row4 col0" >20</td>
#       <td id="T_73b14_row4_col1" class="data row4 col1" >207.16</td>
#       <td id="T_73b14_row4_col2" class="data row4 col2" >2.9% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_73b14_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_73b14_row5_col0" class="data row5 col0" >47</td>
#       <td id="T_73b14_row5_col1" class="data row5 col1" >207.10</td>
#       <td id="T_73b14_row5_col2" class="data row5 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 207.10 at iteration 45
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 80.48 seconds
# 📏 Goodness-of-fit (reduced χ²): 207.10
# 📏 R-factor (Rf): 9.83%
# 📏 R-factor squared (Rf²): 9.48%
# 📏 Weighted R-factor (wR): 9.48%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_9804a   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_9804a thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_9804a th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_9804a  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_9804a th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_9804a tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_9804a  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_9804a th.col0 {
#   text-align: left;
# }
# #T_9804a th.col1 {
#   text-align: left;
# }
# #T_9804a th.col2 {
#   text-align: left;
# }
# #T_9804a th.col3 {
#   text-align: left;
# }
# #T_9804a th.col4 {
#   text-align: right;
# }
# #T_9804a th.col5 {
#   text-align: right;
# }
# #T_9804a th.col6 {
#   text-align: right;
# }
# #T_9804a th.col7 {
#   text-align: left;
# }
# #T_9804a th.col8 {
#   text-align: right;
# }
# #T_9804a_row0_col0, #T_9804a_row0_col1, #T_9804a_row0_col2, #T_9804a_row0_col3, #T_9804a_row0_col7, #T_9804a_row1_col0, #T_9804a_row1_col1, #T_9804a_row1_col2, #T_9804a_row1_col3, #T_9804a_row1_col7, #T_9804a_row2_col0, #T_9804a_row2_col1, #T_9804a_row2_col2, #T_9804a_row2_col3, #T_9804a_row2_col7, #T_9804a_row3_col0, #T_9804a_row3_col1, #T_9804a_row3_col2, #T_9804a_row3_col3, #T_9804a_row3_col7, #T_9804a_row4_col0, #T_9804a_row4_col1, #T_9804a_row4_col2, #T_9804a_row4_col3, #T_9804a_row4_col7 {
#   text-align: left;
# }
# #T_9804a_row0_col4, #T_9804a_row0_col5, #T_9804a_row0_col6, #T_9804a_row0_col8, #T_9804a_row1_col4, #T_9804a_row1_col5, #T_9804a_row1_col6, #T_9804a_row1_col8, #T_9804a_row2_col4, #T_9804a_row2_col5, #T_9804a_row2_col6, #T_9804a_row2_col8, #T_9804a_row3_col4, #T_9804a_row3_col5, #T_9804a_row3_col6, #T_9804a_row3_col8, #T_9804a_row4_col4, #T_9804a_row4_col5, #T_9804a_row4_col6, #T_9804a_row4_col8 {
#   text-align: right;
# }
# </style>
# <table id="T_9804a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9804a_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_9804a_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_9804a_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_9804a_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_9804a_level0_col4" class="col_heading level0 col4" >start</th>
#       <th id="T_9804a_level0_col5" class="col_heading level0 col5" >fitted</th>
#       <th id="T_9804a_level0_col6" class="col_heading level0 col6" >uncertainty</th>
#       <th id="T_9804a_level0_col7" class="col_heading level0 col7" >units</th>
#       <th id="T_9804a_level0_col8" class="col_heading level0 col8" >change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9804a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9804a_row0_col0" class="data row0 col0" >ni</td>
#       <td id="T_9804a_row0_col1" class="data row0 col1" >cell</td>
#       <td id="T_9804a_row0_col2" class="data row0 col2" ></td>
#       <td id="T_9804a_row0_col3" class="data row0 col3" >length_a</td>
#       <td id="T_9804a_row0_col4" class="data row0 col4" >3.5239</td>
#       <td id="T_9804a_row0_col5" class="data row0 col5" >3.5260</td>
#       <td id="T_9804a_row0_col6" class="data row0 col6" >N/A</td>
#       <td id="T_9804a_row0_col7" class="data row0 col7" >Å</td>
#       <td id="T_9804a_row0_col8" class="data row0 col8" >0.06 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_9804a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9804a_row1_col0" class="data row1 col0" >ni</td>
#       <td id="T_9804a_row1_col1" class="data row1 col1" >atom_site</td>
#       <td id="T_9804a_row1_col2" class="data row1 col2" >Ni</td>
#       <td id="T_9804a_row1_col3" class="data row1 col3" >adp_iso</td>
#       <td id="T_9804a_row1_col4" class="data row1 col4" >0.5000</td>
#       <td id="T_9804a_row1_col5" class="data row1 col5" >0.4281</td>
#       <td id="T_9804a_row1_col6" class="data row1 col6" >N/A</td>
#       <td id="T_9804a_row1_col7" class="data row1 col7" >Å²</td>
#       <td id="T_9804a_row1_col8" class="data row1 col8" >14.39 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_9804a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9804a_row2_col0" class="data row2 col0" >pdf</td>
#       <td id="T_9804a_row2_col1" class="data row2 col1" >linked_phases</td>
#       <td id="T_9804a_row2_col2" class="data row2 col2" >ni</td>
#       <td id="T_9804a_row2_col3" class="data row2 col3" >scale</td>
#       <td id="T_9804a_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_9804a_row2_col5" class="data row2 col5" >0.9892</td>
#       <td id="T_9804a_row2_col6" class="data row2 col6" >N/A</td>
#       <td id="T_9804a_row2_col7" class="data row2 col7" ></td>
#       <td id="T_9804a_row2_col8" class="data row2 col8" >1.08 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_9804a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9804a_row3_col0" class="data row3 col0" >pdf</td>
#       <td id="T_9804a_row3_col1" class="data row3 col1" >peak</td>
#       <td id="T_9804a_row3_col2" class="data row3 col2" ></td>
#       <td id="T_9804a_row3_col3" class="data row3 col3" >broad_q</td>
#       <td id="T_9804a_row3_col4" class="data row3 col4" >0.0300</td>
#       <td id="T_9804a_row3_col5" class="data row3 col5" >0.0220</td>
#       <td id="T_9804a_row3_col6" class="data row3 col6" >N/A</td>
#       <td id="T_9804a_row3_col7" class="data row3 col7" >Å⁻²</td>
#       <td id="T_9804a_row3_col8" class="data row3 col8" >26.76 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_9804a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_9804a_row4_col0" class="data row4 col0" >pdf</td>
#       <td id="T_9804a_row4_col1" class="data row4 col1" >peak</td>
#       <td id="T_9804a_row4_col2" class="data row4 col2" ></td>
#       <td id="T_9804a_row4_col3" class="data row4 col3" >sharp_delta_2</td>
#       <td id="T_9804a_row4_col4" class="data row4 col4" >2.0000</td>
#       <td id="T_9804a_row4_col5" class="data row4 col5" >2.5586</td>
#       <td id="T_9804a_row4_col6" class="data row4 col6" >N/A</td>
#       <td id="T_9804a_row4_col7" class="data row4 col7" >Å²</td>
#       <td id="T_9804a_row4_col8" class="data row4 col8" >27.93 % ↑</td>
#     </tr>
#   </tbody>
# </table>
# ⚠️ Correlation matrix is unavailable for this fit. Use the lmfit minimizer and ensure covariance estimation succeeds.

# %% [markdown]
# ## Plot Measured vs Calculated

# %%
project.plotter.plot_meas_vs_calc(expt_name='pdf', show_residual=True)
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.4.0.min.js" integrity="sha256-KEmPoupLpFyGMyGAiOsiNDbKDKAvxXAn/W+oQa0ZAfk=" crossorigin="anonymous"></script>                <div id="672c3dd4-5f84-4575-bc7c-53daa10494ee" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("672c3dd4-5f84-4575-bc7c-53daa10494ee")) {                    Plotly.newPlot(                        "672c3dd4-5f84-4575-bc7c-53daa10494ee",                        [{"line":{"color":"rgb(31, 119, 180)"},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"\u002fC9ShcjwJApHA9CtejAkC4HoXrUbgCQM3MzMzMzAJA4XoUrkfhAkD2KFyPwvUCQArXo3A9CgNAH4XrUbgeA0AzMzMzMzMDQEjhehSuRwNAXI\u002fC9ShcA0BxPQrXo3ADQIXrUbgehQNAmpmZmZmZA0CuR+F6FK4DQMP1KFyPwgNA16NwPQrXA0DsUbgehesDQAAAAAAAAARAFK5H4XoUBEApXI\u002fC9SgEQD0K16NwP