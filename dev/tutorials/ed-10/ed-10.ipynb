# %%
# Check whether easydiffraction is installed; install it if needed.
# Required for remote environments such as Google Colab.
import importlib.util

if importlib.util.find_spec('easydiffraction') is None:
    # %pip install easydiffraction

# %% [markdown]
# # Pair Distribution Function: Ni, NPD
#
# This example demonstrates a pair distribution function (PDF) analysis
# of Ni, based on data collected from a constant wavelength neutron
# powder diffraction experiment.
#
# The dataset is taken from:
# https://github.com/diffpy/cmi_exchange/tree/main/cmi_scripts/fitNiPDF

# %% [markdown]
# ## Import Library

# %%
import easydiffraction as ed

# %% [markdown]
# ## Create Project

# %%
project = ed.Project()

# %% [markdown]
# ## Add Structure

# %%
project.structures.create(name='ni')

# %%
project.structures['ni'].space_group.name_h_m = 'F m -3 m'
project.structures['ni'].space_group.it_coordinate_system_code = '1'
project.structures['ni'].cell.length_a = 3.52387
project.structures['ni'].atom_sites.create(
    label='Ni',
    type_symbol='Ni',
    fract_x=0.0,
    fract_y=0.0,
    fract_z=0.0,
    wyckoff_letter='a',
    adp_iso=0.5,
)

# %% [markdown]
# ## Add Experiment

# %%
data_path = ed.download_data(id=6, destination='data')
# Out:
# Getting data...
# Data #6: ni-q27r100-neutron_from-2.gr
# ✅ Data #6 downloaded to:
# '/home/runner/work/diffraction-lib/diffraction-lib/data/ed-6.gr'

# %%
project.experiments.add_from_data_path(
    name='pdf',
    data_path=data_path,
    sample_form='powder',
    beam_mode='constant wavelength',
    radiation_probe='neutron',
    scattering_type='total',
)
# Out:
# ⚠️ No uncertainty (sy) column provided. Defaulting to 0.03.
# Data loaded successfully
# Experiment 🔬 'pdf'. Number of data points: 9801.

# %%
project.experiments['pdf'].linked_phases.create(id='ni', scale=1.0)
project.experiments['pdf'].peak.damp_q = 0
project.experiments['pdf'].peak.broad_q = 0.03
project.experiments['pdf'].peak.cutoff_q = 27.0
project.experiments['pdf'].peak.sharp_delta_1 = 0.0
project.experiments['pdf'].peak.sharp_delta_2 = 2.0
project.experiments['pdf'].peak.damp_particle_diameter = 0

# %% [markdown]
# ## Select Fitting Parameters

# %%
project.structures['ni'].cell.length_a.free = True
project.structures['ni'].atom_sites['Ni'].adp_iso.free = True

# %%
project.experiments['pdf'].linked_phases['ni'].scale.free = True
project.experiments['pdf'].peak.broad_q.free = True
project.experiments['pdf'].peak.sharp_delta_2.free = True

# %% [markdown]
# ## Run Fitting

# %%
project.analysis.fit()
project.display.fit.results()
project.display.fit.correlations(threshold=0.75)
# Out:
# Standard fitting
# 📋 Using experiment 🔬 'pdf' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit progress:
# <style>.ed-activity-stack {display: flex;flex-direction: column;align-items: flex-start;gap: 0.35rem;margin-top: 0.5rem;}.ed-activity {display: inline-flex;align-items: center;gap: 0.45rem;color: #d97706;font-size: 0.95rem;font-weight: 400;line-height: 1.1;}.ed-activity-label {font-family: var(--jp-ui-font-family, -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif);}.ed-activity-pre {margin: 0;font-family: ui-monospace, SFMono-Regular, Menlo, monospace;white-space: pre-wrap;}.ed-activity-spinner {font-family: ui-monospace, SFMono-Regular, Menlo, monospace;}.ed-activity-spinner::before {animation: ed-activity-frames 1.0s steps(1) infinite;content: "⠋";display: inline-block;width: 1ch;}@keyframes ed-activity-frames { 0% { content: "⠋"; } 10% { content: "⠙"; } 20% { content: "⠹"; } 30% { content: "⠸"; } 40% { content: "⠼"; } 50% { content: "⠴"; } 60% { content: "⠦"; } 70% { content: "⠧"; } 80% { content: "⠇"; } 90% { content: "⠏"; } 100% { content: "⠋"; } }</style><div class="ed-activity-stack"><style type="text/css">
# #T_4c20e   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_4c20e thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_4c20e th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_4c20e  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_4c20e th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_4c20e tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_4c20e  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_4c20e th.col0 {
#   text-align: center;
# }
# #T_4c20e th.col1 {
#   text-align: center;
# }
# #T_4c20e th.col2 {
#   text-align: center;
# }
# #T_4c20e th.col3 {
#   text-align: center;
# }
# #T_4c20e_row0_col0, #T_4c20e_row0_col1, #T_4c20e_row0_col2, #T_4c20e_row0_col3, #T_4c20e_row1_col0, #T_4c20e_row1_col1, #T_4c20e_row1_col2, #T_4c20e_row1_col3, #T_4c20e_row2_col0, #T_4c20e_row2_col1, #T_4c20e_row2_col2, #T_4c20e_row2_col3, #T_4c20e_row3_col0, #T_4c20e_row3_col1, #T_4c20e_row3_col2, #T_4c20e_row3_col3, #T_4c20e_row4_col0, #T_4c20e_row4_col1, #T_4c20e_row4_col2, #T_4c20e_row4_col3, #T_4c20e_row5_col0, #T_4c20e_row5_col1, #T_4c20e_row5_col2, #T_4c20e_row5_col3, #T_4c20e_row6_col0, #T_4c20e_row6_col1, #T_4c20e_row6_col2, #T_4c20e_row6_col3, #T_4c20e_row7_col0, #T_4c20e_row7_col1, #T_4c20e_row7_col2, #T_4c20e_row7_col3, #T_4c20e_row8_col0, #T_4c20e_row8_col1, #T_4c20e_row8_col2, #T_4c20e_row8_col3, #T_4c20e_row9_col0, #T_4c20e_row9_col1, #T_4c20e_row9_col2, #T_4c20e_row9_col3, #T_4c20e_row10_col0, #T_4c20e_row10_col1, #T_4c20e_row10_col2, #T_4c20e_row10_col3, #T_4c20e_row11_col0, #T_4c20e_row11_col1, #T_4c20e_row11_col2, #T_4c20e_row11_col3, #T_4c20e_row12_col0, #T_4c20e_row12_col1, #T_4c20e_row12_col2, #T_4c20e_row12_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_4c20e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c20e_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_4c20e_level0_col1" class="col_heading level0 col1" >time (s)</th>
#       <th id="T_4c20e_level0_col2" class="col_heading level0 col2" >χ²</th>
#       <th id="T_4c20e_level0_col3" class="col_heading level0 col3" >change / status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c20e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4c20e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4c20e_row0_col1" class="data row0 col1" >1.95</td>
#       <td id="T_4c20e_row0_col2" class="data row0 col2" >2334.39</td>
#       <td id="T_4c20e_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c20e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_4c20e_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_4c20e_row1_col1" class="data row1 col1" >7.97</td>
#       <td id="T_4c20e_row1_col2" class="data row1 col2" >2322.80</td>
#       <td id="T_4c20e_row1_col3" class="data row1 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c20e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_4c20e_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_4c20e_row2_col1" class="data row2 col1" >14.37</td>
#       <td id="T_4c20e_row2_col2" class="data row2 col2" >2334.39</td>
#       <td id="T_4c20e_row2_col3" class="data row2 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c20e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_4c20e_row3_col0" class="data row3 col0" >9</td>
#       <td id="T_4c20e_row3_col1" class="data row3 col1" >15.72</td>
#       <td id="T_4c20e_row3_col2" class="data row3 col2" >416.28</td>
#       <td id="T_4c20e_row3_col3" class="data row3 col3" >82.2% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_4c20e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_4c20e_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_4c20e_row4_col1" class="data row4 col1" >21.67</td>
#       <td id="T_4c20e_row4_col2" class="data row4 col2" >416.28</td>
#       <td id="T_4c20e_row4_col3" class="data row4 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c20e_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_4c20e_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_4c20e_row5_col1" class="data row5 col1" >23.07</td>
#       <td id="T_4c20e_row5_col2" class="data row5 col2" >210.14</td>
#       <td id="T_4c20e_row5_col3" class="data row5 col3" >49.5% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_4c20e_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_4c20e_row6_col0" class="data row6 col0" >20</td>
#       <td id="T_4c20e_row6_col1" class="data row6 col1" >29.08</td>
#       <td id="T_4c20e_row6_col2" class="data row6 col2" >210.14</td>
#       <td id="T_4c20e_row6_col3" class="data row6 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c20e_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_4c20e_row7_col0" class="data row7 col0" >21</td>
#       <td id="T_4c20e_row7_col1" class="data row7 col1" >30.41</td>
#       <td id="T_4c20e_row7_col2" class="data row7 col2" >207.13</td>
#       <td id="T_4c20e_row7_col3" class="data row7 col3" >1.4% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_4c20e_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_4c20e_row8_col0" class="data row8 col0" >26</td>
#       <td id="T_4c20e_row8_col1" class="data row8 col1" >36.32</td>
#       <td id="T_4c20e_row8_col2" class="data row8 col2" >207.13</td>
#       <td id="T_4c20e_row8_col3" class="data row8 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c20e_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_4c20e_row9_col0" class="data row9 col0" >31</td>
#       <td id="T_4c20e_row9_col1" class="data row9 col1" >42.22</td>
#       <td id="T_4c20e_row9_col2" class="data row9 col2" >207.10</td>
#       <td id="T_4c20e_row9_col3" class="data row9 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c20e_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_4c20e_row10_col0" class="data row10 col0" >36</td>
#       <td id="T_4c20e_row10_col1" class="data row10 col1" >48.12</td>
#       <td id="T_4c20e_row10_col2" class="data row10 col2" >207.10</td>
#       <td id="T_4c20e_row10_col3" class="data row10 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c20e_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_4c20e_row11_col0" class="data row11 col0" >41</td>
#       <td id="T_4c20e_row11_col1" class="data row11 col1" >54.01</td>
#       <td id="T_4c20e_row11_col2" class="data row11 col2" >207.10</td>
#       <td id="T_4c20e_row11_col3" class="data row11 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_4c20e_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_4c20e_row12_col0" class="data row12 col0" >45</td>
#       <td id="T_4c20e_row12_col1" class="data row12 col1" >58.89</td>
#       <td id="T_4c20e_row12_col2" class="data row12 col2" >207.10</td>
#       <
# 🏆 Best goodness-of-fit (reduced χ²) is 207.10 at iteration 44
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 58.89 seconds
# 📏 Goodness-of-fit (reduced χ²): 207.10
# 📏 R-factor (Rf): 9.83%
# 📏 R-factor squared (Rf²): 9.48%
# 📏 Weighted R-factor (wR): 9.48%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_cb2c9   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_cb2c9 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_cb2c9 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_cb2c9  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_cb2c9 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_cb2c9 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_cb2c9  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_cb2c9 th.col0 {
#   text-align: left;
# }
# #T_cb2c9 th.col1 {
#   text-align: left;
# }
# #T_cb2c9 th.col2 {
#   text-align: left;
# }
# #T_cb2c9 th.col3 {
#   text-align: left;
# }
# #T_cb2c9 th.col4 {
#   text-align: left;
# }
# #T_cb2c9 th.col5 {
#   text-align: right;
# }
# #T_cb2c9 th.col6 {
#   text-align: right;
# }
# #T_cb2c9 th.col7 {
#   text-align: right;
# }
# #T_cb2c9 th.col8 {
#   text-align: right;
# }
# #T_cb2c9_row0_col0, #T_cb2c9_row0_col1, #T_cb2c9_row0_col2, #T_cb2c9_row0_col3, #T_cb2c9_row0_col4, #T_cb2c9_row1_col0, #T_cb2c9_row1_col1, #T_cb2c9_row1_col2, #T_cb2c9_row1_col3, #T_cb2c9_row1_col4, #T_cb2c9_row2_col0, #T_cb2c9_row2_col1, #T_cb2c9_row2_col2, #T_cb2c9_row2_col3, #T_cb2c9_row2_col4, #T_cb2c9_row3_col0, #T_cb2c9_row3_col1, #T_cb2c9_row3_col2, #T_cb2c9_row3_col3, #T_cb2c9_row3_col4, #T_cb2c9_row4_col0, #T_cb2c9_row4_col1, #T_cb2c9_row4_col2, #T_cb2c9_row4_col3, #T_cb2c9_row4_col4 {
#   text-align: left;
# }
# #T_cb2c9_row0_col5, #T_cb2c9_row0_col6, #T_cb2c9_row0_col7, #T_cb2c9_row0_col8, #T_cb2c9_row1_col5, #T_cb2c9_row1_col6, #T_cb2c9_row1_col7, #T_cb2c9_row1_col8, #T_cb2c9_row2_col5, #T_cb2c9_row2_col6, #T_cb2c9_row2_col7, #T_cb2c9_row2_col8, #T_cb2c9_row3_col5, #T_cb2c9_row3_col6, #T_cb2c9_row3_col7, #T_cb2c9_row3_col8, #T_cb2c9_row4_col5, #T_cb2c9_row4_col6, #T_cb2c9_row4_col7, #T_cb2c9_row4_col8 {
#   text-align: right;
# }
# </style>
# <table id="T_cb2c9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb2c9_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_cb2c9_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_cb2c9_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_cb2c9_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_cb2c9_level0_col4" class="col_heading level0 col4" >units</th>
#       <th id="T_cb2c9_level0_col5" class="col_heading level0 col5" >start</th>
#       <th id="T_cb2c9_level0_col6" class="col_heading level0 col6" >fitted</th>
#       <th id="T_cb2c9_level0_col7" class="col_heading level0 col7" >uncertainty</th>
#       <th id="T_cb2c9_level0_col8" class="col_heading level0 col8" >change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb2c9_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_cb2c9_row0_col0" class="data row0 col0" >ni</td>
#       <td id="T_cb2c9_row0_col1" class="data row0 col1" >cell</td>
#       <td id="T_cb2c9_row0_col2" class="data row0 col2" ></td>
#       <td id="T_cb2c9_row0_col3" class="data row0 col3" >length_a</td>
#       <td id="T_cb2c9_row0_col4" class="data row0 col4" >Å</td>
#       <td id="T_cb2c9_row0_col5" class="data row0 col5" >3.5239</td>
#       <td id="T_cb2c9_row0_col6" class="data row0 col6" >3.5260</td>
#       <td id="T_cb2c9_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_cb2c9_row0_col8" class="data row0 col8" >0.06 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_cb2c9_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_cb2c9_row1_col0" class="data row1 col0" >ni</td>
#       <td id="T_cb2c9_row1_col1" class="data row1 col1" >atom_site</td>
#       <td id="T_cb2c9_row1_col2" class="data row1 col2" >Ni</td>
#       <td id="T_cb2c9_row1_col3" class="data row1 col3" >adp_iso</td>
#       <td id="T_cb2c9_row1_col4" class="data row1 col4" >Å²</td>
#       <td id="T_cb2c9_row1_col5" class="data row1 col5" >0.5000</td>
#       <td id="T_cb2c9_row1_col6" class="data row1 col6" >0.4281</td>
#       <td id="T_cb2c9_row1_col7" class="data row1 col7" >0.0011</td>
#       <td id="T_cb2c9_row1_col8" class="data row1 col8" >14.39 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_cb2c9_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_cb2c9_row2_col0" class="data row2 col0" >pdf</td>
#       <td id="T_cb2c9_row2_col1" class="data row2 col1" >linked_phases</td>
#       <td id="T_cb2c9_row2_col2" class="data row2 col2" >ni</td>
#       <td id="T_cb2c9_row2_col3" class="data row2 col3" >scale</td>
#       <td id="T_cb2c9_row2_col4" class="data row2 col4" ></td>
#       <td id="T_cb2c9_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_cb2c9_row2_col6" class="data row2 col6" >0.9892</td>
#       <td id="T_cb2c9_row2_col7" class="data row2 col7" >0.0007</td>
#       <td id="T_cb2c9_row2_col8" class="data row2 col8" >1.08 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_cb2c9_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_cb2c9_row3_col0" class="data row3 col0" >pdf</td>
#       <td id="T_cb2c9_row3_col1" class="data row3 col1" >peak</td>
#       <td id="T_cb2c9_row3_col2" class="data row3 col2" ></td>
#       <td id="T_cb2c9_row3_col3" class="data row3 col3" >broad_q</td>
#       <td id="T_cb2c9_row3_col4" class="data row3 col4" >Å⁻²</td>
#       <td id="T_cb2c9_row3_col5" class="data row3 col5" >0.0300</td>
#       <td id="T_cb2c9_row3_col6" class="data row3 col6" >0.0220</td>
#       <td id="T_cb2c9_row3_col7" class="data row3 col7" >0.0001</td>
#       <td id="T_cb2c9_row3_col8" class="data row3 col8" >26.77 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_cb2c9_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_cb2c9_row4_col0" class="data row4 col0" >pdf</td>
#       <td id="T_cb2c9_row4_col1" class="data row4 col1" >peak</td>
#       <td id="T_cb2c9_row4_col2" class="data row4 col2" ></td>
#       <td id="T_cb2c9_row4_col3" class="data row4 col3" >sharp_delta_2</td>
#       <td id="T_cb2c9_row4_col4" class="data row4 col4" >Å²</td>
#       <td id="T_cb2c9_row4_col5" class="data row4 col5" >2.0000</td>
#       <td id="T_cb2c9_row4_col6" class="data row4 col6" >2.5587</td>
#       <td id="T_cb2c9_row4_col7" class="data row4 col7" >0.0444</td>
#       <td id="T_cb2c9_row4_col8" class="data row4 col8" >27.94 % ↑</td>
#     </tr>
#   </tbody>
# </table>
# ⚠️ No parameter pairs with |correlation| >= 0.75 were found.

# %% [markdown]
# ## Plot Measured vs Calculated

# %%
project.display.pattern(expt_name='pdf')
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="234684de-6d49-477c-9d5d-b88e7eb02e7a" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("234684de-6d49-477c-9d5d-b88e7eb02e7a")) {                    Plotly.newPlot(                        "234684de-6d49-477c-9d5d-b88e7eb02e7a",                        [{"hovertemplate":"Measured (Imeas)\u003cbr\u003ex: %{x}\u003cbr\u003ey: %{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendrank":10,"line":{"color":"rgb(31, 119, 180)","width":2.0},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":