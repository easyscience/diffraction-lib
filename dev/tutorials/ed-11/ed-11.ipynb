# %%
# Check if the easydiffraction library is installed.
# If not, install it with the 'visualization' extras.
# Needed when running remotely (e.g. Colab) where the lib is absent.
import builtins
import importlib.util

if (hasattr(builtins, '__IPYTHON__') and
    importlib.util.find_spec('easydiffraction') is None):
    # !pip install 'easydiffraction[visualization]'

# %% [markdown]
# # Pair Distribution Function: Si, NPD
#
# This example demonstrates a pair distribution function (PDF) analysis
# of Si, based on data collected from a time-of-flight neutron powder
# diffraction experiment at NOMAD at SNS.

# %% [markdown]
# ## Import Library

# %%
import easydiffraction as ed

# %% [markdown]
# ## Create Project

# %%
project = ed.Project()

# %% [markdown]
# ## Set Plotting Engine

# %%
# Keep the auto-selected engine. Alternatively, you can uncomment the
# line below to explicitly set the engine to the required one.
# project.plotter.engine = 'plotly'

# %%
# Set global plot range for plots
project.plotter.x_max = 40

# %% [markdown]
# ## Add Sample Model

# %%
project.sample_models.add(name='si')

# %%
sample_model = project.sample_models['si']
sample_model.space_group.name_h_m.value = 'F d -3 m'
sample_model.space_group.it_coordinate_system_code = '1'
sample_model.cell.length_a = 5.43146
sample_model.atom_sites.add(
    label='Si',
    type_symbol='Si',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    b_iso=0.5,
)

# %% [markdown]
# ## Add Experiment

# %%
data_path = ed.download_data(id=5, destination='data')
# Out:
# Getting data...
# Data #5: NOM_9999_Si_640g_PAC_50_ff_ftfrgr_up-to-50.gr
# ✅ Data #5 downloaded to 'data/ed-5.gr'

# %%
project.experiments.add(
    name='nomad',
    data_path=data_path,
    sample_form='powder',
    beam_mode='time-of-flight',
    radiation_probe='neutron',
    scattering_type='total',
)
# Out:
# Warning: No uncertainty (sy) column provided. Defaulting to 0.03.
# Data loaded successfully
# Experiment 🔬 'nomad'. Number of data points: 5033

# %%
experiment = project.experiments['nomad']
experiment.linked_phases.add(id='si', scale=1.0)
experiment.peak.damp_q = 0.02
experiment.peak.broad_q = 0.03
experiment.peak.cutoff_q = 35.0
experiment.peak.sharp_delta_1 = 0.0
experiment.peak.sharp_delta_2 = 4.0
experiment.peak.damp_particle_diameter = 0

# %% [markdown]
# ## Select Fitting Parameters

# %%
project.sample_models['si'].cell.length_a.free = True
project.sample_models['si'].atom_sites['Si'].b_iso.free = True
experiment.linked_phases['si'].scale.free = True

# %%
experiment.peak.damp_q.free = True
experiment.peak.broad_q.free = True
experiment.peak.sharp_delta_1.free = True
experiment.peak.sharp_delta_2.free = True

# %% [markdown]
# ## Run Fitting

# %%
project.analysis.current_calculator = 'pdffit'
project.analysis.fit()
project.analysis.show_fit_results()
# Out:
# Current calculator changed to
# pdffit
# Using experiment 🔬 'nomad' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_37b1d   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_37b1d thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_37b1d th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_37b1d  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_37b1d th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_37b1d tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_37b1d  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_37b1d th.col0 {
#   text-align: center;
# }
# #T_37b1d th.col1 {
#   text-align: center;
# }
# #T_37b1d th.col2 {
#   text-align: center;
# }
# #T_37b1d_row0_col0, #T_37b1d_row0_col1, #T_37b1d_row0_col2, #T_37b1d_row1_col0, #T_37b1d_row1_col1, #T_37b1d_row1_col2, #T_37b1d_row2_col0, #T_37b1d_row2_col1, #T_37b1d_row2_col2, #T_37b1d_row3_col0, #T_37b1d_row3_col1, #T_37b1d_row3_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_37b1d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37b1d_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_37b1d_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_37b1d_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37b1d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_37b1d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_37b1d_row0_col1" class="data row0 col1" >3103.72</td>
#       <td id="T_37b1d_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_37b1d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_37b1d_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_37b1d_row1_col1" class="data row1 col1" >270.15</td>
#       <td id="T_37b1d_row1_col2" class="data row1 col2" >91.3% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_37b1d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_37b1d_row2_col0" class="data row2 col0" >19</td>
#       <td id="T_37b1d_row2_col1" class="data row2 col1" >239.11</td>
#       <td id="T_37b1d_row2_col2" class="data row2 col2" >11.5% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_37b1d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_37b1d_row3_col0" class="data row3 col0" >52</td>
#       <td id="T_37b1d_row3_col1" class="data row3 col1" >239.01</td>
#       <td id="T_37b1d_row3_col2" class="data row3 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 239.01 at iteration 51
# ✅ Fitting complete.
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 7.58 seconds
# 📏 Goodness-of-fit (reduced χ²): 239.01
# 📏 R-factor (Rf): 9.88%
# 📏 R-factor squared (Rf²): 9.82%
# 📏 Weighted R-factor (wR): 9.82%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_86e6c   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_86e6c thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_86e6c th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_86e6c  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_86e6c th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_86e6c tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_86e6c  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_86e6c th.col0 {
#   text-align: left;
# }
# #T_86e6c th.col1 {
#   text-align: left;
# }
# #T_86e6c th.col2 {
#   text-align: left;
# }
# #T_86e6c th.col3 {
#   text-align: left;
# }
# #T_86e6c th.col4 {
#   text-align: right;
# }
# #T_86e6c th.col5 {
#   text-align: right;
# }
# #T_86e6c th.col6 {
#   text-align: right;
# }
# #T_86e6c th.col7 {
#   text-align: left;
# }
# #T_86e6c th.col8 {
#   text-align: right;
# }
# #T_86e6c_row0_col0, #T_86e6c_row0_col1, #T_86e6c_row0_col2, #T_86e6c_row0_col3, #T_86e6c_row0_col7, #T_86e6c_row1_col0, #T_86e6c_row1_col1, #T_86e6c_row1_col2, #T_86e6c_row1_col3, #T_86e6c_row1_col7, #T_86e6c_row2_col0, #T_86e6c_row2_col1, #T_86e6c_row2_col2, #T_86e6c_row2_col3, #T_86e6c_row2_col7, #T_86e6c_row3_col0, #T_86e6c_row3_col1, #T_86e6c_row3_col2, #T_86e6c_row3_col3, #T_86e6c_row3_col7, #T_86e6c_row4_col0, #T_86e6c_row4_col1, #T_86e6c_row4_col2, #T_86e6c_row4_col3, #T_86e6c_row4_col7, #T_86e6c_row5_col0, #T_86e6c_row5_col1, #T_86e6c_row5_col2, #T_86e6c_row5_col3, #T_86e6c_row5_col7, #T_86e6c_row6_col0, #T_86e6c_row6_col1, #T_86e6c_row6_col2, #T_86e6c_row6_col3, #T_86e6c_row6_col7 {
#   text-align: left;
# }
# #T_86e6c_row0_col4, #T_86e6c_row0_col5, #T_86e6c_row0_col6, #T_86e6c_row0_col8, #T_86e6c_row1_col4, #T_86e6c_row1_col5, #T_86e6c_row1_col6, #T_86e6c_row1_col8, #T_86e6c_row2_col4, #T_86e6c_row2_col5, #T_86e6c_row2_col6, #T_86e6c_row2_col8, #T_86e6c_row3_col4, #T_86e6c_row3_col5, #T_86e6c_row3_col6, #T_86e6c_row3_col8, #T_86e6c_row4_col4, #T_86e6c_row4_col5, #T_86e6c_row4_col6, #T_86e6c_row4_col8, #T_86e6c_row5_col4, #T_86e6c_row5_col5, #T_86e6c_row5_col6, #T_86e6c_row5_col8, #T_86e6c_row6_col4, #T_86e6c_row6_col5, #T_86e6c_row6_col6, #T_86e6c_row6_col8 {
#   text-align: right;
# }
# </style>
# <table id="T_86e6c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86e6c_level0_col0" class="col_heading level0 col0" >datablock</th>
#       <th id="T_86e6c_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_86e6c_level0_col2" class="col_heading level0 col2" >entry</th>
#       <th id="T_86e6c_level0_col3" class="col_heading level0 col3" >parameter</th>
#       <th id="T_86e6c_level0_col4" class="col_heading level0 col4" >start</th>
#       <th id="T_86e6c_level0_col5" class="col_heading level0 col5" >fitted</th>
#       <th id="T_86e6c_level0_col6" class="col_heading level0 col6" >uncertainty</th>
#       <th id="T_86e6c_level0_col7" class="col_heading level0 col7" >units</th>
#       <th id="T_86e6c_level0_col8" class="col_heading level0 col8" >change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86e6c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_86e6c_row0_col0" class="data row0 col0" >si</td>
#       <td id="T_86e6c_row0_col1" class="data row0 col1" >cell</td>
#       <td id="T_86e6c_row0_col2" class="data row0 col2" ></td>
#       <td id="T_86e6c_row0_col3" class="data row0 col3" >length_a</td>
#       <td id="T_86e6c_row0_col4" class="data row0 col4" >5.4315</td>
#       <td id="T_86e6c_row0_col5" class="data row0 col5" >5.4315</td>
#       <td id="T_86e6c_row0_col6" class="data row0 col6" >N/A</td>
#       <td id="T_86e6c_row0_col7" class="data row0 col7" >Å</td>
#       <td id="T_86e6c_row0_col8" class="data row0 col8" >0.00 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_86e6c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_86e6c_row1_col0" class="data row1 col0" >si</td>
#       <td id="T_86e6c_row1_col1" class="data row1 col1" >atom_site</td>
#       <td id="T_86e6c_row1_col2" class="data row1 col2" >Si</td>
#       <td id="T_86e6c_row1_col3" class="data row1 col3" >b_iso</td>
#       <td id="T_86e6c_row1_col4" class="data row1 col4" >0.5000</td>
#       <td id="T_86e6c_row1_col5" class="data row1 col5" >0.5000</td>
#       <td id="T_86e6c_row1_col6" class="data row1 col6" >N/A</td>
#       <td id="T_86e6c_row1_col7" class="data row1 col7" >Å²</td>
#       <td id="T_86e6c_row1_col8" class="data row1 col8" >0.00 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_86e6c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_86e6c_row2_col0" class="data row2 col0" >nomad</td>
#       <td id="T_86e6c_row2_col1" class="data row2 col1" >linked_phases</td>
#       <td id="T_86e6c_row2_col2" class="data row2 col2" >si</td>
#       <td id="T_86e6c_row2_col3" class="data row2 col3" >scale</td>
#       <td id="T_86e6c_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_86e6c_row2_col5" class="data row2 col5" >1.2501</td>
#       <td id="T_86e6c_row2_col6" class="data row2 col6" >N/A</td>
#       <td id="T_86e6c_row2_col7" class="data row2 col7" ></td>
#       <td id="T_86e6c_row2_col8" class="data row2 col8" >25.01 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_86e6c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_86e6c_row3_col0" class="data row3 col0" >nomad</td>
#       <td id="T_86e6c_row3_col1" class="data row3 col1" >peak</td>
#       <td id="T_86e6c_row3_col2" class="data row3 col2" ></td>
#       <td id="T_86e6c_row3_col3" class="data row3 col3" >damp_q</td>
#       <td id="T_86e6c_row3_col4" class="data row3 col4" >0.0200</td>
#       <td id="T_86e6c_row3_col5" class="data row3 col5" >0.0233</td>
#       <td id="T_86e6c_row3_col6" class="data row3 col6" >N/A</td>
#       <td id="T_86e6c_row3_col7" class="data row3 col7" >Å⁻¹</td>
#       <td id="T_86e6c_row3_col8" class="data row3 col8" >16.62 % ↑</td>
#     </tr>
#     <tr>
#       <th id="T_86e6c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_86e6c_row4_col0" class="data row4 col0" >nomad</td>
#       <td id="T_86e6c_row4_col1" class="data row4 col1" >peak</td>
#       <td id="T_86e6c_row4_col2" class="data row4 col2" ></td>
#       <td id="T_86e6c_row4_col3" class="data row4 col3" >broad_q</td>
#       <td id="T_86e6c_row4_col4" class="data row4 col4" >0.0300</td>
#       <td id="T_86e6c_row4_col5" class="data row4 col5" >0.0290</td>
#       <td id="T_86e6c_row4_col6" class="data row4 col6" >N/A</td>
#       <td id="T_86e6c_row4_col7" class="data row4 col7" >Å⁻²</td>
#       <td id="T_86e6c_row4_col8" class="data row4 col8" >3.46 % ↓</td>
#     </tr>
#     <tr>
#       <th id="T_86e6c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_86e6c_row5_col0" class="data row5 col0" >nomad</td>
#       <td id="T_86e6c_row5_col1" class="data row5 col1" >peak</td>
#       <td id="T_86e6c_row5_col2" class="data row5 col2" ></td>
#       <td id="T_86e6c_row5_col3" class="data row5 col3" >sharp_delta_1</td>
#       <td id="T_86e6c_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_86e6c_row5_col5" class="data row5 col5" >0.0078</td>
#       <td id="T_86e6c_row5_col6" class="data row5 col6" >N/A</td>
#       <td id="T_86e6c_row5_col7" class="data row5 col7" >Å</td>
#       <td id="T_86e6c_row5_col8" class="data row5 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_86e6c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_86e6c_row6_col0" class="data row6 col0" >nomad</td>
#       <td id="T_86e6c_row6_col1" class="data row6 col1" >peak</td>
#       <td id="T_86e6c_row6_col2" class="data row6 col2" ></td>
#       <td id="T_86e6c_row6_col3" class="data row6 col3" >sharp_delta_2</td>
#       <td id="T_86e6c_row6_col4" class="data row6 col4" >4.0000</td>
#       <td id="T_86e6c_row6_col5" class="data row6 col5" >3.8877</td>
#       <td id="T_86e6c_row6_col6" class="data row6 col6" >N/A</td>
#       <td id="T_86e6c_row6_col7" class="data row6

# %% [markdown]
# ## Plot Measured vs Calculated

# %%
project.plot_meas_vs_calc(expt_name='nomad', show_residual=False)
# Out:
# ❌ No time_of_flight data available for experiment nomad
