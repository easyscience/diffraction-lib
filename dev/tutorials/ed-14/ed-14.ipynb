# %%
# Check if the easydiffraction library is installed.
# If not, install it with the 'visualization' extras.
# Needed when running remotely (e.g. Colab) where the lib is absent.
import builtins
import importlib.util

if (hasattr(builtins, '__IPYTHON__') and
    importlib.util.find_spec('easydiffraction') is None):
    # !pip install 'easydiffraction[visualization]'

# %% [markdown]
# # Structure Refinement: Tb2TiO7, HEiDi
#
# Crystal structure refinement of Tb2TiO7 using single crystal neutron
# diffraction data from HEiDi at FRM II.

# %% [markdown]
# ## Import Library

# %%
import easydiffraction as ed

# %% [markdown]
# ## Step 1: Define Project

# %%
# Create minimal project without name and description
project = ed.Project()

# %%
project.plotter.engine = 'plotly'

# %% [markdown]
# ## Step 2: Define Sample Model

# %%
# Download CIF file from repository
model_path = ed.download_data(id=20, destination='data')
# Out:
# Getting data...
# Data #20: Tb2Ti2O7 (crystal structure)
# ✅ Data #20 downloaded to 'data/ed-20.cif'

# %%
project.sample_models.add(cif_path=model_path)

# %%
project.sample_models.show_names()
# Out:
# Defined sample models 🧩
# ['tbti']

# %%
sample_model = project.sample_models['tbti']

# %%
sample_model.atom_sites['Tb'].b_iso.value = 0.0
sample_model.atom_sites['Ti'].b_iso.value = 0.0
sample_model.atom_sites['O1'].b_iso.value = 0.0
sample_model.atom_sites['O2'].b_iso.value = 0.0

# %%
sample_model.show_as_cif()
# Out:
# Sample model 🧩 'tbti' as cif
# <style type="text/css">
# #T_c1ecb   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_c1ecb thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_c1ecb th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_c1ecb  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_c1ecb th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_c1ecb tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_c1ecb  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_c1ecb th.col0 {
#   text-align: left;
# }
# #T_c1ecb_row0_col0, #T_c1ecb_row1_col0, #T_c1ecb_row2_col0, #T_c1ecb_row3_col0, #T_c1ecb_row4_col0, #T_c1ecb_row5_col0, #T_c1ecb_row6_col0, #T_c1ecb_row7_col0, #T_c1ecb_row8_col0, #T_c1ecb_row9_col0, #T_c1ecb_row10_col0, #T_c1ecb_row11_col0, #T_c1ecb_row12_col0, #T_c1ecb_row13_col0, #T_c1ecb_row14_col0, #T_c1ecb_row15_col0, #T_c1ecb_row16_col0, #T_c1ecb_row17_col0, #T_c1ecb_row18_col0, #T_c1ecb_row19_col0, #T_c1ecb_row20_col0, #T_c1ecb_row21_col0, #T_c1ecb_row22_col0, #T_c1ecb_row23_col0, #T_c1ecb_row24_col0, #T_c1ecb_row25_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_c1ecb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1ecb_level0_col0" class="col_heading level0 col0" >CIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1ecb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c1ecb_row0_col0" class="data row0 col0" >data_tbti</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c1ecb_row1_col0" class="data row1 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c1ecb_row2_col0" class="data row2 col0" >_cell.length_a  10.1300</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_c1ecb_row3_col0" class="data row3 col0" >_cell.length_b  10.1300</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_c1ecb_row4_col0" class="data row4 col0" >_cell.length_c  10.1300</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_c1ecb_row5_col0" class="data row5 col0" >_cell.angle_alpha  90.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_c1ecb_row6_col0" class="data row6 col0" >_cell.angle_beta  90.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_c1ecb_row7_col0" class="data row7 col0" >_cell.angle_gamma  90.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_c1ecb_row8_col0" class="data row8 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_c1ecb_row9_col0" class="data row9 col0" >_space_group.name_H-M_alt "F d -3 m"</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_c1ecb_row10_col0" class="data row10 col0" >_space_group.IT_coordinate_system_code        2</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_c1ecb_row11_col0" class="data row11 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_c1ecb_row12_col0" class="data row12 col0" >loop_</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_c1ecb_row13_col0" class="data row13 col0" >_atom_site.label</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_c1ecb_row14_col0" class="data row14 col0" >_atom_site.type_symbol</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_c1ecb_row15_col0" class="data row15 col0" >_atom_site.fract_x</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_c1ecb_row16_col0" class="data row16 col0" >_atom_site.fract_y</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_c1ecb_row17_col0" class="data row17 col0" >_atom_site.fract_z</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_c1ecb_row18_col0" class="data row18 col0" >_atom_site.Wyckoff_letter</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_c1ecb_row19_col0" class="data row19 col0" >_atom_site.occupancy</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row20" class="row_heading level0 row20" >21</th>
#       <td id="T_c1ecb_row20_col0" class="data row20 col0" >_atom_site.B_iso_or_equiv</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row21" class="row_heading level0 row21" >22</th>
#       <td id="T_c1ecb_row21_col0" class="data row21 col0" >_atom_site.adp_type</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_c1ecb_row22_col0" class="data row22 col0" >      Tb       Tb   0.5000   0.5000   0.5000        d   1.0000   0.0000     Biso</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row23" class="row_heading level0 row23" >24</th>
#       <td id="T_c1ecb_row23_col0" class="data row23 col0" >      Ti       Ti   0.0000   0.0000   0.0000        c   1.0000   0.0000     Biso</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row24" class="row_heading level0 row24" >25</th>
#       <td id="T_c1ecb_row24_col0" class="data row24 col0" >      O1        O   0.3280   0.1250   0.1250        f   1.0000   0.0000     Biso</td>
#     </tr>
#     <tr>
#       <th id="T_c1ecb_level0_row25" class="row_heading level0 row25" >26</th>
#       <td id="T_c1ecb_row25_col0" class="data row25 col0" >      O2        O   0.3750   0.3750   0.3750        b   0.9700   0.0000     Biso</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 3: Define Experiment

# %%
data_path = ed.download_data(id=19, destination='data')
# Out:
# Getting data...
# Data #19: Tb2Ti2O7, HEiDi (MLZ)
# ✅ Data #19 downloaded to 'data/ed-19.xye'

# %%
project.experiments.add(
    name='heidi',
    data_path=data_path,
    sample_form='single crystal',
    beam_mode='constant wavelength',
    radiation_probe='neutron',
)
# Out:
# Data loaded successfully
# Experiment 🔬 'heidi'. Number of data points: 220

# %%
experiment = project.experiments['heidi']  # TODO: <heidi (None)>

# %%
experiment.linked_crystal.id = 'tbti'
experiment.linked_crystal.scale = 1.0

# %%
experiment.instrument.setup_wavelength = 0.793
# experiment.instrument.calib_twotheta_offset = 0.6 # TODO: Remove in SC

# %%
experiment.extinction.mosaicity = 29820
experiment.extinction.radius = 30

# %% [markdown]
# ## Step 4: Perform Analysis

# %%
project.plot_meas_vs_calc(expt_name='heidi')
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="751400c8-fa01-4f55-b479-65a66ce381c4" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("751400c8-fa01-4f55-b479-65a66ce381c4")) {                    Plotly.newPlot(                        "751400c8-fa01-4f55-b479-65a66ce381c4",                        [{"error_y":{"array":{"dtype":"f8","bdata":"Qxzr4jaaAkB+jLlrCfnxP+XQItv5fgRA3GgAb4EECkCk374OnBM\u002fQOwvuycPazhAjSjtDb7wEEDdJAaBlTMzQL7BFyZTBR1A+1xtxf76QkDpSC7\u002fIb0YQGgibHh6JQdATRWMSurEFEAAkX77OnADQHqlLEMcKxBAI0p7gy\u002fMGUDrc7UV+yslQPYoXI\u002fCNRdArkfhehSu+z91ApoIG14jQBiV1AloohZAArwFEhTvQUBB8WPMXdNIQF5LyAc9GwhA93XgnBHFLkCyne+nxgssQPkP6bevwxtAMLsnDwsVM0AkufyH9BsUQLmNBvAWyBBAZ9XnaiuWLUBKe4MvTMYjQHe+nxovfSVAuf
row16_col0, #T_75371_row17_col0, #T_75371_row18_col0, #T_75371_row19_col0, #T_75371_row20_col0, #T_75371_row21_col0, #T_75371_row22_col0, #T_75371_row23_col0, #T_75371_row24_col0, #T_75371_row25_col0, #T_75371_row26_col0, #T_75371_row27_col0, #T_75371_row28_col0, #T_75371_row29_col0, #T_75371_row30_col0, #T_75371_row31_col0, #T_75371_row32_col0, #T_75371_row33_col0, #T_75371_row34_col0, #T_75371_row35_col0, #T_75371_row36_col0, #T_75371_row37_col0, #T_75371_row38_col0, #T_75371_row39_col0, #T_75371_row40_col0, #T_75371_row41_col0, #T_75371_row42_col0, #T_75371_row43_col0, #T_75371_row44_col0, #T_75371_row45_col0, #T_75371_row46_col0, #T_75371_row47_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_75371" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75371_level0_col0" class="col_heading level0 col0" >CIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75371_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_75371_row0_col0" class="data row0 col0" >data_heidi</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_75371_row1_col0" class="data row1 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_75371_row2_col0" class="data row2 col0" >_expt_type.sample_form "single crystal"</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_75371_row3_col0" class="data row3 col0" >_expt_type.beam_mode "constant wavelength"</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_75371_row4_col0" class="data row4 col0" >_expt_type.radiation_probe  neutron</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_75371_row5_col0" class="data row5 col0" >_expt_type.scattering_type    bragg</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_75371_row6_col0" class="data row6 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_75371_row7_col0" class="data row7 col0" >_sc_crystal_block.id     tbti</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_75371_row8_col0" class="data row8 col0" >_sc_crystal_block.scale   1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_75371_row9_col0" class="data row9 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_75371_row10_col0" class="data row10 col0" >_instr.wavelength   0.7930</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_75371_row11_col0" class="data row11 col0" >_instr.2theta_offset   0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_75371_row12_col0" class="data row12 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_75371_row13_col0" class="data row13 col0" >_extinction.mosaicity 29820.0000</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_75371_row14_col0" class="data row14 col0" >_extinction.radius  30.0000</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_75371_row15_col0" class="data row15 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_75371_row16_col0" class="data row16 col0" >loop_</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_75371_row17_col0" class="data row17 col0" >_refln.id</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_75371_row18_col0" class="data row18 col0" >_refln.d_spacing</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_75371_row19_col0" class="data row19 col0" >_refln.sin_theta_over_lambda</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row20" class="row_heading level0 row20" >21</th>
#       <td id="T_75371_row20_col0" class="data row20 col0" >_refln.index_h</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row21" class="row_heading level0 row21" >22</th>
#       <td id="T_75371_row21_col0" class="data row21 col0" >_refln.index_k</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_75371_row22_col0" class="data row22 col0" >_refln.index_l</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row23" class="row_heading level0 row23" >24</th>
#       <td id="T_75371_row23_col0" class="data row23 col0" >_refln.intensity_meas</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row24" class="row_heading level0 row24" >25</th>
#       <td id="T_75371_row24_col0" class="data row24 col0" >_refln.intensity_meas_su</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row25" class="row_heading level0 row25" >26</th>
#       <td id="T_75371_row25_col0" class="data row25 col0" >_refln.intensity_calc</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row26" class="row_heading level0 row26" >27</th>
#       <td id="T_75371_row26_col0" class="data row26 col0" >_refln.wavelength</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row27" class="row_heading level0 row27" >28</th>
#       <td id="T_75371_row27_col0" class="data row27 col0" >       1   5.8486   0.0855 1 1 1 194.5677   2.3253  70.6007   0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row28" class="row_heading level0 row28" >29</th>
#       <td id="T_75371_row28_col0" class="data row28 col0" >       2   3.5815   0.1396 2 2 0  22.6319   1.1233   5.3328   0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row29" class="row_heading level0 row29" >30</th>
#       <td id="T_75371_row29_col0" class="data row29 col0" >       3   3.0543   0.1637 3 1 1  99.2917   2.5620  34.5828   0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row30" class="row_heading level0 row30" >31</th>
#       <td id="T_75371_row30_col0" class="data row30 col0" >       4   2.9243   0.1710 2 2 2 219.2877   3.2522  75.5916   0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row31" class="row_heading level0 row31" >32</th>
#       <td id="T_75371_row31_col0" class="data row31 col0" >       5   2.5325   0.1974 4 0 0 1366.7377  31.0766 525.7131   0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_75371_level0_row32" class="row_heading level0 row32" >33</th>
#       <td id="T_75371_

# %%
# Start refinement. All parameters, which have standard uncertainties
# in the input CIF files, are refined by default.
project.analysis.fit()
# Out:
# Using experiment 🔬 'heidi' for 'single' fitting
# 🚀 Starting fit process with 'lmfit (leastsq)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_1ca24   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_1ca24 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_1ca24 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_1ca24  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_1ca24 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_1ca24 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_1ca24  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_1ca24 th.col0 {
#   text-align: center;
# }
# #T_1ca24 th.col1 {
#   text-align: center;
# }
# #T_1ca24 th.col2 {
#   text-align: center;
# }
# #T_1ca24_row0_col0, #T_1ca24_row0_col1, #T_1ca24_row0_col2, #T_1ca24_row1_col0, #T_1ca24_row1_col1, #T_1ca24_row1_col2, #T_1ca24_row2_col0, #T_1ca24_row2_col1, #T_1ca24_row2_col2, #T_1ca24_row3_col0, #T_1ca24_row3_col1, #T_1ca24_row3_col2, #T_1ca24_row4_col0, #T_1ca24_row4_col1, #T_1ca24_row4_col2, #T_1ca24_row5_col0, #T_1ca24_row5_col1, #T_1ca24_row5_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_1ca24" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ca24_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_1ca24_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_1ca24_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ca24_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1ca24_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_1ca24_row0_col1" class="data row0 col1" >512.08</td>
#       <td id="T_1ca24_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_1ca24_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_1ca24_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_1ca24_row1_col1" class="data row1 col1" >187.71</td>
#       <td id="T_1ca24_row1_col2" class="data row1 col2" >63.3% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_1ca24_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_1ca24_row2_col0" class="data row2 col0" >23</td>
#       <td id="T_1ca24_row2_col1" class="data row2 col1" >66.70</td>
#       <td id="T_1ca24_row2_col2" class="data row2 col2" >64.5% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_1ca24_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_1ca24_row3_col0" class="data row3 col0" >33</td>
#       <td id="T_1ca24_row3_col1" class="data row3 col1" >13.20</td>
#       <td id="T_1ca24_row3_col2" class="data row3 col2" >80.2% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_1ca24_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_1ca24_row4_col0" class="data row4 col0" >43</td>
#       <td id="T_1ca24_row4_col1" class="data row4 col1" >12.84</td>
#       <td id="T_1ca24_row4_col2" class="data row4 col2" >2.8% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_1ca24_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_1ca24_row5_col0" class="data row5 col0" >74</td>
#       <td id="T_1ca24_row5_col1" class="data row5 col1" >12.84</td>
#       <td id="T_1ca24_row5_col2" class="data row5 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 12.84 at iteration 73
# ✅ Fitting complete.

# %%
# Show fit results summary
project.analysis.show_fit_results()
# Out:
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 2.23 seconds
# 📏 Goodness-of-fit (reduced χ²): 12.84
# 📏 R-factor (Rf): 7.68%
# 📏 R-factor squared (Rf²): 8.12%
# 📏 Weighted R-factor (wR): 8.51%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_39925   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_39925 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_39925 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_39925  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_39925 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_39925 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_39925  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_39925 th.col0 {
#   text-align: left;
# }
# #T_39925 th.col1 {
#   text-align: left;
# }
# #T_39925 th.col2 {
#   text-align: left;
# }
# #T_39925 th.col3 {
#   text-align: left;
# }
# #T_39925 th.col4 {
#   text-align: right;
# }
# #T_39925 th.col5 {
#   text-align: right;
# }
# #T_39925 th.col6 {
#   text-align: right;
# }
# #T_39925 th.col7 {
#   text-align: left;
# }
# #T_39925 th.col8 {
#   text-align: right;
# }
T_f62bb_row24_col0, #T_f62bb_row25_col0, #T_f62bb_row26_col0, #T_f62bb_row27_col0, #T_f62bb_row28_col0, #T_f62bb_row29_col0, #T_f62bb_row30_col0, #T_f62bb_row31_col0, #T_f62bb_row32_col0, #T_f62bb_row33_col0, #T_f62bb_row34_col0, #T_f62bb_row35_col0, #T_f62bb_row36_col0, #T_f62bb_row37_col0, #T_f62bb_row38_col0, #T_f62bb_row39_col0, #T_f62bb_row40_col0, #T_f62bb_row41_col0, #T_f62bb_row42_col0, #T_f62bb_row43_col0, #T_f62bb_row44_col0, #T_f62bb_row45_col0, #T_f62bb_row46_col0, #T_f62bb_row47_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_f62bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f62bb_level0_col0" class="col_heading level0 col0" >CIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f62bb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f62bb_row0_col0" class="data row0 col0" >data_heidi</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f62bb_row1_col0" class="data row1 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f62bb_row2_col0" class="data row2 col0" >_expt_type.sample_form "single crystal"</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_f62bb_row3_col0" class="data row3 col0" >_expt_type.beam_mode "constant wavelength"</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f62bb_row4_col0" class="data row4 col0" >_expt_type.radiation_probe  neutron</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_f62bb_row5_col0" class="data row5 col0" >_expt_type.scattering_type    bragg</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_f62bb_row6_col0" class="data row6 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_f62bb_row7_col0" class="data row7 col0" >_sc_crystal_block.id     tbti</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_f62bb_row8_col0" class="data row8 col0" >_sc_crystal_block.scale   2.9210</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_f62bb_row9_col0" class="data row9 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_f62bb_row10_col0" class="data row10 col0" >_instr.wavelength   0.7930</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_f62bb_row11_col0" class="data row11 col0" >_instr.2theta_offset   0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_f62bb_row12_col0" class="data row12 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_f62bb_row13_col0" class="data row13 col0" >_extinction.mosaicity 29820.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_f62bb_row14_col0" class="data row14 col0" >_extinction.radius  27.1471</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_f62bb_row15_col0" class="data row15 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_f62bb_row16_col0" class="data row16 col0" >loop_</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_f62bb_row17_col0" class="data row17 col0" >_refln.id</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_f62bb_row18_col0" class="data row18 col0" >_refln.d_spacing</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_f62bb_row19_col0" class="data row19 col0" >_refln.sin_theta_over_lambda</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row20" class="row_heading level0 row20" >21</th>
#       <td id="T_f62bb_row20_col0" class="data row20 col0" >_refln.index_h</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row21" class="row_heading level0 row21" >22</th>
#       <td id="T_f62bb_row21_col0" class="data row21 col0" >_refln.index_k</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_f62bb_row22_col0" class="data row22 col0" >_refln.index_l</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row23" class="row_heading level0 row23" >24</th>
#       <td id="T_f62bb_row23_col0" class="data row23 col0" >_refln.intensity_meas</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row24" class="row_heading level0 row24" >25</th>
#       <td id="T_f62bb_row24_col0" class="data row24 col0" >_refln.intensity_meas_su</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row25" class="row_heading level0 row25" >26</th>
#       <td id="T_f62bb_row25_col0" class="data row25 col0" >_refln.intensity_calc</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row26" class="row_heading level0 row26" >27</th>
#       <td id="T_f62bb_row26_col0" class="data row26 col0" >_refln.wavelength</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row27" class="row_heading level0 row27" >28</th>
#       <td id="T_f62bb_row27_col0" class="data row27 col0" >       1   5.8486   0.0855 1 1 1 194.5677   2.3253 206.0766   0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row28" class="row_heading level0 row28" >29</th>
#       <td id="T_f62bb_row28_col0" class="data row28 col0" >       2   3.5815   0.1396 2 2 0  22.6319   1.1233  15.2422   0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row29" class="row_heading level0 row29" >30</th>
#       <td id="T_f62bb_row29_col0" class="data row29 col0" >       3   3.0543   0.1637 3 1 1  99.2917   2.5620  97.6114   0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row30" class="row_heading level0 row30" >31</th>
#       <td id="T_f62bb_row30_col0" class="data row30 col0" >       4   2.9243   0.1710 2 2 2 219.2877   3.2522 215.5211   0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f62bb_level0_row31" class="row_heading level0 row31" >32</th>
#       <td id="T
RX9gkkA8BB2inpVUQMAm9lMBj2FAp6gGpWWMKUAu3i3dnYhhQEp6vymSQzlAGBHkm5DhlEBB+sjc\u002fg+TQAzhj+zyrJdAL09PEnUZGDrPpA1Josx0QAqO8xWQ1nRAR+GVqx3\u002fj0CSmS0hgElyQPEScA4ZT2tAWr2Q4RCfeEAN5tlLAosQOsNGYKdrDKRArjMAilLDc0C6WUk2kdV9QDkSdoiRMjBAjUZFQZZ5eEAeCZESVAxgQCwJkRJUDGBAZHC7+ ...

# %% [markdown]
# ## Step 5: Show Project Summary

# %%
project.summary.show_report()
# Out:
# ————————————
# PROJECT INFO
# ————————————
# Title
# Untitled Project
# —————————————————————
# CRYSTALLOGRAPHIC DATA
# —————————————————————
# Phase datablock
# 🧩 tbti
# Space group
# F d -3 m
# Cell parameters
# <style type="text/css">
# #T_3ad15   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_3ad15 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_3ad15 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_3ad15  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_3ad15 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_3ad15 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_3ad15  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_3ad15 th.col0 {
#   text-align: left;
# }
# #T_3ad15 th.col1 {
#   text-align: right;
# }
# #T_3ad15_row0_col0, #T_3ad15_row1_col0, #T_3ad15_row2_col0, #T_3ad15_row3_col0, #T_3ad15_row4_col0, #T_3ad15_row5_col0 {
#   text-align: left;
# }
# #T_3ad15_row0_col1, #T_3ad15_row1_col1, #T_3ad15_row2_col1, #T_3ad15_row3_col1, #T_3ad15_row4_col1, #T_3ad15_row5_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_3ad15" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ad15_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_3ad15_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ad15_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_3ad15_row0_col0" class="data row0 col0" >a</td>
#       <td id="T_3ad15_row0_col1" class="data row0 col1" >10.13000</td>
#     </tr>
#     <tr>
#       <th id="T_3ad15_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_3ad15_row1_col0" class="data row1 col0" >b</td>
#       <td id="T_3ad15_row1_col1" class="data row1 col1" >10.13000</td>
#     </tr>
#     <tr>
#       <th id="T_3ad15_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_3ad15_row2_col0" class="data row2 col0" >c</td>
#       <td id="T_3ad15_row2_col1" class="data row2 col1" >10.13000</td>
#     </tr>
#     <tr>
#       <th id="T_3ad15_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_3ad15_row3_col0" class="data row3 col0" >alpha</td>
#       <td id="T_3ad15_row3_col1" class="data row3 col1" >90.00000</td>
#     </tr>
#     <tr>
#       <th id="T_3ad15_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_3ad15_row4_col0" class="data row4 col0" >beta</td>
#       <td id="T_3ad15_row4_col1" class="data row4 col1" >90.00000</td>
#     </tr>
#     <tr>
#       <th id="T_3ad15_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_3ad15_row5_col0" class="data row5 col0" >gamma</td>
#       <td id="T_3ad15_row5_col1" class="data row5 col1" >90.00000</td>
#     </tr>
#   </tbody>
# </table>
# Atom sites
# <style type="text/css">
# #T_24075   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_24075 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_24075 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_24075  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_24075 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_24075 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_24075  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_24075 th.col0 {
#   text-align: left;
# }
# #T_24075 th.col1 {
#   text-align: left;
# }
# #T_24075 th.col2 {
#   text-align: right;
# }
# #T_24075 th.col3 {
#   text-align: right;
# }
# #T_24075 th.col4 {
#   text-align: right;
# }
# #T_24075 th.col5 {
#   text-align: right;
# }
# #T_24075 th.col6 {
#   text-align: right;
# }
# #T_24075_row0_col0, #T_24075_row0_col1, #T_24075_row1_col0, #T_24075_row1_col1, #T_24075_row2_col0, #T_24075_row2_col1, #T_24075_row3_col0, #T_24075_row3_col1 {
#   text-align: left;
# }
# #T_24075_row0_col2, #T_24075_row0_col3, #T_24075_row0_col4, #T_24075_row0_col5, #T_24075_row0_col6, #T_24075_row1_col2, #T_24075_row1_col3, #T_24075_row1_col4, #T_24075_row1_col5, #T_24075_row1_col6, #T_24075_row2_col2, #T_24075_row2_col3, #T_24075_row2_col4, #T_24075_row2_col5, #T_24075_row2_col6, #T_24075_row3_col2, #T_24075_row3_col3, #T_24075_row3_col4, #T_24075_row3_col5, #T_24075_row3_col6 {
#   text-align: right;
# }
# </style>
# <table id="T_24075" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24075_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_24075_level0_col1" class="col_heading level0 col1" >type</th>
#       <th id="T_24075_level0_col2" class="col_heading level0 col2" >x</th>
#       <th id="T_24075_level0_col3" class="col_heading level0 col3" >y</th>
#       <th id="T_24075_level0_col4" class="col_heading level0 col4" >z</th>
#       <th id="T_24075_level0_col5" class="col_heading level0 col5" >occ</th>
#       <th id="T_24075_level0_col6" class="col_heading level0 col6" >Biso</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24075_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_24075_row0_col0" class="data row0 col0" >Tb</td>
#       <td id="T_24075_row0_col1" class="data row0 col1" >Tb</td>
#       <td id="T_24075_row0_col2" class="data row0 col2" >0.50000</td>
#       <td id="T_24075_row0_col3" class="data row0 col3" >0.50000</td>
#       <td id="T_24075_row0_col4" class="data row0 col4" >0.50000</td>
#       <td id="T_24075_row0_col5" class="data row0 col5" >1.00000</td>
#       <td id="T_24075_row0_col6" class="data row0 col6" >0.53035</td>
#     </tr>
#     <tr>
#       <th id="T_24075_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_24075_row1_col0" class="data row1 col0" >Ti</td>
#       <td id="T_24075_row1_col1" class="data row1 col1" >Ti</td>
#       <td id="T_24075_row1_col2" class="data row1 col2" >0.00000</td>
#       <td id="T_24075_row1_col3" class="data row1 col3" >0.00000</td>
#       <td id="T_24075_row1_col4" class="data row1 col4" >0.00000</td>
#       <td id="T_24075_row1_col5" class="data row1 col5" >1.00000</td>
#       <td id="T_24075_row1_col6" class="data row1 col6" >0.47604</td>
#     </tr>
#     <tr>
#       <th id="T_24075_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_24075_row2_col0" class="data row2 col0" >O1</td>
#       <td id="T_24075_row2_col1" class="data row2 col1" >O</td>
#       <td id="T_24075_row2_col2" class="data row2 col2" >0.32804</td>
#       <td id="T_24075_row2_col3" class="data row2 col3" >0.12500</td>
#       <td id="T_24075_row2_col4" class="data row2 col4" >0.12500</td>
#       <td id="T_24075_row2_col5" class="data row2 col5" >1.00155</td>
#       <td id="T_24075_row2_col6" class="data row2 col6" >0.45165</td>
#     </tr>
#     <tr>
#       <th id="T_24075_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_24075_row3_col0" class="data row3 col0" >O2</td>
#       <td id="T_24075_row3_col1" class="data row3 col1" >O</td>
#       <td id="T_24075_row3_col2" class="data row3 col2" >0.37500</td>
#       <td id="T_24075_row3_col3" class="data row3 col3" >0.37500</td>
#       <td id="T_24075_row3_col4" class="data row3 col4" >0.37500</td>
#       <td id="T_24075_row3_col5" class="data row3 col5" >0.96871</td>
#       <td id="T_24075_row3_col6" class="data row3 col6" >0.23334</td>
#     </tr>
#   </tbody>
# </table>
# ———————————
# EXPERIMENTS
# ———————————
# Experiment datablock
# 🔬 heidi
# Experiment type
# single crystal, neutron, constant wavelength
# Wavelength
# 0.79300
# 2θ offset
# 0.00000
# ———————
# FITTING
# ———————
# Calculation engine
# cryspy
# Minimization engine
# lmfit (leastsq)
# Fit quality
# <style type="text/css">
# #T_b57a6   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_b57a6 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_b57a6 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_b57a6  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_b57a6 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_b57a6 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_b57a6  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_b57a6 th.col0 {
#   text-align: left;
# }
# #T_b57a6 th.col1 {
#   text-align: right;
# }
# #T_b57a6_row0_col0 {
#   text-align: left;
# }
# #T_b57a6_row0_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_b57a6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b57a6_level0_col0" class="col_heading level0 col0" >metric</th>
#       <th id="T_b57a6_level0_col1" class="col_heading level0 col1" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b57a6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b57a6_row0_col0" class="data row0 col0" >Goodness-of-fit (reduced χ²)</td>
#       <td id="T_b57a6_row0_col1" class="data row0 col1" >12.84</td>
#     </tr>
#   </tbody>
# </table>
