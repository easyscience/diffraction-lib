# %%
# Check whether easydiffraction is installed; install it if needed.
# Required for remote environments such as Google Colab.
import importlib.util

if importlib.util.find_spec('easydiffraction') is None:
    # %pip install easydiffraction

# %% [markdown]
# # Structure Refinement: LaM7O3, X-Ray
#
# In this example,  LaM7O3 (M = Ti, Cr, Mn, Fe, Co, Ni, Cu) structure is
# refined using synchrotron x-ray powder diffraction data. The example
# includes defining the structure and experiment, setting free
# parameters and constraints, performing Rietveld refinement, and
# plotting results.

# %% [markdown]
# ## Import Library

# %%
import easydiffraction as ed

# %% [markdown]
# ## Step 1: Define Project

# %% [markdown]
# First, we need to create a project object. The project is the main
# container for all structures, experiments, and analysis. It also
# manages saving and loading of data, and provides methods for plotting
# results. The project can be given a name and description for better
# organization.

# %%
project = ed.Project(
    name='hep7c',
    description='LaM7O3 structure refinement using X-ray data.',
)

# %% [markdown]
# Save the project to a desired location. This is necessary before
# running the fit, so that results can be saved to the project
# directory. The `temporary=False` argument ensures that the project is
# saved to a user defined location rather than a temporary directory.

# %%
project.save_as(f'{project.name}', temporary=False)
# Out:
# Saving project 📦 'hep7c' to
# /home/runner/work/diffraction-lib/diffraction-lib/docs/docs/tutorials/hep7c
# ├── 📄 project.cif
# ├── 📁 structures/
# ├── 📁 experiments/
# ├── 📁 analysis/
# │   └── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# ## Step 2: Define Structure

# %% [markdown]
# Second, we need to create a structure in the project. The structure
# will then be linked to the experiment in the next step. The structure
# can be defined in code, or loaded from an external CIF file. In this
# example, we define the structure in code.

# %%
project.structures.create(name='lam7o3')

# %% [markdown]
# Create an alias for the structure, to access its parameters in a more
# convenient way.

# %%
structure = project.structures['lam7o3']

# %% [markdown]
# Set space group. In this example, the space group is Pnma (No. 62),
# and the standard setting is used. The space group can be specified
# using the Hermann-Mauguin notation.
# If system code is not specified, the default setting is used.

# %%
structure.space_group.name_h_m = 'P n m a'
structure.space_group.it_coordinate_system_code = 'abc'

# %% [markdown]
# Set unit cell parameters. In this example, the unit cell is
# orthorhombic, and thus has three independent lengths (a, b, c) and all
# angles are 90 degrees.

# %%
structure.cell.length_a = 5.497532
structure.cell.length_b = 7.781902
structure.cell.length_c = 5.525117

# %% [markdown]
# Add atom sites to the structure, with their parameters. In this
# example, the structure contains 9 atom sites: La, Ti, Cr, Mn, Fe, Co,
# Ni, Cu, O1, and O2. The parameters include fractional coordinates,
# isotropic atomic displacement parameters (Biso), occupancy, and
# Wyckoff letters. Some parameters (e.g. occupancy) are not specified
# for all sites, and thus take default values.

# %%
structure.atom_sites.create(
    label='La',
    type_symbol='La',
    fract_x=0.48446,
    fract_y=0.25,
    fract_z=0.00021,
    wyckoff_letter='c',
    adp_type='Biso',
    adp_iso=1.30369,
)
structure.atom_sites.create(
    label='Ti',
    type_symbol='Ti',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    occupancy=0.14286,
    adp_type='Biso',
    adp_iso=1.10930,
)
structure.atom_sites.create(
    label='Cr',
    type_symbol='Cr',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    occupancy=0.14286,
    adp_type='Biso',
    adp_iso=1.10930,
)
structure.atom_sites.create(
    label='Mn',
    type_symbol='Mn',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    occupancy=0.14286,
    adp_type='Biso',
    adp_iso=1.10930,
)
structure.atom_sites.create(
    label='Fe',
    type_symbol='Fe',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    occupancy=0.14286,
    adp_type='Biso',
    adp_iso=1.10930,
)
structure.atom_sites.create(
    label='Co',
    type_symbol='Co',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    occupancy=0.14286,
    adp_type='Biso',
    adp_iso=1.10930,
)
structure.atom_sites.create(
    label='Ni',
    type_symbol='Ni',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    occupancy=0.14286,
    adp_type='Biso',
    adp_iso=1.10930,
)
structure.atom_sites.create(
    label='Cu',
    type_symbol='Cu',
    fract_x=0,
    fract_y=0,
    fract_z=0,
    wyckoff_letter='a',
    occupancy=0.14286,
    adp_type='Biso',
    adp_iso=1.10930,
)
structure.atom_sites.create(
    label='O1',
    type_symbol='O',
    fract_x=0.50628,
    fract_y=0.25,
    fract_z=0.54423,
    wyckoff_letter='c',
    adp_type='Biso',
    adp_iso=0.25033,
)
structure.atom_sites.create(
    label='O2',
    type_symbol='O',
    fract_x=0.21881,
    fract_y=0.05203,
    fract_z=0.25686,
    wyckoff_letter='d',
    adp_type='Biso',
    adp_iso=0.25033,
)

# %% [markdown]
# Show the structure in CIF format.

# %%
structure.show_as_cif()
# Out:
# Structure 🧩 'lam7o3' as cif
# <style type="text/css">
# #T_0e92e   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_0e92e thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_0e92e th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_0e92e  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_0e92e th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_0e92e tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_0e92e  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_0e92e th.col0 {
#   text-align: left;
# }
# #T_0e92e_row0_col0, #T_0e92e_row1_col0, #T_0e92e_row2_col0, #T_0e92e_row3_col0, #T_0e92e_row4_col0, #T_0e92e_row5_col0, #T_0e92e_row6_col0, #T_0e92e_row7_col0, #T_0e92e_row8_col0, #T_0e92e_row9_col0, #T_0e92e_row10_col0, #T_0e92e_row11_col0, #T_0e92e_row12_col0, #T_0e92e_row13_col0, #T_0e92e_row14_col0, #T_0e92e_row15_col0, #T_0e92e_row16_col0, #T_0e92e_row17_col0, #T_0e92e_row18_col0, #T_0e92e_row19_col0, #T_0e92e_row20_col0, #T_0e92e_row21_col0, #T_0e92e_row22_col0, #T_0e92e_row23_col0, #T_0e92e_row24_col0, #T_0e92e_row25_col0, #T_0e92e_row26_col0, #T_0e92e_row27_col0, #T_0e92e_row28_col0, #T_0e92e_row29_col0, #T_0e92e_row30_col0, #T_0e92e_row31_col0, #T_0e92e_row32_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_0e92e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e92e_level0_col0" class="col_heading level0 col0" >CIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e92e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_0e92e_row0_col0" class="data row0 col0" >data_lam7o3</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_0e92e_row1_col0" class="data row1 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_0e92e_row2_col0" class="data row2 col0" >_cell.length_a 5.49753200</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_0e92e_row3_col0" class="data row3 col0" >_cell.length_b 7.78190200</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_0e92e_row4_col0" class="data row4 col0" >_cell.length_c 5.52511700</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_0e92e_row5_col0" class="data row5 col0" >_cell.angle_alpha 90.00000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_0e92e_row6_col0" class="data row6 col0" >_cell.angle_beta 90.00000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_0e92e_row7_col0" class="data row7 col0" >_cell.angle_gamma 90.00000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_0e92e_row8_col0" class="data row8 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_0e92e_row9_col0" class="data row9 col0" >_space_group.name_H-M_alt "P n m a"</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_0e92e_row10_col0" class="data row10 col0" >_space_group.IT_coordinate_system_code abc</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_0e92e_row11_col0" class="data row11 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_0e92e_row12_col0" class="data row12 col0" >loop_</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_0e92e_row13_col0" class="data row13 col0" >_atom_site.label</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_0e92e_row14_col0" class="data row14 col0" >_atom_site.type_symbol</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_0e92e_row15_col0" class="data row15 col0" >_atom_site.fract_x</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_0e92e_row16_col0" class="data row16 col0" >_atom_site.fract_y</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_0e92e_row17_col0" class="data row17 col0" >_atom_site.fract_z</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_0e92e_row18_col0" class="data row18 col0" >_atom_site.Wyckoff_letter</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_0e92e_row19_col0" class="data row19 col0" >_atom_site.occupancy</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row20" class="row_heading level0 row20" >21</th>
#       <td id="T_0e92e_row20_col0" class="data row20 col0" >_atom_site.B_iso_or_equiv</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row21" class="row_heading level0 row21" >22</th>
#       <td id="T_0e92e_row21_col0" class="data row21 col0" >_atom_site.adp_type</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_0e92e_row22_col0" class="data row22 col0" >La La 0.48446000 0.25000000 0.00021000 c 1.00000000 1.30369000 Biso</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row23" class="row_heading level0 row23" >24</th>
#       <td id="T_0e92e_row23_col0" class="data row23 col0" >Ti Ti 0.00000000 0.00000000 0.00000000 a 0.14286000 1.10930000 Biso</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row24" class="row_heading level0 row24" >25</th>
#       <td id="T_0e92e_row24_col0" class="data row24 col0" >Cr Cr 0.00000000 0.00000000 0.00000000 a 0.14286000 1.10930000 Biso</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row25" class="row_heading level0 row25" >26</th>
#       <td id="T_0e92e_row25_col0" class="data row25 col0" >Mn Mn 0.00000000 0.00000000 0.00000000 a 0.14286000 1.10930000 Biso</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row26" class="row_heading level0 row26" >27</th>
#       <td id="T_0e92e_row26_col0" class="data row26 col0" >Fe Fe 0.00000000 0.00000000 0.00000000 a 0.14286000 1.10930000 Biso</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row27" class="row_heading level0 row27" >28</th>
#       <td id="T_0e92e_row27_col0" class="data row27 col0" >Co Co 0.00000000 0.00000000 0.00000000 a 0.14286000 1.10930000 Biso</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row28" class="row_heading level0 row28" >29</th>
#       <td id="T_0e92e_row28_col0" class="data row28 col0" >Ni Ni 0.00000000 0.00000000 0.00000000 a 0.14286000 1.10930000 Biso</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row29" class="row_heading level0 row29" >30</th>
#       <td id="T_0e92e_row29_col0" class="data row29 col0" >Cu Cu 0.00000000 0.00000000 0.00000000 a 0.14286000 1.10930000 Biso</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row30" class="row_heading level0 row30" >31</th>
#       <td id="T_0e92e_row30_col0" class="data row30 col0" >O1 O 0.50628000 0.25000000 0.54423000 c 1.00000000 0.25033000 Biso</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row31" class="row_heading level0 row31" >32</th>
#       <td id="T_0e92e_row31_col0" class="data row31 col0" >O2 O 0.21881000 0.05203000 0.25686000 d 1.00000000 0.25033000 Biso</td>
#     </tr>
#     <tr>
#       <th id="T_0e92e_level0_row32" class="row_heading level0 row32" >33</th>
#       <td id="T_0e92e_row32_col0" class="data row32 col0" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 3: Define Experiment

# %% [markdown]
# Third, we need to load the experimentally measured data from an
# external file. The data file is plain text, with two columns: the
# first column contains 2-theta values, and the second column contains
# the corresponding intensity values.
# If third column with standard uncertainties for the intensity values
# is absent, it will be automatically generated as the square root of
# the intensity values.

# %%
data_path = ed.download_data(id=32, destination='data')
# Out:
# Getting data...
# Data #32: LaM7O3, X-ray
# ✅ Data #32 downloaded to 'data/ed-32.dat'

# %% [markdown]
# Add an experiment to the project, using the measured data from the
# specified path. The radiation probe is set to 'xray' for this example.

# %%
project.experiments.add_from_data_path(
    name='xrd',
    data_path=data_path,
    radiation_probe='xray',
    sample_form='powder',
)
# Out:
# ⚠️ No uncertainty (sy) column provided. Defaulting to sqrt(y).
# Data loaded successfully
# Experiment 🔬 'xrd'. Number of data points: 9091.

# %% [markdown]
# Create an alias for the structure, to access its parameters in a more
# convenient way.

# %%
experiment = project.experiments['xrd']

# %% [markdown]
# Show all the public attributes and methods of the experiment object,
# which can be used to define the experiment and set parameters.

# %%
experiment.help()
# Out:
# Help for 'BraggPdExperiment'
# Properties
# <style type="text/css">
# #T_30e3e   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_30e3e thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_30e3e th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_30e3e  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_30e3e th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_30e3e tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_30e3e  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_30e3e th.col0 {
#   text-align: right;
# }
# #T_30e3e th.col1 {
#   text-align: left;
# }
# #T_30e3e th.col2 {
#   text-align: center;
# }
# #T_30e3e th.col3 {
#   text-align: left;
# }
# #T_30e3e_row0_col0, #T_30e3e_row1_col0, #T_30e3e_row2_col0, #T_30e3e_row3_col0, #T_30e3e_row4_col0, #T_30e3e_row5_col0, #T_30e3e_row6_col0, #T_30e3e_row7_col0, #T_30e3e_row8_col0, #T_30e3e_row9_col0, #T_30e3e_row10_col0, #T_30e3e_row11_col0, #T_30e3e_row12_col0, #T_30e3e_row13_col0, #T_30e3e_row14_col0, #T_30e3e_row15_col0, #T_30e3e_row16_col0 {
#   text-align: right;
# }
# #T_30e3e_row0_col1, #T_30e3e_row0_col3, #T_30e3e_row1_col1, #T_30e3e_row1_col3, #T_30e3e_row2_col1, #T_30e3e_row2_col3, #T_30e3e_row3_col1, #T_30e3e_row3_col3, #T_30e3e_row4_col1, #T_30e3e_row4_col3, #T_30e3e_row5_col1, #T_30e3e_row5_col3, #T_30e3e_row6_col1, #T_30e3e_row6_col3, #T_30e3e_row7_col1, #T_30e3e_row7_col3, #T_30e3e_row8_col1, #T_30e3e_row8_col3, #T_30e3e_row9_col1, #T_30e3e_row9_col3, #T_30e3e_row10_col1, #T_30e3e_row10_col3, #T_30e3e_row11_col1, #T_30e3e_row11_col3, #T_30e3e_row12_col1, #T_30e3e_row12_col3, #T_30e3e_row13_col1, #T_30e3e_row13_col3, #T_30e3e_row14_col1, #T_30e3e_row14_col3, #T_30e3e_row15_col1, #T_30e3e_row15_col3, #T_30e3e_row16_col1, #T_30e3e_row16_col3 {
#   text-align: left;
# }
# #T_30e3e_row0_col2, #T_30e3e_row1_col2, #T_30e3e_row2_col2, #T_30e3e_row3_col2, #T_30e3e_row4_col2, #T_30e3e_row5_col2, #T_30e3e_row6_col2, #T_30e3e_row7_col2, #T_30e3e_row8_col2, #T_30e3e_row9_col2, #T_30e3e_row10_col2, #T_30e3e_row11_col2, #T_30e3e_row12_col2, #T_30e3e_row13_col2, #T_30e3e_row14_col2, #T_30e3e_row15_col2, #T_30e3e_row16_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_30e3e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30e3e_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_30e3e_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_30e3e_level0_col2" class="col_heading level0 col2" >Writable</th>
#       <th id="T_30e3e_level0_col3" class="col_heading level0 col3" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30e3e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_30e3e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_30e3e_row0_col1" class="data row0 col1" >as_cif</td>
#       <td id="T_30e3e_row0_col2" class="data row0 col2" >✗</td>
#       <td id="T_30e3e_row0_col3" class="data row0 col3" >Serialize this experiment to a CIF fragment.</td>
#     </tr>
#     <tr>
#       <th id="T_30e3e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_30e3e_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_30e3e_row1_col1" class="data row1 col1" >background</td>
#       <td id="T_30e3e_row1_col2" class="data row1 col2" >✗</td>
#       <td id="T_30e3e_row1_col3" class="data row1 col3" >Active background model for this experiment.</td>
#     </tr>
#     <tr>
#       <th id="T_30e3e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_30e3e_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_30e3e_row2_col1" class="data row2 col1" >background_type</td>
#       <td id="T_30e3e_row2_col2" class="data row2 col2" >✓</td>
#       <td id="T_30e3e_row2_col3" class="data row2 col3" >Current background type enum value.</td>
#     </tr>
#     <tr>
#       <th id="T_30e3e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_30e3e_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_30e3e_row3_col1" class="data row3 col1" >calculator</td>
#       <td id="T_30e3e_row3_col2" class="data row3 col2" >✗</td>
#       <td id="T_30e3e_row3_col3" class="data row3 col3" >The active calculator instance for this experiment.</td>
#     </tr>
#     <tr>
#       <th id="T_30e3e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_30e3e_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_30e3e_row4_col1" class="data row4 col1" >calculator_type</td>
#       <td id="T_30e3e_row4_col2" class="data row4 col2" >✓</td>
#       <td id="T_30e3e_row4_col3" class="data row4 col3" >Tag of the active calculator backend (e.g. ``'cryspy'``).</td>
#     </tr>
#     <tr>
#       <th id="T_30e3e_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_30e3e_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_30e3e_row5_col1" class="data row5 col1" >categories</td>
#       <td id="T_30e3e_row5_col2" class="data row5 col2" >✗</td>
#       <td id="T_30e3e_row5_col3" class="data row5 col3" >All category objects in this datablock by priority.</td>
#     </tr>
#     <tr>
#       <th id="T_30e3e_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_30e3e_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_30e3e_row6_col1" class="data row6 col1" >data</td>
#       <td id="T_30e3e_row6_col2" class="data row6 col2" >✗</td>
#       <td id="T_30e3e_row6_col3" class="data row6 col3" >Data collection for this experiment.</td>
#     </tr>
#     <tr>
#       <th id="T_30e3e_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_30e3e_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_30e3e_row7_col1" class="data row7 col1" >diffrn</td>
#       <td id="T_30e3e_row7_col2" class="data row7 col2" >✗</td>
#       <td id="T_30e3e_row7_col3" class="data row7 col3" >Ambient conditions recorded during measurement.</td>
#     </tr>
#     <tr>
#       <th id="T_30e3e_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_30e3e_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_30e3e_row8_col1" class="data row8 col1" >excluded_regions</td>
#       <td id="T_30e3e_row8_col2" class="data row8 col2" >✗</td>
#       <td id="T_30e3e_row8_col3" class="data row8 col3" >Collection of excluded regions for the x-grid.</td>
#     </tr>
#     <tr>
#       <th id="T_30e3e_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_30e3e_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_30e3e_row9_col1" class="data row9 col1" >instrument</td>
#       <td id="T_30e3e_row9_col2" class="data row9 col2" >✗</td>
#       <td id="T_30e3e_row9_col3" class="data row9 col3" >Active instrument model for this experiment.</td>
#     </tr>
#     <tr>
#       <th id="T_30e3e_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_30e3e_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_30e3e_row10_col1" class="data row10 col1" >linked_phases</td>
#       <td id="T_30e3e_row10_col2" class="data row10 col2" >✗</td>
#       <td id="T_30e3e_row10_col3" class="data row10 col3" >Collection of phases linked to this experiment.</td>
#     </tr>
#     <tr>
#       <th id="T_30e3e_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_30e3e_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_30e3e_row11_col1" class="data row11 col1" >name</td>
#       <td id="T_30e3e_row11_col2" class="data row11 col2" >✓</td>
#       <td id="T_30e3e_row11_col3" class="data row11 col3" >Human-readable name of the experiment.</td>
#     </tr>
#     <tr>
#       <th id="T_30e3e_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_30e3e_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_30e3e_row12_col1" class="data row12 col1" >parameters</td>
#       <td id="T_30e3e_row12_col2" class="data row12 col2" >✗</td>
#       <td id="T_30e3e_row12_col3" class="data row12 col3" >All parameters from all categories in this datablock.</td>
#     </tr>
#     <tr>
# Methods
# <style type="text/css">
# #T_ce4f8   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_ce4f8 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_ce4f8 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_ce4f8  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_ce4f8 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_ce4f8 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_ce4f8  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_ce4f8 th.col0 {
#   text-align: right;
# }
# #T_ce4f8 th.col1 {
#   text-align: left;
# }
# #T_ce4f8 th.col2 {
#   text-align: left;
# }
# #T_ce4f8_row0_col0, #T_ce4f8_row1_col0, #T_ce4f8_row2_col0, #T_ce4f8_row3_col0, #T_ce4f8_row4_col0, #T_ce4f8_row5_col0, #T_ce4f8_row6_col0, #T_ce4f8_row7_col0 {
#   text-align: right;
# }
# #T_ce4f8_row0_col1, #T_ce4f8_row0_col2, #T_ce4f8_row1_col1, #T_ce4f8_row1_col2, #T_ce4f8_row2_col1, #T_ce4f8_row2_col2, #T_ce4f8_row3_col1, #T_ce4f8_row3_col2, #T_ce4f8_row4_col1, #T_ce4f8_row4_col2, #T_ce4f8_row5_col1, #T_ce4f8_row5_col2, #T_ce4f8_row6_col1, #T_ce4f8_row6_col2, #T_ce4f8_row7_col1, #T_ce4f8_row7_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_ce4f8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce4f8_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_ce4f8_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_ce4f8_level0_col2" class="col_heading level0 col2" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce4f8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ce4f8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ce4f8_row0_col1" class="data row0 col1" >help()</td>
#       <td id="T_ce4f8_row0_col2" class="data row0 col2" >Print a summary of public attributes and categories.</td>
#     </tr>
#     <tr>
#       <th id="T_ce4f8_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ce4f8_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ce4f8_row1_col1" class="data row1 col1" >show_as_cif()</td>
#       <td id="T_ce4f8_row1_col2" class="data row1 col2" >Pretty-print the experiment as CIF text.</td>
#     </tr>
#     <tr>
#       <th id="T_ce4f8_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_ce4f8_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ce4f8_row2_col1" class="data row2 col1" >show_current_background_type()</td>
#       <td id="T_ce4f8_row2_col2" class="data row2 col2" >Print the currently used background type.</td>
#     </tr>
#     <tr>
#       <th id="T_ce4f8_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ce4f8_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ce4f8_row3_col1" class="data row3 col1" >show_current_calculator_type()</td>
#       <td id="T_ce4f8_row3_col2" class="data row3 col2" >Print the name of the currently active calculator.</td>
#     </tr>
#     <tr>
#       <th id="T_ce4f8_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_ce4f8_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_ce4f8_row4_col1" class="data row4 col1" >show_current_peak_profile_type()</td>
#       <td id="T_ce4f8_row4_col2" class="data row4 col2" >Print the currently selected peak profile type.</td>
#     </tr>
#     <tr>
#       <th id="T_ce4f8_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_ce4f8_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_ce4f8_row5_col1" class="data row5 col1" >show_supported_background_types()</td>
#       <td id="T_ce4f8_row5_col2" class="data row5 col2" >Print a table of supported background types.</td>
#     </tr>
#     <tr>
#       <th id="T_ce4f8_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_ce4f8_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_ce4f8_row6_col1" class="data row6 col1" >show_supported_calculator_types()</td>
#       <td id="T_ce4f8_row6_col2" class="data row6 col2" >Print a table of supported calculator backends.</td>
#     </tr>
#     <tr>
#       <th id="T_ce4f8_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_ce4f8_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_ce4f8_row7_col1" class="data row7 col1" >show_supported_peak_profile_types()</td>
#       <td id="T_ce4f8_row7_col2" class="data row7 col2" >Print available peak profile types for this experiment.</td>
#     </tr>
#   </tbody>
# </table>
# Categories
# <style type="text/css">
# #T_10ede   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_10ede thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_10ede th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_10ede  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_10ede th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_10ede tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_10ede  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_10ede th.col0 {
#   text-align: left;
# }
# #T_10ede th.col1 {
#   text-align: left;
# }
# #T_10ede th.col2 {
#   text-align: right;
# }
# #T_10ede_row0_col0, #T_10ede_row0_col1, #T_10ede_row1_col0, #T_10ede_row1_col1, #T_10ede_row2_col0, #T_10ede_row2_col1, #T_10ede_row3_col0, #T_10ede_row3_col1, #T_10ede_row4_col0, #T_10ede_row4_col1, #T_10ede_row5_col0, #T_10ede_row5_col1, #T_10ede_row6_col0, #T_10ede_row6_col1, #T_10ede_row7_col0, #T_10ede_row7_col1 {
#   text-align: left;
# }
# #T_10ede_row0_col2, #T_10ede_row1_col2, #T_10ede_row2_col2, #T_10ede_row3_col2, #T_10ede_row4_col2, #T_10ede_row5_col2, #T_10ede_row6_col2, #T_10ede_row7_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_10ede" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10ede_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_10ede_level0_col1" class="col_heading level0 col1" >Type</th>
#       <th id="T_10ede_level0_col2" class="col_heading level0 col2" ># Parameters</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10ede_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_10ede_row0_col0" class="data row0 col0" >expt_type</td>
#       <td id="T_10ede_row0_col1" class="data row0 col1" >ExperimentType</td>
#       <td id="T_10ede_row0_col2" class="data row0 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_10ede_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_10ede_row1_col0" class="data row1 col0" >diffrn</td>
#       <td id="T_10ede_row1_col1" class="data row1 col1" >DefaultDiffrn</td>
#       <td id="T_10ede_row1_col2" class="data row1 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_10ede_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_10ede_row2_col0" class="data row2 col0" >LinkedPhases</td>
#       <td id="T_10ede_row2_col1" class="data row2 col1" >LinkedPhases</td>
#       <td id="T_10ede_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_10ede_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_10ede_row3_col0" class="data row3 col0" >ExcludedRegions</td>
#       <td id="T_10ede_row3_col1" class="data row3 col1" >ExcludedRegions</td>
#       <td id="T_10ede_row3_col2" class="data row3 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_10ede_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_10ede_row4_col0" class="data row4 col0" >peak</td>
#       <td id="T_10ede_row4_col1" class="data row4 col1" >CwlPseudoVoigt</td>
#       <td id="T_10ede_row4_col2" class="data row4 col2" >6</td>
#     </tr>
#     <tr>
#       <th id="T_10ede_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_10ede_row5_col0" class="data row5 col0" >instrument</td>
#       <td id="T_10ede_row5_col1" class="data row5 col1" >CwlPdInstrument</td>
#       <td id="T_10ede_row5_col2" class="data row5 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_10ede_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_10ede_row6_col0" class="data row6 col0" >LineSegmentBackground</td>
#       <td id="T_10ede_row6_col1" class="data row6 col1" >LineSegmentBackground</td>
#       <td id="T_10ede_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_10ede_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_10ede_row7_col0" class="data row7 col0" >PdCwlData</td>
#       <td id="T_10ede_row7_col1" class="data row7 col1" >PdCwlData</td>
#       <td id="T_10ede_row7_col2" class="data row7 col2" >72728</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Link the structure to the experiment and set its scale factor.

# %%
experiment.linked_phases.create(id='lam7o3', scale=0.35960e-02)

# %% [markdown]
# Show all the public attributes and methods of the linked_phases
# category of the experiment object. The same help method can also be
# used for other categories, defined below.

# %%
experiment.linked_phases.help()
# Out:
# Help for 'LinkedPhases'
# Properties
# <style type="text/css">
# #T_5b7c5   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_5b7c5 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_5b7c5 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_5b7c5  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_5b7c5 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_5b7c5 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_5b7c5  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_5b7c5 th.col0 {
#   text-align: right;
# }
# #T_5b7c5 th.col1 {
#   text-align: left;
# }
# #T_5b7c5 th.col2 {
#   text-align: center;
# }
# #T_5b7c5 th.col3 {
#   text-align: left;
# }
# #T_5b7c5_row0_col0, #T_5b7c5_row1_col0, #T_5b7c5_row2_col0, #T_5b7c5_row3_col0 {
#   text-align: right;
# }
# #T_5b7c5_row0_col1, #T_5b7c5_row0_col3, #T_5b7c5_row1_col1, #T_5b7c5_row1_col3, #T_5b7c5_row2_col1, #T_5b7c5_row2_col3, #T_5b7c5_row3_col1, #T_5b7c5_row3_col3 {
#   text-align: left;
# }
# #T_5b7c5_row0_col2, #T_5b7c5_row1_col2, #T_5b7c5_row2_col2, #T_5b7c5_row3_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_5b7c5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b7c5_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_5b7c5_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_5b7c5_level0_col2" class="col_heading level0 col2" >Writable</th>
#       <th id="T_5b7c5_level0_col3" class="col_heading level0 col3" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b7c5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5b7c5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5b7c5_row0_col1" class="data row0 col1" >as_cif</td>
#       <td id="T_5b7c5_row0_col2" class="data row0 col2" >✗</td>
#       <td id="T_5b7c5_row0_col3" class="data row0 col3" >Return CIF representation of this object.</td>
#     </tr>
#     <tr>
#       <th id="T_5b7c5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_5b7c5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_5b7c5_row1_col1" class="data row1 col1" >names</td>
#       <td id="T_5b7c5_row1_col2" class="data row1 col2" >✗</td>
#       <td id="T_5b7c5_row1_col3" class="data row1 col3" >List of all item keys in the collection.</td>
#     </tr>
#     <tr>
#       <th id="T_5b7c5_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_5b7c5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_5b7c5_row2_col1" class="data row2 col1" >parameters</td>
#       <td id="T_5b7c5_row2_col2" class="data row2 col2" >✗</td>
#       <td id="T_5b7c5_row2_col3" class="data row2 col3" >All parameters from all items in this collection.</td>
#     </tr>
#     <tr>
#       <th id="T_5b7c5_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_5b7c5_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_5b7c5_row3_col1" class="data row3 col1" >unique_name</td>
#       <td id="T_5b7c5_row3_col2" class="data row3 col2" >✗</td>
#       <td id="T_5b7c5_row3_col3" class="data row3 col3" >Return None; collections have no unique name.</td>
#     </tr>
#   </tbody>
# </table>
# Methods
# <style type="text/css">
# #T_768ea   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_768ea thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_768ea th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_768ea  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_768ea th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_768ea tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_768ea  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_768ea th.col0 {
#   text-align: right;
# }
# #T_768ea th.col1 {
#   text-align: left;
# }
# #T_768ea th.col2 {
#   text-align: left;
# }
# #T_768ea_row0_col0, #T_768ea_row1_col0, #T_768ea_row2_col0, #T_768ea_row3_col0, #T_768ea_row4_col0, #T_768ea_row5_col0, #T_768ea_row6_col0, #T_768ea_row7_col0 {
#   text-align: right;
# }
# #T_768ea_row0_col1, #T_768ea_row0_col2, #T_768ea_row1_col1, #T_768ea_row1_col2, #T_768ea_row2_col1, #T_768ea_row2_col2, #T_768ea_row3_col1, #T_768ea_row3_col2, #T_768ea_row4_col1, #T_768ea_row4_col2, #T_768ea_row5_col1, #T_768ea_row5_col2, #T_768ea_row6_col1, #T_768ea_row6_col2, #T_768ea_row7_col1, #T_768ea_row7_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_768ea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_768ea_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_768ea_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_768ea_level0_col2" class="col_heading level0 col2" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_768ea_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_768ea_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_768ea_row0_col1" class="data row0 col1" >add()</td>
#       <td id="T_768ea_row0_col2" class="data row0 col2" >Insert or replace a pre-built item into the collection.</td>
#     </tr>
#     <tr>
#       <th id="T_768ea_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_768ea_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_768ea_row1_col1" class="data row1 col1" >create()</td>
#       <td id="T_768ea_row1_col2" class="data row1 col2" >Create a new item with the given attributes and add it.</td>
#     </tr>
#     <tr>
#       <th id="T_768ea_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_768ea_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_768ea_row2_col1" class="data row2 col1" >from_cif()</td>
#       <td id="T_768ea_row2_col2" class="data row2 col2" >Populate this collection from a CIF block.</td>
#     </tr>
#     <tr>
#       <th id="T_768ea_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_768ea_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_768ea_row3_col1" class="data row3 col1" >help()</td>
#       <td id="T_768ea_row3_col2" class="data row3 col2" >Print a summary of public attributes and contained items.</td>
#     </tr>
#     <tr>
#       <th id="T_768ea_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_768ea_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_768ea_row4_col1" class="data row4 col1" >items()</td>
#       <td id="T_768ea_row4_col2" class="data row4 col2" >Yield ``(key, item)`` pairs in insertion order.</td>
#     </tr>
#     <tr>
#       <th id="T_768ea_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_768ea_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_768ea_row5_col1" class="data row5 col1" >keys()</td>
#       <td id="T_768ea_row5_col2" class="data row5 col2" >Yield keys for all items in insertion order.</td>
#     </tr>
#     <tr>
#       <th id="T_768ea_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_768ea_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_768ea_row6_col1" class="data row6 col1" >remove()</td>
#       <td id="T_768ea_row6_col2" class="data row6 col2" >Remove an item by its key.</td>
#     </tr>
#     <tr>
#       <th id="T_768ea_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_768ea_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_768ea_row7_col1" class="data row7 col1" >values()</td>
#       <td id="T_768ea_row7_col2" class="data row7 col2" >Yield items in insertion order.</td>
#     </tr>
#   </tbody>
# </table>
# Items (1)
# <style type="text/css">
# #T_7e9aa   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_7e9aa thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_7e9aa th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7e9aa  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7e9aa th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_7e9aa tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_7e9aa  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_7e9aa th.col0 {
#   text-align: right;
# }
# #T_7e9aa th.col1 {
#   text-align: left;
# }
# #T_7e9aa th.col2 {
#   text-align: left;
# }
# #T_7e9aa_row0_col0 {
#   text-align: right;
# }
# #T_7e9aa_row0_col1, #T_7e9aa_row0_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_7e9aa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e9aa_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_7e9aa_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_7e9aa_level0_col2" class="col_heading level0 col2" >Access</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e9aa_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7e9aa_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7e9aa_row0_col1" class="data row0 col1" >lam7o3</td>
#       <td id="T_7e9aa_row0_col2" class="data row0 col2" >['lam7o3']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Set instrumental parameters. In this example, the wavelength and
# 2-theta offset are set.

# %%
experiment.instrument.setup_wavelength = 1.54056
experiment.instrument.calib_twotheta_offset = 0.048

# %% [markdown]
# Set peak shape parameters. In this example, a pseudo-Voigt profile is
# used, with Gaussian and Lorentzian contributions to the peak
# broadening.

# %%
experiment.show_current_peak_profile_type()
# Out:
# Current peak profile type
# pseudo-voigt

# %%
experiment.show_supported_peak_profile_types()
# Out:
# Supported types
# <style type="text/css">
# #T_75335   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_75335 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_75335 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_75335  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_75335 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_75335 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_75335  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_75335 th.col0 {
#   text-align: left;
# }
# #T_75335 th.col1 {
#   text-align: left;
# }
# #T_75335_row0_col0, #T_75335_row0_col1, #T_75335_row1_col0, #T_75335_row1_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_75335" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75335_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_75335_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75335_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_75335_row0_col0" class="data row0 col0" >pseudo-voigt</td>
#       <td id="T_75335_row0_col1" class="data row0 col1" >Pseudo-Voigt profile</td>
#     </tr>
#     <tr>
#       <th id="T_75335_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_75335_row1_col0" class="data row1 col0" >pseudo-voigt + empirical asymmetry</td>
#       <td id="T_75335_row1_col1" class="data row1 col1" >Pseudo-Voigt with empirical asymmetry correction</td>
#     </tr>
#   </tbody>
# </table>

# %%
experiment.peak.help()
# Out:
# Help for 'CwlPseudoVoigt'
# Parameters
# <style type="text/css">
# #T_03d2b   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_03d2b thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_03d2b th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_03d2b  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_03d2b th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_03d2b tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_03d2b  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_03d2b th.col0 {
#   text-align: right;
# }
# #T_03d2b th.col1 {
#   text-align: left;
# }
# #T_03d2b th.col2 {
#   text-align: left;
# }
# #T_03d2b th.col3 {
#   text-align: right;
# }
# #T_03d2b th.col4 {
#   text-align: center;
# }
# #T_03d2b th.col5 {
#   text-align: left;
# }
# #T_03d2b_row0_col0, #T_03d2b_row0_col3, #T_03d2b_row1_col0, #T_03d2b_row1_col3, #T_03d2b_row2_col0, #T_03d2b_row2_col3, #T_03d2b_row3_col0, #T_03d2b_row3_col3, #T_03d2b_row4_col0, #T_03d2b_row4_col3, #T_03d2b_row5_col0, #T_03d2b_row5_col3 {
#   text-align: right;
# }
# #T_03d2b_row0_col1, #T_03d2b_row0_col2, #T_03d2b_row0_col5, #T_03d2b_row1_col1, #T_03d2b_row1_col2, #T_03d2b_row1_col5, #T_03d2b_row2_col1, #T_03d2b_row2_col2, #T_03d2b_row2_col5, #T_03d2b_row3_col1, #T_03d2b_row3_col2, #T_03d2b_row3_col5, #T_03d2b_row4_col1, #T_03d2b_row4_col2, #T_03d2b_row4_col5, #T_03d2b_row5_col1, #T_03d2b_row5_col2, #T_03d2b_row5_col5 {
#   text-align: left;
# }
# #T_03d2b_row0_col4, #T_03d2b_row1_col4, #T_03d2b_row2_col4, #T_03d2b_row3_col4, #T_03d2b_row4_col4, #T_03d2b_row5_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_03d2b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03d2b_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_03d2b_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_03d2b_level0_col2" class="col_heading level0 col2" >Type</th>
#       <th id="T_03d2b_level0_col3" class="col_heading level0 col3" >Value</th>
#       <th id="T_03d2b_level0_col4" class="col_heading level0 col4" >Writable</th>
#       <th id="T_03d2b_level0_col5" class="col_heading level0 col5" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03d2b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_03d2b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_03d2b_row0_col1" class="data row0 col1" >broad_gauss_u</td>
#       <td id="T_03d2b_row0_col2" class="data row0 col2" >numeric</td>
#       <td id="T_03d2b_row0_col3" class="data row0 col3" >0.01</td>
#       <td id="T_03d2b_row0_col4" class="data row0 col4" >✓</td>
#       <td id="T_03d2b_row0_col5" class="data row0 col5" >Gaussian broadening from sample size and resolution</td>
#     </tr>
#     <tr>
#       <th id="T_03d2b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_03d2b_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_03d2b_row1_col1" class="data row1 col1" >broad_gauss_v</td>
#       <td id="T_03d2b_row1_col2" class="data row1 col2" >numeric</td>
#       <td id="T_03d2b_row1_col3" class="data row1 col3" >-0.01</td>
#       <td id="T_03d2b_row1_col4" class="data row1 col4" >✓</td>
#       <td id="T_03d2b_row1_col5" class="data row1 col5" >Gaussian broadening instrumental contribution</td>
#     </tr>
#     <tr>
#       <th id="T_03d2b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_03d2b_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_03d2b_row2_col1" class="data row2 col1" >broad_gauss_w</td>
#       <td id="T_03d2b_row2_col2" class="data row2 col2" >numeric</td>
#       <td id="T_03d2b_row2_col3" class="data row2 col3" >0.02</td>
#       <td id="T_03d2b_row2_col4" class="data row2 col4" >✓</td>
#       <td id="T_03d2b_row2_col5" class="data row2 col5" >Gaussian broadening instrumental contribution</td>
#     </tr>
#     <tr>
#       <th id="T_03d2b_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_03d2b_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_03d2b_row3_col1" class="data row3 col1" >broad_lorentz_x</td>
#       <td id="T_03d2b_row3_col2" class="data row3 col2" >numeric</td>
#       <td id="T_03d2b_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_03d2b_row3_col4" class="data row3 col4" >✓</td>
#       <td id="T_03d2b_row3_col5" class="data row3 col5" >Lorentzian broadening from sample strain effects</td>
#     </tr>
#     <tr>
#       <th id="T_03d2b_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_03d2b_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_03d2b_row4_col1" class="data row4 col1" >broad_lorentz_y</td>
#       <td id="T_03d2b_row4_col2" class="data row4 col2" >numeric</td>
#       <td id="T_03d2b_row4_col3" class="data row4 col3" >0.0</td>
#       <td id="T_03d2b_row4_col4" class="data row4 col4" >✓</td>
#       <td id="T_03d2b_row4_col5" class="data row4 col5" >Lorentzian broadening from microstructural defects</td>
#     </tr>
#     <tr>
#       <th id="T_03d2b_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_03d2b_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_03d2b_row5_col1" class="data row5 col1" >profile_type</td>
#       <td id="T_03d2b_row5_col2" class="data row5 col2" >string</td>
#       <td id="T_03d2b_row5_col3" class="data row5 col3" >pseudo-voigt</td>
#       <td id="T_03d2b_row5_col4" class="data row5 col4" >✗</td>
#       <td id="T_03d2b_row5_col5" class="data row5 col5" >Active peak profile type tag</td>
#     </tr>
#   </tbody>
# </table>
# Other properties
# <style type="text/css">
# #T_57d09   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_57d09 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_57d09 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_57d09  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_57d09 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_57d09 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_57d09  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_57d09 th.col0 {
#   text-align: right;
# }
# #T_57d09 th.col1 {
#   text-align: left;
# }
# #T_57d09 th.col2 {
#   text-align: center;
# }
# #T_57d09 th.col3 {
#   text-align: left;
# }
# #T_57d09_row0_col0, #T_57d09_row1_col0, #T_57d09_row2_col0 {
#   text-align: right;
# }
# #T_57d09_row0_col1, #T_57d09_row0_col3, #T_57d09_row1_col1, #T_57d09_row1_col3, #T_57d09_row2_col1, #T_57d09_row2_col3 {
#   text-align: left;
# }
# #T_57d09_row0_col2, #T_57d09_row1_col2, #T_57d09_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_57d09" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57d09_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_57d09_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_57d09_level0_col2" class="col_heading level0 col2" >Writable</th>
#       <th id="T_57d09_level0_col3" class="col_heading level0 col3" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57d09_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_57d09_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_57d09_row0_col1" class="data row0 col1" >as_cif</td>
#       <td id="T_57d09_row0_col2" class="data row0 col2" >✗</td>
#       <td id="T_57d09_row0_col3" class="data row0 col3" >Return CIF representation of this object.</td>
#     </tr>
#     <tr>
#       <th id="T_57d09_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_57d09_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_57d09_row1_col1" class="data row1 col1" >parameters</td>
#       <td id="T_57d09_row1_col2" class="data row1 col2" >✗</td>
#       <td id="T_57d09_row1_col3" class="data row1 col3" >All GenericDescriptorBase instances on this item.</td>
#     </tr>
#     <tr>
#       <th id="T_57d09_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_57d09_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_57d09_row2_col1" class="data row2 col1" >unique_name</td>
#       <td id="T_57d09_row2_col2" class="data row2 col2" >✗</td>
#       <td id="T_57d09_row2_col3" class="data row2 col3" >Fully qualified name: datablock, category, entry.</td>
#     </tr>
#   </tbody>
# </table>
# Methods
# <style type="text/css">
# #T_b36a3   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_b36a3 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_b36a3 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_b36a3  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_b36a3 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_b36a3 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_b36a3  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_b36a3 th.col0 {
#   text-align: right;
# }
# #T_b36a3 th.col1 {
#   text-align: left;
# }
# #T_b36a3 th.col2 {
#   text-align: left;
# }
# #T_b36a3_row0_col0, #T_b36a3_row1_col0 {
#   text-align: right;
# }
# #T_b36a3_row0_col1, #T_b36a3_row0_col2, #T_b36a3_row1_col1, #T_b36a3_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_b36a3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b36a3_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_b36a3_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_b36a3_level0_col2" class="col_heading level0 col2" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b36a3_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b36a3_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b36a3_row0_col1" class="data row0 col1" >from_cif()</td>
#       <td id="T_b36a3_row0_col2" class="data row0 col2" >Populate this item from a CIF block.</td>
#     </tr>
#     <tr>
#       <th id="T_b36a3_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b36a3_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_b36a3_row1_col1" class="data row1 col1" >help()</td>
#       <td id="T_b36a3_row1_col2" class="data row1 col2" >Print parameters, other properties, and methods.</td>
#     </tr>
#   </tbody>
# </table>

# %%
experiment.peak_profile_type = 'pseudo-voigt + empirical asymmetry'
# Out:
# ⚠️ Switching peak profile type discards existing peak parameters.
# Peak profile type for experiment 'xrd' changed to
# pseudo-voigt + empirical asymmetry

# %%
experiment.peak.help()
# Out:
# Help for 'CwlPseudoVoigtEmpiricalAsymmetry'
# Parameters
# <style type="text/css">
# #T_a0f53   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_a0f53 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_a0f53 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a0f53  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a0f53 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_a0f53 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_a0f53  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_a0f53 th.col0 {
#   text-align: right;
# }
# #T_a0f53 th.col1 {
#   text-align: left;
# }
# #T_a0f53 th.col2 {
#   text-align: left;
# }
# #T_a0f53 th.col3 {
#   text-align: right;
# }
# #T_a0f53 th.col4 {
#   text-align: center;
# }
# #T_a0f53 th.col5 {
#   text-align: left;
# }
# #T_a0f53_row0_col0, #T_a0f53_row0_col3, #T_a0f53_row1_col0, #T_a0f53_row1_col3, #T_a0f53_row2_col0, #T_a0f53_row2_col3, #T_a0f53_row3_col0, #T_a0f53_row3_col3, #T_a0f53_row4_col0, #T_a0f53_row4_col3, #T_a0f53_row5_col0, #T_a0f53_row5_col3, #T_a0f53_row6_col0, #T_a0f53_row6_col3, #T_a0f53_row7_col0, #T_a0f53_row7_col3, #T_a0f53_row8_col0, #T_a0f53_row8_col3, #T_a0f53_row9_col0, #T_a0f53_row9_col3 {
#   text-align: right;
# }
# #T_a0f53_row0_col1, #T_a0f53_row0_col2, #T_a0f53_row0_col5, #T_a0f53_row1_col1, #T_a0f53_row1_col2, #T_a0f53_row1_col5, #T_a0f53_row2_col1, #T_a0f53_row2_col2, #T_a0f53_row2_col5, #T_a0f53_row3_col1, #T_a0f53_row3_col2, #T_a0f53_row3_col5, #T_a0f53_row4_col1, #T_a0f53_row4_col2, #T_a0f53_row4_col5, #T_a0f53_row5_col1, #T_a0f53_row5_col2, #T_a0f53_row5_col5, #T_a0f53_row6_col1, #T_a0f53_row6_col2, #T_a0f53_row6_col5, #T_a0f53_row7_col1, #T_a0f53_row7_col2, #T_a0f53_row7_col5, #T_a0f53_row8_col1, #T_a0f53_row8_col2, #T_a0f53_row8_col5, #T_a0f53_row9_col1, #T_a0f53_row9_col2, #T_a0f53_row9_col5 {
#   text-align: left;
# }
# #T_a0f53_row0_col4, #T_a0f53_row1_col4, #T_a0f53_row2_col4, #T_a0f53_row3_col4, #T_a0f53_row4_col4, #T_a0f53_row5_col4, #T_a0f53_row6_col4, #T_a0f53_row7_col4, #T_a0f53_row8_col4, #T_a0f53_row9_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_a0f53" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0f53_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_a0f53_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_a0f53_level0_col2" class="col_heading level0 col2" >Type</th>
#       <th id="T_a0f53_level0_col3" class="col_heading level0 col3" >Value</th>
#       <th id="T_a0f53_level0_col4" class="col_heading level0 col4" >Writable</th>
#       <th id="T_a0f53_level0_col5" class="col_heading level0 col5" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0f53_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a0f53_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a0f53_row0_col1" class="data row0 col1" >asym_empir_1</td>
#       <td id="T_a0f53_row0_col2" class="data row0 col2" >numeric</td>
#       <td id="T_a0f53_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_a0f53_row0_col4" class="data row0 col4" >✓</td>
#       <td id="T_a0f53_row0_col5" class="data row0 col5" >Empirical asymmetry coefficient p1</td>
#     </tr>
#     <tr>
#       <th id="T_a0f53_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a0f53_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a0f53_row1_col1" class="data row1 col1" >asym_empir_2</td>
#       <td id="T_a0f53_row1_col2" class="data row1 col2" >numeric</td>
#       <td id="T_a0f53_row1_col3" class="data row1 col3" >0.0</td>
#       <td id="T_a0f53_row1_col4" class="data row1 col4" >✓</td>
#       <td id="T_a0f53_row1_col5" class="data row1 col5" >Empirical asymmetry coefficient p2</td>
#     </tr>
#     <tr>
#       <th id="T_a0f53_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a0f53_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a0f53_row2_col1" class="data row2 col1" >asym_empir_3</td>
#       <td id="T_a0f53_row2_col2" class="data row2 col2" >numeric</td>
#       <td id="T_a0f53_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_a0f53_row2_col4" class="data row2 col4" >✓</td>
#       <td id="T_a0f53_row2_col5" class="data row2 col5" >Empirical asymmetry coefficient p3</td>
#     </tr>
#     <tr>
#       <th id="T_a0f53_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a0f53_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_a0f53_row3_col1" class="data row3 col1" >asym_empir_4</td>
#       <td id="T_a0f53_row3_col2" class="data row3 col2" >numeric</td>
#       <td id="T_a0f53_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_a0f53_row3_col4" class="data row3 col4" >✓</td>
#       <td id="T_a0f53_row3_col5" class="data row3 col5" >Empirical asymmetry coefficient p4</td>
#     </tr>
#     <tr>
#       <th id="T_a0f53_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_a0f53_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a0f53_row4_col1" class="data row4 col1" >broad_gauss_u</td>
#       <td id="T_a0f53_row4_col2" class="data row4 col2" >numeric</td>
#       <td id="T_a0f53_row4_col3" class="data row4 col3" >0.01</td>
#       <td id="T_a0f53_row4_col4" class="data row4 col4" >✓</td>
#       <td id="T_a0f53_row4_col5" class="data row4 col5" >Gaussian broadening from sample size and resolution</td>
#     </tr>
#     <tr>
#       <th id="T_a0f53_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_a0f53_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_a0f53_row5_col1" class="data row5 col1" >broad_gauss_v</td>
#       <td id="T_a0f53_row5_col2" class="data row5 col2" >numeric</td>
#       <td id="T_a0f53_row5_col3" class="data row5 col3" >-0.01</td>
#       <td id="T_a0f53_row5_col4" class="data row5 col4" >✓</td>
#       <td id="T_a0f53_row5_col5" class="data row5 col5" >Gaussian broadening instrumental contribution</td>
#     </tr>
#     <tr>
#       <th id="T_a0f53_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_a0f53_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_a0f53_row6_col1" class="data row6 col1" >broad_gauss_w</td>
#       <td id="T_a0f53_row6_col2" class="data row6 col2" >numeric</td>
#       <td id="T_a0f53_row6_col3" class="data row6 col3" >0.02</td>
#       <td id="T_a0f53_row6_col4" class="data row6 col4" >✓</td>
#       <td id="T_a0f53_row6_col5" class="data row6 col5" >Gaussian broadening instrumental contribution</td>
#     </tr>
#     <tr>
#       <th id="T_a0f53_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_a0f53_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_a0f53_row7_col1" class="data row7 col1" >broad_lorentz_x</td>
#       <td id="T_a0f53_row7_col2" class="data row7 col2" >numeric</td>
#       <td id="T_a0f53_row7_col3" class="data row7 col3" >0.0</td>
#       <td id="T_a0f53_row7_col4" class="data row7 col4" >✓</td>
#       <td id="T_a0f53_row7_col5" class="data row7 col5" >Lorentzian broadening from sample strain effects</td>
#     </tr>
#     <tr>
#       <th id="T_a0f53_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_a0f53_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_a0f53_row8_col1" class="data row8 col1" >broad_lorentz_y</td>
#       <td id="T_a0f53_row8_col2" class="data row8 col2" >numeric</td>
#       <td id="T_a0f53_row8_col3" class="data row8 col3" >0.0</td>
#       <td id="T_a0f53_row8_col4" class="data row8 col4" >✓</td>
#       <td id="T_a0f53_row8_col5" class="data row8 col5" >Lorentzian broadening from microstructural defects</td>
#     </tr>
#     <tr>
#       <th id="T_a0f53_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_a0f53_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_a0f53_row9_col1" class="data row9 col1" >profile_type</td>
#       <td id="T_a0f53_row9_col2" class="data row9 col2" >string</td>
#       <td id="T_a0f53_row9_col3" class="data row9 col3" >pseudo-voigt + empirical asymmetry</td>
# Other properties
# <style type="text/css">
# #T_2ecda   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_2ecda thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_2ecda th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_2ecda  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_2ecda th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_2ecda tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_2ecda  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_2ecda th.col0 {
#   text-align: right;
# }
# #T_2ecda th.col1 {
#   text-align: left;
# }
# #T_2ecda th.col2 {
#   text-align: center;
# }
# #T_2ecda th.col3 {
#   text-align: left;
# }
# #T_2ecda_row0_col0, #T_2ecda_row1_col0, #T_2ecda_row2_col0 {
#   text-align: right;
# }
# #T_2ecda_row0_col1, #T_2ecda_row0_col3, #T_2ecda_row1_col1, #T_2ecda_row1_col3, #T_2ecda_row2_col1, #T_2ecda_row2_col3 {
#   text-align: left;
# }
# #T_2ecda_row0_col2, #T_2ecda_row1_col2, #T_2ecda_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_2ecda" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ecda_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_2ecda_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_2ecda_level0_col2" class="col_heading level0 col2" >Writable</th>
#       <th id="T_2ecda_level0_col3" class="col_heading level0 col3" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ecda_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2ecda_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_2ecda_row0_col1" class="data row0 col1" >as_cif</td>
#       <td id="T_2ecda_row0_col2" class="data row0 col2" >✗</td>
#       <td id="T_2ecda_row0_col3" class="data row0 col3" >Return CIF representation of this object.</td>
#     </tr>
#     <tr>
#       <th id="T_2ecda_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2ecda_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_2ecda_row1_col1" class="data row1 col1" >parameters</td>
#       <td id="T_2ecda_row1_col2" class="data row1 col2" >✗</td>
#       <td id="T_2ecda_row1_col3" class="data row1 col3" >All GenericDescriptorBase instances on this item.</td>
#     </tr>
#     <tr>
#       <th id="T_2ecda_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2ecda_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_2ecda_row2_col1" class="data row2 col1" >unique_name</td>
#       <td id="T_2ecda_row2_col2" class="data row2 col2" >✗</td>
#       <td id="T_2ecda_row2_col3" class="data row2 col3" >Fully qualified name: datablock, category, entry.</td>
#     </tr>
#   </tbody>
# </table>
# Methods
# <style type="text/css">
# #T_52f30   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_52f30 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_52f30 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_52f30  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_52f30 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_52f30 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_52f30  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_52f30 th.col0 {
#   text-align: right;
# }
# #T_52f30 th.col1 {
#   text-align: left;
# }
# #T_52f30 th.col2 {
#   text-align: left;
# }
# #T_52f30_row0_col0, #T_52f30_row1_col0 {
#   text-align: right;
# }
# #T_52f30_row0_col1, #T_52f30_row0_col2, #T_52f30_row1_col1, #T_52f30_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_52f30" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52f30_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_52f30_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_52f30_level0_col2" class="col_heading level0 col2" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52f30_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_52f30_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_52f30_row0_col1" class="data row0 col1" >from_cif()</td>
#       <td id="T_52f30_row0_col2" class="data row0 col2" >Populate this item from a CIF block.</td>
#     </tr>
#     <tr>
#       <th id="T_52f30_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_52f30_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_52f30_row1_col1" class="data row1 col1" >help()</td>
#       <td id="T_52f30_row1_col2" class="data row1 col2" >Print parameters, other properties, and methods.</td>
#     </tr>
#   </tbody>
# </table>

# %%
experiment.peak.broad_gauss_u = 0.009618201
experiment.peak.broad_gauss_v = -0.012946068
experiment.peak.broad_gauss_w = 0.0058880704
experiment.peak.broad_lorentz_x = 0.020095311
experiment.peak.broad_lorentz_y = 0.0032597019

experiment.peak.asym_empir_1 = 0.0
experiment.peak.asym_empir_2 = 0.0
experiment.peak.asym_empir_3 = 0.0
experiment.peak.asym_empir_4 = 0.0

# %%
experiment.peak.help()
# Out:
# Help for 'CwlPseudoVoigtEmpiricalAsymmetry'
# Parameters
# <style type="text/css">
# #T_fcf50   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_fcf50 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_fcf50 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_fcf50  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_fcf50 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_fcf50 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_fcf50  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_fcf50 th.col0 {
#   text-align: right;
# }
# #T_fcf50 th.col1 {
#   text-align: left;
# }
# #T_fcf50 th.col2 {
#   text-align: left;
# }
# #T_fcf50 th.col3 {
#   text-align: right;
# }
# #T_fcf50 th.col4 {
#   text-align: center;
# }
# #T_fcf50 th.col5 {
#   text-align: left;
# }
# #T_fcf50_row0_col0, #T_fcf50_row0_col3, #T_fcf50_row1_col0, #T_fcf50_row1_col3, #T_fcf50_row2_col0, #T_fcf50_row2_col3, #T_fcf50_row3_col0, #T_fcf50_row3_col3, #T_fcf50_row4_col0, #T_fcf50_row4_col3, #T_fcf50_row5_col0, #T_fcf50_row5_col3, #T_fcf50_row6_col0, #T_fcf50_row6_col3, #T_fcf50_row7_col0, #T_fcf50_row7_col3, #T_fcf50_row8_col0, #T_fcf50_row8_col3, #T_fcf50_row9_col0, #T_fcf50_row9_col3 {
#   text-align: right;
# }
# #T_fcf50_row0_col1, #T_fcf50_row0_col2, #T_fcf50_row0_col5, #T_fcf50_row1_col1, #T_fcf50_row1_col2, #T_fcf50_row1_col5, #T_fcf50_row2_col1, #T_fcf50_row2_col2, #T_fcf50_row2_col5, #T_fcf50_row3_col1, #T_fcf50_row3_col2, #T_fcf50_row3_col5, #T_fcf50_row4_col1, #T_fcf50_row4_col2, #T_fcf50_row4_col5, #T_fcf50_row5_col1, #T_fcf50_row5_col2, #T_fcf50_row5_col5, #T_fcf50_row6_col1, #T_fcf50_row6_col2, #T_fcf50_row6_col5, #T_fcf50_row7_col1, #T_fcf50_row7_col2, #T_fcf50_row7_col5, #T_fcf50_row8_col1, #T_fcf50_row8_col2, #T_fcf50_row8_col5, #T_fcf50_row9_col1, #T_fcf50_row9_col2, #T_fcf50_row9_col5 {
#   text-align: left;
# }
# #T_fcf50_row0_col4, #T_fcf50_row1_col4, #T_fcf50_row2_col4, #T_fcf50_row3_col4, #T_fcf50_row4_col4, #T_fcf50_row5_col4, #T_fcf50_row6_col4, #T_fcf50_row7_col4, #T_fcf50_row8_col4, #T_fcf50_row9_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_fcf50" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcf50_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_fcf50_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_fcf50_level0_col2" class="col_heading level0 col2" >Type</th>
#       <th id="T_fcf50_level0_col3" class="col_heading level0 col3" >Value</th>
#       <th id="T_fcf50_level0_col4" class="col_heading level0 col4" >Writable</th>
#       <th id="T_fcf50_level0_col5" class="col_heading level0 col5" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcf50_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_fcf50_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_fcf50_row0_col1" class="data row0 col1" >asym_empir_1</td>
#       <td id="T_fcf50_row0_col2" class="data row0 col2" >numeric</td>
#       <td id="T_fcf50_row0_col3" class="data row0 col3" >0.0</td>
#       <td id="T_fcf50_row0_col4" class="data row0 col4" >✓</td>
#       <td id="T_fcf50_row0_col5" class="data row0 col5" >Empirical asymmetry coefficient p1</td>
#     </tr>
#     <tr>
#       <th id="T_fcf50_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_fcf50_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_fcf50_row1_col1" class="data row1 col1" >asym_empir_2</td>
#       <td id="T_fcf50_row1_col2" class="data row1 col2" >numeric</td>
#       <td id="T_fcf50_row1_col3" class="data row1 col3" >0.0</td>
#       <td id="T_fcf50_row1_col4" class="data row1 col4" >✓</td>
#       <td id="T_fcf50_row1_col5" class="data row1 col5" >Empirical asymmetry coefficient p2</td>
#     </tr>
#     <tr>
#       <th id="T_fcf50_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_fcf50_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_fcf50_row2_col1" class="data row2 col1" >asym_empir_3</td>
#       <td id="T_fcf50_row2_col2" class="data row2 col2" >numeric</td>
#       <td id="T_fcf50_row2_col3" class="data row2 col3" >0.0</td>
#       <td id="T_fcf50_row2_col4" class="data row2 col4" >✓</td>
#       <td id="T_fcf50_row2_col5" class="data row2 col5" >Empirical asymmetry coefficient p3</td>
#     </tr>
#     <tr>
#       <th id="T_fcf50_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_fcf50_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_fcf50_row3_col1" class="data row3 col1" >asym_empir_4</td>
#       <td id="T_fcf50_row3_col2" class="data row3 col2" >numeric</td>
#       <td id="T_fcf50_row3_col3" class="data row3 col3" >0.0</td>
#       <td id="T_fcf50_row3_col4" class="data row3 col4" >✓</td>
#       <td id="T_fcf50_row3_col5" class="data row3 col5" >Empirical asymmetry coefficient p4</td>
#     </tr>
#     <tr>
#       <th id="T_fcf50_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_fcf50_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_fcf50_row4_col1" class="data row4 col1" >broad_gauss_u</td>
#       <td id="T_fcf50_row4_col2" class="data row4 col2" >numeric</td>
#       <td id="T_fcf50_row4_col3" class="data row4 col3" >0.009618201</td>
#       <td id="T_fcf50_row4_col4" class="data row4 col4" >✓</td>
#       <td id="T_fcf50_row4_col5" class="data row4 col5" >Gaussian broadening from sample size and resolution</td>
#     </tr>
#     <tr>
#       <th id="T_fcf50_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_fcf50_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_fcf50_row5_col1" class="data row5 col1" >broad_gauss_v</td>
#       <td id="T_fcf50_row5_col2" class="data row5 col2" >numeric</td>
#       <td id="T_fcf50_row5_col3" class="data row5 col3" >-0.012946068</td>
#       <td id="T_fcf50_row5_col4" class="data row5 col4" >✓</td>
#       <td id="T_fcf50_row5_col5" class="data row5 col5" >Gaussian broadening instrumental contribution</td>
#     </tr>
#     <tr>
#       <th id="T_fcf50_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_fcf50_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_fcf50_row6_col1" class="data row6 col1" >broad_gauss_w</td>
#       <td id="T_fcf50_row6_col2" class="data row6 col2" >numeric</td>
#       <td id="T_fcf50_row6_col3" class="data row6 col3" >0.0058880704</td>
#       <td id="T_fcf50_row6_col4" class="data row6 col4" >✓</td>
#       <td id="T_fcf50_row6_col5" class="data row6 col5" >Gaussian broadening instrumental contribution</td>
#     </tr>
#     <tr>
#       <th id="T_fcf50_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_fcf50_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_fcf50_row7_col1" class="data row7 col1" >broad_lorentz_x</td>
#       <td id="T_fcf50_row7_col2" class="data row7 col2" >numeric</td>
#       <td id="T_fcf50_row7_col3" class="data row7 col3" >0.020095311</td>
#       <td id="T_fcf50_row7_col4" class="data row7 col4" >✓</td>
#       <td id="T_fcf50_row7_col5" class="data row7 col5" >Lorentzian broadening from sample strain effects</td>
#     </tr>
#     <tr>
#       <th id="T_fcf50_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_fcf50_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_fcf50_row8_col1" class="data row8 col1" >broad_lorentz_y</td>
#       <td id="T_fcf50_row8_col2" class="data row8 col2" >numeric</td>
#       <td id="T_fcf50_row8_col3" class="data row8 col3" >0.0032597019</td>
#       <td id="T_fcf50_row8_col4" class="data row8 col4" >✓</td>
#       <td id="T_fcf50_row8_col5" class="data row8 col5" >Lorentzian broadening from microstructural defects</td>
#     </tr>
#     <tr>
#       <th id="T_fcf50_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_fcf50_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_fcf50_row9_col1" class="data row9 col1" >profile_type</td>
#       <td id="T_fcf50_row9_col2" class="data row9 col2" >string</td>
#       <td id="T_fcf50_row9_col3" class="data row9 col3" >ps
# Other properties
# <style type="text/css">
# #T_7aab5   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_7aab5 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_7aab5 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7aab5  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7aab5 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_7aab5 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_7aab5  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_7aab5 th.col0 {
#   text-align: right;
# }
# #T_7aab5 th.col1 {
#   text-align: left;
# }
# #T_7aab5 th.col2 {
#   text-align: center;
# }
# #T_7aab5 th.col3 {
#   text-align: left;
# }
# #T_7aab5_row0_col0, #T_7aab5_row1_col0, #T_7aab5_row2_col0 {
#   text-align: right;
# }
# #T_7aab5_row0_col1, #T_7aab5_row0_col3, #T_7aab5_row1_col1, #T_7aab5_row1_col3, #T_7aab5_row2_col1, #T_7aab5_row2_col3 {
#   text-align: left;
# }
# #T_7aab5_row0_col2, #T_7aab5_row1_col2, #T_7aab5_row2_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_7aab5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7aab5_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_7aab5_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_7aab5_level0_col2" class="col_heading level0 col2" >Writable</th>
#       <th id="T_7aab5_level0_col3" class="col_heading level0 col3" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7aab5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7aab5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7aab5_row0_col1" class="data row0 col1" >as_cif</td>
#       <td id="T_7aab5_row0_col2" class="data row0 col2" >✗</td>
#       <td id="T_7aab5_row0_col3" class="data row0 col3" >Return CIF representation of this object.</td>
#     </tr>
#     <tr>
#       <th id="T_7aab5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7aab5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_7aab5_row1_col1" class="data row1 col1" >parameters</td>
#       <td id="T_7aab5_row1_col2" class="data row1 col2" >✗</td>
#       <td id="T_7aab5_row1_col3" class="data row1 col3" >All GenericDescriptorBase instances on this item.</td>
#     </tr>
#     <tr>
#       <th id="T_7aab5_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7aab5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_7aab5_row2_col1" class="data row2 col1" >unique_name</td>
#       <td id="T_7aab5_row2_col2" class="data row2 col2" >✗</td>
#       <td id="T_7aab5_row2_col3" class="data row2 col3" >Fully qualified name: datablock, category, entry.</td>
#     </tr>
#   </tbody>
# </table>
# Methods
# <style type="text/css">
# #T_e9380   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_e9380 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_e9380 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_e9380  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_e9380 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_e9380 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_e9380  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_e9380 th.col0 {
#   text-align: right;
# }
# #T_e9380 th.col1 {
#   text-align: left;
# }
# #T_e9380 th.col2 {
#   text-align: left;
# }
# #T_e9380_row0_col0, #T_e9380_row1_col0 {
#   text-align: right;
# }
# #T_e9380_row0_col1, #T_e9380_row0_col2, #T_e9380_row1_col1, #T_e9380_row1_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_e9380" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9380_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_e9380_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_e9380_level0_col2" class="col_heading level0 col2" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9380_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e9380_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e9380_row0_col1" class="data row0 col1" >from_cif()</td>
#       <td id="T_e9380_row0_col2" class="data row0 col2" >Populate this item from a CIF block.</td>
#     </tr>
#     <tr>
#       <th id="T_e9380_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e9380_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e9380_row1_col1" class="data row1 col1" >help()</td>
#       <td id="T_e9380_row1_col2" class="data row1 col2" >Print parameters, other properties, and methods.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Define background points. In this example, multiple points are defined
# across the 2-theta range of the experiment, with their x and y values
# taken from the measured data.
# Some points are commented out and thus not used.

# %%
experiment.show_current_background_type()
experiment.show_supported_background_types()
# Out:
# Current background type
# line-segment
# Supported types
# <style type="text/css">
# #T_23137   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_23137 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_23137 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_23137  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_23137 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_23137 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_23137  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_23137 th.col0 {
#   text-align: left;
# }
# #T_23137 th.col1 {
#   text-align: left;
# }
# #T_23137_row0_col0, #T_23137_row0_col1, #T_23137_row1_col0, #T_23137_row1_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_23137" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23137_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_23137_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23137_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_23137_row0_col0" class="data row0 col0" >chebyshev</td>
#       <td id="T_23137_row0_col1" class="data row0 col1" >Chebyshev polynomial background</td>
#     </tr>
#     <tr>
#       <th id="T_23137_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_23137_row1_col0" class="data row1 col0" >line-segment</td>
#       <td id="T_23137_row1_col1" class="data row1 col1" >Linear interpolation between points</td>
#     </tr>
#   </tbody>
# </table>

# %%
for x, y in [
    (10.1697, 15191.8789),
    (11.0891, 14639.7656),
    (11.8670, 13974.3184),
    (12.8100, 12506.7393),
    (13.6351, 10947.9717),
    (14.7430, 8589.5996),
    (16.0160, 6800.0322),
    (17.0533, 5837.3257),
    (18.5620, 4922.7090),
    (20.4715, 4156.3442),
    (22.4281, 3339.8083),
    (23.3710, 3090.7004),
    (24.9741, 2824.6865),
    (26.6007, 2480.6602),
    (29.4295, 2072.3389),
    (31.5012, 1613.6263),
    (33.8586, 1398.0791),
    (36.8053, 1324.0001),
    (38.8798, 1163.8712),
    (41.2371, 1090.6232),
    (42.7459, 1031.0789),
    (45.6921, 942.9998),
    (47.6629, 944.0351),
    (49.1150, 858.3295),
    (50.4635, 886.5879),
    (51.8897, 835.0275),
    (53.4456, 843.0234),
    (55.0273, 773.7563),
    (56.7907, 836.8652),
    (60.0495, 805.0693),
    (61.5111, 780.1295),
    (62.9962, 775.5878),
    (65.5658, 733.4941),
    (67.1924, 785.8816),
    (68.9840, 785.5795),
    (71.0113, 725.6704),
    (75.7704, 752.8492),
    (79.7779, 774.0583),
    (81.1924, 728.9919),
    (82.6775, 762.2854),
    (85.1056, 753.4788),
    (88.5002, 760.7822),
    (91.7586, 734.2062),
    (93.8850, 824.3625),
    (98.1377, 791.0035),
    (99.8232, 760.6655),
    (103.4795, 787.4377),
    (107.2654, 798.0887),
    (109.9057, 746.7008),
]:
    experiment.background.create(
        id=str(x).replace('.', '_'),
        x=x,
        y=y,
    )

# %% [markdown]
# Set excluded regions. In this example, the region from 0 to 2 degrees
# and the region from 14.97 to 180 degrees are excluded from the fit.

# %%
experiment.excluded_regions.create(id='1', start=0, end=10)
experiment.excluded_regions.create(id='2', start=110, end=180)

# %% [markdown]
# Show the experiment in CIF format.

# %%
experiment.show_as_cif()
# Out:
# Experiment 🔬 'xrd' as cif
# <style type="text/css">
# #T_a13e9   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_a13e9 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_a13e9 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a13e9  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_a13e9 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_a13e9 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_a13e9  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_a13e9 th.col0 {
#   text-align: left;
# }
# #T_a13e9_row0_col0, #T_a13e9_row1_col0, #T_a13e9_row2_col0, #T_a13e9_row3_col0, #T_a13e9_row4_col0, #T_a13e9_row5_col0, #T_a13e9_row6_col0, #T_a13e9_row7_col0, #T_a13e9_row8_col0, #T_a13e9_row9_col0, #T_a13e9_row10_col0, #T_a13e9_row11_col0, #T_a13e9_row12_col0, #T_a13e9_row13_col0, #T_a13e9_row14_col0, #T_a13e9_row15_col0, #T_a13e9_row16_col0, #T_a13e9_row17_col0, #T_a13e9_row18_col0, #T_a13e9_row19_col0, #T_a13e9_row20_col0, #T_a13e9_row21_col0, #T_a13e9_row22_col0, #T_a13e9_row23_col0, #T_a13e9_row24_col0, #T_a13e9_row25_col0, #T_a13e9_row26_col0, #T_a13e9_row27_col0, #T_a13e9_row28_col0, #T_a13e9_row29_col0, #T_a13e9_row30_col0, #T_a13e9_row31_col0, #T_a13e9_row32_col0, #T_a13e9_row33_col0, #T_a13e9_row34_col0, #T_a13e9_row35_col0, #T_a13e9_row36_col0, #T_a13e9_row37_col0, #T_a13e9_row38_col0, #T_a13e9_row39_col0, #T_a13e9_row40_col0, #T_a13e9_row41_col0, #T_a13e9_row42_col0, #T_a13e9_row43_col0, #T_a13e9_row44_col0, #T_a13e9_row45_col0, #T_a13e9_row46_col0, #T_a13e9_row47_col0, #T_a13e9_row48_col0, #T_a13e9_row49_col0, #T_a13e9_row50_col0, #T_a13e9_row51_col0, #T_a13e9_row52_col0, #T_a13e9_row53_col0, #T_a13e9_row54_col0, #T_a13e9_row55_col0, #T_a13e9_row56_col0, #T_a13e9_row57_col0, #T_a13e9_row58_col0, #T_a13e9_row59_col0, #T_a13e9_row60_col0, #T_a13e9_row61_col0, #T_a13e9_row62_col0, #T_a13e9_row63_col0, #T_a13e9_row64_col0, #T_a13e9_row65_col0, #T_a13e9_row66_col0, #T_a13e9_row67_col0, #T_a13e9_row68_col0, #T_a13e9_row69_col0, #T_a13e9_row70_col0, #T_a13e9_row71_col0, #T_a13e9_row72_col0, #T_a13e9_row73_col0, #T_a13e9_row74_col0, #T_a13e9_row75_col0, #T_a13e9_row76_col0, #T_a13e9_row77_col0, #T_a13e9_row78_col0, #T_a13e9_row79_col0, #T_a13e9_row80_col0, #T_a13e9_row81_col0, #T_a13e9_row82_col0, #T_a13e9_row83_col0, #T_a13e9_row84_col0, #T_a13e9_row85_col0, #T_a13e9_row86_col0, #T_a13e9_row87_col0, #T_a13e9_row88_col0, #T_a13e9_row89_col0, #T_a13e9_row90_col0, #T_a13e9_row91_col0, #T_a13e9_row92_col0, #T_a13e9_row93_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_a13e9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a13e9_level0_col0" class="col_heading level0 col0" >CIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a13e9_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a13e9_row0_col0" class="data row0 col0" >data_xrd</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a13e9_row1_col0" class="data row1 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a13e9_row2_col0" class="data row2 col0" >_expt_type.sample_form powder</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a13e9_row3_col0" class="data row3 col0" >_expt_type.beam_mode "constant wavelength"</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_a13e9_row4_col0" class="data row4 col0" >_expt_type.radiation_probe xray</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_a13e9_row5_col0" class="data row5 col0" >_expt_type.scattering_type bragg</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_a13e9_row6_col0" class="data row6 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_a13e9_row7_col0" class="data row7 col0" >_diffrn.ambient_temperature ?</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_a13e9_row8_col0" class="data row8 col0" >_diffrn.ambient_pressure ?</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_a13e9_row9_col0" class="data row9 col0" >_diffrn.ambient_magnetic_field ?</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_a13e9_row10_col0" class="data row10 col0" >_diffrn.ambient_electric_field ?</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_a13e9_row11_col0" class="data row11 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_a13e9_row12_col0" class="data row12 col0" >_peak.asym_empir_1 0.00000000</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_a13e9_row13_col0" class="data row13 col0" >_peak.asym_empir_2 0.00000000</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_a13e9_row14_col0" class="data row14 col0" >_peak.asym_empir_3 0.00000000</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_a13e9_row15_col0" class="data row15 col0" >_peak.asym_empir_4 0.00000000</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_a13e9_row16_col0" class="data row16 col0" >_peak.broad_gauss_u 0.00961820</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_a13e9_row17_col0" class="data row17 col0" >_peak.broad_gauss_v -0.01294607</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_a13e9_row18_col0" class="data row18 col0" >_peak.broad_gauss_w 0.00588807</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row19" class="row_heading level0 row19" >20</th>
#       <td id="T_a13e9_row19_col0" class="data row19 col0" >_peak.broad_lorentz_x 0.02009531</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row20" class="row_heading level0 row20" >21</th>
#       <td id="T_a13e9_row20_col0" class="data row20 col0" >_peak.broad_lorentz_y 0.00325970</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row21" class="row_heading level0 row21" >22</th>
#       <td id="T_a13e9_row21_col0" class="data row21 col0" >_peak.profile_type "pseudo-voigt + empirical asymmetry"</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row22" class="row_heading level0 row22" >23</th>
#       <td id="T_a13e9_row22_col0" class="data row22 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row23" class="row_heading level0 row23" >24</th>
#       <td id="T_a13e9_row23_col0" class="data row23 col0" >_instr.wavelength 1.54056000</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row24" class="row_heading level0 row24" >25</th>
#       <td id="T_a13e9_row24_col0" class="data row24 col0" >_instr.2theta_offset 0.04800000</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row25" class="row_heading level0 row25" >26</th>
#       <td id="T_a13e9_row25_col0" class="data row25 col0" ></td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row26" class="row_heading level0 row26" >27</th>
#       <td id="T_a13e9_row26_col0" class="data row26 col0" >loop_</td>
#     </tr>
#     <tr>
#       <th id="T_a13e9_level0_row27" class="row_heading level0 row27" >28</th>
#       <td id="T_a13e9_row27_col0" class="data row27 col0" >_pd_phase_block.

# %% [markdown]
# ## Step 4: Set free parameters
#
# Now, set free parameters for the structure. In this example,
# cell parameters, the fractional coordinates of atoms, as well as
# isotropic atomic displacement parameters (Biso) are set free.

# %%
structure.cell.length_a.free = True
structure.cell.length_b.free = True
structure.cell.length_c.free = True

structure.atom_sites['La'].fract_x.free = True
structure.atom_sites['La'].fract_z.free = True
structure.atom_sites['O1'].fract_x.free = True
structure.atom_sites['O1'].fract_z.free = True
structure.atom_sites['O2'].fract_x.free = True
structure.atom_sites['O2'].fract_y.free = True
structure.atom_sites['O2'].fract_z.free = True

structure.atom_sites['La'].adp_iso.free = True
structure.atom_sites['Ti'].adp_iso.free = True
structure.atom_sites['O1'].adp_iso.free = True

# %% [markdown]
# Now, set free parameters for the experiment. In this example, the
# scale factor, instrumental calibration parameter, peak shape
# parameters, and background points are set free.

# %%
experiment.linked_phases['lam7o3'].scale.free = True

experiment.instrument.calib_twotheta_offset.free = True

experiment.peak.broad_gauss_u.free = True
experiment.peak.broad_gauss_v.free = True
experiment.peak.broad_gauss_w.free = True
experiment.peak.broad_lorentz_x.free = True

experiment.peak.asym_empir_2.free = True
experiment.peak.asym_empir_4.free = True

for point in experiment.background:
    point.y.free = True

# %% [markdown]
# Show all free parameters in the experiment.

# %%
project.analysis.display.free_params()
# Out:
# Free parameters for both structures (🧩 data blocks) and experiments (🔬 data blocks)
# <style type="text/css">
# #T_e8862   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_e8862 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_e8862 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_e8862  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_e8862 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_e8862 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_e8862  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_e8862 th.col0 {
#   text-align: left;
# }
# #T_e8862 th.col1 {
#   text-align: left;
# }
# #T_e8862 th.col2 {
#   text-align: left;
# }
# #T_e8862 th.col3 {
#   text-align: left;
# }
# #T_e8862 th.col4 {
#   text-align: right;
# }
# #T_e8862 th.col5 {
#   text-align: right;
# }
# #T_e8862 th.col6 {
#   text-align: right;
# }
# #T_e8862 th.col7 {
#   text-align: right;
# }
# #T_e8862 th.col8 {
#   text-align: left;
# }
# #T_e8862_row0_col0, #T_e8862_row0_col1, #T_e8862_row0_col2, #T_e8862_row0_col3, #T_e8862_row0_col8, #T_e8862_row1_col0, #T_e8862_row1_col1, #T_e8862_row1_col2, #T_e8862_row1_col3, #T_e8862_row1_col8, #T_e8862_row2_col0, #T_e8862_row2_col1, #T_e8862_row2_col2, #T_e8862_row2_col3, #T_e8862_row2_col8, #T_e8862_row3_col0, #T_e8862_row3_col1, #T_e8862_row3_col2, #T_e8862_row3_col3, #T_e8862_row3_col8, #T_e8862_row4_col0, #T_e8862_row4_col1, #T_e8862_row4_col2, #T_e8862_row4_col3, #T_e8862_row4_col8, #T_e8862_row5_col0, #T_e8862_row5_col1, #T_e8862_row5_col2, #T_e8862_row5_col3, #T_e8862_row5_col8, #T_e8862_row6_col0, #T_e8862_row6_col1, #T_e8862_row6_col2, #T_e8862_row6_col3, #T_e8862_row6_col8, #T_e8862_row7_col0, #T_e8862_row7_col1, #T_e8862_row7_col2, #T_e8862_row7_col3, #T_e8862_row7_col8, #T_e8862_row8_col0, #T_e8862_row8_col1, #T_e8862_row8_col2, #T_e8862_row8_col3, #T_e8862_row8_col8, #T_e8862_row9_col0, #T_e8862_row9_col1, #T_e8862_row9_col2, #T_e8862_row9_col3, #T_e8862_row9_col8, #T_e8862_row10_col0, #T_e8862_row10_col1, #T_e8862_row10_col2, #T_e8862_row10_col3, #T_e8862_row10_col8, #T_e8862_row11_col0, #T_e8862_row11_col1, #T_e8862_row11_col2, #T_e8862_row11_col3, #T_e8862_row11_col8, #T_e8862_row12_col0, #T_e8862_row12_col1, #T_e8862_row12_col2, #T_e8862_row12_col3, #T_e8862_row12_col8, #T_e8862_row13_col0, #T_e8862_row13_col1, #T_e8862_row13_col2, #T_e8862_row13_col3, #T_e8862_row13_col8, #T_e8862_row14_col0, #T_e8862_row14_col1, #T_e8862_row14_col2, #T_e8862_row14_col3, #T_e8862_row14_col8, #T_e8862_row15_col0, #T_e8862_row15_col1, #T_e8862_row15_col2, #T_e8862_row15_col3, #T_e8862_row15_col8, #T_e8862_row16_col0, #T_e8862_row16_col1, #T_e8862_row16_col2, #T_e8862_row16_col3, #T_e8862_row16_col8, #T_e8862_row17_col0, #T_e8862_row17_col1, #T_e8862_row17_col2, #T_e8862_row17_col3, #T_e8862_row17_col8, #T_e8862_row18_col0, #T_e8862_row18_col1, #T_e8862_row18_col2, #T_e8862_row18_col3, #T_e8862_row18_col8, #T_e8862_row19_col0, #T_e8862_row19_col1, #T_e8862_row19_col2, #T_e8862_row19_col3, #T_e8862_row19_col8, #T_e8862_row20_col0, #T_e8862_row20_col1, #T_e8862_row20_col2, #T_e8862_row20_col3, #T_e8862_row20_col8, #T_e8862_row21_col0, #T_e8862_row21_col1, #T_e8862_row21_col2, #T_e8862_row21_col3, #T_e8862_row21_col8, #T_e8862_row22_col0, #T_e8862_row22_col1, #T_e8862_row22_col2, #T_e8862_row22_col3, #T_e8862_row22_col8, #T_e8862_row23_col0, #T_e8862_row23_col1, #T_e8862_row23_col2, #T_e8862_row23_col3, #T_e8862_row23_col8, #T_e8862_row24_col0, #T_e8862_row24_col1, #T_e8862_row24_col2, #T_e8862_row24_col3, #T_e8862_row24_col8, #T_e8862_row25_col0, #T_e8862_row25_col1, #T_e8862_row25_col2, #T_e8862_row25_col3, #T_e8862_row25_col8, #T_e8862_row26_col0, #T_e8862_row26_col1, #T_e8862_row26_col2, #T_e8862_row26_col3, #T_e8862_row26_col8, #T_e8862_row27_col0, #T_e8862_row27_col1, #T_e8862_row27_col2, #T_e8862_row27_col3, #T_e8862_row27_col8, #T_e8862_row28_col0, #T_e8862_row28_col1, #T_e8862_row28_col2, #T_e8862_row28_col3, #T_e8862_row28_col8, #T_e8862_row29_col0, #T_e8862_row29_col1, #T_e8862_row29_col2, #T_e8862_row29_col3, #T_e8862_row29_col8, #T_e8862_row30_col0, #T_e8862_row30_col1, #T_e8862_row30_col2, #T_e8862_row30_col3, #T_e8862_row30_col8, #T_e8862_row31_col0, #T_e8862_row31_col1, #T_e8862_row31_col2, #T_e8862_row31_col3, #T_e8862_row31_col8, #T_e8862_row32_col0, #T_e8862_row32_col1, #T_e8862_row32_col2, #T_e8862_row32_col3, #T_e8862_row32_col8, #T_e8862_row33_col0, #T_e8862_row33_col1, #T_e8862_row33_col2, #T_e8862_row33_col3, #T_e8862_row33_col8, #T_e8862_row34_col0, #T_e8862_row34_col1, #T_e8862_row34_col2, #T_e8862_row34_col3, #T_e8862_row34_col8, #T_e8862_row35_col0, #T_e8862_row35_col1, #T_e8862_row35_col2, #T_e8862_row35_col3, #T_e8862_row35_col8, #T_e8862_row36_col0, #T_e8862_row36_col1, #T_e8862_row36_col2, #T_e8862_row36_col3, #T_e8862_row36_col8, #T_e8862_row37_col0, #T_e8862_row37_col1, #T_e8862_row37_col2, #T_e8862_row37_col3, #T_e8862_row37_col8, #T_e8862_row38_col0, #T_e8862_row38_col1, #T_e8862_row38_col ...

# %% [markdown]
# ## Step 5: Define constraints
#
# Create aliases for those parameters that we want to reference in
# constraint expressions. In this example, we want to constrain the Biso
# values of all M sites to be the same, and the Biso values of the two O
# sites to be the same.

# %%
# M sites: Ti, Cr, Mn, Fe, Co, Ni, Cu
project.analysis.aliases.create(
    label='biso_Ti',
    param=structure.atom_sites['Ti'].adp_iso,
)
project.analysis.aliases.create(
    label='biso_Cr',
    param=structure.atom_sites['Cr'].adp_iso,
)
project.analysis.aliases.create(
    label='biso_Mn',
    param=structure.atom_sites['Mn'].adp_iso,
)
project.analysis.aliases.create(
    label='biso_Fe',
    param=structure.atom_sites['Fe'].adp_iso,
)
project.analysis.aliases.create(
    label='biso_Co',
    param=structure.atom_sites['Co'].adp_iso,
)
project.analysis.aliases.create(
    label='biso_Ni',
    param=structure.atom_sites['Ni'].adp_iso,
)
project.analysis.aliases.create(
    label='biso_Cu',
    param=structure.atom_sites['Cu'].adp_iso,
)

# O sites: O1, O2
project.analysis.aliases.create(
    label='biso_O1',
    param=structure.atom_sites['O1'].adp_iso,
)
project.analysis.aliases.create(
    label='biso_O2',
    param=structure.atom_sites['O2'].adp_iso,
)

# %% [markdown]
# Set constraints using the aliases. In this example, all M sites are
# constrained to have the same Biso, and the two O sites are constrained
# to have the same Biso.

# %%
project.analysis.constraints.create(expression='biso_Cr = biso_Ti')
project.analysis.constraints.create(expression='biso_Mn = biso_Ti')
project.analysis.constraints.create(expression='biso_Fe = biso_Ti')
project.analysis.constraints.create(expression='biso_Co = biso_Ti')
project.analysis.constraints.create(expression='biso_Ni = biso_Ti')
project.analysis.constraints.create(expression='biso_Cu = biso_Ti')
project.analysis.constraints.create(expression='biso_O2 = biso_O1')

# %% [markdown]
# Show defined constraints.

# %%
project.analysis.display.constraints()
# Out:
# User defined constraints
# <style type="text/css">
# #T_29b0f   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_29b0f thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_29b0f th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_29b0f  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_29b0f th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_29b0f tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_29b0f  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_29b0f th.col0 {
#   text-align: left;
# }
# #T_29b0f_row0_col0, #T_29b0f_row1_col0, #T_29b0f_row2_col0, #T_29b0f_row3_col0, #T_29b0f_row4_col0, #T_29b0f_row5_col0, #T_29b0f_row6_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_29b0f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29b0f_level0_col0" class="col_heading level0 col0" >expression</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29b0f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_29b0f_row0_col0" class="data row0 col0" >biso_Cr = biso_Ti</td>
#     </tr>
#     <tr>
#       <th id="T_29b0f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_29b0f_row1_col0" class="data row1 col0" >biso_Mn = biso_Ti</td>
#     </tr>
#     <tr>
#       <th id="T_29b0f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_29b0f_row2_col0" class="data row2 col0" >biso_Fe = biso_Ti</td>
#     </tr>
#     <tr>
#       <th id="T_29b0f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_29b0f_row3_col0" class="data row3 col0" >biso_Co = biso_Ti</td>
#     </tr>
#     <tr>
#       <th id="T_29b0f_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_29b0f_row4_col0" class="data row4 col0" >biso_Ni = biso_Ti</td>
#     </tr>
#     <tr>
#       <th id="T_29b0f_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_29b0f_row5_col0" class="data row5 col0" >biso_Cu = biso_Ti</td>
#     </tr>
#     <tr>
#       <th id="T_29b0f_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_29b0f_row6_col0" class="data row6 col0" >biso_O2 = biso_O1</td>
#     </tr>
#   </tbody>
# </table>
# Constraints enabled: True

# %% [markdown]
# ## Step 6: Perform Analysis

# %% [markdown]
# Before performing the fit, we can plot the measured data and compare
# it with the calculated pattern using the initial parameters. This can
# be helpful to check if the initial parameters are reasonable and to
# identify any issues with the data or the model before running the fit.

# %%
project.plotter.plot_meas_vs_calc(expt_name='xrd')
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="a691e804-2be2-4445-97b8-3761de0554e6" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a691e804-2be2-4445-97b8-3761de0554e6")) {                    Plotly.newPlot(                        "a691e804-2be2-4445-97b8-3761de0554e6",                        [{"line":{"color":"rgb(31, 119, 180)"},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"\u002fJECF61G4HsUkQJhuEoPAyiRAqvHSTWLQJEC8dJMYBNYkQM\u002f3U+Ol2yRA4XoUrkfhJED0\u002fdR46eYkQAaBlUOL7CRAGQRWDi3yJEArhxbZzvckQD0K16Nw\u002fSRAUI2XbhIDJUBiEFg5tAglQHWTGARWDiVAhxbZzvcTJUCamZmZmRklQKwcWmQ7HyVAvp8aL90kJUDRItv5fiolQOOlm8QgMCVA9ihcj8I1JUAIrBxaZDslQBsv3SQGQSVALbKd76dGJUA\u002fNV66SUwlQFK4HoXrUSVAZDvfT41XJUB3vp8aL10lQIlBYOXQYiVAnMQgsHJoJUCuR+F6FG4lQMHKoUW2cyVA001iEFh5JUDl0CLb+X4lQPhT46WbhCVACtejcD2KJUAdWmQ7348lQC\u002fdJAaBlSVAQmDl0CKbJUBU46WbxKAlQGZmZmZmpiVAeekmMQisJUCLbOf7qbElQJ7vp8ZLtyVAsHJoke28JUDD9Shcj8IlQNV46SYxyCVA5\u002fup8dLNJUD6fmq8dNMlQAwCK4cW2SVAH4XrUbjeJUAxCKwcWuQlQESLbOf76SVAVg4tsp3vJUBoke18P\u002fUlQHsUrkfh+iVAjZduEoMAJkCgGi\u002fdJAYmQLKd76fGCyZAxSCwcmgRJkDXo3A9ChcmQOkmMQisHCZA\u002fKnx0k0iJkAOLbKd7ycmQCGwcmiRLSZAMzMzMzMzJkBGtvP91DgmQFg5tMh2PiZAarx0kxhEJkB9PzVeukkmQI\u002fC9ShcTyZAokW28\u002f1UJkC0yHa+n1omQMdLN4lBYCZA2c73U+NlJkDsUbgehWsmQP7UeOkmcSZAEFg5tMh2JkAj2\u002fl+anwmQDVeukkMgiZASOF6FK6HJkBaZDvfT40mQG3n+6nxkiZAf2q8dJOYJkCR7Xw\u002fNZ4mQKRwPQrXoyZAtvP91HipJkDJdr6fGq8mQNv5fmq8tCZA7nw\u002fNV66JkAAAAAAAMAmQBKDwMqhxSZAJQaBlUPLJkA3iUFg5dAmQEoMAiuH1iZAXI\\u002fC9WgnQDvfT42XbidATmIQWDl0J0Bg5dAi23knQHNoke18fydAhetRuB6FJ0CYbhKDwIonQKrx0k1ikCdAvHSTGASWJ0DP91PjpZsnQOF6FK5HoSdA9P3UeOmmJ0AGgZVDi6wnQBkEVg4tsidAK4cW2c63J0A9CtejcL0nQFCNl24SwydAYhBYObTIJ0B1kxgEVs4nQIcW2c730ydAmpmZmZnZJ0CsHFpkO98nQL6fGi\u002fd5CdA0SLb+X7qJ0DjpZvEIPAnQPYoXI\u002fC9SdACKwcWmT7J0AbL90kBgEoQC2yne+nBihAPzVeukkMKEBSuB6F6xEoQGQ730+NFyhAd76fGi8dKECJQWDl0CIoQJzEILByKChArkfhehQuKEDByqFFtjMoQNNNYhBYOShA5dAi2\u002fk+KED4U+Olm0QoQArXo3A9SihAHVpkO99PKEAv3SQGgVUoQEJg5dAiWyhAVOOlm8RgKEBmZmZmZmYoQHnpJjEIbChAi2zn+6lxKECe76fGS3coQLByaJHtfChAw\u002fUoXI+CKEDVeOkmMYgoQOf7qfHSjShA+n5qvHSTKEAMAiuHFpkoQB+F61G4nihAMQisHFqkKEBEi2zn+6koQFYOLbKdryhAaJHtfD+1KEB7FK5H4booQI2XbhKDwChAoBov3STGKECyne+nxssoQMUgsHJo0ShA16NwPQrXKEDpJjEIrNwoQPyp8dJN4ihADi2yne\u002fnKEAhsHJoke0oQDMzMzMz8yhARrbz\u002fdT4KEBYObTIdv4oQGq8dJMYBClAfT81XroJKUCPwvUoXA8pQKJFtvP9FClAtMh2vp8aKUDHSzeJQSApQNnO91PjJSlA7FG4HoUrKUD+1HjpJjEpQBBYObTINilAI9v5fmo8KUA1XrpJDEIpQEjhehSuRylAWmQ7309NKUBt5\u002fup8VIpQH9qvHSTWClAke18PzVeKUCkcD0K12MpQLbz\\u002fspQKjGSzeJASpAukkMAisHKkDNzMzMzAwqQN9PjZduEipA8tJNYhAYKkAEVg4tsh0qQBfZzvdTIypAKVyPwvUoKkA730+Nly4qQE5iEFg5NCpAYOXQIts5KkBzaJHtfD8qQIXrUbgeRSpAmG4Sg8BKKkCq8dJNYlAqQLx0kxgEVipAz\u002fdT46VbKkDhehSuR2EqQPT91HjpZipABoGVQ4tsKkAZBFYOLXIqQCuHFtnOdypAPQrXo3B9KkBQ ...

# %% [markdown]
# Show supported fitting engines.

# %%
project.analysis.show_available_minimizers()
# Out:
# Supported types
# <style type="text/css">
# #T_b0e5c   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_b0e5c thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_b0e5c th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_b0e5c  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_b0e5c th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_b0e5c tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_b0e5c  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_b0e5c th.col0 {
#   text-align: left;
# }
# #T_b0e5c th.col1 {
#   text-align: left;
# }
# #T_b0e5c_row0_col0, #T_b0e5c_row0_col1, #T_b0e5c_row1_col0, #T_b0e5c_row1_col1, #T_b0e5c_row2_col0, #T_b0e5c_row2_col1, #T_b0e5c_row3_col0, #T_b0e5c_row3_col1, #T_b0e5c_row4_col0, #T_b0e5c_row4_col1, #T_b0e5c_row5_col0, #T_b0e5c_row5_col1, #T_b0e5c_row6_col0, #T_b0e5c_row6_col1, #T_b0e5c_row7_col0, #T_b0e5c_row7_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_b0e5c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0e5c_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_b0e5c_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0e5c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b0e5c_row0_col0" class="data row0 col0" >bumps</td>
#       <td id="T_b0e5c_row0_col1" class="data row0 col1" >Bumps library using the default Levenberg-Marquardt method</td>
#     </tr>
#     <tr>
#       <th id="T_b0e5c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b0e5c_row1_col0" class="data row1 col0" >bumps (amoeba)</td>
#       <td id="T_b0e5c_row1_col1" class="data row1 col1" >Bumps library with Nelder-Mead simplex method</td>
#     </tr>
#     <tr>
#       <th id="T_b0e5c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b0e5c_row2_col0" class="data row2 col0" >bumps (de)</td>
#       <td id="T_b0e5c_row2_col1" class="data row2 col1" >Bumps library with differential evolution method</td>
#     </tr>
#     <tr>
#       <th id="T_b0e5c_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b0e5c_row3_col0" class="data row3 col0" >bumps (lm)</td>
#       <td id="T_b0e5c_row3_col1" class="data row3 col1" >Bumps library with Levenberg-Marquardt method</td>
#     </tr>
#     <tr>
#       <th id="T_b0e5c_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_b0e5c_row4_col0" class="data row4 col0" >dfols</td>
#       <td id="T_b0e5c_row4_col1" class="data row4 col1" >DFO-LS library for derivative-free least-squares optimization</td>
#     </tr>
#     <tr>
#       <th id="T_b0e5c_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_b0e5c_row5_col0" class="data row5 col0" >lmfit</td>
#       <td id="T_b0e5c_row5_col1" class="data row5 col1" >LMFIT library using the default Levenberg-Marquardt least squares method</td>
#     </tr>
#     <tr>
#       <th id="T_b0e5c_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b0e5c_row6_col0" class="data row6 col0" >lmfit (least_squares)</td>
#       <td id="T_b0e5c_row6_col1" class="data row6 col1" >LMFIT library with SciPy's trust region reflective algorithm</td>
#     </tr>
#     <tr>
#       <th id="T_b0e5c_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_b0e5c_row7_col0" class="data row7 col0" >lmfit (leastsq)</td>
#       <td id="T_b0e5c_row7_col1" class="data row7 col1" >LMFIT library with Levenberg-Marquardt least squares method</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Show current fitting engine.

# %%
project.analysis.show_current_minimizer()
# Out:
# Current minimizer
# lmfit (leastsq)

# %% [markdown]
# Select desired fitting engine.

# %%
project.analysis.current_minimizer = 'bumps (lm)'
# Out:
# Current minimizer changed to
# bumps (lm)

# %% [markdown]
# Rietveld refinement is performed by calling the `fit()` method of the
# `analysis` object of the project.

# %%
project.analysis.fit()
# Out:
# Standard fitting
# 📋 Using experiment 🔬 'xrd' for 'single' fitting
# 🚀 Starting fit process with 'bumps (lm)'...
# 📈 Goodness-of-fit (reduced χ²) change:
# <style type="text/css">
# #T_67642   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_67642 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_67642 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_67642  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_67642 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_67642 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_67642  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_67642 th.col0 {
#   text-align: center;
# }
# #T_67642 th.col1 {
#   text-align: center;
# }
# #T_67642 th.col2 {
#   text-align: center;
# }
# #T_67642_row0_col0, #T_67642_row0_col1, #T_67642_row0_col2, #T_67642_row1_col0, #T_67642_row1_col1, #T_67642_row1_col2, #T_67642_row2_col0, #T_67642_row2_col1, #T_67642_row2_col2, #T_67642_row3_col0, #T_67642_row3_col1, #T_67642_row3_col2, #T_67642_row4_col0, #T_67642_row4_col1, #T_67642_row4_col2, #T_67642_row5_col0, #T_67642_row5_col1, #T_67642_row5_col2, #T_67642_row6_col0, #T_67642_row6_col1, #T_67642_row6_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_67642" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67642_level0_col0" class="col_heading level0 col0" >iteration</th>
#       <th id="T_67642_level0_col1" class="col_heading level0 col1" >χ²</th>
#       <th id="T_67642_level0_col2" class="col_heading level0 col2" >improvement [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67642_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_67642_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_67642_row0_col1" class="data row0 col1" >177.34</td>
#       <td id="T_67642_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_67642_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_67642_row1_col0" class="data row1 col0" >14</td>
#       <td id="T_67642_row1_col1" class="data row1 col1" >175.34</td>
#       <td id="T_67642_row1_col2" class="data row1 col2" >1.1% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_67642_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_67642_row2_col0" class="data row2 col0" >73</td>
#       <td id="T_67642_row2_col1" class="data row2 col1" >8.94</td>
#       <td id="T_67642_row2_col2" class="data row2 col2" >94.9% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_67642_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_67642_row3_col0" class="data row3 col0" >144</td>
#       <td id="T_67642_row3_col1" class="data row3 col1" >5.29</td>
#       <td id="T_67642_row3_col2" class="data row3 col2" >40.8% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_67642_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_67642_row4_col0" class="data row4 col0" >215</td>
#       <td id="T_67642_row4_col1" class="data row4 col1" >3.63</td>
#       <td id="T_67642_row4_col2" class="data row4 col2" >31.4% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_67642_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_67642_row5_col0" class="data row5 col0" >286</td>
#       <td id="T_67642_row5_col1" class="data row5 col1" >3.55</td>
#       <td id="T_67642_row5_col2" class="data row5 col2" >2.1% ↓</td>
#     </tr>
#     <tr>
#       <th id="T_67642_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_67642_row6_col0" class="data row6 col0" >576</td>
#       <td id="T_67642_row6_col1" class="data row6 col1" >3.53</td>
#       <td id="T_67642_row6_col2" class="data row6 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# 🏆 Best goodness-of-fit (reduced χ²) is 3.53 at iteration 509
# ✅ Fitting complete.
# Saving project 📦 'hep7c' to
# /home/runner/work/diffraction-lib/diffraction-lib/docs/docs/tutorials/hep7c
# ├── 📄 project.cif
# ├── 📁 structures/
# │   └── 📄 lam7o3.cif
# ├── 📁 experiments/
# │   └── 📄 xrd.cif
# ├── 📁 analysis/
# │   └── 📄 analysis.cif
# └── 📄 summary.cif

# %% [markdown]
# Show results of the fit.

# %%
project.analysis.display.fit_results()
# Out:
# Fit results
# ✅ Success: True
# ⏱️ Fitting time: 92.62 seconds
# 📏 Goodness-of-fit (reduced χ²): 3.53
# 📏 R-factor (Rf): 2.36%
# 📏 R-factor squared (Rf²): 3.42%
# 📏 Weighted R-factor (wR): 3.06%
# 📈 Fitted parameters:
# <style type="text/css">
# #T_2a859   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_2a859 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_2a859 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_2a859  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_2a859 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_2a859 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_2a859  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_2a859 th.col0 {
#   text-align: left;
# }
# #T_2a859 th.col1 {
#   text-align: left;
# }
# #T_2a859 th.col2 {
#   text-align: left;
# }
# #T_2a859 th.col3 {
#   text-align: left;
# }
# #T_2a859 th.col4 {
#   text-align: right;
# }
# #T_2a859 th.col5 {
#   text-align: right;
# }
# #T_2a859 th.col6 {
#   text-align: right;
# }
# #T_2a859 th.col7 {
#   text-align: left;
# }
# #T_2a859 th.col8 {
#   text-align: right;
# }
# #T_2a859_row0_col0, #T_2a859_row0_col1, #T_2a859_row0_col2, #T_2a859_row0_col3, #T_2a859_row0_col7, #T_2a859_row1_col0, #T_2a859_row1_col1, #T_2a859_row1_col2, #T_2a859_row1_col3, #T_2a859_row1_col7, #T_2a859_row2_col0, #T_2a859_row2_col1, #T_2a859_row2_col2, #T_2a859_row2_col3, #T_2a859_row2_col7, #T_2a859_row3_col0, #T_2a859_row3_col1, #T_2a859_row3_col2, #T_2a859_row3_col3, #T_2a859_row3_col7, #T_2a859_row4_col0, #T_2a859_row4_col1, #T_2a859_row4_col2, #T_2a859_row4_col3, #T_2a859_row4_col7, #T_2a859_row5_col0, #T_2a859_row5_col1, #T_2a859_row5_col2, #T_2a859_row5_col3, #T_2a859_row5_col7, #T_2a859_row6_col0, #T_2a859_row6_col1, #T_2a859_row6_col2, #T_2a859_row6_col3, #T_2a859_row6_col7, #T_2a859_row7_col0, #T_2a859_row7_col1, #T_2a859_row7_col2, #T_2a859_row7_col3, #T_2a859_row7_col7, #T_2a859_row8_col0, #T_2a859_row8_col1, #T_2a859_row8_col2, #T_2a859_row8_col3, #T_2a859_row8_col7, #T_2a859_row9_col0, #T_2a859_row9_col1, #T_2a859_row9_col2, #T_2a859_row9_col3, #T_2a859_row9_col7, #T_2a859_row10_col0, #T_2a859_row10_col1, #T_2a859_row10_col2, #T_2a859_row10_col3, #T_2a859_row10_col7, #T_2a859_row11_col0, #T_2a859_row11_col1, #T_2a859_row11_col2, #T_2a859_row11_col3, #T_2a859_row11_col7, #T_2a859_row12_col0, #T_2a859_row12_col1, #T_2a859_row12_col2, #T_2a859_row12_col3, #T_2a859_row12_col7, #T_2a859_row13_col0, #T_2a859_row13_col1, #T_2a859_row13_col2, #T_2a859_row13_col3, #T_2a859_row13_col7, #T_2a859_row14_col0, #T_2a859_row14_col1, #T_2a859_row14_col2, #T_2a859_row14_col3, #T_2a859_row14_col7, #T_2a859_row15_col0, #T_2a859_row15_col1, #T_2a859_row15_col2, #T_2a859_row15_col3, #T_2a859_row15_col7, #T_2a859_row16_col0, #T_2a859_row16_col1, #T_2a859_row16_col2, #T_2a859_row16_col3, #T_2a859_row16_col7, #T_2a859_row17_col0, #T_2a859_row17_col1, #T_2a859_row17_col2, #T_2a859_row17_col3, #T_2a859_row17_col7, #T_2a859_row18_col0, #T_2a859_row18_col1, #T_2a859_row18_col2, #T_2a859_row18_col3, #T_2a859_row18_col7, #T_2a859_row19_col0, #T_2a859_row19_col1, #T_2a859_row19_col2, #T_2a859_row19_col3, #T_2a859_row19_col7, #T_2a859_row20_col0, #T_2a859_row20_col1, #T_2a859_row20_col2, #T_2a859_row20_col3, #T_2a859_row20_col7, #T_2a859_row21_col0, #T_2a859_row21_col1, #T_2a859_row21_col2, #T_2a859_row21_col3, #T_2a859_row21_col7, #T_2a859_row22_col0, #T_2a859_row22_col1, #T_2a859_row22_col2, #T_2a859_row22_col3, #T_2a859_row22_col7, #T_2a859_row23_col0, #T_2a859_row23_col1, #T_2a859_row23_col2, #T_2a859_row23_col3, #T_2a859_row23_col7, #T_2a859_row24_col0, #T_2a859_row24_col1, #T_2a859_row24_col2, #T_2a859_row24_col3, #T_2a859_row24_col7, #T_2a859_row25_col0, #T_2a859_row25_col1, #T_2a859_row25_col2, #T_2a859_row25_col3, #T_2a859_row25_col7, #T_2a859_row26_col0, #T_2a859_row26_col1, #T_2a859_row26_col2, #T_2a859_row26_col3, #T_2a859_row26_col7, #T_2a859_row27_col0, #T_2a859_row27_col1, #T_2a859_row27_col2, #T_2a859_row27_col3, #T_2a859_row27_col7, #T_2a859_row28_col0, #T_2a859_row28_col1, #T_2a859_row28_col2, #T_2a859_row28_col3, #T_2a859_row28_col7, #T_2a859_row29_col0, #T_2a859_row29_col1, #T_2a859_row29_col2, #T_2a859_row29_col3, #T_2a859_row29_col7, #T_2a859_row30_col0, #T_2a859_row30_col1, #T_2a859_row30_col2, #T_2a859_row30_col3, #T_2a859_row30_col7, #T_2a859_row31_col0, #T_2a859_row31_col1, #T_2a859_row31_col2, #T_2a859_row31_col3, #T_2a859_row31_col7, #T_2a859_row32_col0, #T_2a859_row32_col1, #T_2a859_row32_col2, #T_2a859_row32_col3, #T_2a859_row32_col7, #T_2a859_row33_col0, #T_2a859_row33_col1, #T_2a859_row33_col2, #T_2a859_row33_col3, #T_2a859_row33_col7, #T_2a859_row34_col0, #T_2a859_row34_col1, #T_2a859_row34_col2, #T_2a859_row34_col3, #T_2a859_row34_col7, #T_2a859_row35_col0, #T_2a859_row35_col1, #T_2a859_row35_col2, #T_2a859_row35_col3, #T_2a859_row35_col7, #T_2a859_row36_col0, #T_2a859_row36_col1, #T_2a859_row36_col2, #T_2a859_row36_col3, #T_2a859_row36_col7, #T_2a859_row37_col0, #T_2a859_row37_col1, #T_2a859_row37_col2, #T_2a859_row37_col3, #T_2a859_row37_col7, #T_2a859_row38_col0, #T_2a859_row38_col1, #T_2a859_row38_col ...

# %% [markdown]
# Show parameter correlations.

# %%
project.plotter.plot_param_correlations()
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="1fef20eb-25b3-4fb7-bf7a-212debe9b737" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1fef20eb-25b3-4fb7-bf7a-212debe9b737")) {                    Plotly.newPlot(                        "1fef20eb-25b3-4fb7-bf7a-212debe9b737",                        [{"colorbar":{"len":1.0,"lenmode":"fraction","title":{"text":""},"y":0.5,"yanchor":"middle"},"colorscale":[[0.0,"#d73027"],[0.5,"#f7f7f7"],[1.0,"#4575b4"]],"hoverongaps":false,"hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecorr: %{z:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","x":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRAAAAAAAAAGEAAAAAAAAAcQAAAAAAAACBA"},"y":{"dtype":"f8","bdata":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRAAAAAAAAAGEAAAAAAAAAcQAAAAAAAACBA"},"z":{"dtype":"f8","bdata":"henYTg5u6j8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4f1d5H81DC+w\u002foib3fka+6z8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8OPmaLioLrv78ZxXoTROu\u002fZoZnhohj678AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fjKCTuXN87D9y3w5OsBnsPwg8I+W7a+w\u002fTm\u002fa2F+o778AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fw9VjXNKwuC\u002fmS3j0D\u002fz4b9RpRA+o8vgvyPbAjnbWuA\u002fG+\u002f4HTbT4L8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8+5XHaySzbP9EAG+ihad4\u002fanOZDl9j3D9IhPVm043ZvwR\u002fa22MINs\u002fYsTibqSz7r8AAAAAAAD4fwAAAAAAAPh\u002ffUaHJOlx2L+16HQdVQHcv0ml7e9Y6tm\u002fiZois3sA1j\u002fHC8tHHvrXv4GJsz\u002fp+Ow\u002fBnJKXyA7778AAAAAAAD4fw5PMtBae+w\u002fOtY59+QP7D9ZG7d1y87sPzdDMDlJ2ee\u002fDcbuq2BI6j+5xC804L7gv4yS9iAcHt4\u002fpH9y9XX83L8=","shape":"8, 8"},"zmax":1.0,"zmid":0.0,"zmin":-1.0,"type":"heatmap"},{"hoverinfo":"skip","mode":"text","showlegend":false,"text":["0.83","0.88","0.87","-0.86","-0.85","-0.86","0.89","0.88","0.89","-0.99","-0.96","0.91","-0.98","0.89","0.88","0.90","-0.75","0.82"],"textfont":{"color":"#f5f5f5"},"textposition":"middle center","x":[0.5,0.5,1.5,0.5,1.5,2.5,0.5,1.5,2.5,3.5,5.5,5.5,6.5,0.5,1.5,2.5,3.5,4.5],"y":[0.5,1.5,1.5,2.5,2.5,2.5,3.5,3.5,3.5,3.5,5.5,6.5,6.5,7.5,7.5,7.5,7.5,7.5],"type":"scatter"}],                        {"legend":{"x":1.0,"xanchor":"right","y":1.0,"yanchor":"top"},"margin":{"autoexpand":true,"b":45,"r":30,"t":40},"shapes":[{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":1.0,"x1":1.0,"xref":"x","y0":0.0,"y1":8.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":2.0,"x1":2.0,"xref":"x","y0":0.0,"y1":8.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":3.0,"x1":3.0,"xref":"x","y0":0.0,"y1":8.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":4.0,"x1":4.0,"xref":"x","y0":0.0,"y1":8.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":5.0,"x1":5.0,"xref":"x","y0":0.0,"y1":8.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":6.0,"x1":6.0,"xref":"x","y0":0.0,"y1":8.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":7.0,"x1":7.0,"xref":"x","y0":0.0,"y1":8.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":0.0,"x1":8.0,"xref":"x","y0":1.0,"y1":1.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0.28)","width":1},"type":"line","x0":0.0,"x1":8.0,"xref":"x","y0":2.0,"y1":2.0,"yref":"y"},{"layer":"above","line":{"color":"rgba(120, 140, 160, 0. ...

# %% [markdown]
# Plot measured vs calculated data for the experiment, including the residual.

# %%
project.plotter.plot_meas_vs_calc(expt_name='xrd', show_residual=True)
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="68edca6b-0b09-47e5-b057-fe1ce0debd15" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("68edca6b-0b09-47e5-b057-fe1ce0debd15")) {                    Plotly.newPlot(                        "68edca6b-0b09-47e5-b057-fe1ce0debd15",                        [{"line":{"color":"rgb(31, 119, 180)"},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"\u002fJECF61G4HsUkQJhuEoPAyiRAqvHSTWLQJEC8dJMYBNYkQM\u002f3U+Ol2yRA4XoUrkfhJED0\u002fdR46eYkQAaBlUOL7CRAGQRWDi3yJEArhxbZzvckQD0K16Nw\u002fSRAUI2XbhIDJUBiEFg5tAglQHWTGARWDiVAhxbZzvcTJUCamZmZmRklQKwcWmQ7HyVAvp8aL90kJUDRItv5fiolQOOlm8QgMCVA9ihcj8I1JUAIrBxaZDslQBsv3SQGQSVALbKd76dGJUA\u002fNV66SUwlQFK4HoXrUSVAZDvfT41XJUB3vp8aL10lQIlBYOXQYiVAnMQgsHJoJUCuR+F6FG4lQMHKoUW2cyVA001iEFh5JUDl0CLb+X4lQPhT46WbhCVACtejcD2KJUAdWmQ7348lQC\u002fdJAaBlSVAQmDl0CKbJUBU46WbxKAlQGZmZmZmpiVAeekmMQisJUCLbOf7qbElQJ7vp8ZLtyVAsHJoke28JUDD9Shcj8IlQNV46SYxyCVA5\u002fup8dLNJUD6fmq8dNMlQAwCK4cW2SVAH4XrUbjeJUAxCKwcWuQlQESLbOf76SVAVg4tsp3vJUBoke18P\u002fUlQHsUrkfh+iVAjZduEoMAJkCgGi\u002fdJAYmQLKd76fGCyZAxSCwcmgRJkDXo3A9ChcmQOkmMQisHCZA\u002fKnx0k0iJkAOLbKd7ycmQCGwcmiRLSZAMzMzMzMzJkBGtvP91DgmQFg5tMh2PiZAarx0kxhEJkB9PzVeukkmQI\u002fC9ShcTyZAokW28\u002f1UJkC0yHa+n1omQMdLN4lBYCZA2c73U+NlJkDsUbgehWsmQP7UeOkmcSZAEFg5tMh2JkAj2\u002fl+anwmQDVeukkMgiZASOF6FK6HJkBaZDvfT40mQG3n+6nxkiZAf2q8dJOYJkCR7Xw\u002fNZ4mQKRwPQrXoyZAtvP91HipJkDJdr6fGq8mQNv5fmq8tCZA7nw\u002fNV66JkAAAAAAAMAmQBKDwMqhxSZAJQaBlUPLJkA3iUFg5dAmQEoMAiuH1iZAXI\\u002fC9WgnQDvfT42XbidATmIQWDl0J0Bg5dAi23knQHNoke18fydAhetRuB6FJ0CYbhKDwIonQKrx0k1ikCdAvHSTGASWJ0DP91PjpZsnQOF6FK5HoSdA9P3UeOmmJ0AGgZVDi6wnQBkEVg4tsidAK4cW2c63J0A9CtejcL0nQFCNl24SwydAYhBYObTIJ0B1kxgEVs4nQIcW2c730ydAmpmZmZnZJ0CsHFpkO98nQL6fGi\u002fd5CdA0SLb+X7qJ0DjpZvEIPAnQPYoXI\u002fC9SdACKwcWmT7J0AbL90kBgEoQC2yne+nBihAPzVeukkMKEBSuB6F6xEoQGQ730+NFyhAd76fGi8dKECJQWDl0CIoQJzEILByKChArkfhehQuKEDByqFFtjMoQNNNYhBYOShA5dAi2\u002fk+KED4U+Olm0QoQArXo3A9SihAHVpkO99PKEAv3SQGgVUoQEJg5dAiWyhAVOOlm8RgKEBmZmZmZmYoQHnpJjEIbChAi2zn+6lxKECe76fGS3coQLByaJHtfChAw\u002fUoXI+CKEDVeOkmMYgoQOf7qfHSjShA+n5qvHSTKEAMAiuHFpkoQB+F61G4nihAMQisHFqkKEBEi2zn+6koQFYOLbKdryhAaJHtfD+1KEB7FK5H4booQI2XbhKDwChAoBov3STGKECyne+nxssoQMUgsHJo0ShA16NwPQrXKEDpJjEIrNwoQPyp8dJN4ihADi2yne\u002fnKEAhsHJoke0oQDMzMzMz8yhARrbz\u002fdT4KEBYObTIdv4oQGq8dJMYBClAfT81XroJKUCPwvUoXA8pQKJFtvP9FClAtMh2vp8aKUDHSzeJQSApQNnO91PjJSlA7FG4HoUrKUD+1HjpJjEpQBBYObTINilAI9v5fmo8KUA1XrpJDEIpQEjhehSuRylAWmQ7309NKUBt5\u002fup8VIpQH9qvHSTWClAke18PzVeKUCkcD0K12MpQLbz\\u002fspQKjGSzeJASpAukkMAisHKkDNzMzMzAwqQN9PjZduEipA8tJNYhAYKkAEVg4tsh0qQBfZzvdTIypAKVyPwvUoKkA730+Nly4qQE5iEFg5NCpAYOXQIts5KkBzaJHtfD8qQIXrUbgeRSpAmG4Sg8BKKkCq8dJNYlAqQLx0kxgEVipAz\u002fdT46VbKkDhehSuR2EqQPT91HjpZipABoGVQ4tsKkAZBFYOLXIqQCuHFtnOdypAPQrXo3B9KkBQ ...

# %%
project.plotter.plot_meas_vs_calc(expt_name='xrd', x_min=46.00, x_max=47.4)
# Out:
# <div>                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="8b3ca95e-a20e-4298-8d49-301dd141ddf4" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8b3ca95e-a20e-4298-8d49-301dd141ddf4")) {                    Plotly.newPlot(                        "8b3ca95e-a20e-4298-8d49-301dd141ddf4",                        [{"line":{"color":"rgb(31, 119, 180)"},"mode":"lines+markers","name":"Measured (Imeas)","x":{"dtype":"f8","bdata":"qvHSTWIAR0BvEoPAygFHQDMzMzMzA0dA+FPjpZsER0C8dJMYBAZHQIGVQ4tsB0dARrbz\u002fdQIR0AK16NwPQpHQM\u002f3U+OlC0dAkxgEVg4NR0BYObTIdg5HQB1aZDvfD0dA4XoUrkcRR0Cmm8QgsBJHQGq8dJMYFEdAL90kBoEVR0D0\u002fdR46RZHQLgehetRGEdAfT81XroZR0BCYOXQIhtHQAaBlUOLHEdAy6FFtvMdR0CPwvUoXB9HQFTjpZvEIEdAGQRWDi0iR0DdJAaBlSNHQKJFtvP9JEdAZmZmZmYmR0ArhxbZzidHQPCnxks3KUdAtMh2vp8qR0B56SYxCCxHQD0K16NwLUdAAiuHFtkuR0DHSzeJQTBHQIts5\u002fupMUdAUI2XbhIzR0AUrkfhejRHQNnO91PjNUdAnu+nxks3R0BiEFg5tDhHQCcxCKwcOkdA7FG4HoU7R0CwcmiR7TxHQHWTGARWPkdAObTIdr4\\u002fup8WJHQDEIrBxaZEdA9ihcj8JlR0C6SQwCK2dHQH9qvHSTaEdARIts5\u002ftpR0AIrBxaZGtHQM3MzMzMbEdAke18PzVuR0BWDi2ynW9HQBsv3SQGcUdA30+Nl25yR0CkcD0K13NHQGiR7Xw\u002fdUdALbKd76d2R0Dy0k1iEHhHQLbz\u002fdR4eUdAexSuR+F6R0A\u002fNV66SXxHQARWDi2yfUdAyXa+nxp\u002fR0CNl24Sg4BHQFK4HoXrgUdAF9nO91ODR0Db+X5qvIRHQKAaL90khkdAZDvfT42HR0ApXI\"},"y":{"dtype":"f8","bdata":"xI0aE3snkUALchhaPneRQMBkHN7Vm5FAlSYWO6f3kEDH1RlrPYiRQJw\u002fgb8Pn5FAPrO3OSyVkEC2gh2ThyGRQBoYoV\u002f9QpFAS085XO8kkUD0OlpaHRySQPV8waBupZJA3OeDeMmKk0B4sJgZqxSTQOyCKYNz2ZJA9Hir8f35kkDJ0o7dZq+TQFg9Qv8Pq5NAvYCciaoNlECt9A10+zmUQLCwH9jA85RAdcv6orcblUBya\u002flZbmSVQAUc9NIScpZAfUBBEkCglkD\u002fhIVE2NOWQJgOBgYgLJhA5oDjnPFYmUDhhdWWLQSZQOKwnPS2CZpA3FGwHa+mmkA+2PSstEGbQCogWQ1hQZxAcu8kM5tVnUCy3tvTCYueQDKGLMq8tp9A+G3u1abboEBfcGoxh2ChQAZ7CbBqI6RAcXLy\u002f9QNpUBu9N3oonWmQOyI4+RM8adAohtiNKWLq0B0f8gPbLyuQGQBuc5Nw7FAKgv6NpW7tECHVmBtQQ65QO1oXB1Alb5AtDvzyoP+wkDL3TuPfjTIQJ4WTNSlus5AwxyxxOI000CbREJFjqbXQJOk8QiFt9xAOnpwBsux4EAmkSSAGG7iQL08rLZCo+NAPz1YNOwR5ECXVWrTMbjjQA\u002fYuAoE8+JAqOV0SrEQ4kCs4+0SRBPhQBmnnzz2J+BAyq7RbZXU3UC0rz19Zo7aQOUOhgYCYNdAHABVy\u002fpn1EA21T+q3D3RQGtCR4R5LcxAM8gJxTnJx0DrneWnw3jDQHHclC4r379AFYL+HUB2ukAu3BViNDO2QCAufvC3uLJABh53WbE7sEB\u002frt\u002fPsdSsQOEoUArtU6pAPZkF97Vdp0ApvdLz872kQGswvpsqlqJAl35OBzhzoUB1mLKEmKagQOQl1GfDOZ9AoRk0NEOrnUAHFdcF3EqcQNo\u002fR3zokpxA69EtJaTum0BCmWOj0ZaZQKZh8qoCdJhA230RgjTll0B1JZL1ZvyWQGDyNm7m7ZZAQSdODRMtl0DZCvSfxwaWQJQtssk2opVAjmnlC1XjlUCLZx3jE6+UQOG0r\u002fKO15RAsENsYa3clEDmxql61DiTQCTLMIAfeJNAXHIPJvxyk0C0Gu7YjtqSQFgkpLnudpJANLIxX3oZk0CqWUtw8PCSQP+xZ6Gw0ZFAMgmmbTtxkUCvrxG5ma6RQBE1YnYJ5ZFAGVFngDV\u002fkUCLF3FROheRQHwOHT1K65BAsrs+imndkEBvR1wqrceQQNJ1aFu7hJFAs5aVKrC5kEAo2PmloPOQQLYbUoNH2JBAi9HMphhGkUAaZehSalKQQNpRDbMnOZBACgwirF0xkECSVQ+DyJ+QQES2QsT1j5BAkSfI7PV8kEB\u002fCTaCMbCPQA=="},"type":"scatter"},{"line":{"color":"rgb(214, 39, 40)"},"mode":"lines","name":"Total calculated (Icalc)","x":{"dtype":"f8","bdata":"qvHSTWIAR0BvEoPAygFHQDMzMzMzA0dA+FPjpZsER0C8dJMYBAZHQIGVQ4tsB0dARrbz\u002fdQIR0AK16NwPQpHQM\u002f3U+OlC0dAkxgEVg4NR0BYObTIdg5HQB1aZDvfD0dA4XoUrkcRR0Cmm8QgsBJHQGq8dJMYFEdAL90kBoEVR0D0\u002fdR46RZHQLgehetRGEdAfT81XroZR0BCYOXQIhtHQAaBlUOLHEdAy6FFtvMdR0CPwvUoXB9 ...

# %% [markdown]
# ## Step 7: Show Project Summary

# %%
project.summary.show_report()
# Out:
# ————————————
# PROJECT INFO
# ————————————
# Title
# Untitled Project
# Description
# LaM7O3 structure refinement using X-ray data.
# —————————————————————
# CRYSTALLOGRAPHIC DATA
# —————————————————————
# Phase datablock
# 🧩 lam7o3
# Space group
# P n m a
# <style type="text/css">
# #T_2ded8   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_2ded8 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_2ded8 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_2ded8  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_2ded8 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_2ded8 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_2ded8  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_2ded8 th.col0 {
#   text-align: left;
# }
# #T_2ded8 th.col1 {
#   text-align: right;
# }
# #T_2ded8 th.col2 {
#   text-align: right;
# }
# #T_2ded8_row0_col0, #T_2ded8_row1_col0, #T_2ded8_row2_col0, #T_2ded8_row3_col0, #T_2ded8_row4_col0, #T_2ded8_row5_col0 {
#   text-align: left;
# }
# #T_2ded8_row0_col1, #T_2ded8_row0_col2, #T_2ded8_row1_col1, #T_2ded8_row1_col2, #T_2ded8_row2_col1, #T_2ded8_row2_col2, #T_2ded8_row3_col1, #T_2ded8_row3_col2, #T_2ded8_row4_col1, #T_2ded8_row4_col2, #T_2ded8_row5_col1, #T_2ded8_row5_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_2ded8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ded8_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_2ded8_level0_col1" class="col_heading level0 col1" >Value</th>
#       <th id="T_2ded8_level0_col2" class="col_heading level0 col2" >Uncertainty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ded8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2ded8_row0_col0" class="data row0 col0" >a</td>
#       <td id="T_2ded8_row0_col1" class="data row0 col1" >5.49597193</td>
#       <td id="T_2ded8_row0_col2" class="data row0 col2" >0.00006944</td>
#     </tr>
#     <tr>
#       <th id="T_2ded8_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2ded8_row1_col0" class="data row1 col0" >b</td>
#       <td id="T_2ded8_row1_col1" class="data row1 col1" >5.49597193</td>
#       <td id="T_2ded8_row1_col2" class="data row1 col2" >0.00006944</td>
#     </tr>
#     <tr>
#       <th id="T_2ded8_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_2ded8_row2_col0" class="data row2 col0" >c</td>
#       <td id="T_2ded8_row2_col1" class="data row2 col1" >5.49597193</td>
#       <td id="T_2ded8_row2_col2" class="data row2 col2" >0.00006944</td>
#     </tr>
#     <tr>
#       <th id="T_2ded8_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2ded8_row3_col0" class="data row3 col0" >α</td>
#       <td id="T_2ded8_row3_col1" class="data row3 col1" >90.00000000</td>
#       <td id="T_2ded8_row3_col2" class="data row3 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_2ded8_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_2ded8_row4_col0" class="data row4 col0" >β</td>
#       <td id="T_2ded8_row4_col1" class="data row4 col1" >90.00000000</td>
#       <td id="T_2ded8_row4_col2" class="data row4 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_2ded8_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_2ded8_row5_col0" class="data row5 col0" >γ</td>
#       <td id="T_2ded8_row5_col1" class="data row5 col1" >90.00000000</td>
#       <td id="T_2ded8_row5_col2" class="data row5 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# Atom sites
# <style type="text/css">
# #T_72cae   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_72cae thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_72cae th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_72cae  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_72cae th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_72cae tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_72cae  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_72cae th.col0 {
#   text-align: left;
# }
# #T_72cae th.col1 {
#   text-align: left;
# }
# #T_72cae th.col2 {
#   text-align: right;
# }
# #T_72cae th.col3 {
#   text-align: right;
# }
# #T_72cae th.col4 {
#   text-align: right;
# }
# #T_72cae th.col5 {
#   text-align: right;
# }
# #T_72cae th.col6 {
#   text-align: right;
# }
# #T_72cae_row0_col0, #T_72cae_row0_col1, #T_72cae_row1_col0, #T_72cae_row1_col1, #T_72cae_row2_col0, #T_72cae_row2_col1, #T_72cae_row3_col0, #T_72cae_row3_col1, #T_72cae_row4_col0, #T_72cae_row4_col1, #T_72cae_row5_col0, #T_72cae_row5_col1, #T_72cae_row6_col0, #T_72cae_row6_col1, #T_72cae_row7_col0, #T_72cae_row7_col1, #T_72cae_row8_col0, #T_72cae_row8_col1, #T_72cae_row9_col0, #T_72cae_row9_col1 {
#   text-align: left;
# }
# #T_72cae_row0_col2, #T_72cae_row0_col3, #T_72cae_row0_col4, #T_72cae_row0_col5, #T_72cae_row0_col6, #T_72cae_row1_col2, #T_72cae_row1_col3, #T_72cae_row1_col4, #T_72cae_row1_col5, #T_72cae_row1_col6, #T_72cae_row2_col2, #T_72cae_row2_col3, #T_72cae_row2_col4, #T_72cae_row2_col5, #T_72cae_row2_col6, #T_72cae_row3_col2, #T_72cae_row3_col3, #T_72cae_row3_col4, #T_72cae_row3_col5, #T_72cae_row3_col6, #T_72cae_row4_col2, #T_72cae_row4_col3, #T_72cae_row4_col4, #T_72cae_row4_col5, #T_72cae_row4_col6, #T_72cae_row5_col2, #T_72cae_row5_col3, #T_72cae_row5_col4, #T_72cae_row5_col5, #T_72cae_row5_col6, #T_72cae_row6_col2, #T_72cae_row6_col3, #T_72cae_row6_col4, #T_72cae_row6_col5, #T_72cae_row6_col6, #T_72cae_row7_col2, #T_72cae_row7_col3, #T_72cae_row7_col4, #T_72cae_row7_col5, #T_72cae_row7_col6, #T_72cae_row8_col2, #T_72cae_row8_col3, #T_72cae_row8_col4, #T_72cae_row8_col5, #T_72cae_row8_col6, #T_72cae_row9_col2, #T_72cae_row9_col3, #T_72cae_row9_col4, #T_72cae_row9_col5, #T_72cae_row9_col6 {
#   text-align: right;
# }
# </style>
# <table id="T_72cae" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72cae_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_72cae_level0_col1" class="col_heading level0 col1" >type</th>
#       <th id="T_72cae_level0_col2" class="col_heading level0 col2" >x</th>
#       <th id="T_72cae_level0_col3" class="col_heading level0 col3" >y</th>
#       <th id="T_72cae_level0_col4" class="col_heading level0 col4" >z</th>
#       <th id="T_72cae_level0_col5" class="col_heading level0 col5" >occ</th>
#       <th id="T_72cae_level0_col6" class="col_heading level0 col6" >Biso</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72cae_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_72cae_row0_col0" class="data row0 col0" >La</td>
#       <td id="T_72cae_row0_col1" class="data row0 col1" >La</td>
#       <td id="T_72cae_row0_col2" class="data row0 col2" >0.47665722</td>
#       <td id="T_72cae_row0_col3" class="data row0 col3" >0.25000000</td>
#       <td id="T_72cae_row0_col4" class="data row0 col4" >0.00398922</td>
#       <td id="T_72cae_row0_col5" class="data row0 col5" >1.00000000</td>
#       <td id="T_72cae_row0_col6" class="data row0 col6" >1.04581721</td>
#     </tr>
#     <tr>
#       <th id="T_72cae_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_72cae_row1_col0" class="data row1 col0" >Ti</td>
#       <td id="T_72cae_row1_col1" class="data row1 col1" >Ti</td>
#       <td id="T_72cae_row1_col2" class="data row1 col2" >0.00000000</td>
#       <td id="T_72cae_row1_col3" class="data row1 col3" >0.00000000</td>
#       <td id="T_72cae_row1_col4" class="data row1 col4" >0.00000000</td>
#       <td id="T_72cae_row1_col5" class="data row1 col5" >0.14286000</td>
#       <td id="T_72cae_row1_col6" class="data row1 col6" >0.76656651</td>
#     </tr>
#     <tr>
#       <th id="T_72cae_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_72cae_row2_col0" class="data row2 col0" >Cr</td>
#       <td id="T_72cae_row2_col1" class="data row2 col1" >Cr</td>
#       <td id="T_72cae_row2_col2" class="data row2 col2" >0.00000000</td>
#       <td id="T_72cae_row2_col3" class="data row2 col3" >0.00000000</td>
#       <td id="T_72cae_row2_col4" class="data row2 col4" >0.00000000</td>
#       <td id="T_72cae_row2_col5" class="data row2 col5" >0.14286000</td>
#       <td id="T_72cae_row2_col6" class="data row2 col6" >0.76656651</td>
#     </tr>
#     <tr>
#       <th id="T_72cae_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_72cae_row3_col0" class="data row3 col0" >Mn</td>
#       <td id="T_72cae_row3_col1" class="data row3 col1" >Mn</td>
#       <td id="T_72cae_row3_col2" class="data row3 col2" >0.00000000</td>
#       <td id="T_72cae_row3_col3" class="data row3 col3" >0.00000000</td>
#       <td id="T_72cae_row3_col4" class="data row3 col4" >0.00000000</td>
#       <td id="T_72cae_row3_col5" class="data row3 col5" >0.14286000</td>
#       <td id="T_72cae_row3_col6" class="data row3 col6" >0.76656651</td>
#     </tr>
#     <tr>
#       <th id="T_72cae_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_72cae_row4_col0" class="data row4 col0" >Fe</td>
#       <td id="T_72cae_row4_col1" class="data row4 col1" >Fe</td>
#       <td id="T_72cae_row4_col2" class="data row4 col2" >0.00000000</td>
#       <td id="T_72cae_row4_col3" class="data row4 col3" >0.00000000</td>
#       <td id="T_72cae_row4_col4" class="data row4 col4" >0.00000000</td>
#       <td id="T_72cae_row4_col5" class="data row4 col5" >0.14286000</td>
#       <td id="T_72cae_row4_col6" class="data row4 col6" >0.76656651</td>
#     </tr>
#     <tr>
#       <th id="T_72cae_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_72cae_row5_col0" class="data row5 col0" >Co</td>
#       <td id="T_72cae_row5_col1" class="data row5 col1" >Co</td>
#       <td id="T_72cae_row5_col2" class="data row5 col2" >0.00000000</td>
#       <td id="T_72cae_row5_col3" class="data row5 col3" >0.00000000</td>
#       <td id="T_72cae_row5_col4" class="data row5 col4" >0.00000000</td>
#       <td id="T_72cae_row5_col5" class="data row5 col5" >0.14286000</td>
#       <td id="T_72cae_row5_col6" class="data row5 col6" >0.76656651</td>
#     </tr>
#     <tr>
#       <th id="T_72cae_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_72cae_row6_col0" class="data row6 col0" >Ni</td>
#       <td id="T_72cae_row6_col1" class="data row6 col1" >Ni</td>
#       <td id="T_72cae_row6_col2" class="data row6 col2" >0.00000000</td>
#       <td id="T_72cae_row6_col3" class="data row6 col3" >0.00000000</td>
#       <td id="T_72cae_row6_col4" class="data row6 col4" >0.00000000</td>
#       <td id="T_72cae_row6_col5" class="data row6 col5" >0.14286000</td>
#       <td id="T_72cae_row6_col6" class="data row6 col6" >0.76656651</td>
#     </tr>
#     <tr>
#       <th id="T_72cae_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_72cae_row7_col0" class="data row7 col0" >Cu</td>
#       <td id="T_72cae_row7_col1" class="data row7 col1" >Cu</td>
#       <td id="T_72cae_row7_col2" class="data row7 col2" >0.00000000</td>
#       <td id="T_72cae_row7_col3" class="data row7 col3" >0.00000000</td>
#       <td id="T_72cae_row7_col4" class="data row7 col4" >0.00000000</td>
#       <td id="T_72cae_row7_col5" class="data row7 col5" >0.14286000</td>
#       <td id="T_72cae_row7_col6" class="data row7 col6" >0.76656651</td>
#     </tr>
#     <tr>
#       <th id="T_72cae_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_72cae_row8_col0" class="data row8 col0" >O1</td>
#       <td id="T_72cae_row8_col1" class="data row8 col1" >O</td>
#       <td id="T_72cae_row8_col2" class="da
# ———————————
# EXPERIMENTS
# ———————————
# Experiment datablock
# 🔬 xrd
# Experiment type
# powder, xray, constant wavelength bragg
# Calculation engine
# cryspy
# Wavelength
# 1.54056
# 2θ offset
# 0.03487
# Profile type
# pseudo-voigt + empirical asymmetry
# Peak broadening (Gaussian)
# <style type="text/css">
# #T_8e36c   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_8e36c thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_8e36c th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_8e36c  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_8e36c th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_8e36c tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_8e36c  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_8e36c th.col0 {
#   text-align: left;
# }
# #T_8e36c th.col1 {
#   text-align: right;
# }
# #T_8e36c th.col2 {
#   text-align: right;
# }
# #T_8e36c_row0_col0, #T_8e36c_row1_col0, #T_8e36c_row2_col0 {
#   text-align: left;
# }
# #T_8e36c_row0_col1, #T_8e36c_row0_col2, #T_8e36c_row1_col1, #T_8e36c_row1_col2, #T_8e36c_row2_col1, #T_8e36c_row2_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_8e36c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e36c_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_8e36c_level0_col1" class="col_heading level0 col1" >Value</th>
#       <th id="T_8e36c_level0_col2" class="col_heading level0 col2" >Uncertainty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e36c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8e36c_row0_col0" class="data row0 col0" >U</td>
#       <td id="T_8e36c_row0_col1" class="data row0 col1" >0.04489629</td>
#       <td id="T_8e36c_row0_col2" class="data row0 col2" >0.00152184</td>
#     </tr>
#     <tr>
#       <th id="T_8e36c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8e36c_row1_col0" class="data row1 col0" >V</td>
#       <td id="T_8e36c_row1_col1" class="data row1 col1" >-0.03804775</td>
#       <td id="T_8e36c_row1_col2" class="data row1 col2" >0.00135245</td>
#     </tr>
#     <tr>
#       <th id="T_8e36c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_8e36c_row2_col0" class="data row2 col0" >W</td>
#       <td id="T_8e36c_row2_col1" class="data row2 col1" >0.01408210</td>
#       <td id="T_8e36c_row2_col2" class="data row2 col2" >0.00028842</td>
#     </tr>
#   </tbody>
# </table>
# Peak broadening (Lorentzian)
# <style type="text/css">
# #T_d533e   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_d533e thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_d533e th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_d533e  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_d533e th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_d533e tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_d533e  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_d533e th.col0 {
#   text-align: left;
# }
# #T_d533e th.col1 {
#   text-align: right;
# }
# #T_d533e th.col2 {
#   text-align: right;
# }
# #T_d533e_row0_col0, #T_d533e_row1_col0 {
#   text-align: left;
# }
# #T_d533e_row0_col1, #T_d533e_row0_col2, #T_d533e_row1_col1, #T_d533e_row1_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_d533e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d533e_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_d533e_level0_col1" class="col_heading level0 col1" >Value</th>
#       <th id="T_d533e_level0_col2" class="col_heading level0 col2" >Uncertainty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d533e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d533e_row0_col0" class="data row0 col0" >X</td>
#       <td id="T_d533e_row0_col1" class="data row0 col1" >0.13485847</td>
#       <td id="T_d533e_row0_col2" class="data row0 col2" >0.00071442</td>
#     </tr>
#     <tr>
#       <th id="T_d533e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d533e_row1_col0" class="data row1 col0" >Y</td>
#       <td id="T_d533e_row1_col1" class="data row1 col1" >0.00325970</td>
#       <td id="T_d533e_row1_col2" class="data row1 col2" ></td>
#     </tr>
#   </tbody>
# </table>
# Asymmetry (Empirical)
# <style type="text/css">
# #T_73df6   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_73df6 thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_73df6 th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_73df6  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_73df6 th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_73df6 tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_73df6  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_73df6 th.col0 {
#   text-align: left;
# }
# #T_73df6 th.col1 {
#   text-align: right;
# }
# #T_73df6 th.col2 {
#   text-align: right;
# }
# #T_73df6_row0_col0, #T_73df6_row1_col0, #T_73df6_row2_col0, #T_73df6_row3_col0 {
#   text-align: left;
# }
# #T_73df6_row0_col1, #T_73df6_row0_col2, #T_73df6_row1_col1, #T_73df6_row1_col2, #T_73df6_row2_col1, #T_73df6_row2_col2, #T_73df6_row3_col1, #T_73df6_row3_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_73df6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73df6_level0_col0" class="col_heading level0 col0" >Parameter</th>
#       <th id="T_73df6_level0_col1" class="col_heading level0 col1" >Value</th>
#       <th id="T_73df6_level0_col2" class="col_heading level0 col2" >Uncertainty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73df6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_73df6_row0_col0" class="data row0 col0" >p1</td>
#       <td id="T_73df6_row0_col1" class="data row0 col1" >0.00000000</td>
#       <td id="T_73df6_row0_col2" class="data row0 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_73df6_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_73df6_row1_col0" class="data row1 col0" >p2</td>
#       <td id="T_73df6_row1_col1" class="data row1 col1" >0.08047408</td>
#       <td id="T_73df6_row1_col2" class="data row1 col2" >0.00285232</td>
#     </tr>
#     <tr>
#       <th id="T_73df6_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_73df6_row2_col0" class="data row2 col0" >p3</td>
#       <td id="T_73df6_row2_col1" class="data row2 col1" >0.00000000</td>
#       <td id="T_73df6_row2_col2" class="data row2 col2" ></td>
#     </tr>
#     <tr>
#       <th id="T_73df6_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_73df6_row3_col0" class="data row3 col0" >p4</td>
#       <td id="T_73df6_row3_col1" class="data row3 col1" >-0.18368077</td>
#       <td id="T_73df6_row3_col2" class="data row3 col2" >0.00650710</td>
#     </tr>
#   </tbody>
# </table>
# ———————
# FITTING
# ———————
# Minimization engine
# bumps (lm)
# Fit quality
# <style type="text/css">
# #T_7417c   {
#   border: 1px solid #dadada;
#   border-collapse: collapse;
#   margin-top: 0.5em;
#   margin-left: 0.5em;
# }
# #T_7417c thead {
#   border-bottom: 1px solid #dadada;
# }
# #T_7417c th {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7417c  td {
#   border: none;
#   padding-top: 0.25em;
#   padding-bottom: 0.25em;
#   line-height: 1.15em;
# }
# #T_7417c th.row_heading {
#   color: #dadada;
#   font-weight: normal;
# }
# #T_7417c tbody tr:nth-child(odd) {
#   background-color: transparent;
# }
# #T_7417c  tbody tr:nth-child(even) {
#   background-color: transparent;
# }
# #T_7417c th.col0 {
#   text-align: left;
# }
# #T_7417c th.col1 {
#   text-align: right;
# }
# #T_7417c_row0_col0 {
#   text-align: left;
# }
# #T_7417c_row0_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_7417c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7417c_level0_col0" class="col_heading level0 col0" >metric</th>
#       <th id="T_7417c_level0_col1" class="col_heading level0 col1" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7417c_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7417c_row0_col0" class="data row0 col0" >Goodness-of-fit (reduced χ²)</td>
#       <td id="T_7417c_row0_col1" class="data row0 col1" >3.53</td>
#     </tr>
#   </tbody>
# </table>
